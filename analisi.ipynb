# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('100pM/7pullA.txt', sep = "\t")

# %%
data
# Out:
#        #CycleCount/n  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  \
# 0                  0  -17.42  -60.82   8224.69   -236.06  -1533.82
# 1                100  -16.76  -60.73   8226.67   -236.47  -1533.08
# 2                200  -25.82  -67.76   8234.49   -236.88  -1534.18
# 3                300  -11.24  -61.71   8228.24   -233.41  -1531.94
# 4                400  -36.00  -71.00   8241.00   -234.00  -1533.00
# ...              ...     ...     ...       ...       ...       ...
# 414064        437440  -15.25  -44.50   8208.50   -213.75  -1631.50
# 414065        437441  -10.00  -42.33   8208.33   -213.33  -1630.33
# 414066        437442  -15.33  -50.00   8209.00   -213.00  -1631.00
# 414067        437443  -20.67  -49.33   8212.33   -213.33  -1631.33
# 414068        437444  -13.25  -47.25   8210.50   -213.50  -1630.50
#
#         A_LeverSum  B_PsdX  B_PsdY  B_PsdSum  ...  B_forceZ   A_dist-X  \
# 0         23518.48  -19.79  -64.84  10337.12  ...    0.4310 -2869.4468
# ...

# %%
data2 = pd.read_csv('100pM/7pullB.txt', sep = "\t")
data2
# Out:
#        #CycleCount/n  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  \
# 0             437445  -28.00  -45.00   8209.00   -212.00  -1633.00
# 1             437446  -17.67  -43.33   8211.00   -213.33  -1631.33
# 2             437447  -16.50  -42.00   8210.00   -213.50  -1631.00
# 3             437448  -10.67  -45.00   8207.00   -212.67  -1630.67
# 4             437449  -18.25  -45.50   8207.25   -213.50  -1631.75
# ...              ...     ...     ...       ...       ...       ...
# 236858        844500  -20.35   21.60   8207.87   -321.02  -1728.38
# 236859        844600  -26.64   15.00   8215.21   -323.64  -1730.43
# 236860        844700  -18.40   15.60   8214.80   -324.80  -1730.00
# 236861        844800  -27.30    8.19   8216.74   -324.96  -1729.59
# 236862    #End Write     NaN     NaN       NaN       NaN       NaN
#
#         A_LeverSum  B_PsdX  B_PsdY  B_PsdSum  ...  B_forceZ   A_dist-X  \
# 0         23518.00  -37.00  -51.00  10343.00  ...    0.5191 -2853.6523
# ...

# %%
result = pd.concat([data, data2], ignore_index=True)

# %%
result
# Out:
#        #CycleCount/n  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  \
# 0                  0  -17.42  -60.82   8224.69   -236.06  -1533.82
# 1                100  -16.76  -60.73   8226.67   -236.47  -1533.08
# 2                200  -25.82  -67.76   8234.49   -236.88  -1534.18
# 3                300  -11.24  -61.71   8228.24   -233.41  -1531.94
# 4                400  -36.00  -71.00   8241.00   -234.00  -1533.00
# ...              ...     ...     ...       ...       ...       ...
# 650927        844500  -20.35   21.60   8207.87   -321.02  -1728.38
# 650928        844600  -26.64   15.00   8215.21   -323.64  -1730.43
# 650929        844700  -18.40   15.60   8214.80   -324.80  -1730.00
# 650930        844800  -27.30    8.19   8216.74   -324.96  -1729.59
# 650931    #End Write     NaN     NaN       NaN       NaN       NaN
#
#         A_LeverSum  B_PsdX  B_PsdY  B_PsdSum  ...  B_forceZ   A_dist-X  \
# 0         23518.48  -19.79  -64.84  10337.12  ...    0.4310 -2869.4468
# ...

# %%
result['lambda'] = ((result['A_dist-Y']+data['B_dist-Y']).values)/2

# %%
result
# Out:
#        #CycleCount/n  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  \
# 0                  0  -17.42  -60.82   8224.69   -236.06  -1533.82
# 1                100  -16.76  -60.73   8226.67   -236.47  -1533.08
# 2                200  -25.82  -67.76   8234.49   -236.88  -1534.18
# 3                300  -11.24  -61.71   8228.24   -233.41  -1531.94
# 4                400  -36.00  -71.00   8241.00   -234.00  -1533.00
# ...              ...     ...     ...       ...       ...       ...
# 650927        844500  -20.35   21.60   8207.87   -321.02  -1728.38
# 650928        844600  -26.64   15.00   8215.21   -323.64  -1730.43
# 650929        844700  -18.40   15.60   8214.80   -324.80  -1730.00
# 650930        844800  -27.30    8.19   8216.74   -324.96  -1729.59
# 650931    #End Write     NaN     NaN       NaN       NaN       NaN
#
#         A_LeverSum  B_PsdX  B_PsdY  B_PsdSum  ...   A_dist-X   A_dist-Y  \
# 0         23518.48  -19.79  -64.84  10337.12  ... -2869.4468 -3542.4663
# ...

# %%
# result.iloc[414069] # ok it works
# Out:
# #CycleCount/n     437445
# A_PsdX               -28
# A_PsdY               -45
# A_PsdSum            8209
# A_LeverX            -212
# A_LeverY           -1633
# A_LeverSum         23518
# B_PsdX               -37
# B_PsdY               -51
# B_PsdSum           10343
# B_LeverX             158
# B_LeverY             308
# B_LeverSum         28047
# A_Temperature      22.77
# B_Temperature      21.98
# X_force           -0.595
# A_forceX         -0.2067
# B_forceX         -0.3883
# Y_force          -2.4922
# A_forceY         -1.1984
# B_forceY         -1.2938
# Z_force           0.5348
# A_forceZ         -0.0158
# B_forceZ          0.5191
# A_dist-X        -2853.65
# A_dist-Y        -3612.15
# B_dist-X            -inf
# B_dist-Y             inf
# Motor_X           -15.33
# Motor_Y           229.06
# Motor_Z          -350.59
# time(sec)        17910.9
# Status               131
# Name: 414069, dtype: object

# %%
prova = [data, data2]

# %%
result_prova = pd.concat([j for j in prova], ignore_index=True)

# %%
result_prova
# Out:
#        #CycleCount/n  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  \
# 0                  0  -17.42  -60.82   8224.69   -236.06  -1533.82
# 1                100  -16.76  -60.73   8226.67   -236.47  -1533.08
# 2                200  -25.82  -67.76   8234.49   -236.88  -1534.18
# 3                300  -11.24  -61.71   8228.24   -233.41  -1531.94
# 4                400  -36.00  -71.00   8241.00   -234.00  -1533.00
# ...              ...     ...     ...       ...       ...       ...
# 650927        844500  -20.35   21.60   8207.87   -321.02  -1728.38
# 650928        844600  -26.64   15.00   8215.21   -323.64  -1730.43
# 650929        844700  -18.40   15.60   8214.80   -324.80  -1730.00
# 650930        844800  -27.30    8.19   8216.74   -324.96  -1729.59
# 650931    #End Write     NaN     NaN       NaN       NaN       NaN
#
#         A_LeverSum  B_PsdX  B_PsdY  B_PsdSum  ...  B_forceZ   A_dist-X  \
# 0         23518.48  -19.79  -64.84  10337.12  ...    0.4310 -2869.4468
# ...

# %%
result_prova.rename(columns = {'#CycleCount/n':'CycleCount'}, inplace = True)

# %%
result_prova
# Out:
#         CycleCount  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  A_LeverSum  \
# 0                0  -17.42  -60.82   8224.69   -236.06  -1533.82    23518.48
# 1              100  -16.76  -60.73   8226.67   -236.47  -1533.08    23517.23
# 2              200  -25.82  -67.76   8234.49   -236.88  -1534.18    23511.49
# 3              300  -11.24  -61.71   8228.24   -233.41  -1531.94    23518.12
# 4              400  -36.00  -71.00   8241.00   -234.00  -1533.00    23517.00
# ...            ...     ...     ...       ...       ...       ...         ...
# 650927      844500  -20.35   21.60   8207.87   -321.02  -1728.38    23672.20
# 650928      844600  -26.64   15.00   8215.21   -323.64  -1730.43    23677.14
# 650929      844700  -18.40   15.60   8214.80   -324.80  -1730.00    23670.80
# 650930      844800  -27.30    8.19   8216.74   -324.96  -1729.59    23677.15
# 650931  #End Write     NaN     NaN       NaN       NaN       NaN         NaN
#
# ...

# %%
result_prova.drop(result_prova[result_prova['CycleCount'] == "#End Write"].index, inplace = True)
result_prova.drop(result_prova[result_prova['CycleCount'] == "#Skipped"].index, inplace = True)
result_prova
# Out:
#        CycleCount  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  A_LeverSum  \
# 0               0  -17.42  -60.82   8224.69   -236.06  -1533.82    23518.48
# 1             100  -16.76  -60.73   8226.67   -236.47  -1533.08    23517.23
# 2             200  -25.82  -67.76   8234.49   -236.88  -1534.18    23511.49
# 3             300  -11.24  -61.71   8228.24   -233.41  -1531.94    23518.12
# 4             400  -36.00  -71.00   8241.00   -234.00  -1533.00    23517.00
# ...           ...     ...     ...       ...       ...       ...         ...
# 650926     844400  -21.89    4.56   8207.44   -323.22  -1732.11    23680.45
# 650927     844500  -20.35   21.60   8207.87   -321.02  -1728.38    23672.20
# 650928     844600  -26.64   15.00   8215.21   -323.64  -1730.43    23677.14
# 650929     844700  -18.40   15.60   8214.80   -324.80  -1730.00    23670.80
# 650930     844800  -27.30    8.19   8216.74   -324.96  -1729.59    23677.15
#
# ...

# %%
data['Z_force']
# Out:
# 0        0.3766
# 1        0.2311
# 2        0.3471
# 3        0.2893
# 4        0.2772
#           ...
# 65530    0.2094
# 65531    0.0594
# 65532    0.0213
# 65533    0.1306
# 65534    0.2501
# Name: Z_force, Length: 65535, dtype: float64

# %%
data['difference_force'] = (data['A_dist-X']+data['B_dist-Y']).values

# %%
data
# Out:
#       #CycleCount/n  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  A_LeverSum  \
# 0                 0  -19.24  -81.27   8234.19   -203.16  -1315.46    23635.15
# 1               100  -22.05  -93.51   8240.12   -202.07  -1315.90    23640.97
# 2               200  -20.68  -83.54   8236.73   -202.17  -1314.71    23638.12
# 3               300  -31.43  -91.14   8238.57   -202.43  -1315.57    23633.14
# 4               400  -12.00  -94.83   8239.33   -201.83  -1315.83    23640.50
# ...             ...     ...     ...       ...       ...       ...         ...
# 65530        101193  -19.50  -93.25   8203.50   -237.25  -1363.00    23774.25
# 65531        101194  -24.00  -94.50   8209.25   -236.75  -1363.50    23777.25
# 65532        101195  -28.00  -95.75   8211.25   -236.25  -1362.25    23776.75
# 65533        101196  -20.75  -96.25   8206.50   -236.75  -1363.00    23782.00
# 65534        101197  -11.00  -94.67   8203.00   -236.67  -1363.00    23778.67
#
# ...

# %%
data['A_dist-X']
# Out:
# 0       -28471892.0
# 1       -28464402.0
# 2       -28465242.0
# 3       -28467202.0
# 4       -28462903.0
#             ...
# 65530   -28685525.0
# 65531   -28682085.0
# 65532   -28678867.0
# 65533   -28681775.0
# 65534   -28681453.0
# Name: A_dist-X, Length: 65535, dtype: float64

# %%
data.plot(x = 'A_dist-Y', y = 'Z_force', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='A_dist-Y', ylabel='Z_force'>
