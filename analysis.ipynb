# %%
from files_sorting import Txt
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from graphs import Graph

# %%
# directory name
dir_name = "Pulling_3bs"
# molecule name is a number in these experimets
number = "16"

# %%
file = Txt(dir_name, number)
dataFrame = file.bricolage()

# %%
# dataFrame

# %%
grafici = Graph(dir_name, number, 'f', '2', True)
grafici.do_graph()
# Out:
# The df mean is -0.003641501843781428 and the df std is 0.13933527733942455
# [1927, 1980, 2216, 2219, 2330, 2381]
# No handles with labels found to put in legend.
# Il coefficient k_eff = 0.005417541118554923(pN/nm), la f_F = 3.3287(pN) e la f_U = 3.777304956189752(pN)
# Salto avvenuto tra 3.3287(pN) e 3.777304956189752(pN)
# x_d = 0.9283907132924916, con un x_ssDNA = 83.73439926453221(nm)
# [3.3287, 3.777304956189752]

# %%
f_F, f_U = grafici.maximum_f()
# Out:
# The df mean is -0.003641501843781428 and the df std is 0.13933527733942455
# [1927, 1980, 2216, 2219, 2330, 2381]
# Il coefficient k_eff = 0.005417541118554923(pN/nm), la f_F = 3.3287(pN) e la f_U = 3.777304956189752(pN)
# Salto avvenuto tra 3.3287(pN) e 3.777304956189752(pN)
# x_d = 0.9283907132924916, con un x_ssDNA = 83.73439926453221(nm)

# %%
f_F, f_U
# Out:
# (3.3287, 3.777304956189752)

# %%
# no: f1, u1, f2, u2, u3, u4
# si f2, f3, f4
