# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %%
# directory name
dir_name = "Hopping_3bs"
# molecule name is a number in these experimets
number = "14"

# %%
file = Txt_hop(dir_name, number)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.8452   0.1649 -197.82490   4.1656  20436.29492
# 1      -0.3531   0.0895 -197.11875   4.3524  20436.29688
# 2       0.3065   0.2084 -197.56045   4.5292  20436.29688
# 3       0.0133   0.2548 -197.23390   4.7211  20436.29883
# 4      -0.0599   0.1243 -197.21345   4.6251  20436.29883
# ...        ...      ...        ...      ...          ...
# 29643   0.8824   0.1910 -213.34860   5.2059  20497.04297
# 29644  -0.4212   0.1910 -213.34300   4.9837  20497.04297
# 29645  -0.6463   0.1678 -213.50265   4.9433  20497.04492
# 29646   0.2385   0.3534 -213.08535   5.0089  20497.04492
# 29647   0.5264   0.3476 -213.15775   5.0948  20497.04680
#
# [29648 rows x 5 columns]

# %%
froces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.5547012948992185, con deviazione standard = 0.27842877602992255

# %%
prova = [2.1, 4.6, 0.1, 0.5, 4.15, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.8066608326979914, mu_1 = 4.652105075749436, sigma_1 = 0.1775104249511136
# c_2 = 0.4535879982125059, mu_2 = 4.1235667416036135, sigma_2 = 0.16332730316781113
# sigma_c_1 = 0.032592936409940446, sigma_mu_1 = 0.005427164268442428, sigma_sigma_1 = 0.005797761331291739
# sigma_c_2 = 0.03355189140270818, sigma_mu_2 = 0.020729054382447768, sigma_sigma_2 = 0.018640964130049068
# w_U = 0.8038785255652775, sigma_w_U = 0.029994821878990576
# w_N = 0.18569930573111668, sigma_w_N = 0.02525633391583917

# %%
froces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.8452   0.1649 -197.82490   4.1656    0.00000
# 1     -0.3531   0.0895 -197.11875   4.3524    0.00196
# 2      0.3065   0.2084 -197.56045   4.5292    0.00196
# 3      0.0133   0.2548 -197.23390   4.7211    0.00391
# 4     -0.0599   0.1243 -197.21345   4.6251    0.00391
# ...       ...      ...        ...      ...        ...
# 8876   0.0901  -0.0854 -199.06810   4.9399    9.27930
# 8877   0.0866   0.0112 -199.07010   5.0140    9.28320
# 8878   0.1756   0.0141 -199.15290   4.7564    9.28320
# 8879  -0.0756   0.1649 -199.23270   4.4130    9.28516
# 8880   0.0343   0.1649 -198.99335   4.5494    9.28508
#
# [8881 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.334090208406122, con deviazione standard = 0.2879556556950704

# %%
prova = [2., 5.1, 0.2, 0.25, 6., 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.7919159239974412, mu_1 = 5.255962119974296, sigma_1 = 0.19726513637537488
# c_2 = 0.2339785123241136, mu_2 = 5.916057427175182, sigma_2 = 0.19503553497007262
# sigma_c_1 = 0.03245831799173836, sigma_mu_1 = 0.005260101007686258, sigma_sigma_1 = 0.005198901768294991
# sigma_c_2 = 0.0338675377458248, sigma_mu_2 = 0.0403207289046851, sigma_sigma_2 = 0.04407711956567392
# w_U = 0.8860493271479573, sigma_w_U = 0.028335414148572696
# w_N = 0.11438778631514371, sigma_w_N = 0.030698876665233528

# %%
froces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2786   0.1852 -177.85220   5.4045    0.00000
# 1     -0.2030   0.1698 -177.88505   5.0477    0.00196
# 2     -0.4613   0.1582 -178.21165   4.8322    0.00196
# 3      0.1913   0.0402 -178.67135   5.2160    0.00391
# 4      0.2437   0.0344 -178.13650   5.2362    0.00391
# ...       ...      ...        ...      ...        ...
# 8584  -0.2850   0.1533 -174.23900   5.3422    8.97266
# 8585  -0.0233   0.0924 -174.25455   5.5846    8.97266
# 8586  -0.3688  -0.0294 -173.92815   5.3927    8.97461
# 8587   0.1285   0.1156 -174.08440   5.2867    8.97657
# 8588  -0.0652   0.1185 -174.28815   5.1503    8.97651
#
# [8589 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.164348488612838, con deviazione standard = 0.2392815212642769

# %%
prova = [2., 4.1, 0.2, 0.2, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.963274509162627, mu_1 = 4.188112142127388, sigma_1 = 0.1912106548513292
# c_2 = 0.1484659435410466, mu_2 = 3.5861841758583077, sigma_2 = 0.11887213275898675
# sigma_c_1 = 0.039727932062628875, sigma_mu_1 = 0.004588570198584762, sigma_sigma_1 = 0.0049723380081459
# sigma_c_2 = 0.04935847953713322, sigma_mu_2 = 0.04914905422863405, sigma_sigma_2 = 0.04869910302604585
# w_U = 0.9409857590731305, sigma_w_U = 0.03100560921686877
# w_N = 0.04423813723890306, sigma_w_N = 0.02334005540908028

# %%
froces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0692   0.2084 -213.29090   4.1925    0.00000
# 1      0.5089   0.2162 -213.37840   4.0377    0.00195
# 2     -0.0006   0.0924 -213.59885   4.2127    0.00195
# 3     -0.4822  -0.0738 -213.59790   4.1993    0.00391
# 4      0.0343  -0.0352 -213.65850   4.3272    0.00391
# ...       ...      ...        ...      ...        ...
# 7240   0.3205  -0.1241 -221.28655   4.2599    7.55078
# 7241   0.4880  -0.1164 -221.57470   4.2195    7.55274
# 7242  -0.2065  -0.2092 -221.75720   4.1151    7.55274
# 7243   0.0971  -0.1106 -221.34955   4.1807    7.55469
# 7244   0.1023  -0.2614 -221.05030   4.1858    7.55467
#
# [7245 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.915202878572868, con deviazione standard = 0.33847411852760834

# %%
prova = [1.6, 5.2, 0.25, 1.6, 4.6, 0.25]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.349671737973893, mu_1 = 5.197694000491263, sigma_1 = 0.14926676588383506
# c_2 = 1.0886640463543575, mu_2 = 4.617183497284216, sigma_2 = 0.1784936439698744
# sigma_c_1 = 0.04601310499402012, sigma_mu_1 = 0.006803253032310907, sigma_sigma_1 = 0.007300770294860056
# sigma_c_2 = 0.04100162256286568, sigma_mu_2 = 0.008982680794803386, sigma_sigma_2 = 0.009312876322313838
# w_U = 0.5049881780628994, sigma_w_U = 0.030107395313642905
# w_N = 0.48708703549106125, sigma_w_N = 0.03134307355676165

# %%
froces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1180   0.0924 -219.57590   5.1756    0.00000
# 1     -0.1646   0.0663 -219.62195   5.0847    0.00195
# 2      0.0971   0.1707 -219.59630   5.0796    0.00390
# 3     -0.0390   0.0170 -219.67580   5.1806    0.00390
# 4     -0.2536   0.1214 -219.56035   5.1251    0.00586
# ...       ...      ...        ...      ...        ...
# 4928   0.8824   0.1910 -213.34860   5.2059    5.11328
# 4929  -0.4212   0.1910 -213.34300   4.9837    5.11328
# 4930  -0.6463   0.1678 -213.50265   4.9433    5.11523
# 4931   0.2385   0.3534 -213.08535   5.0089    5.11523
# 4932   0.5264   0.3476 -213.15775   5.0948    5.11711
#
# [4933 rows x 5 columns]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, froces_average)
# Out:
# La forza di coesistenza vale f_c = 7.141916822675228
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 2.770662813810124
# La differenza di energia libera DeltaG_NU = 19.787843359911207

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
froces_average = remove_element(froces_average, 1)
w_U = remove_element(w_U, 1)
w_N = remove_element(w_N, 1)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, froces_average)
# Out:
# La forza di coesistenza vale f_c = 4.907541761392712
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 12.164941114603815
# La differenza di energia libera DeltaG_NU = 59.699956544801424
