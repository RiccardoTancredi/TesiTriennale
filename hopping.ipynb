# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop

# %%
# directory name
dir_name = "Hopping_3bs"
# molecule name is a number in these experimets
number = "14"

# %%
file = Txt_hop(dir_name, number)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.8452   0.1649 -197.82490   4.1656  20436.29492
# 1      -0.3531   0.0895 -197.11875   4.3524  20436.29688
# 2       0.3065   0.2084 -197.56045   4.5292  20436.29688
# 3       0.0133   0.2548 -197.23390   4.7211  20436.29883
# 4      -0.0599   0.1243 -197.21345   4.6251  20436.29883
# ...        ...      ...        ...      ...          ...
# 29643   0.8824   0.1910 -213.34860   5.2059  20497.04297
# 29644  -0.4212   0.1910 -213.34300   4.9837  20497.04297
# 29645  -0.6463   0.1678 -213.50265   4.9433  20497.04492
# 29646   0.2385   0.3534 -213.08535   5.0089  20497.04492
# 29647   0.5264   0.3476 -213.15775   5.0948  20497.04680
#
# [29648 rows x 5 columns]

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)

# %%
prova = [4.65, 0.05, 2, 4.15, 0.05, 0.5]
grafici.fit([3.50, 5.250], data_frame['Y_force'], guess=prova)
# Out:
# Beta: [4.36913997 0.04729835 1.83722354 4.38371711 0.04607203 0.52323442]
# Beta Std Error: [1.22876750e+08 1.33384350e+07 2.49816003e+10 3.15257133e+08
#  1.73860244e+07 2.49858514e+10]
# Beta Covariance: [[ 1.05776333e-01 -1.09029522e-02  2.09947677e+01  2.43207134e-01
#   -1.47762320e-02 -2.09919736e+01]
#  [-1.09029522e-02  1.24640397e-03 -2.31082475e+00 -2.90068533e-02
#    1.49239952e-03  2.31170736e+00]
#  [ 2.09947677e+01 -2.31082475e+00  4.37209493e+03  5.35049587e+01
#   -2.92943037e+00 -4.37283178e+03]
#  [ 2.43207134e-01 -2.90068533e-02  5.35049587e+01  6.96271975e-01
#   -3.35202703e-02 -5.35342973e+01]
#  [-1.47762320e-02  1.49239952e-03 -2.92943037e+00 -3.35202703e-02
#    2.11762786e-03  2.92865827e+00]
#  [-2.09919736e+01  2.31170736e+00 -4.37283178e+03 -5.35342973e+01
#    2.92865827e+00  4.37358305e+03]]
# Residual Variance: 1.4274172048258794e+17
# Inverse Condition #: 1.9722737806207377e-05
# Reason(s) for Halting:
#   Iteration limit reached
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5347f91356f2> in <module>
#       1 prova = [4.65, 0.05, 2, 4.15, 0.05, 0.5]
# ----> 2 grafici.fit([3.50, 5.250], data_frame['Y_force'], guess=prova)
#
# c:\Users\ricta\Documents\TesiTriennale\graph_hop.py in fit(self, lista_fit_gaussiano, y, guess)
#      56         # covariana_matrice = myoutput.cov_beta
#      57         self.sigma_diagonale = np.sqrt(np.diag(self.myoutput.cov_beta))
# ---> 58         self._fit_plot()
#      59         return self.myoutput.beta, self.sigma_diagonale
#      60
#
# c:\Users\ricta\Documents\TesiTriennale\graph_hop.py in _fit_plot(self)
#      85     def _fit_plot(self):
#      86         gaussianadoppia = np.vectorize(self._doublegaussian)
# ---> 87         y_pred = gaussianadoppia(self.myoutput, self.x)
#      88         plt.plot(self.x, y_pred, color='r', label='Fit')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# c:\Users\ricta\Documents\TesiTriennale\graph_hop.py in _doublegaussian(self, B, x)
#      44         # B is a vector of the parameters:
#      45         # B = [f_U, sigma_U, w_U, f_F, sigma_F, w_F]
# ---> 46         return B[2]/np.sqrt(2*np.pi*B[1])*np.exp(((x-B[0])/(4*B[1]))**2) + B[5]/np.sqrt(2*np.pi*B[4])*np.exp(((x-B[3])/(4*B[4]))**2)
#      47
#      48     def fit(self, lista_fit_gaussiano, y, guess:list):
#
# TypeError: 'Output' object is not subscriptable

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.8452   0.1649 -197.82490   4.1656    0.00000
# 1     -0.3531   0.0895 -197.11875   4.3524    0.00196
# 2      0.3065   0.2084 -197.56045   4.5292    0.00196
# 3      0.0133   0.2548 -197.23390   4.7211    0.00391
# 4     -0.0599   0.1243 -197.21345   4.6251    0.00391
# ...       ...      ...        ...      ...        ...
# 8876   0.0901  -0.0854 -199.06810   4.9399    9.27930
# 8877   0.0866   0.0112 -199.07010   5.0140    9.28320
# 8878   0.1756   0.0141 -199.15290   4.7564    9.28320
# 8879  -0.0756   0.1649 -199.23270   4.4130    9.28516
# 8880   0.0343   0.1649 -198.99335   4.5494    9.28508
#
# [8881 rows x 5 columns]
