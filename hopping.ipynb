# %%
from file_hopping import Txt_hop
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from graph_hop import Graph_hop

# %%
# directory name
dir_name = "Hopping_3bs"
# molecule name is a number in these experimets
number = "14"

# %%
file = Txt_hop(dir_name, number)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        CycleCount  A_PsdX  A_PsdY  A_PsdSum  A_LeverX  A_LeverY  A_LeverSum  \
# 0           28729  -46.25 -115.50   8146.50    371.00   -335.75    20502.00
# 1           28730  -38.00 -121.50   8150.00    371.00   -334.50    20498.25
# 2           28731  -24.00 -124.00   8150.00    372.00   -335.00    20497.00
# 3           28732  -29.00 -125.50   8145.50    371.50   -335.00    20495.00
# 4           28733  -31.25 -126.25   8150.25    371.00   -334.75    20496.25
# ...           ...     ...     ...       ...       ...       ...         ...
# 29643       89353  -11.50 -139.00   8154.00    325.25   -328.75    20558.00
# 29644       89354  -36.25 -132.50   8151.00    325.75   -329.00    20560.75
# 29645       89355  -41.75 -132.50   8150.75    325.25   -328.75    20557.75
# 29646       89356  -22.50 -131.75   8146.75    325.50   -328.75    20558.25
# 29647       89357  -16.25 -134.25   8147.25    325.50   -328.25    20555.25
#
#        B_PsdX  B_PsdY  B_PsdSum  ...  A_dist-X  A_dist-Y  B_dist-X  B_dist-Y  \
# 0      -57.75 -122.50  10533.00  ...  258.0280 -249.8883 -174.0432 -145.7615
# 1      -42.50 -125.75  10527.00  ...  258.0752 -249.0035 -173.8631 -145.2340
# 2      -25.00 -132.00  10530.00  ...  258.7866 -249.3909 -173.5673 -145.7300
# 3      -34.00 -140.00  10537.00  ...  258.4639 -249.4152 -174.1374 -145.0526
# 4      -35.25 -134.50  10530.50  ...  258.1003 -249.2139 -174.2763 -145.2130
# ...       ...     ...       ...  ...       ...       ...       ...       ...
# 29643  -10.00 -150.50  10531.00  ...  225.5930 -244.0120 -230.4673 -182.6852
# 29644  -47.50 -146.00  10543.00  ...  225.9094 -244.1647 -230.1784 -182.5213
# 29645  -52.75 -144.00  10544.75  ...  225.5957 -244.0148 -230.1431 -182.9905
# 29646  -29.75 -148.00  10543.25  ...  225.7636 -244.0089 -230.1431 -182.1618
# 29647  -22.25 -149.75  10541.00  ...  225.7966 -243.6733 -229.9764 -182.6422
#
#        Motor_X  Motor_Y  Motor_Z    time(sec)  Status     lambda
# 0        75.32   264.33  -420.23  20436.29492    30.0 -197.82490
# 1        75.32   264.33  -420.23  20436.29688    30.0 -197.11875
# 2        75.32   264.33  -420.23  20436.29688    30.0 -197.56045
# 3        75.32   264.33  -420.23  20436.29883    30.0 -197.23390
# 4        75.32   264.33  -420.23  20436.29883    30.0 -197.21345
# ...        ...      ...      ...          ...     ...        ...
# 29643    75.32   264.33  -420.23  20497.04297    30.0 -213.34860
# 29644    75.32   264.33  -420.23  20497.04297    30.0 -213.34300
# 29645    75.32   264.33  -420.23  20497.04492    30.0 -213.50265
# 29646    75.32   264.33  -420.23  20497.04492    30.0 -213.08535
# 29647    75.32   264.33  -420.23  20497.04688    30.0 -213.15775
#
# [29648 rows x 34 columns]

# %%
grafici = Graph_hop(dir_name, number)
grafici.do_graph()
