# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %%
# directory name
dir_name = "Hopping_3bs"
# molecule name is a number in these experimets
number = "14"

# %%
file = Txt_hop(dir_name, number)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.8452   0.1649 -197.82490   4.1656  20436.29492
# 1      -0.3531   0.0895 -197.11875   4.3524  20436.29688
# 2       0.3065   0.2084 -197.56045   4.5292  20436.29688
# 3       0.0133   0.2548 -197.23390   4.7211  20436.29883
# 4      -0.0599   0.1243 -197.21345   4.6251  20436.29883
# ...        ...      ...        ...      ...          ...
# 29643   0.8824   0.1910 -213.34860   5.2059  20497.04297
# 29644  -0.4212   0.1910 -213.34300   4.9837  20497.04297
# 29645  -0.6463   0.1678 -213.50265   4.9433  20497.04492
# 29646   0.2385   0.3534 -213.08535   5.0089  20497.04492
# 29647   0.5264   0.3476 -213.15775   5.0948  20497.04680
#
# [29648 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph(5.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.587691345606384, con deviazione standard = 0.25545858251667225

# %%
prova = [2.1, 4.6, 0.1, 0.5, 4.15, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 2.0028102976518407, mu_1 = 4.651769018721643, sigma_1 = 0.17409961933880622
# c_2 = 0.31251034396534694, mu_2 = 4.107367183403535, sigma_2 = 0.14727820066463201
# sigma_c_1 = 0.03844311006343563, sigma_mu_1 = 0.004594674555042537, sigma_sigma_1 = 0.00512740979628622
# sigma_c_2 = 0.04010927971037784, sigma_mu_2 = 0.027414581342298575, sigma_sigma_2 = 0.02648364164984714
# w_U = 0.11536997558140054, sigma_w_U = 0.13696512282722045
# w_N = 0.8740324792803646, sigma_w_N = 0.0027910774090835217

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, Markov=False, n_points_fig=600)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.437 sec nello stato nativo e 0.8320000000000001 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.8452   0.1649 -197.82490   4.1656    0.00000
# 1     -0.3531   0.0895 -197.11875   4.3524    0.00196
# 2      0.3065   0.2084 -197.56045   4.5292    0.00196
# 3      0.0133   0.2548 -197.23390   4.7211    0.00391
# 4     -0.0599   0.1243 -197.21345   4.6251    0.00391
# ...       ...      ...        ...      ...        ...
# 5264  -0.9237  -0.0555 -195.06685   4.1100    5.49414
# 5265  -0.0495   0.0953 -195.11125   3.7767    5.49610
# 5266  -0.5677   0.1881 -195.45995   3.9686    5.49610
# 5267  -0.9918   0.1098 -195.06620   3.9787    5.49805
# 5268  -0.0128   0.0373 -195.16910   4.0646    5.49805
#
# [5269 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(5.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.291169933396773, con deviazione standard = 0.2735527946897644

# %%
prova = [0.25, 6., 0.2, 2., 5.1, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.26457560322579843, mu_1 = 5.85997709968482, sigma_1 = 0.17165116033963485
# c_2 = 1.9063096651730298, mu_2 = 5.217643187679446, sigma_2 = 0.18553513509535896
# sigma_c_1 = 0.03531029167387981, sigma_mu_1 = 0.029829726708677583, sigma_sigma_1 = 0.03248240307944111
# sigma_c_2 = 0.032849692628353036, sigma_mu_2 = 0.004240224036548376, sigma_sigma_2 = 0.004344751505103944
# w_U = 0.8865628905153178, sigma_w_U = 0.0023716500609974357
# w_N = 0.1138377943936374, sigma_w_N = 0.1450392841829493

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.769 sec nello stato nativo e 4.486 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2786   0.1852 -177.85220   5.4045    0.00000
# 1     -0.2030   0.1698 -177.88505   5.0477    0.00196
# 2     -0.4613   0.1582 -178.21165   4.8322    0.00196
# 3      0.1913   0.0402 -178.67135   5.2160    0.00391
# 4      0.2437   0.0344 -178.13650   5.2362    0.00391
# ...       ...      ...        ...      ...        ...
# 5250   0.2646   0.0808 -175.61445   5.9280    5.49414
# 5251  -0.1961   0.0634 -175.58650   5.8725    5.49610
# 5252  -0.1018   0.0460 -175.70280   5.8169    5.49610
# 5253  -0.4578   0.0982 -175.86665   5.8977    5.49805
# 5254  -0.4578  -0.0236 -175.97960   5.8826    5.49805
#
# [5255 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(5.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.1815189194312845, con deviazione standard = 0.23960257970746612

# %%
prova = [2., 4.1, 0.2, 0.2, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.0185190499865233, mu_1 = 4.209792404740574, sigma_1 = 0.18330364846954922
# c_2 = 0.16103561724752113, mu_2 = 3.616799763808086, sigma_2 = 0.14060145865554216
# sigma_c_1 = 0.04557688324714665, sigma_mu_1 = 0.005127001991984999, sigma_sigma_1 = 0.005676516355668369
# sigma_c_2 = 0.050333148723798474, sigma_mu_2 = 0.057313552095200636, sigma_sigma_2 = 0.05734943803385839
# w_U = 0.05675468305268088, sigma_w_U = 0.3461367417881976
# w_N = 0.9274572401689448, sigma_w_N = 0.0015538551930609408

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.7700000000000005 sec nello stato nativo e 0.505 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0692   0.2084 -213.29090   4.1925    0.00000
# 1      0.5089   0.2162 -213.37840   4.0377    0.00195
# 2     -0.0006   0.0924 -213.59885   4.2127    0.00195
# 3     -0.4822  -0.0738 -213.59790   4.1993    0.00391
# 4      0.0343  -0.0352 -213.65850   4.3272    0.00391
# ...       ...      ...        ...      ...        ...
# 5270  -0.3426  -0.2788 -218.37555   4.7716    5.49414
# 5271   0.0552  -0.3020 -218.73745   4.3171    5.49609
# 5272   0.0971  -0.2826 -218.38955   4.3541    5.49609
# 5273  -0.0076  -0.1318 -218.30810   4.2195    5.49609
# 5274  -0.2798  -0.1338 -218.57570   4.2666    5.49805
#
# [5275 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.915202878572868, con deviazione standard = 0.33847411852760834

# %%
prova = [1.6, 5.2, 0.25, 1.6, 4.6, 0.25]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.349671737973893, mu_1 = 5.197694000491263, sigma_1 = 0.14926676588383506
# c_2 = 1.0886640463543575, mu_2 = 4.617183497284216, sigma_2 = 0.1784936439698744
# sigma_c_1 = 0.04601310499402012, sigma_mu_1 = 0.006803253032310907, sigma_sigma_1 = 0.007300770294860056
# sigma_c_2 = 0.04100162256286568, sigma_mu_2 = 0.008982680794803386, sigma_sigma_2 = 0.009312876322313838
# w_U = 0.48708703549106125, sigma_w_U = 0.0231359786746184
# w_N = 0.5049881780628994, sigma_w_N = 0.020436410348599963

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.524 sec nello stato nativo e 2.4090000000000003 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1180   0.0924 -219.57590   5.1756    0.00000
# 1     -0.1646   0.0663 -219.62195   5.0847    0.00195
# 2      0.0971   0.1707 -219.59630   5.0796    0.00390
# 3     -0.0390   0.0170 -219.67580   5.1806    0.00390
# 4     -0.2536   0.1214 -219.56035   5.1251    0.00586
# ...       ...      ...        ...      ...        ...
# 4928   0.8824   0.1910 -213.34860   5.2059    5.11328
# 4929  -0.4212   0.1910 -213.34300   4.9837    5.11328
# 4930  -0.6463   0.1678 -213.50265   4.9433    5.11523
# 4931   0.2385   0.3534 -213.08535   5.0089    5.11523
# 4932   0.5264   0.3476 -213.15775   5.0948    5.11711
#
# [4933 rows x 5 columns]

# %%
forces_average
# Out:
# [4.379568101062588, 5.538810143682133, 3.9132960842743296, 4.90743874888774]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.91800993198514, con sigma = 2.91994366625994
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 14.267083207088262, con sigma = 5.996059604535883
# La differenza di energia libera DeltaG_NU = 70.16565691291848, con sigma = 29.426120963485662

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 42.90476021797663, con sigma = 15.868812611000289

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6809146182126333, con incertezza = 0.010973490427038523,
#  q1 = 5.485714910560402, con incertezza = 0.010902612186901611
# Stimiamo i parametri del fit lineare: m2 = 0.638985579906722, con incertezza = 0.010004040430923292,
#  q2 = 4.38868135239168, con incertezza = 0.009102934477036024
# La forza di coesistenza qui vale: fc = 4.9197734950721435, con incertezza = 0.009370562275630325
# Il tempo medi di residenza vale: tc = 2.295954979404328, con incertezza = 0.03273075978900443
# Stimiamo un nuovo DeltaG_NU = 70.1908178142217, con incertezza = 29.499558058519966
# ((-0.6809146182126333, 0.010973490427038523),
#  (5.485714910560402, 0.010902612186901611),
#  (0.638985579906722, 0.010004040430923292),
#  (4.38868135239168, 0.009102934477036024),
#  (4.9197734950721435, 0.009370562275630325),
#  (2.295954979404328, 0.03273075978900443),
#  (70.1908178142217, 29.499558058519966))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
forces_average = remove_element(forces_average, 2)
forces_average_std = remove_element(forces_average_std, 2)
w_U = remove_element(w_U, 2)
w_N = remove_element(w_N, 2)
sigma_w_U = remove_element(sigma_w_U, 2)
sigma_w_N = remove_element(sigma_w_N, 2)
native_time = remove_element(native_time, 2)
unfolded_time = remove_element(unfolded_time, 2)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.9179052552944915, con sigma = 2.970374799455658
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 14.439068293778647, con sigma = 6.173155552580767
# La differenza di energia libera DeltaG_NU = 71.00996984353007, con sigma = 30.29580717203964

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 42.90331597672606, con sigma = 16.120442687118075

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6259205563718543, con incertezza = 0.011365808463852737,
#  q1 = 5.4528537420618655, con incertezza = 0.01104518921639192
# Stimiamo i parametri del fit lineare: m2 = 0.6294669543517196, con incertezza = 0.01164953564268158,
#  q2 = 4.397551653317284, con incertezza = 0.010667982296684222
# La forza di coesistenza qui vale: fc = 4.9266932817378075, con incertezza = 0.010283600059910726
# Il tempo medi di residenza vale: tc = 2.317800319184689, con incertezza = 0.03797180867015257
# Stimiamo un nuovo DeltaG_NU = 71.13686075751265, con incertezza = 30.413606459106933
# ((-0.6259205563718543, 0.011365808463852737),
#  (5.4528537420618655, 0.01104518921639192),
#  (0.6294669543517196, 0.01164953564268158),
#  (4.397551653317284, 0.010667982296684222),
#  (4.9266932817378075, 0.010283600059910726),
#  (2.317800319184689, 0.03797180867015257),
#  (71.13686075751265, 30.413606459106933))

# %%
grafici.write_on_txt()
