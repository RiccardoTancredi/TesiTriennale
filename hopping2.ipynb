# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 2hop

# %%
# directory name
dir_name = "0nM/2"
# molecule name is a number in these experimets
number = "2"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force   time(sec)
# 0       -0.5566   0.3585 -900.59065   4.4411  9648.24707
# 1       -0.4930   0.3008 -900.18430   4.7530  9648.24805
# 2       -0.2703   0.3924 -900.13680   4.7331  9648.25000
# 3        0.2228   0.3847 -900.22915   4.4295  9648.25195
# 4        0.6205   0.3008 -900.37405   4.6485  9648.25293
# ...         ...      ...        ...      ...         ...
# 103286   0.0479   0.0339 -950.51450   4.0960  9848.21484
# 103287   0.6241   0.2330 -951.07830   3.8637  9848.21680
# 103288   0.0090   0.2059 -950.85070   3.9434  9848.21777
# 103289  -0.0547   0.1584 -950.93800   3.9898  9848.21875
# 103290  -0.1589   0.1534 -950.94785   4.0711  9848.21870
#
# [103291 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.668163998493297, con deviazione standard = 0.2719575130985384

# %%
prova = [0.5, 5.21, 0.1, 2.1, 4.52, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.4812759964776053, mu_1 = 5.192151396902048, sigma_1 = 0.11758142525366534
# c_2 = 2.019491845201298, mu_2 = 4.575616923534201, sigma_2 = 0.16908089342099983
# sigma_c_1 = 0.04734005999687153, sigma_mu_1 = 0.013802319975005698, sigma_sigma_1 = 0.013904059041411001
# sigma_c_2 = 0.03858939848892234, sigma_mu_2 = 0.0038008916445979074, sigma_sigma_2 = 0.003879252714145079
# w_U = 0.8559069875959749, sigma_w_U = 0.0031614292204064785
# w_N = 0.14184788222815709, sigma_w_N = 0.09822889052384633

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.676 sec nello stato nativo e 8.943 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.5566   0.3585 -900.59065   4.4411    0.00000
# 1      -0.4930   0.3008 -900.18430   4.7530    0.00098
# 2      -0.2703   0.3924 -900.13680   4.7331    0.00293
# 3       0.2228   0.3847 -900.22915   4.4295    0.00488
# 4       0.6205   0.3008 -900.37405   4.6485    0.00586
# ...        ...      ...        ...      ...        ...
# 10614   0.3978   0.4127 -901.40545   4.3300   11.07324
# 10615   0.0638   0.3288 -901.11120   4.3648   11.07324
# 10616  -0.0529   0.2144 -901.19450   4.9472   11.07520
# 10617   0.8008   0.3415 -901.58025   4.3051   11.07520
# 10618   0.4296   0.1712 -901.11600   4.8725   11.07713
#
# [10619 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.519857158361173, con deviazione standard = 0.338060246855991

# %%
prova = [1.1, 4.9, 0.2, 1.5, 4.25, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.184659161435128, mu_1 = 4.910402203679537, sigma_1 = 0.120936603694002
# c_2 = 1.4524257516688024, mu_2 = 4.292374458684253, sigma_2 = 0.17511697183446098
# sigma_c_1 = 0.03820571093723647, sigma_mu_1 = 0.0046811363439362855, sigma_sigma_1 = 0.004763502569453585
# sigma_c_2 = 0.031146614002428036, sigma_mu_2 = 0.004435315868778802, sigma_sigma_2 = 0.0045724390905243
# w_U = 0.637546863146968, sigma_w_U = 0.009016101975179503
# w_N = 0.35912126279216583, sigma_w_N = 0.02409175804625468

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.112 sec nello stato nativo e 6.945 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.9278   0.4534 -904.48825   4.5788    0.00000
# 1      -0.5566   0.4432 -904.45060   4.2155    0.00195
# 2      -0.7263   0.3618 -904.63140   4.2354    0.00293
# 3      -0.3604   0.2474 -904.74995   4.4793    0.00391
# 4      -0.2438   0.3186 -904.75800   4.2354    0.00391
# ...        ...      ...        ...      ...        ...
# 11052  -0.5354  -0.2585 -906.25470   4.7862   11.54004
# 11053  -0.7263  -0.1746 -905.84980   4.9820   11.54102
# 11054  -0.6309   0.1915 -905.39525   4.9621   11.54102
# 11055  -0.5460   0.1661 -905.03365   4.9721   11.54297
# 11056   0.0001   0.1305 -904.90305   5.0368   11.54293
#
# [11057 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.3240346317079865, con deviazione standard = 0.33885793515461043

# %%
prova = [1.5, 4.6, 0.1, 1., 4.1, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.5840324968808135, mu_1 = 4.597316707267886, sigma_1 = 0.1318178829334734
# c_2 = 1.0011160383484774, mu_2 = 4.0068178440178635, sigma_2 = 0.1868441067058568
# sigma_c_1 = 0.032092269495656155, sigma_mu_1 = 0.003415390431053427, sigma_sigma_1 = 0.003579674946651339
# sigma_c_2 = 0.02662849076441042, sigma_mu_2 = 0.006199963603351137, sigma_sigma_2 = 0.006575854038665665
# w_U = 0.46887141594996457, sigma_w_U = 0.01669253505124685
# w_N = 0.5233935345898795, sigma_w_N = 0.011435338082155909

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.683 sec nello stato nativo e 4.92 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.0744   0.5703 -911.92665   4.0960    0.00000
# 1      -0.0476   0.5042 -912.56540   3.8471    0.00000
# 2      -0.1324   0.3822 -911.95030   4.0761    0.00098
# 3       0.1433   0.4737 -911.84240   3.9832    0.00195
# 4      -0.3869   0.4161 -911.79905   4.3482    0.00391
# ...        ...      ...        ...      ...        ...
# 10598  -0.9490   0.2322 -918.09050   4.4444   11.06348
# 10599  -0.7051   0.3186 -918.07335   4.5390   11.06445
# 10600   0.2228   0.3746 -917.97990   4.6087   11.06641
# 10601  -0.2915   0.1534 -918.09505   4.5390   11.06738
# 10602   0.0585  -0.0958 -918.16765   4.5672   11.06731
#
# [10603 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(11)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.233700636337726, con deviazione standard = 0.3103857570304069

# %%
prova = [1.6, 4.4, 0.25, 1., 3.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.876725004204011, mu_1 = 4.4002147889773005, sigma_1 = 0.14637131152616129
# c_2 = 0.6811886623221459, mu_2 = 3.833500443256075, sigma_2 = 0.17468316915692036
# sigma_c_1 = 0.0388770314469942, sigma_mu_1 = 0.00406217650001564, sigma_sigma_1 = 0.004356932512544028
# sigma_c_2 = 0.03491227530430053, sigma_mu_2 = 0.011946910787980887, sigma_sigma_2 = 0.012491863624465407
# w_U = 0.29826919876344193, sigma_w_U = 0.0430299172094426
# w_N = 0.6885675290241688, sigma_w_N = 0.007608111491012082

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.267 sec nello stato nativo e 3.262 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.9172  -0.3501 -922.58130   3.7376    0.00000
# 1       0.3413  -0.1839 -922.23915   3.9367    0.00195
# 2      -0.2385  -0.1907 -922.88915   3.7775    0.00293
# 3      -0.0971  -0.1534 -922.31375   3.8372    0.00390
# 4       0.2547  -0.0958 -922.34300   3.8919    0.00390
# ...        ...      ...        ...      ...        ...
# 10524  -0.6839  -0.2992 -924.85320   3.7127   10.99414
# 10525  -0.8430  -0.4136 -924.87735   3.8670   10.99609
# 10526  -0.5566  -0.3738 -925.25035   3.9301   10.99609
# 10527  -0.1536  -0.2484 -925.22260   3.9566   10.99707
# 10528  -0.1607  -0.1534 -925.24275   3.5916   10.99902
#
# [10529 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.919299954052527, con deviazione standard = 0.3070760454879594

# %%
prova = [1.6, 4.1, 0.25, 0.8, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.7498558131302806, mu_1 = 4.0810962264673725, sigma_1 = 0.155858503844114
# c_2 = 0.6760568852728672, mu_2 = 3.5361893858110136, sigma_2 = 0.17928295299714622
# sigma_c_1 = 0.05422921637664891, sigma_mu_1 = 0.007434038884507827, sigma_sigma_1 = 0.007857214019883837
# sigma_c_2 = 0.04974632099032158, sigma_mu_2 = 0.020326852444122842, sigma_sigma_2 = 0.020434940204804533
# w_U = 0.3038170701380922, sigma_w_U = 0.06362708934658697
# w_N = 0.6836325011803178, sigma_w_N = 0.012136633130724639

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.361 sec nello stato nativo e 3.521 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.0617   0.4635 -931.00845   3.6049    0.00000
# 1       0.2388   0.5602 -931.16490   3.5485    0.00098
# 2      -0.0900   0.5449 -930.76350   3.0607    0.00196
# 3       0.3130   0.3957 -930.92970   3.5186    0.00391
# 4      -0.1183   0.3449 -930.79075   3.4257    0.00391
# ...        ...      ...        ...      ...        ...
# 10877   0.6789   0.2195 -931.70790   3.6082   11.33594
# 10878  -0.1377   0.1025 -931.48960   3.6630   11.33789
# 10879   0.0638   0.0923 -931.82335   3.5485   11.33887
# 10880   0.1433   0.0161 -931.57520   3.5037   11.33887
# 10881   0.5251   0.0500 -931.24625   3.5651   11.33984
#
# [10882 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(11)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.972380240712622, con deviazione standard = 0.27074859062283757

# %%
prova = [1.9, 4.2, 0.25, 0.5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.1493990161382346, mu_1 = 4.080700269995753, sigma_1 = 0.14431375659937776
# c_2 = 0.51918620369005, mu_2 = 3.551510491262672, sigma_2 = 0.15908710079969607
# sigma_c_1 = 0.03536762647772801, sigma_mu_1 = 0.003218374822380422, sigma_sigma_1 = 0.0034853057038230577
# sigma_c_2 = 0.032861953938114946, sigma_mu_2 = 0.013779488309362948, sigma_sigma_2 = 0.014225497279063835
# w_U = 0.20703703763145656, sigma_w_U = 0.060253151802560655
# w_N = 0.7775256263582566, sigma_w_N = 0.004225646515317043

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8.103 sec nello stato nativo e 2.449 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.2494  -0.1746 -935.96330   3.6431    0.00000
# 1       0.7372  -0.0882 -935.68015   3.7177    0.00000
# 2       0.8432  -0.1568 -936.16830   3.6381    0.00097
# 3      -0.1854  -0.2331 -935.70005   3.3096    0.00195
# 4      -0.6362  -0.1924 -936.09420   3.5584    0.00390
# ...        ...      ...        ...      ...        ...
# 10547   0.5675  -0.1128 -943.47340   4.2619   10.99511
# 10548   0.8503  -0.1500 -943.50765   4.1889   10.99609
# 10549   0.6099  -0.1975 -942.81810   4.3150   10.99707
# 10550   0.9705  -0.0450 -943.46355   4.0761   10.99804
# 10551   0.2635   0.0296 -943.52945   4.2287   10.99902
#
# [10552 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.244958456416021, con deviazione standard = 0.1706853777720469

# %%
prova = [2., 5.3, 0.1, 1., 4.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.7527037824686986, mu_1 = 5.191565825921971, sigma_1 = 0.17833471925328165
# c_2 = -0.7561927786735573, mu_2 = 5.002313602086201, sigma_2 = 0.12690405662136647
# sigma_c_1 = 1.5304559704211262, sigma_mu_1 = 0.16824740812215813, sigma_sigma_1 = 0.08157443600395034
# sigma_c_2 = 3.2741248511255123, sigma_mu_2 = 0.11757553981057214, sigma_sigma_2 = 0.10027151602526678
# w_U = -0.2405459032943176, sigma_w_U = 5.349934151583825
# w_N = 1.2305104782076113, sigma_w_N = -0.14461308276907076

# %% [markdown]
# ### Suspicious data/fit

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2455   0.1483 -920.21450   5.3238    0.00000
# 1      -0.1254  -0.0314 -920.22865   5.5561    0.00098
# 2      -0.5637  -0.0992 -919.90115   5.2508    0.00195
# 3       0.1009   0.1245 -919.82465   5.4101    0.00195
# 4       0.0160   0.0669 -920.11000   5.5295    0.00391
# ...        ...      ...        ...      ...        ...
# 11708  -0.2385   0.1313 -922.74765   5.3371   12.20410
# 11709  -0.7122   0.1788 -923.20160   5.0119   12.20410
# 11710   0.1433   0.2500 -922.79320   5.4101   12.20508
# 11711  -0.1819  -0.0517 -922.95645   5.2707   12.20606
# 11712  -0.4789   0.0432 -922.69505   5.0915   12.20796
#
# [11713 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8938200497558046, con deviazione standard = 0.23524497432817396

# %%
prova = [2.2, 4., 0.25, .2, 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.593410192701232, mu_1 = 3.955777858577052, sigma_1 = 0.13139103312521455
# c_2 = 0.3370088499051843, mu_2 = 3.424568589050126, sigma_2 = 0.14645884549390809
# sigma_c_1 = 0.053617158824615235, sigma_mu_1 = 0.0033489853431143586, sigma_sigma_1 = 0.003572801103715358
# sigma_c_2 = 0.04979817875556392, sigma_mu_2 = 0.026798646997503773, sigma_sigma_2 = 0.027929399573795883
# w_U = 0.12372197559174979, sigma_w_U = 0.1502064570426326
# w_N = 0.8541357015195247, sigma_w_N = 0.003061420347022984

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 9.239 sec nello stato nativo e 1.614 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.3516   0.1788 -960.59285   3.8438    0.00000
# 1      -0.0476   0.1347 -961.21370   4.1093    0.00098
# 2       0.1433   0.1279 -961.11970   3.9467    0.00195
# 3       0.3978   0.1483 -961.19010   3.8571    0.00391
# 4      -0.1112   0.1686 -960.87810   3.7177    0.00488
# ...        ...      ...        ...      ...        ...
# 10848   0.6895  -0.1467 -960.63290   4.2105   11.31543
# 10849   0.3713  -0.1187 -961.09505   3.9915   11.31641
# 10850  -0.1377  -0.1975 -960.77585   3.9616   11.31641
# 10851   0.1327  -0.1543 -961.09435   3.9965   11.31738
# 10852  -0.3551  -0.1034 -960.66165   3.7725   11.31932
#
# [10853 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph(11)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.282179092029159, con deviazione standard = 0.3232157190566056

# %%
prova = [1.5, 4.6, 0.2, 1.5, 4., 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2118366548772597, mu_1 = 4.65979074698825, sigma_1 = 0.11417661064975632
# c_2 = 1.5049849470998, mu_2 = 4.074005050731684, sigma_2 = 0.17170355683572883
# sigma_c_1 = 0.03459798769958878, sigma_mu_1 = 0.003941556856743736, sigma_sigma_1 = 0.004020523943636937
# sigma_c_2 = 0.027684989865608772, sigma_mu_2 = 0.003743744966544046, sigma_sigma_2 = 0.003881869953318472
# w_U = 0.6477409918578759, sigma_w_U = 0.007488345981197766
# w_N = 0.34682561541433227, sigma_w_N = 0.021726832792811915

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.813 sec nello stato nativo e 6.738 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.7263  -0.1161 -950.34310   3.6381    0.00000
# 1      -0.4294  -0.1534 -949.71920   4.0761    0.00195
# 2      -0.3286  -0.2458 -949.68770   3.9766    0.00195
# 3      -0.8430  -0.1339 -949.51175   3.6879    0.00390
# 4       0.0160  -0.0195 -949.89575   3.8621    0.00390
# ...        ...      ...        ...      ...        ...
# 10546  -0.4241  -0.1161 -950.43810   3.7725   10.99414
# 10547  -1.0232  -0.1263 -950.91745   3.9965   10.99511
# 10548  -0.1642   0.0110 -950.14575   4.1557   10.99609
# 10549   0.3660   0.0567 -950.37855   3.8521   10.99804
# 10550   0.1115  -0.0144 -950.64235   4.1309   10.99804
#
# [10551 rows x 5 columns]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.297211407327883, con sigma = 0.48851651655530354
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 9.672043678641945, con sigma = 0.7723770229257788
# La differenza di energia libera DeltaG_NU = 41.562816428033706, con sigma = 3.3628817352618787

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 34.56932943243811, con sigma = 2.596150388831842

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6093077524356346, con incertezza = 0.004689585413750237,
#  q1 = 5.288028573171846, con incertezza = 0.007235277463018677
# Stimiamo i parametri del fit lineare: m2 = 0.6425555601307943, con incertezza = 0.004662630666948708,
#  q2 = 3.258266566860723, con incertezza = 0.008233622219776636
# La forza di coesistenza qui vale: fc = 4.3001014459607845, con incertezza = 0.0076565505909509295
# Il tempo medi di residenza vale: tc = 5.060132536650606, con incertezza = 0.061978468405836075
# Stimiamo un nuovo DeltaG_NU = 41.590769007924095, con incertezza = 3.3221250411801546
# ((-0.6093077524356346, 0.004689585413750237),
#  (5.288028573171846, 0.007235277463018677),
#  (0.6425555601307943, 0.004662630666948708),
#  (3.258266566860723, 0.008233622219776636),
#  (4.3001014459607845, 0.0076565505909509295),
#  (5.060132536650606, 0.061978468405836075),
#  (41.590769007924095, 3.3221250411801546))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
forces_average = remove_element(forces_average, 4)
forces_average_std = remove_element(forces_average_std, 4)
w_U = remove_element(w_U, 4)
w_N = remove_element(w_N, 4)
sigma_w_U = remove_element(sigma_w_U, 4)
sigma_w_N = remove_element(sigma_w_N, 4)
native_time = remove_element(native_time, 4)
unfolded_time = remove_element(unfolded_time, 4)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.3049883093863475, con sigma = 0.5181376736302992
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 10.482897306560947, con sigma = 0.8860087243673557
# La differenza di energia libera DeltaG_NU = 45.12875035324251, con sigma = 3.8669816409617903

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 34.67073208224948, con sigma = 2.7553611646417657

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5832676607141802, con incertezza = 0.00480232628359884,
#  q1 = 5.255024556399129, con incertezza = 0.00735311300944291
# Stimiamo i parametri del fit lineare: m2 = 0.6183034017526817, con incertezza = 0.004765076355603241,
#  q2 = 3.3063169473877796, con incertezza = 0.00846072509074441
# La forza di coesistenza qui vale: fc = 4.309081229343248, con incertezza = 0.007830642732768867
# Il tempo medi di residenza vale: tc = 5.062192637230661, con incertezza = 0.06608247519200382
# Stimiamo un nuovo DeltaG_NU = 45.17165601283467, con incertezza = 3.81876594111001
# ((-0.5832676607141802, 0.00480232628359884),
#  (5.255024556399129, 0.00735311300944291),
#  (0.6183034017526817, 0.004765076355603241),
#  (3.3063169473877796, 0.00846072509074441),
#  (4.309081229343248, 0.007830642732768867),
#  (5.062192637230661, 0.06608247519200382),
#  (45.17165601283467, 3.81876594111001))

# %%
grafici.write_on_txt()
