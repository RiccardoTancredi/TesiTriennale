# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 3hop

# %%
# directory name
dir_name = "0nM/3"
# molecule name is a number in these experimets
number = "3"

# %%
file = Txt_hop(dir_name, number)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0       0.2090   0.3928 -290.24885   4.2925   9927.82520
# 1      -0.7896   0.3928 -290.66800   4.1597   9927.82715
# 2      -0.8373   0.3623 -290.73185   4.2593   9927.82812
# 3      -0.6252   0.3013 -291.16540   3.9407   9927.82910
# 4      -0.6818   0.2945 -290.68090   3.9341   9927.83008
# ...        ...      ...        ...      ...          ...
# 81710   0.6736   0.1303 -296.97430   7.0049  10299.66309
# 81711   0.4721   0.0845 -296.92515   6.9153  10299.66406
# 81712   0.1646   0.1989 -296.95005   6.8158  10299.66602
# 81713  -0.3869   0.0921 -297.15595   6.5122  10299.66699
# 81714  -0.4364   0.0303 -297.04545   6.5702  10299.66690
#
# [81715 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.203279126962438, con deviazione standard = 0.22912602907364077

# %%
prova = [0.2, 4.8, 0.1, 2.1, 4.2, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.30276244886920956, mu_1 = 4.8171555738937535, sigma_1 = 0.08683759555624822
# c_2 = 2.2812594482238366, mu_2 = 4.151566019391979, sigma_2 = 0.16340492787676414
# sigma_c_1 = 0.07924135165255822, sigma_mu_1 = 0.026975852832157143, sigma_sigma_1 = 0.026026290911460543
# sigma_c_2 = 0.055525145435119896, sigma_mu_2 = 0.004627527921018164, sigma_sigma_2 = 0.004604083890372577
# w_U = 0.9343934045549314, sigma_w_U = 0.0018533526537400057
# w_N = 0.0659021727606019, sigma_w_N = 0.28180645564086293

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.812 sec nello stato nativo e 10.207 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.2090   0.3928 -290.24885   4.2925    0.00000
# 1      -0.7896   0.3928 -290.66800   4.1597    0.00195
# 2      -0.8373   0.3623 -290.73185   4.2593    0.00292
# 3      -0.6252   0.3013 -291.16540   3.9407    0.00390
# 4      -0.6818   0.2945 -290.68090   3.9341    0.00488
# ...        ...      ...        ...      ...        ...
# 11014  -0.1303  -0.0479 -291.74610   4.6840   11.48242
# 11015   0.0888  -0.0852 -291.55755   4.7106   11.48339
# 11016   1.0504  -0.0343 -291.38795   4.7504   11.48437
# 11017   0.7322  -0.0471 -291.59515   4.7620   11.48535
# 11018   0.0800   0.0750 -291.82060   4.7471   11.48730
#
# [11019 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7150730088495183, con deviazione standard = 0.32162256551512586

# %%
prova = [0.6, 4.2, 0.2, 1.5, 3.5, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.5604454674570142, mu_1 = 4.179158455265274, sigma_1 = 0.17490457807214188
# c_2 = 1.4835977776180431, mu_2 = 3.567845024541278, sigma_2 = 0.20461358972743768
# sigma_c_1 = 0.034290443641216306, sigma_mu_1 = 0.016772772951360322, sigma_sigma_1 = 0.017565561221714255
# sigma_c_2 = 0.03136204757858794, sigma_mu_2 = 0.006757416516266324, sigma_sigma_2 = 0.00681476017424833
# w_U = 0.7609227748049602, sigma_w_U = 0.006612223975549243
# w_N = 0.24571092820589735, sigma_w_N = 0.060228516316939

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.786 sec nello stato nativo e 7.384 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.8542   0.2224 -297.10470   3.5525    0.00000
# 1       0.8312   0.0979 -297.29830   3.8545    0.00195
# 2       0.6049   0.0216 -297.82955   3.7516    0.00195
# 3       0.5625   0.0267 -297.22685   3.6421    0.00390
# 4       0.3787  -0.0411 -297.11445   3.6354    0.00488
# ...        ...      ...        ...      ...        ...
# 10165   0.4406  -0.0928 -302.14355   3.3833   10.59375
# 10166   0.2603  -0.0776 -302.31340   3.3733   10.59375
# 10167   0.3363  -0.0920 -301.92105   3.4563   10.59472
# 10168   0.0181  -0.1360 -302.07190   3.7881   10.59570
# 10169  -0.5333  -0.0784 -301.89815   3.4297   10.59668
#
# [10170 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.3936351429069056, con deviazione standard = 0.2113690713183131

# %%
prova = [1., 3.4, 0.1, 1.6, 3.2, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.4539041664522575, mu_1 = 3.5850150999232224, sigma_1 = 0.21688390393949908
# c_2 = 1.7532500792229668, mu_2 = 3.3268143584847323, sigma_2 = 0.1725676973652486
# sigma_c_1 = 1.2147527555027557, sigma_mu_1 = 0.8225723140947813, sigma_sigma_1 = 0.3470888157248939
# sigma_c_2 = 2.1488799140543366, sigma_mu_2 = 0.08155636540362939, sigma_sigma_2 = 0.02767011055908686
# w_U = 0.7583912358762878, sigma_w_U = 0.303093636648876
# w_N = 0.24676378631894008, sigma_w_N = 2.118409723966275

# %% [markdown]
# ### Suspicious data/fit

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.689 sec nello stato nativo e 7.787 sec nello stato unfolded

# %%
data_frame.loc[data_frame['time(sec)']<15]
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2594  -0.1386 -300.13595   3.5624    0.00000
# 1       0.3928  -0.1157 -300.35690   3.5127    0.00000
# 2      -0.0950  -0.2123 -300.46345   3.4629    0.00098
# 3      -0.5192  -0.1666 -300.30125   3.5226    0.00196
# 4      -0.6305  -0.1360 -300.21435   3.6471    0.00391
# ...        ...      ...        ...      ...        ...
# 11471  -0.3283  -0.1666 -302.56465   3.8279   11.99219
# 11472   0.2391   0.0724 -302.88250   3.4231   11.99610
# 11473   0.5360   0.2021 -302.92210   3.6471   11.99610
# 11474   0.5042   0.2275 -302.88130   3.6421   11.99707
# 11475   0.3080   0.0724 -302.83745   3.5176   11.99903
#
# [11476 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 8.04433703591903, con deviazione standard = 0.26092387896867164

# %%
prova = [0.5, 8.5, 0.1, 1.7, 8., 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.3738483589198415, mu_1 = 8.465472114209907, sigma_1 = 0.15666321268322697
# c_2 = 1.698113562374373, mu_2 = 7.966333380740307, sigma_2 = 0.20128321071100685
# sigma_c_1 = 0.034282516707290545, sigma_mu_1 = 0.03404948462133994, sigma_sigma_1 = 0.03267924366778525
# sigma_c_2 = 0.03262074040784325, sigma_mu_2 = 0.008598579081719987, sigma_sigma_2 = 0.006404596433807294
# w_U = 0.8567699308348165, sigma_w_U = 0.0036617956343298137
# w_N = 0.1468089190892492, sigma_w_N = 0.11898686047759924

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.448 sec nello stato nativo e 5.178 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2176   0.1201 -238.97770   7.6620    0.00000
# 1      0.0214   0.1379 -239.19670   7.6122    0.00098
# 2     -0.1253   0.1455 -238.92280   7.7847    0.00196
# 3     -0.4293   0.0743 -239.41355   7.9507    0.00293
# 4     -0.2738  -0.0206 -239.20865   7.7449    0.00391
# ...       ...      ...        ...      ...        ...
# 6621  -0.3798   0.2506 -230.44730   8.0568    6.89844
# 6622  -0.2702   0.2116 -230.55050   8.1597    6.89942
# 6623   0.2229   0.1684 -230.62155   8.1746    6.90137
# 6624   0.6153   0.1531 -230.37670   8.0104    6.90137
# 6625   0.4350   0.2828 -230.47470   8.0502    6.90328
#
# [6626 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.774369136990656, con deviazione standard = 0.2729054739628888

# %%
prova = [0.5, 8.2, 0.1, 2., 7.6, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.7369511305576322, mu_1 = 8.145519612255503, sigma_1 = 0.1376958817900687
# c_2 = 1.7413169367293855, mu_2 = 7.645331820405225, sigma_2 = 0.17062931068720016
# sigma_c_1 = 0.04559424052630222, sigma_mu_1 = 0.013618631792899872, sigma_sigma_1 = 0.014360787927264893
# sigma_c_2 = 0.03838201724065232, sigma_mu_2 = 0.0061201239455257244, sigma_sigma_2 = 0.0055913790765814856
# w_U = 0.7447686625321024, sigma_w_U = 0.006985897058548383
# w_N = 0.2543604444638272, sigma_w_N = 0.06026198379866269

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.7830000000000001 sec nello stato nativo e 4.4510000000000005 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0515  -0.0850 -239.21190   7.4662    0.00000
# 1     -0.1642  -0.1494 -239.24720   7.4230    0.00195
# 2      0.3343  -0.1799 -238.98965   7.6719    0.00195
# 3      0.2918   0.0269 -239.17840   7.6188    0.00391
# 4     -0.0210   0.0565 -239.23595   7.5276    0.00391
# ...       ...      ...        ...      ...        ...
# 6229   0.1115  -0.0070 -244.91740   8.2841    6.49902
# 6230   0.3449  -0.0681 -245.01000   8.2493    6.49902
# 6231  -0.1801  -0.1723 -245.06805   8.2095    6.50000
# 6232  -0.9967  -0.0681 -245.08065   8.1647    6.50195
# 6233  -0.3657  -0.0647 -245.12030   8.1697    6.50290
#
# [6234 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.185939393497555, con deviazione standard = 0.28603977315227225

# %%
prova = [0.8, 7.7, 0.1, 1., 6.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.4323901206712593, mu_1 = 7.249048111232376, sigma_1 = 0.24595047144634416
# c_2 = 0.3308813102439445, mu_2 = 6.7494584768479955, sigma_2 = 0.13955194753430805
# sigma_c_1 = 0.034412058579670626, sigma_mu_1 = 0.013713327468190801, sigma_sigma_1 = 0.013998472391772723
# sigma_c_2 = 0.07725906511209288, sigma_mu_2 = 0.0369491791504274, sigma_sigma_2 = 0.026445118818767748
# w_U = 0.11574388956914436, sigma_w_U = 0.22252401327165738
# w_N = 0.8830776851219824, sigma_w_N = 0.004310610526228207

# %% [markdown]
# ### Suspicious data/fit

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.319 sec nello stato nativo e 1.54 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5248  -0.0274 -265.42265   7.0000    0.00000
# 1     -0.5354  -0.0655 -265.17375   7.1343    0.00000
# 2     -0.6838   0.1353 -265.31295   7.0448    0.00196
# 3     -0.4293   0.1353 -264.93770   6.6963    0.00196
# 4     -0.0475   0.0947 -265.38470   6.8954    0.00293
# ...       ...      ...        ...      ...        ...
# 6854  -0.5194   0.0489 -273.97320   7.3185    7.15821
# 6855  -0.4770  -0.0426 -275.15890   7.2986    7.15821
# 6856   0.3820   0.3031 -278.01325   7.3384    7.16016
# 6857  -0.0422  -0.1977 -274.34590   7.7316    7.16016
# 6858   0.0868  -0.2138 -274.41185   7.3003    7.16110
#
# [6859 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 6.394641945866866, con deviazione standard = 0.19764638372687285

# %%
prova = [2., 6.4, 0.1, .5, 6.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.420620815938838, mu_1 = 6.418787312609047, sigma_1 = 0.15201681227941502
# c_2 = 0.18377158931833323, mu_2 = 5.9626016051531465, sigma_2 = 0.1310754704827195
# sigma_c_1 = 0.04770530371305704, sigma_mu_1 = 0.004603094188664174, sigma_sigma_1 = 0.005121145347677721
# sigma_c_2 = 0.04961723019740821, sigma_mu_2 = 0.057101831773302573, sigma_sigma_2 = 0.04867533385363008
# w_U = 0.0603795303596784, sigma_w_U = 0.30224220216697023
# w_N = 0.9223766901967537, sigma_w_N = 0.0015653574452149635

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.032 sec nello stato nativo e 0.803 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.4770  -0.0070 -295.91375   6.1189    0.00000
# 1     -0.2596  -0.1155 -296.17685   6.3114    0.00098
# 2     -0.3020  -0.1257 -295.81840   6.1388    0.00293
# 3     -0.4187  -0.1189 -295.42965   5.9298    0.00391
# 4     -0.7475  -0.0070 -295.43560   5.5216    0.00391
# ...       ...      ...        ...      ...        ...
# 6830  -0.8376  -0.2257 -298.47030   6.6864    7.14844
# 6831  -0.3180  -0.1087 -298.57810   6.7162    7.15039
# 6832  -0.2013  -0.0731 -298.43145   6.3180    7.15039
# 6833  -0.1960  -0.1011 -298.37270   6.4723    7.15234
# 6834  -0.0405  -0.2376 -298.87030   6.7030    7.15230
#
# [6835 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.017673580136763, con deviazione standard = 0.2696813126899127

# %%
prova = [1., 7.2, 0.1, 1., 6.75, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.6170639038651036, mu_1 = 7.165852623648914, sigma_1 = 0.157171100241815
# c_2 = 0.7031733674952424, mu_2 = 6.748084255209095, sigma_2 = 0.20293583070155788
# sigma_c_1 = 0.08146074691980831, sigma_mu_1 = 0.016929212018326964, sigma_sigma_1 = 0.01347629370355148
# sigma_c_2 = 0.08107676164491218, sigma_mu_2 = 0.05178591549021116, sigma_sigma_2 = 0.027532253632357524
# w_U = 0.3576935272848718, sigma_w_U = 0.08522502669451211
# w_N = 0.6370738961938569, sigma_w_N = 0.02366101543118492

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.247 sec nello stato nativo e 2.479 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.0581   0.0184 -291.95625   6.4375    0.00000
# 1     -0.8040  -0.0714 -291.79630   6.6034    0.00098
# 2     -0.2808  -0.0986 -291.78410   6.8954    0.00195
# 3     -0.1324  -0.2918 -291.91825   6.9153    0.00390
# 4     -0.1483  -0.2994 -291.91925   7.1543    0.00390
# ...       ...      ...        ...      ...        ...
# 6721  -0.4505   0.0158 -294.19705   7.2190    6.99609
# 6722  -0.1536   0.1684 -294.23625   7.0398    6.99609
# 6723   0.4686   0.2167 -294.20660   7.1211    6.99707
# 6724   0.1964   0.1150 -294.15905   6.8058    6.99805
# 6725  -0.1324   0.1455 -293.36610   6.8954    6.99902
#
# [6726 rows x 5 columns]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 11.121093771382874, con sigma = 8.752784553253331
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = -0.4848520038593222, con sigma = 0.32855472379801837
# La differenza di energia libera DeltaG_NU = -5.392084600162414, con sigma = 2.1584682650476843

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 142.5289115301074, con sigma = 59.83825108676228

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# forces_average = remove_element(forces_average, 4)
# forces_average_std = remove_element(forces_average_std, 4)
# w_U = remove_element(w_U, 4)
# w_N = remove_element(w_N, 4)
# sigma_w_U = remove_element(sigma_w_U, 4)
# sigma_w_N = remove_element(sigma_w_N, 4)

# %% [markdown]
# ## Sono due molecole diverse?

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:3], w_N[:3], forces_average[:3], sigma_w_U[:3], sigma_w_N[:3])
# Out:
# La forza di coesistenza vale f_c = 3.3666282389509274, con sigma = 15.253824285856965
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 9.175958993066596, con sigma = 27.265893250286318
# La differenza di energia libera DeltaG_NU = 30.892042665513717, con sigma = 105.66461049709754

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 23.083992144710454, con sigma = -53.72732494897403

# %%
grafici.residence_time(native_time[:3], unfolded_time[:3], forces_average[:3], forces_average_std[:3])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.4956695171342121, con incertezza = 0.013301026895546434,
#  q1 = 4.381204643884934, con incertezza = 0.011475283397035822
# Stimiamo i parametri del fit lineare: m2 = 1.8871270492193848, con incertezza = 0.050660398208514035,
#  q2 = 0.1003323146303364, con incertezza = 0.10653657330069465
# La forza di coesistenza qui vale: fc = 3.4906972668317664, con incertezza = 0.035921669831684135
# Il tempo medi di residenza vale: tc = 6.028961822147295, con incertezza = 0.3608227487225798
# Stimiamo un nuovo DeltaG_NU = 32.03049497765793, con incertezza = 95.17754980547416
# ((-0.4956695171342121, 0.013301026895546434),
#  (4.381204643884934, 0.011475283397035822),
#  (1.8871270492193848, 0.050660398208514035),
#  (0.1003323146303364, 0.10653657330069465),
#  (3.4906972668317664, 0.035921669831684135),
#  (6.028961822147295, 0.3608227487225798),
#  (32.03049497765793, 95.17754980547416))

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[3:], w_N[3:], forces_average[3:], sigma_w_U[3:], sigma_w_N[3:])
# Out:
# La forza di coesistenza vale f_c = 7.29302684798707, con sigma = 1.9623387091280917
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 7.410392865733424, con sigma = 1.3921723382311257
# La differenza di energia libera DeltaG_NU = 54.044194123925706, con sigma = 10.410312267237815

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 78.28267354773641, con sigma = 12.593323344666901

# %%
grafici.residence_time(native_time[3:], unfolded_time[3:], forces_average[3:], forces_average_std[3:])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.0695952247882643, con incertezza = 0.013908724967645423,
#  q1 = 8.53362914857675, con incertezza = 0.012240938946406925
# Stimiamo i parametri del fit lineare: m2 = 0.9987594038187653, con incertezza = 0.012892620408507086,
#  q2 = 6.423189854546343, con incertezza = 0.017842097966480633
# La forza di coesistenza qui vale: fc = 7.442270945355734, con incertezza = 0.01460501959726787
# Il tempo medi di residenza vale: tc = 2.7741570334298653, con incertezza = 0.03893379497677247
# Stimiamo un nuovo DeltaG_NU = 55.150151518319284, con incertezza = 10.361489001376817
# ((-1.0695952247882643, 0.013908724967645423),
#  (8.53362914857675, 0.012240938946406925),
#  (0.9987594038187653, 0.012892620408507086),
#  (6.423189854546343, 0.017842097966480633),
#  (7.442270945355734, 0.01460501959726787),
#  (2.7741570334298653, 0.03893379497677247),
#  (55.150151518319284, 10.361489001376817))

# %%
grafici.write_on_txt()

# %% [markdown]
# ## Il rapporto tra le due $\Delta G$ qui è di 2.5, come dicevano i prof

# %% [markdown]
# ## Prova a trovare $\Delta G_0$ per le due e calcolare gli integrali per singola molecola e doppia molecola, usando qui $f_c' = 2f_c$, con $f_c'$ forza di coesistenza nel caso di 2 molecole
