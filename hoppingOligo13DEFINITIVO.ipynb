# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 13hop - Oligo

# %%
# directory name
dir_name = "100pM/13"
# molecule name is a number in these experimets
number = "13"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force    time(sec)
# 0        0.5114   0.0055 -896.40600   4.4681  10954.41211
# 1       -0.0400  -0.0708 -895.99490   4.3735  10954.41211
# 2        0.1508  -0.1318 -896.36040   3.8260  10954.41406
# 3       -0.3052  -0.2208 -895.89575   3.9704  10954.41406
# 4       -0.1620  -0.1801 -896.03835   4.1545  10954.41602
# ...         ...      ...        ...      ...          ...
# 409436  -0.1390   0.1428 -983.32750   2.1934  11653.93066
# 409437  -0.1302  -0.0403 -982.98575   2.2631  11653.93262
# 409438  -0.2893   0.0843 -983.75690   2.1884  11653.93262
# 409439  -0.5915  -0.2157 -982.40500   2.2930  11653.93359
# 409440  -0.2734  -0.2386 -982.50940   2.1785  11653.93550
#
# [409441 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 4.3755221725303395, con deviazione standard = 0.3574187668428891

# %%
prova = [2., 4.8, 0.1, 1.5, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.6466458122647536, mu_1 = 4.797061874045061, sigma_1 = 0.08555499000834986
# c_2 = 1.4862784075204398, mu_2 = 4.122927045649008, sigma_2 = 0.1711665005672351
# sigma_c_1 = 0.06494085755945549, sigma_mu_1 = 0.0040080488478904065, sigma_sigma_1 = 0.003865383392454255
# sigma_c_2 = 0.04403539068324435, sigma_mu_2 = 0.005897608866719973, sigma_sigma_2 = 0.00587439494239497
# w_U = 0.6376889248939156, sigma_w_U = 0.012090678435125627
# w_N = 0.3531306981898332, sigma_w_N = 0.02898285558486549

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.662 sec nello stato nativo e 6.4 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.5114   0.0055 -896.40600   4.4681    0.00000
# 1      -0.0400  -0.0708 -895.99490   4.3735    0.00000
# 2       0.1508  -0.1318 -896.36040   3.8260    0.00195
# 3      -0.3052  -0.2208 -895.89575   3.9704    0.00195
# 4      -0.1620  -0.1801 -896.03835   4.1545    0.00391
# ...        ...      ...        ...      ...        ...
# 10057   0.3205  -0.0199 -895.88700   4.8613   10.49609
# 10058   0.4549  -0.0606 -896.08475   4.8746   10.49707
# 10059   0.6599  -0.1216 -895.85755   4.9144   10.49707
# 10060  -0.3370  -0.2606 -895.64325   4.7950   10.49805
# 10061  -0.7470  -0.2471 -895.89800   4.8348   10.49902
#
# [10062 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 4.085449624060161, con deviazione standard = 0.34648825464275207

# %%
prova = [2., 4.5, 0.1, 1., 3.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.8494450744267183, mu_1 = 4.4198003012178715, sigma_1 = 0.0955695006759579
# c_2 = 1.2430096332460003, mu_2 = 3.7968340686388102, sigma_2 = 0.17583419091486194
# sigma_c_1 = 0.05452102563221897, sigma_mu_1 = 0.0033440609392612606, sigma_sigma_1 = 0.0033013465948480117
# sigma_c_2 = 0.039148282001194176, sigma_mu_2 = 0.006445297583011883, sigma_sigma_2 = 0.006524620780594889
# w_U = 0.547857682422785, sigma_w_U = 0.0161948748258505
# w_N = 0.44304790686190837, sigma_w_N = 0.018718555276635112

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.625 sec nello stato nativo e 5.4830000000000005 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.1885  -0.3962 -902.92505   4.5179    0.00000
# 1      -0.2097  -0.3386 -902.87030   4.4233    0.00098
# 2      -0.1885  -0.1827 -902.78235   4.3835    0.00195
# 3      -0.6763  -0.1454 -903.25505   4.4631    0.00391
# 4       0.1508   0.0106 -902.92560   4.4631    0.00391
# ...        ...      ...        ...      ...        ...
# 10103   0.3364  -0.0403 -906.56365   4.4233   10.49512
# 10104   0.2569  -0.1827 -906.08095   4.3238   10.49512
# 10105   0.3629  -0.0911 -906.12765   4.5229   10.49609
# 10106  -0.1320  -0.1691 -906.30150   4.4233   10.49707
# 10107  -0.4077  -0.1555 -906.49645   4.3835   10.49805
#
# [10108 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 2.941000725213604, con deviazione standard = 0.1629776939332238

# %% [markdown]
# # No Hopping Data

# %%
# prova = [1.8, 4.9, 0.1, 1., 4.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2681  -0.2793 -926.71120   2.8305    0.00000
# 1       0.8667  -0.2208 -926.94705   2.8803    0.00098
# 2       0.9515  -0.2767 -926.60730   2.9500    0.00098
# 3       0.5697  -0.2996 -926.79680   2.8455    0.00195
# 4       0.2993  -0.1827 -926.75170   2.6712    0.00391
# ...        ...      ...        ...      ...        ...
# 10061   0.1933  -0.0327 -928.96025   2.8305   10.49609
# 10062  -0.0294  -0.1089 -929.04040   2.7708   10.49707
# 10063  -0.0400  -0.0377 -928.76800   2.9599   10.49707
# 10064  -0.0082  -0.0250 -928.95295   2.8305   10.49805
# 10065  -0.2415  -0.0606 -929.04765   2.7011   10.49902
#
# [10066 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 1.4522175985698806, con deviazione standard = 0.23585236181866068

# %% [markdown]
# # No Hopping Data

# %%
# prova = [.4, 4.1, 0.1, 2., 3.3, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.1532  -0.2505 -962.06805   1.3970    0.00000
# 1       0.2569  -0.2166 -961.82995   1.1846    0.00196
# 2      -0.3370  -0.2539 -961.51615   1.0386    0.00293
# 3      -0.0400  -0.1572 -961.20985   1.1880    0.00293
# 4      -0.2097  -0.4674 -961.38595   1.4567    0.00489
# ...        ...      ...        ...      ...        ...
# 10064  -0.3087  -0.3861 -962.03275   1.5629   10.49512
# 10065  -0.2097  -0.2640 -962.32170   1.7952   10.49512
# 10066   0.0448  -0.1623 -962.22600   1.0784   10.49805
# 10067   0.2357  -0.0327 -962.19055   1.1382   10.49805
# 10068  -0.0613  -0.0301 -961.69490   1.5613   10.49903
#
# [10069 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 3.531000248311465, con deviazione standard = 0.15759279646388025

# %% [markdown]
# # No Hopping Data

# %%
# prova = [0.5, 3.9, 0.1, 1.8, 3.4, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.6033  -0.1861 -920.75185   3.7597    0.00000
# 1       0.7447  -0.0708 -920.67410   3.7265    0.00098
# 2       0.6387  -0.0810 -921.74105   3.4876    0.00195
# 3      -0.0506  -0.1115 -921.39925   3.4179    0.00391
# 4      -0.2840  -0.1064 -920.66055   3.6219    0.00391
# ...        ...      ...        ...      ...        ...
# 10063   0.0307  -0.1013 -921.54690   3.3615   10.49512
# 10064   0.2357  -0.1115 -921.51215   3.4079   10.49512
# 10065   0.4902  -0.0454 -921.67320   3.2984   10.49609
# 10066   0.0448  -0.1369 -921.20895   3.7862   10.49805
# 10067  -0.4572  -0.0199 -921.37405   3.6933   10.49902
#
# [10068 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 3.760788868976505, con deviazione standard = 0.1576618530651376

# %% [markdown]
# # No Hopping Data

# %%
# prova = [.7, 3.3, 0.1, 1.5, 2.8, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.3682  -0.2462 -917.97720   4.1048    0.00000
# 1       0.5114  -0.2369 -918.26245   3.9057    0.00097
# 2       0.8578  -0.1928 -918.33410   3.9123    0.00293
# 3       0.9073  -0.2166 -918.24540   3.6336    0.00390
# 4       0.3629  -0.3250 -918.15705   3.6170    0.00390
# ...        ...      ...        ...      ...        ...
# 10039   0.2198  -0.2462 -917.08130   3.8808   10.49511
# 10040  -0.0666  -0.2310 -916.87865   4.0600   10.49511
# 10041   0.0554  -0.1242 -917.02855   3.7016   10.49609
# 10042   0.5397  -0.2437 -917.40410   3.7663   10.49707
# 10043   0.3629  -0.2742 -917.16725   4.0052   10.49902
#
# [10044 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# Out:
# f media vale = 4.715270191153418, con deviazione standard = 0.4464918655194517

# %%
prova = [1.2, 5., 0.1, 0.8, 4.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2308197200852435, mu_1 = 4.998369315604422, sigma_1 = 0.19711279972884804
# c_2 = 0.839964758268611, mu_2 = 4.207252946453102, sigma_2 = 0.17949509887242018
# sigma_c_1 = 0.023862543752348746, sigma_mu_1 = 0.004490671823174316, sigma_sigma_1 = 0.004680157002826666
# sigma_c_2 = 0.02471821930985686, sigma_mu_2 = 0.0062784669339241116, sigma_sigma_2 = 0.006413588996166661
# w_U = 0.37792323536894135, sigma_w_U = 0.02093579631365555
# w_N = 0.6081338903045188, sigma_w_N = 0.008591542569019166

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.674 sec nello stato nativo e 4.155 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1031   0.3080 -920.88050   4.2392    0.00000
# 1      -0.3158   0.2546 -920.99290   4.3039    0.00000
# 2       0.5326   0.4072 -921.40185   3.9853    0.00097
# 3       0.8826   0.5089 -921.37025   4.0550    0.00195
# 4       0.0130   0.3360 -921.30935   4.0351    0.00390
# ...        ...      ...        ...      ...        ...
# 10824  -0.1090   0.0131 -913.80550   5.2147   11.27148
# 10825   0.2198   0.0385 -913.67785   5.1202   11.27343
# 10826  -0.1090   0.0589 -913.30650   5.1052   11.27441
# 10827  -0.1355   0.0741 -913.58580   5.0156   11.27441
# 10828   0.1190   0.2063 -913.34775   4.8962   11.27530
#
# [10829 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph()
# Out:
# f media vale = 4.1895174680691865, con deviazione standard = 0.33071407223469235

# %%
prova = [2., 4.5, 0.1, .5, 3.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.401651187758956, mu_1 = 4.429550951018788, sigma_1 = 0.09793746749936502
# c_2 = 0.8369905175603437, mu_2 = 3.8210353696251533, sigma_2 = 0.19175032970481867
# sigma_c_1 = 0.06529541474377126, sigma_mu_1 = 0.0032148884708019464, sigma_sigma_1 = 0.0032137355570515773
# sigma_c_2 = 0.0456621638769768, sigma_mu_2 = 0.012254537889783592, sigma_sigma_2 = 0.012685178643929845
# w_U = 0.4022968123120659, sigma_w_U = 0.037615431817452034
# w_N = 0.5895881351790395, sigma_w_N = 0.012774835314838945

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.42 sec nello stato nativo e 4.228 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2663   0.0750 -935.52760   4.4101    0.00000
# 1       0.0766  -0.0555 -935.71330   4.5129    0.00098
# 2       0.8084   0.2038 -935.27285   4.7419    0.00293
# 3       0.9144   0.3055 -935.14165   4.5627    0.00488
# 4       0.3205   0.3767 -935.35710   4.5478    0.00488
# ...        ...      ...        ...      ...        ...
# 10643   0.0024   0.3157 -934.99355   3.8791   11.10742
# 10644   0.4054   0.2004 -935.01450   3.9521   11.10937
# 10645   0.4266   0.2648 -935.02695   3.7016   11.10937
# 10646   0.3152   0.2445 -934.91745   4.0102   11.11035
# 10647   1.0205   0.3207 -934.73815   4.0002   11.11227
#
# [10648 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph()
# Out:
# f media vale = 4.273714518461424, con deviazione standard = 0.3529007561046434

# %%
prova = [1.5, 4.7, 0.1, 1.2, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.6611345422352046, mu_1 = 4.680155544763864, sigma_1 = 0.08911785123310682
# c_2 = 1.4280192745342009, mu_2 = 4.020465051422444, sigma_2 = 0.17471488148576678
# sigma_c_1 = 0.053581553783864165, sigma_mu_1 = 0.003408843582635552, sigma_sigma_1 = 0.0033113468342747913
# sigma_c_2 = 0.036907942542365006, sigma_mu_2 = 0.00524958425392473, sigma_sigma_2 = 0.005249758856342991
# w_U = 0.6253942752284363, sigma_w_U = 0.011093202526911181
# w_N = 0.371073080707643, sigma_w_N = 0.02327953258158387

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.946 sec nello stato nativo e 6.4270000000000005 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.0895   0.2106 -929.83500   4.7021    0.00000
# 1       0.4124   0.1631 -929.63380   4.6622    0.00097
# 2       0.2198   0.0334 -929.54470   4.6573    0.00097
# 3       0.4160   0.0233 -929.57685   4.5776    0.00293
# 4      -0.0754   0.1190 -928.99955   4.7618    0.00390
# ...        ...      ...        ...      ...        ...
# 10368   0.7801   0.3326 -929.63170   4.2375   10.83984
# 10369   1.0682   0.2445 -929.94480   4.0749   10.84082
# 10370   0.5432   0.2572 -929.93050   3.7862   10.84277
# 10371  -0.1461   0.2038 -929.85820   4.0699   10.84277
# 10372  -0.0029   0.1021 -929.80445   3.8907   10.84466
#
# [10373 rows x 5 columns]

# %% [markdown]
# # File 10

# %%
grafici = Graph_hop(dir_name, number, 10)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 3.8349338415841543, con deviazione standard = 0.24274110440140026

# %%
prova = [3., 4., 0.1, 0.2, 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 3.4930956068165258, mu_1 = 3.92516275774972, sigma_1 = 0.09334172555863707
# c_2 = 0.37309223786859225, mu_2 = 3.3631081622219856, sigma_2 = 0.17927053439489368
# sigma_c_1 = 0.06074074508571804, sigma_mu_1 = 0.001966424846759467, sigma_sigma_1 = 0.0019781433073836055
# sigma_c_2 = 0.04309496197921991, sigma_mu_2 = 0.024325941689110696, sigma_sigma_2 = 0.025319554778725807
# w_U = 0.16765444062230594, sigma_w_U = 0.11064831346397008
# w_N = 0.8172900880635214, sigma_w_N = 0.0034139433185260645

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8.343 sec nello stato nativo e 1.7570000000000001 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.6122   0.3385 -941.60370   4.0948    0.00000
# 1       0.2993   0.3614 -941.41535   4.0301    0.00097
# 2      -0.2734   0.3360 -941.32270   3.9455    0.00195
# 3      -0.3158   0.2292 -941.38585   4.0948    0.00488
# 4      -0.5385   0.2674 -941.54885   3.9505    0.00488
# ...        ...      ...        ...      ...        ...
# 10095   0.6599   0.0106 -941.44590   3.8459   10.49414
# 10096   0.0872   0.0716 -941.55775   3.9654   10.49609
# 10097  -0.0613   0.1224 -946.36775   3.8061   10.49707
# 10098  -0.3653   0.0377 -941.61485   3.8327   10.49707
# 10099  -0.3158   0.0682 -941.61705   3.8260   10.49804
#
# [10100 rows x 5 columns]

# %% [markdown]
# # File 11

# %%
grafici = Graph_hop(dir_name, number, 11)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 3.5547151765290885, con deviazione standard = 0.21128361786858252

# %%
prova = [5, 3.7, 0.1, .2, 3.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 3.508848347685331, mu_1 = 3.6077337393802136, sigma_1 = 0.09931804520652195
# c_2 = 0.28087356291842625, mu_2 = 3.0652507544578778, sigma_2 = 0.1458201002708931
# sigma_c_1 = 0.08711057863731438, sigma_mu_1 = 0.002914048932537247, sigma_sigma_1 = 0.0029340583368868585
# sigma_c_2 = 0.07083386764843413, sigma_mu_2 = 0.04293301735786259, sigma_sigma_2 = 0.043780716208710393
# w_U = 0.10266400208820993, sigma_w_U = 0.25637484374600744
# w_N = 0.8735397974553465, sigma_w_N = 0.0029657498455240936

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8.879 sec nello stato nativo e 1.176 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.3016   0.2953 -948.47370   3.6667    0.00000
# 1      -0.0542   0.2072 -948.35725   3.5606    0.00000
# 2       0.6811   0.1123 -948.12710   3.5075    0.00098
# 3       0.3205   0.2953 -948.75315   3.4876    0.00195
# 4       0.1296   0.1767 -948.08645   3.5406    0.00391
# ...        ...      ...        ...      ...        ...
# 10050  -0.4148  -0.0369 -951.57120   3.5340   10.49414
# 10051   0.0377  -0.1183 -951.42625   4.0384   10.49609
# 10052  -0.2451   0.0648 -951.52405   3.5805   10.49707
# 10053   0.0342   0.1809 -951.20775   3.5871   10.49707
# 10054   0.2410   0.1351 -951.45825   3.5523   10.49902
#
# [10055 rows x 5 columns]

# %% [markdown]
# # File 12

# %%
grafici = Graph_hop(dir_name, number, 12)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 2.323700346843744, con deviazione standard = 0.3182313967975335

# %%
prova = [1., 2.7, 0.1, 1.5, 2.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.0302767006595093, mu_1 = 2.674812356443696, sigma_1 = 0.13656813924703762
# c_2 = 1.3460368186174188, mu_2 = 2.1196275753455103, sigma_2 = 0.19143938701280547
# sigma_c_1 = 0.04025370367464218, sigma_mu_1 = 0.007524420660761358, sigma_sigma_1 = 0.00781769110959898
# sigma_c_2 = 0.034338410172953686, sigma_mu_2 = 0.0066658931638005426, sigma_sigma_2 = 0.0071767784158871225
# w_U = 0.6459191620238708, sigma_w_U = 0.011164997248079506
# w_N = 0.35269004773589063, sigma_w_N = 0.031283704081093

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.8240000000000003 sec nello stato nativo e 6.267 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.4425   0.3080 -977.02835   2.6016    0.00000
# 1       0.8649   0.4580 -977.22820   2.7111    0.00000
# 2      -0.1355   0.5343 -977.17180   2.6912    0.00098
# 3      -0.5491   0.3767 -978.14725   2.7907    0.00293
# 4       0.2357   0.6818 -976.62675   2.6912    0.00391
# ...        ...      ...        ...      ...        ...
# 10086   1.1477   0.6742 -976.65460   2.1934   10.49512
# 10087   0.7518   0.5157 -976.70325   2.0806   10.49610
# 10088   0.3912   0.4784 -976.85990   1.8682   10.49707
# 10089   0.3842   0.5292 -976.20295   2.0341   10.49805
# 10090  -0.5279   0.3360 -976.58715   2.1138   10.49903
#
# [10091 rows x 5 columns]

# %% [markdown]
# # File 13

# %%
grafici = Graph_hop(dir_name, number, 13)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 1.6338144620284647, con deviazione standard = 0.23357534613095127

# %%
prova = [2.5, 1.7, 0.1, 0.5, 1.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.4520178414030425, mu_1 = 1.709141588957546, sigma_1 = 0.13155011106688766
# c_2 = 0.475620059226909, mu_2 = 1.2434449786534576, sigma_2 = 0.14103229721278074
# sigma_c_1 = 0.05311443665208019, sigma_mu_1 = 0.003972341861195625, sigma_sigma_1 = 0.0042565752470447695
# sigma_c_2 = 0.05093114724799615, sigma_mu_2 = 0.021048311998981488, sigma_sigma_2 = 0.022185876840410224
# w_U = 0.1681390838939239, sigma_w_U = 0.1074288870521257
# w_N = 0.8085460860402752, sigma_w_N = 0.004545873856891736

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8.007 sec nello stato nativo e 2.04 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.2357   0.5547 -988.92990   1.8350    0.00000
# 1       0.7235   0.6208 -989.08325   1.6359    0.00195
# 2       1.0063   0.4953 -988.57690   1.8018    0.00293
# 3       0.9886   0.4962 -988.39990   1.9047    0.00488
# 4       0.5538   0.6869 -988.92060   1.9047    0.00586
# ...        ...      ...        ...      ...        ...
# 10042  -1.3975   0.4072 -991.73870   1.9744   10.49609
# 10043  -0.7771   0.4301 -991.98440   1.7703   10.49707
# 10044   0.0236   0.5292 -992.08175   1.8350   10.49707
# 10045   0.5008   0.6462 -991.91205   1.6061   10.49902
# 10046   0.2145   0.9081 -991.71450   1.6608   10.49902
#
# [10047 rows x 5 columns]

# %% [markdown]
# # File 14

# %%
grafici = Graph_hop(dir_name, number, 14)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 1.9413940563603866, con deviazione standard = 0.2840519718092001

# %%
prova = [1.5, 2.2, 0.1, .5, 1.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.896972411557606, mu_1 = 2.101770879225394, sigma_1 = 0.13337197508864862
# c_2 = 0.8045535548768222, mu_2 = 1.619753295404972, sigma_2 = 0.17110444400929414
# sigma_c_1 = 0.039020250191230225, sigma_mu_1 = 0.0043777301661032135, sigma_sigma_1 = 0.0044339256838832304
# sigma_c_2 = 0.03462260970548433, sigma_mu_2 = 0.011581452300817177, sigma_sigma_2 = 0.011996609232634611
# w_U = 0.34506918781428164, sigma_w_U = 0.03520047290712324
# w_N = 0.6341843661281839, sigma_w_N = 0.009125882758271114

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.5120000000000005 sec nello stato nativo e 3.5660000000000003 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.9215   0.6208 -986.61505   1.6691    0.00000
# 1       0.9498   0.5835 -986.80895   1.7554    0.00097
# 2       0.5185   0.5733 -986.97720   1.3970    0.00293
# 3       0.2145   0.6614 -986.98005   1.3373    0.00293
# 4       1.2644   0.5699 -986.33000   1.5961    0.00390
# ...        ...      ...        ...      ...        ...
# 10073  -0.9468   0.2979 -986.49700   1.4418   10.49511
# 10074  -0.2893   0.5064 -987.38980   1.6708   10.49511
# 10075  -0.9521   0.2496 -987.24140   1.4418   10.49609
# 10076  -0.1673   0.3258 -986.74635   1.5165   10.49707
# 10077   0.3099   0.4326 -987.18310   1.5961   10.49804
#
# [10078 rows x 5 columns]

# %% [markdown]
# # File 15

# %%
grafici = Graph_hop(dir_name, number, 15)
data_frame = grafici.do_graph(10.5)
# Out:
# f media vale = 1.9886857171196315, con deviazione standard = 0.2733241206941022

# %%
prova = [1.5, 2.2, 0.1, .5, 1.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.8671372732266849, mu_1 = 2.142317685519972, sigma_1 = 0.13430977650145673
# c_2 = 0.7928415679240283, mu_2 = 1.6925778519404204, sigma_2 = 0.1766627179756024
# sigma_c_1 = 0.04391107182546661, sigma_mu_1 = 0.005867151606229893, sigma_sigma_1 = 0.0055007233937767385
# sigma_c_2 = 0.03702832491422769, sigma_mu_2 = 0.016225981875809144, sigma_sigma_2 = 0.015420099486731488
# w_U = 0.3510922586910495, sigma_w_U = 0.0401806680307847
# w_N = 0.6285991788392926, sigma_w_N = 0.010948382174394408

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.452 sec nello stato nativo e 3.63 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       1.0205   0.6920 -990.11155   1.8151    0.00000
# 1      -0.2309   0.4886 -989.35460   1.7355    0.00098
# 2      -0.2168  -0.1250 -984.83580   1.7156    0.00195
# 3       0.0077   0.3716 -987.80980   1.9097    0.00391
# 4       0.7341   0.6182 -989.09910   2.1138    0.00391
# ...        ...      ...        ...      ...        ...
# 10077   0.1190  -0.2335 -983.32155   2.1934   10.49512
# 10078  -0.1037  -0.2166 -983.56890   2.2664   10.49609
# 10079  -0.1037  -0.1454 -983.31080   2.4390   10.49707
# 10080   0.4549  -0.1115 -983.66620   2.4987   10.49707
# 10081   0.7447  -0.1471 -983.33700   2.4871   10.49902
#
# [10082 rows x 5 columns]

# %%
forces_average
# Out:
# [4.459994459847034,
#  4.108317184928341,
#  4.602811131028762,
#  4.125293160321971,
#  4.350310298093154,
#  3.644135459985853,
#  3.336492246919046,
#  2.397219965894603,
#  1.4762932838055018,
#  1.8607620873151829,
#  1.9174477687301963]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N, particolare=True)
# Out:
# La forza di coesistenza vale f_c = 3.3862596356130554, con sigma = 1.6695504983483942
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 0.36568976511169077, con sigma = 0.11668889788376109
# La differenza di energia libera DeltaG_NU = 1.2383204907545378, con sigma = 0.46542595643220963

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 23.3116308095789, con sigma = 7.717763173821158

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.9159740108783243, con incertezza = 0.005776043471746361,
#  q1 = 5.321372157172517, con incertezza = 0.00915407099780499
# Stimiamo i parametri del fit lineare: m2 = 1.256416355761135, con incertezza = 0.005016675302876755,
#  q2 = 1.8296548533024308, con incertezza = 0.008359176347682216
# La forza di coesistenza qui vale: fc = 3.849112680793638, con incertezza = 0.00899123677553311
# Il tempo medi di residenza vale: tc = 4.989400559202598, con incertezza = 0.04010297279689486
# Stimiamo un nuovo DeltaG_NU = 1.4075811121278559, con incertezza = 0.4491607513418473
# ((-0.9159740108783243, 0.005776043471746361),
#  (5.321372157172517, 0.00915407099780499),
#  (1.256416355761135, 0.005016675302876755),
#  (1.8296548533024308, 0.008359176347682216),
#  (3.849112680793638, 0.00899123677553311),
#  (4.989400559202598, 0.04010297279689486),
#  (1.4075811121278559, 0.4491607513418473))

# %% [markdown]
# # Due molecole diverse?!

# %% [markdown]
# ## 1° molecola

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[7:], w_N[7:], forces_average[7:], sigma_w_U[7:], sigma_w_N[7:])
# Out:
# La forza di coesistenza vale f_c = 2.1400715975084674, con sigma = 0.29005018672661925
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 9.611596613446697, con sigma = 0.9273129895674916
# La differenza di energia libera DeltaG_NU = 20.56950491914585, con sigma = 1.9580034269848663

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 10.465990128570805, con sigma = 1.0397259795509242

# %%
grafici.residence_time(native_time[7:], unfolded_time[7:], forces_average[7:], forces_average_std[7:])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.0791512228246392, con incertezza = 0.011697207904242625,
#  q1 = 3.856690516153326, con incertezza = 0.019625685738045687
# Stimiamo i parametri del fit lineare: m2 = 0.8602128570664608, con incertezza = 0.00922694192273914,
#  q2 = 0.8060802116120872, con incertezza = 0.014002496807698364
# La forza di coesistenza qui vale: fc = 2.1591908694175874, con incertezza = 0.016380435095485278
# Il tempo medi di residenza vale: tc = 4.821066439481254, con incertezza = 0.0835809538069264
# Stimiamo un nuovo DeltaG_NU = 20.753271648279114, con incertezza = 2.0084262569802394
# ((-1.0791512228246392, 0.011697207904242625),
#  (3.856690516153326, 0.019625685738045687),
#  (0.8602128570664608, 0.00922694192273914),
#  (0.8060802116120872, 0.014002496807698364),
#  (2.1591908694175874, 0.016380435095485278),
#  (4.821066439481254, 0.0835809538069264),
#  (20.753271648279114, 2.0084262569802394))

# %% [markdown]
# ## 2° molecola

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:7], w_N[:7], forces_average[:7], sigma_w_U[:7], sigma_w_N[:7])
# Out:
# La forza di coesistenza vale f_c = 4.452319826957877, con sigma = 1.3372708008677114
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = -2.7137958598113663, con sigma = 0.5840549182178358
# La differenza di energia libera DeltaG_NU = -12.082687112954346, con sigma = 2.5314313928511516

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.60690988350972, con sigma = 7.16372456736025

# %%
grafici.residence_time(native_time[:7], unfolded_time[:7], forces_average[:7], forces_average_std[:7])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.08304985952332622, con incertezza = 0.006774220126120566,
#  q1 = 4.463454070996804, con incertezza = 0.010575564947839535
# Stimiamo i parametri del fit lineare: m2 = 0.2702690038373108, con incertezza = 0.006329908006994536,
#  q2 = 3.8813329134538233, con incertezza = 0.010766033705750766
# La forza di coesistenza qui vale: fc = 4.326622768247609, con incertezza = 0.012277920622461098
# Il tempo medi di residenza vale: tc = 5.194395121210412, con incertezza = 0.3156881637069888
# Stimiamo un nuovo DeltaG_NU = -11.741570955435954, con incertezza = 2.5272049677899084
# ((-0.08304985952332622, 0.006774220126120566),
#  (4.463454070996804, 0.010575564947839535),
#  (0.2702690038373108, 0.006329908006994536),
#  (3.8813329134538233, 0.010766033705750766),
#  (4.326622768247609, 0.012277920622461098),
#  (5.194395121210412, 0.3156881637069888),
#  (-11.741570955435954, 2.5272049677899084))

# %% [markdown]
# ### Vediamo cosa accade eliminando qualche punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
forces_average
# Out:
# [4.459994459847034,
#  4.108317184928341,
#  4.602811131028762,
#  4.125293160321971,
#  4.350310298093154,
#  3.644135459985853,
#  3.336492246919046,
#  2.397219965894603,
#  1.4762932838055018,
#  1.8607620873151829,
#  1.9174477687301963]

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:6], w_N[:6], forces_average[:6], sigma_w_U[:6], sigma_w_N[:6])
# Out:
# La forza di coesistenza vale f_c = 4.062696822541871, con sigma = 0.8306917958876592
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 6.745206121177159, con sigma = 0.9547743965875222
# La differenza di energia libera DeltaG_NU = 27.403727475896417, con sigma = 4.043437483536451

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 31.550640325724626, con sigma = 4.291373323003868

# %%
grafici.residence_time(native_time[:6], unfolded_time[:6], forces_average[:6], forces_average_std[:6])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.8596624559922903, con incertezza = 0.009417730780778396,
#  q1 = 5.527922887659121, con incertezza = 0.013865698431610608
# Stimiamo i parametri del fit lineare: m2 = 0.6343328600045103, con incertezza = 0.007152504008956234,
#  q2 = 3.1703238091812858, con incertezza = 0.012578091022543685
# La forza di coesistenza qui vale: fc = 4.1713326812854365, con incertezza = 0.013001531147389797
# Il tempo medi di residenza vale: tc = 4.845497126154963, con incertezza = 0.08573223489554899
# Stimiamo un nuovo DeltaG_NU = 28.136498735272863, con incertezza = 3.9836470747168895
# ((-0.8596624559922903, 0.009417730780778396),
#  (5.527922887659121, 0.013865698431610608),
#  (0.6343328600045103, 0.007152504008956234),
#  (3.1703238091812858, 0.012578091022543685),
#  (4.1713326812854365, 0.013001531147389797),
#  (4.845497126154963, 0.08573223489554899),
#  (28.136498735272863, 3.9836470747168895))

# %%
# f_c, t_c

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average
# Out:
# [4.459994459847034,
#  4.108317184928341,
#  4.125293160321971,
#  4.350310298093154,
#  3.644135459985853,
#  3.336492246919046,
#  2.397219965894603,
#  1.4762932838055018,
#  1.8607620873151829,
#  1.9174477687301963]

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = 5
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:5], w_N[:5], forces_average[:5], sigma_w_U[:5], sigma_w_N[:5])
# Out:
# La forza di coesistenza vale f_c = 4.061817994998865, con sigma = 0.8373033378667337
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 6.7147396498406495, con sigma = 0.9581084526207977
# La differenza di energia libera DeltaG_NU = 27.274050341455126, con sigma = 4.057700054196808

# %%
grafici.residence_time(native_time[:5], unfolded_time[:5], forces_average[:5], forces_average_std[:5])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.810758015707479, con incertezza = 0.009934655486033346,
#  q1 = 5.459188655219288, con incertezza = 0.014560862444513337
# Stimiamo i parametri del fit lineare: m2 = 0.6497135754943052, con incertezza = 0.008411548003866655,
#  q2 = 3.1429155308865746, con incertezza = 0.01484704236122622
# La forza di coesistenza qui vale: fc = 4.173345771705718, con incertezza = 0.014624246755490043
# Il tempo medi di residenza vale: tc = 4.884056667464638, con incertezza = 0.09799475011375551
# Stimiamo un nuovo DeltaG_NU = 28.022930325767213, con incertezza = 3.9997234807498376
# ((-0.810758015707479, 0.009934655486033346),
#  (5.459188655219288, 0.014560862444513337),
#  (0.6497135754943052, 0.008411548003866655),
#  (3.1429155308865746, 0.01484704236122622),
#  (4.173345771705718, 0.014624246755490043),
#  (4.884056667464638, 0.09799475011375551),
#  (28.022930325767213, 3.9997234807498376))

# %% [markdown]
# ## No grandi cambiamenti

# %%
grafici.write_on_txt()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-117-34283a3d455e> in <module>
# ----> 1 grafici.write_on_txt()
#
# c:\Users\ricta\Documents\TesiTriennale\graph_hop.py in write_on_txt(self)
#     387         status = "r" if os.path.isfile(self.nome_txt) else "a"
#     388         f = open(self.nome_txt, status)
# --> 389         f.write(self.output)
#     390         f.close()
#
# UnsupportedOperation: not writable
