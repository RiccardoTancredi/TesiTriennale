# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 8hop - Oligo

# %%
# directory name
dir_name = "100pM/8"
# molecule name is a number in these experimets
number = "8"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force lambda  Y      _force  time(sec)
# 0        0.4207   0.3104       inf  5.5329  20  734.96680
# 1        0.8555   0.3867       inf  5.5627  20  734.96875
# 2        0.9191   0.4579       inf  5.0052  20  734.96875
# 3        0.4153   0.3435       inf  5.1944  20  734.97070
# 4        0.3411   0.3740       inf  5.0003  20  734.97070
# ...         ...      ...       ...         ...        ...
# 248503  -1.6615   5.4039    inf  1  9.6656  21  167.53906
# 248504  -1.4211   5.4785    inf  1  9.6856  21  167.54102
# 248505  -1.6950   5.4437    inf  1  9.4898  21  167.54102
# 248506  -1.4299   5.5225    inf  1  9.8631  21  167.54297
# 248507  -1.2019   5.6191    inf  1  9.2907  21  167.54290
#
# [248508 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph(max_time=7, space=-2)
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.254864606657718, con deviazione standard = 0.22922410561270348

# %% [markdown]
# ## Suspicious Data?! - Check the entire sequence to see this
# ## Drift?!

# %%
prova = [0.5, 5.7, 0.1, 2., 5.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.501334414595529, mu_1 = 5.7122211191884045, sigma_1 = 0.057445263928676514
# c_2 = 1.8216281987261784, mu_2 = 5.210497250485839, sigma_2 = 0.20555343557190064
# sigma_c_1 = 0.11172234815602253, sigma_mu_1 = 0.016444550552256125, sigma_sigma_1 = 0.015249977450654066
# sigma_c_2 = 0.05189819938306399, sigma_mu_2 = 0.006982381519964011, sigma_sigma_2 = 0.007338949012424744
# w_U = 0.9385867404328254, sigma_w_U = 0.002427060773195245
# w_N = 0.07218910899589191, sigma_w_N = 0.24345543479486006

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.6880000000000001 sec nello stato nativo e 6.011 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.4207   0.3104     inf   5.5329    0.00000
# 1      0.8555   0.3867     inf   5.5627    0.00195
# 2      0.9191   0.4579     inf   5.0052    0.00195
# 3      0.4153   0.3435     inf   5.1944    0.00390
# 4      0.3411   0.3740     inf   5.0003    0.00390
# ...       ...      ...     ...      ...        ...
# 6694   0.5373   0.0918     inf   5.1944    6.99218
# 6695   1.1948   0.1833     inf   5.1844    6.99609
# 6696   0.5797   0.0918     inf   5.2392    6.99609
# 6697   0.0124   0.1223     inf   5.1396    6.99804
# 6698  -0.0195   0.1273     inf   5.0749    6.99804
#
# [6699 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.796532084763493, con deviazione standard = 0.3813013958352841

# %%
prova = [1.5, 5.1, 0.1, .8, 4.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.3419082897800758, mu_1 = 5.122437159001267, sigma_1 = 0.16065746454160687
# c_2 = 0.9937702649752536, mu_2 = 4.428581464891062, sigma_2 = 0.1869413082733354
# sigma_c_1 = 0.04727733698210663, sigma_mu_1 = 0.006828501525369272, sigma_sigma_1 = 0.007163689038540891
# sigma_c_2 = 0.04310923471955246, sigma_mu_2 = 0.009772098328323282, sigma_sigma_2 = 0.010141740555057894
# w_U = 0.4656731627208745, sigma_w_U = 0.027647943426269563
# w_N = 0.540397932418939, sigma_w_N = 0.019415367405243984

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.621 sec nello stato nativo e 3.08 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0     -0.2970  -0.0066     inf   4.5805    0.00000
# 1      0.4666   0.0104     inf   4.6535    0.00195
# 2      0.4100   0.0053     inf   4.7265    0.00195
# 3      0.8130   0.0307     inf   4.8460    0.00390
# 4      1.1524   0.0104     inf   4.7597    0.00390
# ...       ...      ...     ...      ...        ...
# 6696   0.5055  -0.0684     inf   4.4577    6.99414
# 6697  -0.1149  -0.0837     inf   4.1591    6.99609
# 6698  -0.2475  -0.0735     inf   4.2437    6.99609
# 6699  -0.2050  -0.0608     inf   4.1889    6.99804
# 6700   0.0389  -0.0099     inf   4.5374    6.99804
#
# [6701 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.592856809048988, con deviazione standard = 0.3607157465929757

# %%
prova = [1.8, 4.9, 0.1, 1., 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.8314767658147717, mu_1 = 4.87678743485808, sigma_1 = 0.12346293838531865
# c_2 = 1.0593800321677416, mu_2 = 4.208069050127302, sigma_2 = 0.16174964095731498
# sigma_c_1 = 0.04354124985324801, sigma_mu_1 = 0.003449962197193973, sigma_sigma_1 = 0.0034332648959963276
# sigma_c_2 = 0.0374324587846494, sigma_mu_2 = 0.006666845456734505, sigma_sigma_2 = 0.0066954069363041125
# w_U = 0.42952163322487896, sigma_w_U = 0.02321014571162037
# w_N = 0.5667975398957482, sigma_w_N = 0.011829542782646378

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.8120000000000003 sec nello stato nativo e 2.907 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0     -0.0071   0.1019     inf   4.8061    0.00000
# 1     -0.5868  -0.0201     inf   4.5274    0.00196
# 2     -0.6505  -0.0913     inf   4.0960    0.00196
# 3     -0.0071  -0.1489     inf   4.3947    0.00391
# 4      0.2686  -0.0710     inf   4.2553    0.00391
# ...       ...      ...     ...      ...        ...
# 6714   0.3888  -0.1116     inf   5.0351    6.99414
# 6715  -0.0407  -0.1727     inf   4.7613    6.99610
# 6716   0.4896  -0.2439     inf   4.6867    6.99610
# 6717   0.6221  -0.2718     inf   4.8808    6.99805
# 6718   0.1343  -0.3659     inf   4.8526    6.99805
#
# [6719 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.4537711057908216, con deviazione standard = 0.28867777135333594

# %%
prova = [.4, 4.1, 0.1, 2., 3.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.39380238797173406, mu_1 = 4.099164717606013, sigma_1 = 0.12472957393425685
# c_2 = 2.1119228361862836, mu_2 = 3.3525078732208007, sigma_2 = 0.16421791139319328
# sigma_c_1 = 0.05118506245844934, sigma_mu_1 = 0.018935649676652046, sigma_sigma_1 = 0.01876865426579907
# sigma_c_2 = 0.044104775036042265, sigma_mu_2 = 0.003983265629614282, sigma_sigma_2 = 0.003977378421669599
# w_U = 0.8693376817145578, sigma_w_U = 0.002972289282414441
# w_N = 0.12312258308791406, sigma_w_N = 0.13055865733788835

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.884 sec nello stato nativo e 5.799 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.6009  -0.2845     inf   4.0396    0.00000
# 1      0.0919  -0.2540     inf   4.1093    0.00000
# 2      0.2775  -0.1905     inf   4.0247    0.00195
# 3      1.0941  -0.1828     inf   3.8803    0.00195
# 4      1.0039  -0.0379     inf   4.0545    0.00391
# ...       ...      ...     ...      ...        ...
# 6678  -0.1414  -0.1998     inf   3.0806    6.93750
# 6679   1.0817  -0.1218     inf   3.1403    6.93750
# 6680   1.1736  -0.2235     inf   3.2598    6.93945
# 6681   1.1736  -0.0778     inf   3.3129    6.93945
# 6682   0.4666  -0.1354     inf   3.2797    6.94136
#
# [6683 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.4703523378358523, con deviazione standard = 0.2649311302594205

# %%
prova = [0.5, 3.9, 0.1, 1.8, 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.3716111437594096, mu_1 = 3.9247451840854697, sigma_1 = 0.16679354296908805
# c_2 = 1.7729330906122036, mu_2 = 3.385499586601445, sigma_2 = 0.19148963146969844
# sigma_c_1 = 0.041115734810848764, sigma_mu_1 = 0.03410371802647025, sigma_sigma_1 = 0.03431784913884484
# sigma_c_2 = 0.038250806720192404, sigma_mu_2 = 0.007648120175398224, sigma_sigma_2 = 0.007134184058990674
# w_U = 0.8509960483510214, sigma_w_U = 0.004428582955868681
# w_N = 0.15536668415305038, sigma_w_N = 0.12856780811755184

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.383 sec nello stato nativo e 5.354 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.1555  -0.4473     inf   3.4871    0.00000
# 1      0.4030  -0.3727     inf   3.4523    0.00195
# 2      0.8130  -0.2845     inf   3.2133    0.00195
# 3      0.4100  -0.3557     inf   3.2333    0.00195
# 4      0.1272  -0.4201     inf   3.2996    0.00391
# ...       ...      ...     ...      ...        ...
# 6732  -0.1520  -0.2032     inf   3.5867    6.99219
# 6733   0.3358  -0.0939     inf   3.6414    6.99414
# 6734  -0.0283  -0.1625     inf   3.5120    6.99414
# 6735   0.0654   0.0358     inf   3.4174    6.99805
# 6736  -0.0301   0.0536     inf   3.6514    6.99805
#
# [6737 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.9446597441237774, con deviazione standard = 0.2492059699167738

# %% [markdown]
# # No data?!

# %%
prova = [.7, 3.3, 0.1, 1.5, 2.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.5451619045900973, mu_1 = 3.231207847124055, sigma_1 = 0.16870194602117533
# c_2 = 1.5670787521310783, mu_2 = 2.858683375201442, sigma_2 = 0.19438024632451795
# sigma_c_1 = 0.18708564536343342, sigma_mu_1 = 0.08601314226182656, sigma_sigma_1 = 0.050938301086463036
# sigma_c_2 = 0.16582283588570176, sigma_mu_2 = 0.037519728108538736, sigma_sigma_2 = 0.01778655845613118
# w_U = 0.7635419177497219, sigma_w_U = 0.02657689490673008
# w_N = 0.23053428708638185, sigma_w_N = 0.2862631015644326

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.191 sec nello stato nativo e 4.531 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0     -0.2846  -0.1727     inf   3.1088    0.00000
# 1     -0.6292  -0.2744     inf   3.1138    0.00000
# 2      0.1131  -0.3201     inf   2.7703    0.00195
# 3      0.5532  -0.2718     inf   2.8799    0.00391
# 4      0.8077  -0.3227     inf   2.9844    0.00586
# ...       ...      ...     ...      ...        ...
# 6717  -0.5868  -0.2303     inf   2.9678    6.99414
# 6718   0.0636  -0.1693     inf   2.9678    6.99609
# 6719  -0.2263  -0.2235     inf   2.8019    6.99609
# 6720   0.1909  -0.2879     inf   2.8085    6.99805
# 6721   0.2563  -0.4345     inf   2.8500    6.99805
#
# [6722 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.7738115264333696, con deviazione standard = 0.33944314170035006

# %%
prova = [.8, 3.2, 0.1, 1.2, 2.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.0571532309008194, mu_1 = 3.1827940113697006, sigma_1 = 0.12560163700856378
# c_2 = 1.5810508702989716, mu_2 = 2.549560340065499, sigma_2 = 0.1664691799225411
# sigma_c_1 = 0.043642910870268246, sigma_mu_1 = 0.006107505912916568, sigma_sigma_1 = 0.006235983982592188
# sigma_c_2 = 0.037659202401809574, sigma_mu_2 = 0.004630939794229354, sigma_sigma_2 = 0.004764482528817007
# w_U = 0.6597351414586853, sigma_w_U = 0.009248479924165227
# w_N = 0.33283054439962106, sigma_w_N = 0.031780990328750064

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.336 sec nello stato nativo e 4.3790000000000004 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.4472   0.0206     inf   2.8052    0.00000
# 1     -0.0707  -0.1930     inf   2.6426    0.00196
# 2     -0.3111  -0.1422     inf   2.7753    0.00196
# 3     -0.3394  -0.1523     inf   2.5961    0.00391
# 4     -0.6982   0.0002     inf   2.2477    0.00391
# ...       ...      ...     ...      ...        ...
# 6710   0.4878   0.2036     inf   3.0342    6.99414
# 6711   0.6292   0.0748     inf   2.9612    6.99610
# 6712   0.2404  -0.0659     inf   3.0441    6.99610
# 6713  -0.0990  -0.2133     inf   3.2532    6.99805
# 6714   0.0495  -0.1455     inf   3.1005    6.99805
#
# [6715 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.707352172619047, con deviazione standard = 0.3582566773908271

# %%
prova = [1.2, 3.1, 0.1, 1.5, 2.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2149506819833635, mu_1 = 3.0733340417638346, sigma_1 = 0.13340263435447638
# c_2 = 1.459737302884944, mu_2 = 2.425379862736202, sigma_2 = 0.15962856580673224
# sigma_c_1 = 0.04250193586729256, sigma_mu_1 = 0.005464644835128179, sigma_sigma_1 = 0.00557359947283318
# sigma_c_2 = 0.038612086584648105, sigma_mu_2 = 0.004925123859412834, sigma_sigma_2 = 0.005035979104789751
# w_U = 0.5840839228162048, sigma_w_U = 0.012512122076205182
# w_N = 0.4062683489557912, sigma_w_N = 0.02379859864637412

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.831 sec nello stato nativo e 3.8890000000000002 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0     -0.5285  -0.0252     inf   2.4319    0.00000
# 1     -0.1343   0.1019     inf   2.3174    0.00195
# 2      0.5797   0.0206     inf   2.3373    0.00195
# 3     -0.0248  -0.0049     inf   2.6459    0.00391
# 4      0.1237  -0.0455     inf   2.3473    0.00391
# ...       ...      ...     ...      ...        ...
# 6715  -0.1255  -0.0913     inf   3.0590    6.99414
# 6716   0.4260  -0.2820     inf   2.8898    6.99609
# 6717   0.1449  -0.2667     inf   2.6907    6.99609
# 6718  -0.5550  -0.3100     inf   2.4269    6.99805
# 6719  -1.2231  -0.2133     inf   2.4767    6.99805
#
# [6720 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.933337526142813, con deviazione standard = 0.306110617462103

# %%
prova = [.8, 3.4, 0.1, 1.8, 2.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8473238519077988, mu_1 = 3.3802619628341497, sigma_1 = 0.11733149263001648
# c_2 = 2.0491590051221165, mu_2 = 2.766100609878725, sigma_2 = 0.14462611618024698
# sigma_c_1 = 0.046697892855645885, sigma_mu_1 = 0.007553433561368522, sigma_sigma_1 = 0.00758421510627875
# sigma_c_2 = 0.041696864614072654, sigma_mu_2 = 0.0034227966948005666, sigma_sigma_2 = 0.0034527284556337585
# w_U = 0.7428691389851649, sigma_w_U = 0.005878973379489647
# w_N = 0.24920339901130228, sigma_w_N = 0.04746179797612159

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.764 sec nello stato nativo e 4.93 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0     -0.0990  -0.2235     inf   3.6514    0.00000
# 1     -0.0566  -0.1625     inf   3.4921    0.00000
# 2     -0.0672  -0.1650     inf   3.5518    0.00195
# 3     -0.1679  -0.1930     inf   3.4622    0.00195
# 4     -0.0407  -0.2820     inf   3.2880    0.00390
# ...       ...      ...     ...      ...        ...
# 6689  -0.1361   0.1070     inf   2.9296    6.99414
# 6690  -0.0354   0.1960     inf   2.7056    6.99609
# 6691   0.0813   0.0867     inf   2.4767    6.99609
# 6692   0.1767  -0.0303     inf   2.9844    6.99804
# 6693   0.1502   0.0002     inf   2.8500    6.99804
#
# [6694 rows x 5 columns]

# %% [markdown]
# # File 10

# %%
grafici = Graph_hop(dir_name, number, 10)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.549903992821909, con deviazione standard = 0.16031226856512387

# %% [markdown]
# # NO hop

# %%
# prova = [1., 5.6, 0.1, 1.5, 5., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0     -0.2846  -0.2718     inf   1.9939    0.00000
# 1     -0.5444  -0.2795     inf   1.8296    0.00195
# 2      0.1979  -0.0303     inf   2.0586    0.00195
# 3     -0.3323  -0.3201     inf   2.2776    0.00390
# 4     -0.2422  -0.4142     inf   2.1780    0.00390
# ...       ...      ...     ...      ...        ...
# 6682  -0.1308   0.1629     inf   2.4866    6.99414
# 6683  -0.6929  -0.0811     inf   2.3970    6.99609
# 6684  -0.8131  -0.2506     inf   2.3771    6.99609
# 6685  -0.1202  -0.1557     inf   2.3572    6.99804
# 6686  -0.0424   0.0240     inf   2.3970    6.99804
#
# [6687 rows x 5 columns]

# %% [markdown]
# # File 11

# %%
grafici = Graph_hop(dir_name, number, 11)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.9908777465205634, con deviazione standard = 0.1465306813548152

# %% [markdown]
# # NO hop

# %%
# prova = [.5, 5.8, 0.1, 1.5, 5.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.2969  -0.5117     inf   3.1470    0.00000
# 1     -0.1485  -0.5015     inf   2.9412    0.00000
# 2      0.6009  -0.4676     inf   2.8848    0.00196
# 3      0.6858  -0.4168     inf   2.8948    0.00196
# 4      0.2192  -0.3761     inf   3.1138    0.00391
# ...       ...      ...     ...      ...        ...
# 6749  -0.2899  -0.3591     inf   2.9412    6.99414
# 6750  -0.7565  -0.4371     inf   3.0939    6.99610
# 6751  -0.5939  -0.3320     inf   3.0541    6.99610
# 6752   0.3323  -0.3659     inf   2.9147    6.99805
# 6753   0.3252  -0.3422     inf   3.0474    6.99805
#
# [6754 rows x 5 columns]

# %% [markdown]
# # File 12

# %%
grafici = Graph_hop(dir_name, number, 12)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.3265648387576174, con deviazione standard = 0.12809846173107364

# %% [markdown]
# # No hop

# %%
# prova = [.5, 3.3, 0.1, 1.5, 2.7, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.7176  -0.2032     inf   3.4075    0.00000
# 1      0.4454  -0.4032     inf   3.3859    0.00195
# 2      0.2086  -0.4549     inf   3.3229    0.00391
# 3      0.3729  -0.4193     inf   3.4075    0.00391
# 4     -0.0566  -0.3812     inf   3.3577    0.00586
# ...       ...      ...     ...      ...        ...
# 6724  -0.1485   0.0341     inf   3.4589    6.99414
# 6725  -0.0990   0.0206     inf   3.5120    6.99414
# 6726   0.2757  -0.0303     inf   3.5585    6.99609
# 6727  -0.2687  -0.1422     inf   3.4174    6.99805
# 6728   0.1714  -0.1244     inf   3.3776    6.99805
#
# [6729 rows x 5 columns]

# %% [markdown]
# # File 13

# %%
grafici = Graph_hop(dir_name, number, 13)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.0153770618941005, con deviazione standard = 0.13477650928138285

# %%
prova = [5, 4., 0.1, 0.1, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 5.277655868364368, mu_1 = 4.042387562023466, sigma_1 = 0.07173226864789403
# c_2 = 0.265844134705934, mu_2 = 3.547544229591123, sigma_2 = -0.07445963665059961
# sigma_c_1 = 0.09178292851658809, sigma_mu_1 = 0.0014810043383292786, sigma_sigma_1 = 0.0014241535854130672
# sigma_c_2 = 0.08923629807116155, sigma_mu_2 = 0.02931479685805797, sigma_sigma_2 = 0.028503108668630893
# w_U = 0.04961784861704474, sigma_w_U = 0.3666813876804402
# w_N = 0.9489548919199685, sigma_w_N = 0.0009935773498362286

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.8395  -0.0913     inf   3.5916    0.00000
# 1     -0.0990  -0.2667     inf   3.5419    0.00391
# 2     -0.0142  -0.4574     inf   3.5120    0.00391
# 3      0.3570  -0.3761     inf   3.6215    0.00586
# 4     -0.4171  -0.5362     inf   3.6315    0.00586
# ...       ...      ...     ...      ...        ...
# 6700  -0.1573  -0.4778     inf   3.9699    6.99414
# 6701   0.0760  -0.3684     inf   3.9799    6.99609
# 6702  -0.1043  -0.4473     inf   3.9649    6.99609
# 6703   0.4383  -0.5252     inf   4.0230    6.99805
# 6704  -0.2545  -0.6235     inf   3.9965    6.99805
#
# [6705 rows x 5 columns]

# %% [markdown]
# # File 14

# %%
grafici = Graph_hop(dir_name, number, 14)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.079708862079233, con deviazione standard = 0.14890506272906404

# %% [markdown]
# # No hop
# # Drift?!

# %%
# prova = [.5, 3.3, 0.1, 1.5, 2.7, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.1979  -0.6134     inf   3.2598    0.00000
# 1      0.2616  -0.5557     inf   3.1735    0.00000
# 2     -0.3111  -0.5286     inf   3.2532    0.00195
# 3     -0.3747  -0.4676     inf   3.0740    0.00195
# 4      0.1979  -0.3184     inf   2.9479    0.00390
# ...       ...      ...     ...      ...        ...
# 6709   0.3676  -0.3659     inf   2.9943    6.99414
# 6710   0.6080  -0.3591     inf   2.9943    6.99609
# 6711   0.1343  -0.4168     inf   3.0275    6.99609
# 6712   0.5514  -0.3998     inf   3.0607    6.99804
# 6713   0.6062  -0.3557     inf   3.0839    6.99804
#
# [6714 rows x 5 columns]

# %% [markdown]
# # File 15

# %%
grafici = Graph_hop(dir_name, number, 15)
data_frame = grafici.do_graph(7, -2)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.814474869500364, con deviazione standard = 0.14650904781349142

# %% [markdown]
# # No data -> break

# %%
forces_average
# Out:
# [5.4613591848371215,
#  4.7755093119461645,
#  4.542428242492692,
#  3.7258362954134068,
#  3.655122385343457,
#  3.044945611162748,
#  2.8661771757176,
#  2.749356952250018,
#  3.073181286356437]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.097188068190282, con sigma = 0.5497234239723781
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = -1.549248019074991, con sigma = 0.1497553931235233
# La differenza di energia libera DeltaG_NU = -6.347560498421483, con sigma = 0.5906316131215875

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -20.274448494366794, con sigma = -1.3148981452047257

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = 0.2546058968506241, con incertezza = 0.0041336456947526955,
#  q1 = 3.312388253441585, con incertezza = 0.004119694989266397
# Stimiamo i parametri del fit lineare: m2 = -1.822069582356265, con incertezza = 0.007879000781975228,
#  q2 = 6.047414153507703, con incertezza = 0.010974131292650558
# La forza di coesistenza qui vale: fc = 3.6477096501491566, con incertezza = 0.006269807735362987
# Il tempo medi di residenza vale: tc = 3.732287547773983, con incertezza = 0.029788697586921313
# Stimiamo un nuovo DeltaG_NU = -5.651206949654309, con incertezza = 0.5463505468238875
# ((0.2546058968506241, 0.0041336456947526955),
#  (3.312388253441585, 0.004119694989266397),
#  (-1.822069582356265, 0.007879000781975228),
#  (6.047414153507703, 0.010974131292650558),
#  (3.6477096501491566, 0.006269807735362987),
#  (3.732287547773983, 0.029788697586921313),
#  (-5.651206949654309, 0.5463505468238875))

# %% [markdown]
# # Due molecole diverse?!

# %% [markdown]
# ## 1° molecola

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[3:], w_N[3:], forces_average[3:], sigma_w_U[3:], sigma_w_N[3:])
# Out:
# La forza di coesistenza vale f_c = 2.5611153978650383, con sigma = 0.8261776740900756
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 8.44916446220209, con sigma = 1.8352930357741728
# La differenza di energia libera DeltaG_NU = 21.639285203239847, con sigma = 5.16079452080636

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -10.924817376912914, con sigma = -2.047548955523889

# %%
grafici.residence_time(native_time[3:], unfolded_time[3:], forces_average[3:], forces_average_std[3:])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.8243659561674886, con incertezza = 0.007589693722789259,
#  q1 = 3.5819176959855965, con incertezza = 0.006315513143694074
# Stimiamo i parametri del fit lineare: m2 = 1.924991996931508, con incertezza = 0.01883647300655936,
#  q2 = 0.0782799610437226, con incertezza = 0.028059005455694834
# La forza di coesistenza qui vale: fc = 2.5313889104652296, con incertezza = 0.013711164338110315
# Il tempo medi di residenza vale: tc = 3.5763674603805407, con incertezza = 0.05032841783441576
# Stimiamo un nuovo DeltaG_NU = 21.388121222315277, con incertezza = 4.647284595245275
# ((-0.8243659561674886, 0.007589693722789259),
#  (3.5819176959855965, 0.006315513143694074),
#  (1.924991996931508, 0.01883647300655936),
#  (0.0782799610437226, 0.028059005455694834),
#  (2.5313889104652296, 0.013711164338110315),
#  (3.5763674603805407, 0.05032841783441576),
#  (21.388121222315277, 4.647284595245275))

# %% [markdown]
# ## 2° molecola

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:3], w_N[:3], forces_average[:3], sigma_w_U[:3], sigma_w_N[:3])
# Out:
# La forza di coesistenza vale f_c = 5.026934288174099, con sigma = 4.581225993064427
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 2.3695997224097542, con sigma = 1.5868926939091612
# La differenza di energia libera DeltaG_NU = 11.91182209382942, con sigma = 7.362730934665264

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -25.549594669610716, con sigma = -9.492977533359339

# %%
grafici.residence_time(native_time[:3], unfolded_time[:3], forces_average[:3], forces_average_std[:3])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5090383517882288, con incertezza = 0.005580321960613985,
#  q1 = 5.281072291575148, con incertezza = 0.006995179700979588
# Stimiamo i parametri del fit lineare: m2 = 1.234555922666643, con incertezza = 0.01327245485043629,
#  q2 = 3.268243299469899, con incertezza = 0.015726218187466445
# La forza di coesistenza qui vale: fc = 4.6934314811044, con incertezza = 0.009296550097913978
# Il tempo medi di residenza vale: tc = 3.1721628045758283, con incertezza = 0.043531162092416816
# Stimiamo un nuovo DeltaG_NU = 11.121553934774187, con incertezza = 7.448004704742938
# ((-0.5090383517882288, 0.005580321960613985),
#  (5.281072291575148, 0.006995179700979588),
#  (1.234555922666643, 0.01327245485043629),
#  (3.268243299469899, 0.015726218187466445),
#  (4.6934314811044, 0.009296550097913978),
#  (3.1721628045758283, 0.043531162092416816),
#  (11.121553934774187, 7.448004704742938))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
# def remove_element(arr, pos):
#     arr.pop(pos)
#     return arr

# %%
# # proviamo ad eliminare l'ultimo punto, quello più in alto
# post = 0
# forces_average = remove_element(forces_average, post)
# forces_average_std = remove_element(forces_average_std, post)
# w_U = remove_element(w_U, post)
# w_N = remove_element(w_N, post)
# sigma_w_U = remove_element(sigma_w_U, post)
# sigma_w_N = remove_element(sigma_w_N, post)
# native_time = remove_element(native_time, post)
# unfolded_time = remove_element(unfolded_time, post)

# %%
# x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)

# %%
# f_c

# %%
# G0 = grafici.G0(f_c)

# %%
# m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)

# %%
# f_c, t_c

# %% [markdown]
# ### Tolgo un altro punto

# %%
# forces_average, native_time

# %%
# # proviamo ad eliminare l'ultimo punto, quello più in alto
# pos = 0
# forces_average = remove_element(forces_average, pos)
# forces_average_std = remove_element(forces_average_std, pos)
# w_U = remove_element(w_U, pos)
# w_N = remove_element(w_N, pos)
# sigma_w_U = remove_element(sigma_w_U, pos)
# sigma_w_N = remove_element(sigma_w_N, pos)
# native_time = remove_element(native_time, pos)
# unfolded_time = remove_element(unfolded_time, pos)

# %%
# x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)

# %%
# grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)

# %%
grafici.write_on_txt()

# %% [markdown]
# # Notiamo che questo comportamento, da doppia molecola, non c'era considerando il range di tempo intero dei singoli file, cioè senza troncare a 7 secondi ogni datasheet: rimuovendo l'ultimo dato, si stimava $x_{NU} = (4.9 \pm 0.9) \: nm$
