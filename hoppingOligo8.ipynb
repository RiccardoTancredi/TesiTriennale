# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 8hop - Oligo

# %%
# directory name
dir_name = "100pM/8"
# molecule name is a number in these experimets
number = "8"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force  lambda  Y_force    time(sec)
# 0        0.4207   0.3104     inf   5.5329  20734.96680
# 1        0.8555   0.3867     inf   5.5627  20734.96875
# 2        0.9191   0.4579     inf   5.0052  20734.96875
# 3        0.4153   0.3435     inf   5.1944  20734.97070
# 4        0.3411   0.3740     inf   5.0003  20734.97070
# ...         ...      ...     ...      ...          ...
# 248503  -1.6615   5.4039     inf  19.6656  21167.53906
# 248504  -1.4211   5.4785     inf  19.6856  21167.54102
# 248505  -1.6950   5.4437     inf  19.4898  21167.54102
# 248506  -1.4299   5.5225     inf  19.8631  21167.54297
# 248507  -1.2019   5.6191     inf  19.2907  21167.54290
#
# [248508 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.14771105769238, con deviazione standard = 0.21595427297180209

# %% [markdown]
# ## Suspicious Data?!
# # Drift?!

# %%
# prova = [0.2, 5.6, 0.1, 2.5, 4.9, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0       0.4207   0.3104     inf   5.5329    0.00000
# 1       0.8555   0.3867     inf   5.5627    0.00195
# 2       0.9191   0.4579     inf   5.0052    0.00195
# 3       0.4153   0.3435     inf   5.1944    0.00390
# 4       0.3411   0.3740     inf   5.0003    0.00390
# ...        ...      ...     ...      ...        ...
# 15595   0.8024  -0.1269     inf   4.9754   16.29101
# 15596   0.9191   0.0816     inf   4.9654   16.29101
# 15597   0.7282   0.1680     inf   4.8908   16.29101
# 15598   0.5585   0.0918     inf   5.0301   16.29297
# 15599   0.1626  -0.0099     inf   4.9256   16.29490
#
# [15600 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.621472490557403, con deviazione standard = 0.41212198515027654

# %%
prova = [1., 4.7, 0.1, .5, 4.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.9922206950312157, mu_1 = 4.760710237179075, sigma_1 = 0.3439214865112439
# c_2 = 0.35015668332197936, mu_2 = 3.984736691361053, sigma_2 = 0.1813024714801275
# sigma_c_1 = 0.02129534069035294, sigma_mu_1 = 0.011527782823276468, sigma_sigma_1 = 0.01292995646727768
# sigma_c_2 = 0.032334286297095206, sigma_mu_2 = 0.02214040128960413, sigma_sigma_2 = 0.02034734347449029
# w_U = 0.15913147141907, sigma_w_U = 0.12431658465216774
# w_N = 0.8553769132692054, sigma_w_N = 0.006888875356978949

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 13645 sec nello stato nativo e 3829 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0      -0.2970  -0.0066     inf   4.5805    0.00000
# 1       0.4666   0.0104     inf   4.6535    0.00195
# 2       0.4100   0.0053     inf   4.7265    0.00195
# 3       0.8130   0.0307     inf   4.8460    0.00390
# 4       1.1524   0.0104     inf   4.7597    0.00390
# ...        ...      ...     ...      ...        ...
# 17469   0.1060  -0.2269     inf   4.3482   18.87890
# 17470   0.0919  -0.3490     inf   4.4279   18.87890
# 17471   0.2757  -0.3557     inf   4.3947   18.87890
# 17472   0.0813  -0.4168     inf   4.4478   18.88086
# 17473   0.1237  -0.3532     inf   4.4826   18.88474
#
# [17474 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.644421161034358, con deviazione standard = 0.3714058017807763

# %%
prova = [1.5, 5.0, 0.1, .6, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.7915134217596587, mu_1 = 4.900283423913389, sigma_1 = 0.13711841818038556
# c_2 = 0.9023538456067108, mu_2 = 4.207630460082806, sigma_2 = 0.1668758433943031
# sigma_c_1 = 0.039004248174300316, sigma_mu_1 = 0.0035052437047370676, sigma_sigma_1 = 0.003522161062195211
# sigma_c_2 = 0.034894184912705024, sigma_mu_2 = 0.007540610992166894, sigma_sigma_2 = 0.00760883954481895
# w_U = 0.3774507401777309, sigma_w_U = 0.036813320327109586
# w_N = 0.6157519486112912, sigma_w_N = 0.01270965761721806

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8104 sec nello stato nativo e 5005 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0      -0.0071   0.1019     inf   4.8061    0.00000
# 1      -0.5868  -0.0201     inf   4.5274    0.00196
# 2      -0.6505  -0.0913     inf   4.0960    0.00196
# 3      -0.0071  -0.1489     inf   4.3947    0.00391
# 4       0.2686  -0.0710     inf   4.2553    0.00391
# ...        ...      ...     ...      ...        ...
# 13104  -0.2050  -0.2540     inf   4.9123   14.29883
# 13105   0.3747  -0.2439     inf   5.0583   14.29883
# 13106   0.1078  -0.3227     inf   5.0301   14.30078
# 13107  -0.3376  -0.3532     inf   4.9455   14.30274
# 13108  -0.0142  -0.4218     inf   4.9356   14.30268
#
# [13109 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.4537711057908216, con deviazione standard = 0.28867777135333594

# %%
prova = [.4, 4.1, 0.1, 1.5, 3.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.3949278441801102, mu_1 = 4.099621046193927, sigma_1 = 0.12397427325252039
# c_2 = 2.111172837244181, mu_2 = 3.3525652419162175, sigma_2 = 0.16431623318970565
# sigma_c_1 = 0.051348551437928686, sigma_mu_1 = 0.018829279807774667, sigma_sigma_1 = 0.018655717792662566
# sigma_c_2 = 0.04408968703231028, sigma_mu_2 = 0.003985635136177068, sigma_sigma_2 = 0.003979195357747178
# w_U = 0.8695492688298714, sigma_w_U = 0.003924548859137591
# w_N = 0.12272675741500058, sigma_w_N = 0.1729280142713351

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 884 sec nello stato nativo e 5799 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.6009  -0.2845     inf   4.0396    0.00000
# 1      0.0919  -0.2540     inf   4.1093    0.00000
# 2      0.2775  -0.1905     inf   4.0247    0.00195
# 3      1.0941  -0.1828     inf   3.8803    0.00195
# 4      1.0039  -0.0379     inf   4.0545    0.00391
# ...       ...      ...     ...      ...        ...
# 6678  -0.1414  -0.1998     inf   3.0806    6.93750
# 6679   1.0817  -0.1218     inf   3.1403    6.93750
# 6680   1.1736  -0.2235     inf   3.2598    6.93945
# 6681   1.1736  -0.0778     inf   3.3129    6.93945
# 6682   0.4666  -0.1354     inf   3.2797    6.94136
#
# [6683 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.447595312203462, con deviazione standard = 0.24744664335685068

# %%
prova = [0.4, 4., 0.1, 1.5, 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.2684549163220259, mu_1 = 3.8653080065206953, sigma_1 = 0.19874350561675644
# c_2 = 1.8087525515871072, mu_2 = 3.382255029631701, sigma_2 = 0.1923239513840346
# sigma_c_1 = 0.050776435215456446, sigma_mu_1 = 0.11056458466662922, sigma_sigma_1 = 0.08819308810666386
# sigma_c_2 = 0.07490620525039793, sigma_mu_2 = 0.01589868509938577, sigma_sigma_2 = 0.009876517157538043
# w_U = 0.871971848777596, sigma_w_U = 0.008822884606318426
# w_N = 0.1337378207098172, sigma_w_N = 0.42062331961468813

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2253 sec nello stato nativo e 8285 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0       0.1555  -0.4473     inf   3.4871    0.00000
# 1       0.4030  -0.3727     inf   3.4523    0.00195
# 2       0.8130  -0.2845     inf   3.2133    0.00195
# 3       0.4100  -0.3557     inf   3.2333    0.00195
# 4       0.1272  -0.4201     inf   3.2996    0.00391
# ...        ...      ...     ...      ...        ...
# 10533   0.5797  -0.2371     inf   3.3726   10.96094
# 10534   0.8413  -0.1693     inf   3.2001   10.96094
# 10535   1.0570  -0.0633     inf   3.2980   10.96289
# 10536   0.4578  -0.1447     inf   3.5220   10.96289
# 10537   0.4684  -0.1371     inf   3.6016   10.96484
#
# [10538 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.9445897891321766, con deviazione standard = 0.2547072190187482

# %% [markdown]
# # No data?!

# %%
# prova = [2., 4.8, 0.1, .5, 4.3, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0      -0.2846  -0.1727     inf   3.1088    0.00000
# 1      -0.6292  -0.2744     inf   3.1138    0.00000
# 2       0.1131  -0.3201     inf   2.7703    0.00195
# 3       0.5532  -0.2718     inf   2.8799    0.00391
# 4       0.8077  -0.3227     inf   2.9844    0.00586
# ...        ...      ...     ...      ...        ...
# 12325  -0.6876  -0.2083     inf   3.0989   12.84375
# 12326  -1.1736  -0.3218     inf   2.9943   12.84570
# 12327  -0.5444  -0.2981     inf   2.6360   12.84570
# 12328  -0.5585  -0.2506     inf   2.6360   12.84766
# 12329  -0.1679  -0.2591     inf   2.7455   12.84764
#
# [12330 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.6262192302070138, con deviazione standard = 0.35762158478195816

# %%
prova = [.5, 3., 0.1, 1.2, 2.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.47564191603712697, mu_1 = 3.133313532626412, sigma_1 = 0.142855479909407
# c_2 = 1.1030165181330964, mu_2 = 2.502972379586511, sigma_2 = 0.30405695258706944
# sigma_c_1 = 0.03780636317604058, sigma_mu_1 = 0.01484402805721233, sigma_sigma_1 = 0.015478658269971095
# sigma_c_2 = 0.023104809091145602, sigma_mu_2 = 0.01080131588835994, sigma_sigma_2 = 0.01134785603581734
# w_U = 0.8406725925847616, sigma_w_U = 0.00728937347573547
# w_N = 0.17032051381503466, sigma_w_N = 0.1129695731107955

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4942 sec nello stato nativo e 15583 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0       0.4472   0.0206     inf   2.8052    0.00000
# 1      -0.0707  -0.1930     inf   2.6426    0.00196
# 2      -0.3111  -0.1422     inf   2.7753    0.00196
# 3      -0.3394  -0.1523     inf   2.5961    0.00391
# 4      -0.6982   0.0002     inf   2.2477    0.00391
# ...        ...      ...     ...      ...        ...
# 20520   0.1926  -0.1040     inf   2.2726   21.43360
# 20521   0.0495  -0.0710     inf   2.5165   21.43750
# 20522   0.7653  -0.0430     inf   2.2527   21.43750
# 20523   1.4812   0.0028     inf   1.9640   21.43946
# 20524   1.2531  -0.0201     inf   1.9939   21.43945
#
# [20525 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.636743118708744, con deviazione standard = 0.34864891644930507

# %%
prova = [0.6, 3.0, 0.1, 1.5, 2.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8685083879447304, mu_1 = 3.0013629495056704, sigma_1 = 0.19017742551498973
# c_2 = 1.5019880433298913, mu_2 = 2.377813823611331, sigma_2 = 0.156806547072655
# sigma_c_1 = 0.029278774080418485, sigma_mu_1 = 0.008128361622832198, sigma_sigma_1 = 0.008982224275071386
# sigma_c_2 = 0.03131499667883173, sigma_mu_2 = 0.004315943199542625, sigma_sigma_2 = 0.004419599817087733
# w_U = 0.5903649986208075, sigma_w_U = 0.014514858636429139
# w_N = 0.4140215198331473, sigma_w_N = 0.03425752343672062

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4825 sec nello stato nativo e 6699 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0      -0.5285  -0.0252     inf   2.4319    0.00000
# 1      -0.1343   0.1019     inf   2.3174    0.00195
# 2       0.5797   0.0206     inf   2.3373    0.00195
# 3      -0.0248  -0.0049     inf   2.6459    0.00391
# 4       0.1237  -0.0455     inf   2.3473    0.00391
# ...        ...      ...     ...      ...        ...
# 11519   0.8820  -0.1218     inf   2.9794   12.00391
# 11520   0.7282  -0.0354     inf   2.9446   12.00586
# 11521  -0.2210  -0.2667     inf   3.0740   12.00586
# 11522  -0.3889  -0.0744     inf   2.9877   12.00781
# 11523  -0.0495  -0.0371     inf   3.0607   12.00776
#
# [11524 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.9061128799939207, con deviazione standard = 0.29524652034480514

# %%
prova = [.5, 3.3, 0.1, 1.5, 2.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.751366508027307, mu_1 = 3.366233214803683, sigma_1 = 0.11796140905874049
# c_2 = 2.0708528711140026, mu_2 = 2.758764179215437, sigma_2 = 0.14879946908629235
# sigma_c_1 = 0.053353803327590446, sigma_mu_1 = 0.009805202362767185, sigma_sigma_1 = 0.009897656190202886
# sigma_c_2 = 0.04708288824159633, sigma_mu_2 = 0.003939694651512343, sigma_sigma_2 = 0.003996308947838681
# w_U = 0.7723969679712123, sigma_w_U = 0.007817742599099023
# w_N = 0.2221681089235792, sigma_w_N = 0.08490212934257423

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3103 sec nello stato nativo e 10088 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0      -0.0990  -0.2235     inf   3.6514    0.00000
# 1      -0.0566  -0.1625     inf   3.4921    0.00000
# 2      -0.0672  -0.1650     inf   3.5518    0.00195
# 3      -0.1679  -0.1930     inf   3.4622    0.00195
# 4      -0.0407  -0.2820     inf   3.2880    0.00390
# ...        ...      ...     ...      ...        ...
# 13186   0.5055  -0.1650     inf   2.6160   13.77734
# 13187   0.7600  -0.1015     inf   2.7455   13.77734
# 13188   0.5850  -0.0125     inf   2.7056   13.77929
# 13189   0.8236  -0.0837     inf   2.4269   13.77929
# 13190   0.1767  -0.2388     inf   2.5862   13.78118
#
# [13191 rows x 5 columns]

# %% [markdown]
# # File 10

# %%
grafici = Graph_hop(dir_name, number, 10)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.527440434900383, con deviazione standard = 0.15285503112060292

# %% [markdown]
# # NO hop

# %%
# prova = [1., 5.6, 0.1, 1.5, 5., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0      -0.2846  -0.2718     inf   1.9939    0.00000
# 1      -0.5444  -0.2795     inf   1.8296    0.00195
# 2       0.1979  -0.0303     inf   2.0586    0.00195
# 3      -0.3323  -0.3201     inf   2.2776    0.00390
# 4      -0.2422  -0.4142     inf   2.1780    0.00390
# ...        ...      ...     ...      ...        ...
# 14757  -0.2970  -0.2303     inf   2.3307   15.41406
# 14758  -0.0142  -0.2676     inf   2.5099   15.41601
# 14759  -0.3641  -0.0099     inf   2.7703   15.41797
# 14760  -0.4384   0.0892     inf   2.8749   15.41797
# 14761  -0.7936  -0.1625     inf   2.7256   15.41986
#
# [14762 rows x 5 columns]

# %% [markdown]
# # File 11

# %%
grafici = Graph_hop(dir_name, number, 11)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.9941723003783633, con deviazione standard = 0.14164145675836862

# %% [markdown]
# # NO hop

# %%
# prova = [.5, 5.8, 0.1, 1.5, 5.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0       0.2969  -0.5117     inf   3.1470    0.00000
# 1      -0.1485  -0.5015     inf   2.9412    0.00000
# 2       0.6009  -0.4676     inf   2.8848    0.00196
# 3       0.6858  -0.4168     inf   2.8948    0.00196
# 4       0.2192  -0.3761     inf   3.1138    0.00391
# ...        ...      ...     ...      ...        ...
# 10302   0.6292  -0.1693     inf   2.9213   10.67969
# 10303   0.4313  -0.2439     inf   3.0192   10.67969
# 10304   0.5956  -0.2795     inf   3.0342   10.68164
# 10305  -0.1308  -0.3328     inf   2.9446   10.68164
# 10306  -0.4171  -0.2464     inf   3.1238   10.68352
#
# [10307 rows x 5 columns]

# %% [markdown]
# # File 12

# %%
grafici = Graph_hop(dir_name, number, 12)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.3216092060578233, con deviazione standard = 0.15638332659888757

# %% [markdown]
# # No hop

# %%
# prova = [.5, 3.3, 0.1, 1.5, 2.7, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0       0.7176  -0.2032     inf   3.4075    0.00000
# 1       0.4454  -0.4032     inf   3.3859    0.00195
# 2       0.2086  -0.4549     inf   3.3229    0.00391
# 3       0.3729  -0.4193     inf   3.4075    0.00391
# 4      -0.0566  -0.3812     inf   3.3577    0.00586
# ...        ...      ...     ...      ...        ...
# 10890   0.1131  -0.0506     inf   3.6182   11.36328
# 10891  -0.3252  -0.2405     inf   3.5253   11.36523
# 10892  -0.3535  -0.3608     inf   3.5618   11.36719
# 10893  -0.0460  -0.4803     inf   3.6364   11.36719
# 10894  -0.0195  -0.4981     inf   3.6215   11.36913
#
# [10895 rows x 5 columns]

# %% [markdown]
# # File 13

# %%
grafici = Graph_hop(dir_name, number, 13)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.024609362808827, con deviazione standard = 0.1253069726000071

# %%
prova = [5, 4., 0.1, 0.1, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 5.45787166975924, mu_1 = 4.046088851111825, sigma_1 = 0.06974259061960893
# c_2 = 0.21510323091268313, mu_2 = 3.5488906121677606, sigma_2 = 0.07215268591133671
# sigma_c_1 = 0.10562611151949128, sigma_mu_1 = 0.0016046844027373516, sigma_sigma_1 = 0.0015395220463882019
# sigma_c_2 = 0.10227526698842933, sigma_mu_2 = 0.0404931677416383, sigma_sigma_2 = 0.03929993014138319
# w_U = 0.038903562297130795, sigma_w_U = 0.6898529932114165
# w_N = 0.9541383007470599, sigma_w_N = 0.0011420795095297245

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8098 sec nello stato nativo e 361 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force  lambda  Y_force  time(sec)
# 0      0.8395  -0.0913     inf   3.5916    0.00000
# 1     -0.0990  -0.2667     inf   3.5419    0.00391
# 2     -0.0142  -0.4574     inf   3.5120    0.00391
# 3      0.3570  -0.3761     inf   3.6215    0.00586
# 4     -0.4171  -0.5362     inf   3.6315    0.00586
# ...       ...      ...     ...      ...        ...
# 8454  -0.6292  -0.5456     inf   3.9965    8.81836
# 8455  -0.6575  -0.6405     inf   4.0894    8.82031
# 8456  -1.2655  -0.7066     inf   3.9898    8.82031
# 8457  -1.0481  -0.5388     inf   4.0247    8.82227
# 8458   0.0601  -0.4396     inf   4.0645    8.82219
#
# [8459 rows x 5 columns]

# %% [markdown]
# # File 14

# %%
grafici = Graph_hop(dir_name, number, 14)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.7598621922162954, con deviazione standard = 0.2703889476811766

# %% [markdown]
# # No hop
# # Drift?!

# %%
# prova = [.5, 3.3, 0.1, 1.5, 2.7, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force  lambda  Y_force  time(sec)
# 0       0.1979  -0.6134     inf   3.2598    0.00000
# 1       0.2616  -0.5557     inf   3.1735    0.00000
# 2      -0.3111  -0.5286     inf   3.2532    0.00195
# 3      -0.3747  -0.4676     inf   3.0740    0.00195
# 4       0.1979  -0.3184     inf   2.9479    0.00390
# ...        ...      ...     ...      ...        ...
# 62945  -0.3588  -0.5083     inf   2.2925   65.72656
# 62946  -0.7459  -0.6202     inf   2.3970   65.72851
# 62947  -0.7088  -0.6659     inf   2.3672   65.73047
# 62948  -0.6717  -0.6964     inf   2.3572   65.73047
# 62949   0.4260  -0.5362     inf   2.3572   65.73241
#
# [62950 rows x 5 columns]

# %% [markdown]
# # File 15

# %%
grafici = Graph_hop(dir_name, number, 15)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 6.089668682108995, con deviazione standard = 6.721888532446118

# %% [markdown]
# # No data -> break

# %%
forces_average
# Out:
# [4.372723464270064,
#  4.553956941998097,
#  3.7260931440550724,
#  3.623781518076198,
#  2.8181429561064615,
#  2.6895883865585004,
#  3.06249869700956,
#  3.797489731639793]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.5517321879793213, con sigma = 0.7304970710907821
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = -1.9931549188906412, con sigma = 0.28816338998984736
# La differenza di energia libera DeltaG_NU = -7.079152481053204, con sigma = 1.035571526692091

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = 0.41691797258678653, con incertezza = 0.4839645205753841,
#  q1 = 6.888749017568922, con incertezza = 1.7604142074221565
# Stimiamo i parametri del fit lineare: m2 = -0.6775148107704424, con incertezza = 0.6212541227118161,
#  q2 = 10.929343002572555, con incertezza = 2.259803199804589
# La forza di coesistenza qui vale: fc = 3.6919526228087785, con incertezza = 3.7293823681801
# Il tempo medi di residenza vale: tc = 4573.300439043038, con incertezza = 9049.651791708531
# Stimiamo un nuovo DeltaG_NU = -7.35863353046252, con incertezza = 7.508985419580972
# ((0.41691797258678653, 0.4839645205753841),
#  (6.888749017568922, 1.7604142074221565),
#  (-0.6775148107704424, 0.6212541227118161),
#  (10.929343002572555, 2.259803199804589),
#  (3.6919526228087785, 3.7293823681801),
#  (4573.300439043038, 9049.651791708531),
#  (-7.35863353046252, 7.508985419580972))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 1
forces_average = remove_element(forces_average, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.668805417673707, con sigma = 1.1620121483293067
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 4.89362140217587, con sigma = 0.8253090788876167
# La differenza di energia libera DeltaG_NU = 22.847366114522703, con sigma = 4.181922686258791

# %%
f_c
# Out:
# (4.668805417673707, 1.1620121483293067)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -23.560023273718354, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.7334798673136403, con incertezza = 0.12927037426281537,
#  q1 = 11.638855909920455, con incertezza = 0.6388283033512577
# Stimiamo i parametri del fit lineare: m2 = 0.8347861157888705, con incertezza = 0.20670924583825334,
#  q2 = 4.195367392663198, con incertezza = 1.0215156956870586
# La forza di coesistenza qui vale: fc = 4.746317651124304, con incertezza = 1.0651990952437893
# Il tempo medi di residenza vale: tc = 3489.547912867521, con incertezza = 11912.939673326051
# Stimiamo un nuovo DeltaG_NU = 23.226681639067, con incertezza = 6.520455187080774

# %%
f_c, t_c
# Out:
# ((4.746317651124304, 1.0651990952437893),
#  (3489.547912867521, 11912.939673326051))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.849272340694444,
#   5.285990512264542,
#   5.665308804623351,
#   4.5057134060897415,
#   4.2125882001055315,
#   4.907164012892104,
#   5.310035992167196,
#   5.494785624269275],
#  [6207, 3051, 2156, 4249, 5566, 3139, 2177, 1322])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = 4
forces_average = remove_element(forces_average, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.643256587951081, con sigma = 1.2476709761679226
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 4.670865552573294, con sigma = 0.8472896863705333
# La differenza di energia libera DeltaG_NU = 21.68802724841971, con sigma = 4.299340363217984

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.7090831766022296, con incertezza = 0.15454885036415758,
#  q1 = 11.506033826331537, con incertezza = 0.7785186585989363
# Stimiamo i parametri del fit lineare: m2 = 0.7090235159146061, con incertezza = 0.2131404833164646,
#  q2 = 4.880052474278517, con incertezza = 1.0736659653082594
# La forza di coesistenza qui vale: fc = 4.672413850817756, con incertezza = 1.2755662921008393
# Il tempo medi di residenza vale: tc = 3615.2047449399365, con incertezza = 12182.461995427579
# Stimiamo un nuovo DeltaG_NU = 21.824216903150987, con incertezza = 7.153358839018941
# ((-0.7090831766022296, 0.15454885036415758),
#  (11.506033826331537, 0.7785186585989363),
#  (0.7090235159146061, 0.2131404833164646),
#  (4.880052474278517, 1.0736659653082594),
#  (4.672413850817756, 1.2755662921008393),
#  (3615.2047449399365, 12182.461995427579),
#  (21.824216903150987, 7.153358839018941))
