# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 14bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/14cp"
# molecule name is a number in these experimets
number = "14"

# %%
file = Txt_hop(dir_name, number, different_name="hopcp", first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.5730  -0.0932 -192.22785   4.6908  20552.01758
# 1      -0.0076  -0.0236 -191.47140   4.5292  20552.01758
# 2       0.1529  -0.0274 -192.32165   4.5898  20552.01953
# 3      -0.0495  -0.0323 -192.01725   4.4383  20552.01953
# 4      -0.1961   0.1707 -192.18140   4.2211  20552.02148
# ...        ...      ...        ...      ...          ...
# 51896  -0.4787  -0.1396 -202.11860   4.5847  20685.33984
# 51897  -0.1856  -0.0700 -201.67610   4.5241  20685.33984
# 51898   0.0238  -0.0700 -201.95490   4.7059  20685.34180
# 51899  -0.0285  -0.1048 -201.14295   4.7413  20685.34180
# 51900  -0.6515  -0.0787 -201.94345   4.6706  20685.34370
#
# [51901 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.749707252635607, con deviazione standard = 0.3054215094786547

# %%
prova = [2., 4.9, 0.1, 0.5, 4.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.7683136033524405, mu_1 = 4.926071035488431, sigma_1 = 0.1491255854167658
# c_2 = 0.730071736399064, mu_2 = 4.385061053917408, sigma_2 = 0.18098993755108378
# sigma_c_1 = 0.03979856366512559, sigma_mu_1 = 0.005099541746847006, sigma_sigma_1 = 0.0053926136341325885
# sigma_c_2 = 0.035368766756451855, sigma_mu_2 = 0.013293207992491491, sigma_sigma_2 = 0.013356362518200663
# w_U = 0.33121492624375987, sigma_w_U = 0.04025291182323126
# w_N = 0.6609998845823418, sigma_w_N = 0.009562063474526875

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.1530000000000005 sec nello stato nativo e 2.72 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5730  -0.0932 -192.22785   4.6908    0.00000
# 1     -0.0076  -0.0236 -191.47140   4.5292    0.00000
# 2      0.1529  -0.0274 -192.32165   4.5898    0.00195
# 3     -0.0495  -0.0323 -192.01725   4.4383    0.00195
# 4     -0.1961   0.1707 -192.18140   4.2211    0.00390
# ...       ...      ...        ...      ...        ...
# 7868  -0.4630  -0.0323 -192.55005   4.8726    8.21484
# 7869   0.2960  -0.1309 -192.43440   5.1099    8.21484
# 7870   0.5892  -0.0323 -192.75305   5.1655    8.21680
# 7871   1.0603   0.0779 -192.86490   5.0493    8.21680
# 7872   0.5857   0.0499 -192.66700   4.9803    8.21872
#
# [7873 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8364005866249498, con deviazione standard = 0.1851242489233129

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [0.4, 4.9, 0.1, 1.4, 4.3, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par, True, 500)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.1332   0.2935 -209.28330   3.3441    0.00000
# 1     -0.3740   0.1562 -209.12175   3.3071    0.00195
# 2     -0.4055  -0.0004 -209.46075   3.1051    0.00195
# 3      0.0029  -0.0410 -209.28725   3.4687    0.00391
# 4     -0.6428  -0.1125 -209.49660   3.4990    0.00391
# ...       ...      ...        ...      ...        ...
# 7666   0.0971  -0.0874 -209.62430   3.8878    7.99414
# 7667  -0.1594  -0.2817 -209.75215   3.6303    7.99609
# 7668  -0.4473  -0.3078 -209.48950   3.7919    7.99609
# 7669   0.0448  -0.1454 -209.42915   3.7515    7.99609
# 7670   0.4601  -0.0468 -209.59105   3.7683    7.99805
#
# [7671 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.6697951778965345, con deviazione standard = 0.2749205366284237

# %%
prova = [2., 4.8, 0.1, 0.5, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.188839350218204, mu_1 = 4.768768517610672, sigma_1 = 0.14821465600230188
# c_2 = 0.41237048101870577, mu_2 = 4.1905185122288025, sigma_2 = 0.16885413100950583
# sigma_c_1 = 0.04446385253955473, sigma_mu_1 = 0.0038739786486336283, sigma_sigma_1 = 0.004168899524270673
# sigma_c_2 = 0.04065060866794384, sigma_mu_2 = 0.02152193218882699, sigma_sigma_2 = 0.022389486179766903
# w_U = 0.17453767787239885, sigma_w_U = 0.09660634116572006
# w_N = 0.813195510414313, sigma_w_N = 0.004312326292585543

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.16 sec nello stato nativo e 1.5130000000000001 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3641   0.3186 -199.34590   4.1100    0.00000
# 1      0.3623   0.2896 -199.46400   4.1117    0.00000
# 2      0.0133   0.1156 -199.59900   4.6235    0.00586
# 3      0.3274   0.0074 -199.45280   4.4080    0.00586
# 4     -0.3287  -0.0661 -199.19785   4.1050    0.00781
# ...       ...      ...        ...      ...        ...
# 7668   0.4060  -0.1193 -199.65865   4.8473    7.99414
# 7669   0.0971  -0.0961 -199.57770   4.9130    7.99609
# 7670   0.0971  -0.0468 -199.76785   5.0847    7.99609
# 7671   0.2716   0.1195 -199.92780   4.8726    7.99805
# 7672   0.3554   0.0267 -199.79150   5.0409    7.99805
#
# [7673 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.652238654370695, con deviazione standard = 0.24606924573502575

# %%
prova = [2., 4.7, 0.1, .5, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.173516396864293, mu_1 = 4.716715545281374, sigma_1 = 0.15846825765686753
# c_2 = 0.31678877665368516, mu_2 = 4.182961370502268, sigma_2 = 0.15506316192605127
# sigma_c_1 = 0.045534006905079, sigma_mu_1 = 0.004626832181190097, sigma_sigma_1 = 0.005086457106259016
# sigma_c_2 = 0.044304772765159775, sigma_mu_2 = 0.0313053097211339, sigma_sigma_2 = 0.03104778117016908
# w_U = 0.12313126931840154, sigma_w_U = 0.14849487054962587
# w_N = 0.8633663898775874, sigma_w_N = 0.003249463668474196

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.476 sec nello stato nativo e 1.223 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.9871   0.0257 -194.42535   5.0392    0.00000
# 1      0.8719  -0.0903 -194.18305   5.1705    0.00391
# 2      0.5787  -0.0584 -193.83640   5.1756    0.00391
# 3     -0.1018  -0.0468 -194.41365   4.9736    0.00586
# 4      0.4636   0.0170 -194.36420   4.9685    0.00586
# ...       ...      ...        ...      ...        ...
# 7694   0.2018   0.0538 -194.84320   4.5965    7.99414
# 7695  -0.0756  -0.0149 -194.85995   4.6201    7.99610
# 7696   0.1599   0.0112 -194.62945   4.8120    7.99610
# 7697   0.1809   0.0170 -194.93955   4.9130    7.99610
# 7698   0.1599   0.1388 -195.67015   4.6706    7.99805
#
# [7699 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.7811943884892125, con deviazione standard = 0.3196215227843051

# %%
prova = [1., 5., 0.1, 1., 4.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.3497857670948454, mu_1 = 5.043828722955962, sigma_1 = 0.14732630038323338
# c_2 = 1.0831629172896422, mu_2 = 4.506559230278922, sigma_2 = 0.18216862644214854
# sigma_c_1 = 0.036292271176167464, sigma_mu_1 = 0.006080974235302308, sigma_sigma_1 = 0.00640602451661845
# sigma_c_2 = 0.031967735830859434, sigma_mu_2 = 0.008219979698947387, sigma_sigma_2 = 0.008236094745284818
# w_U = 0.4946036320271057, sigma_w_U = 0.018530940727579152
# w_N = 0.49846545012959764, sigma_w_N = 0.017102149161952084

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.899 sec nello stato nativo e 3.746 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.4159   0.0199 -200.88700   4.8423    0.00000
# 1     -0.1612  -0.1280 -201.55440   5.0140    0.00000
# 2      0.1180  -0.1280 -201.82830   4.9534    0.00196
# 3     -0.0076  -0.3484 -201.14745   5.1487    0.00391
# 4     -0.2170  -0.2875 -201.00830   5.0392    0.00391
# ...       ...      ...        ...      ...        ...
# 7640  -0.1332   0.1814 -201.35120   5.1487    7.99414
# 7641   0.1111   0.0460 -201.77195   5.0477    7.99610
# 7642   0.0692  -0.0893 -201.64075   5.2699    7.99610
# 7643   0.0831  -0.1086 -201.18545   5.2901    7.99805
# 7644   0.1809  -0.1318 -201.75570   5.3372    7.99805
#
# [7645 rows x 5 columns]

# %%
forces_average
# Out:
# [4.655566044702919, 4.479643514919737, 4.44983845789182, 4.775193976617443]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.776797062357976, con sigma = 1.1322193012437505
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 23.02176752497955, con sigma = 3.867130182403907
# La differenza di energia libera DeltaG_NU = 109.97031148361056, con sigma = 18.389862947860703

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 40.967767796037215, con sigma = 6.269396146437553

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5881911614727591, con incertezza = 0.02008161267951969,
#  q1 = 5.5833257285868125, con incertezza = 0.030798263769487983
# Stimiamo i parametri del fit lineare: m2 = 0.31305683693634956, con incertezza = 0.010480221515981885,
#  q2 = 4.356321488656373, con incertezza = 0.01172712918275918
# La forza di coesistenza qui vale: fc = 4.782532772274387, con incertezza = 0.01870643958363092
# Il tempo medi di residenza vale: tc = 3.9018475401514667, con incertezza = 0.1954046109069716
# Stimiamo un nuovo DeltaG_NU = 110.10235766389692, con incertezza = 18.499690135521753
# ((-0.5881911614727591, 0.02008161267951969),
#  (5.5833257285868125, 0.030798263769487983),
#  (0.31305683693634956, 0.010480221515981885),
#  (4.356321488656373, 0.01172712918275918),
#  (4.782532772274387, 0.01870643958363092),
#  (3.9018475401514667, 0.1954046109069716),
#  (110.10235766389692, 18.499690135521753))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare il pimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.7768527581335505, con sigma = 1.1706849177509873
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 22.92754799215829, con sigma = 3.9819377122326767
# La differenza di energia libera DeltaG_NU = 109.52152086358068, con sigma = 18.937591720479052

# %%
f_c
# Out:
# (4.7768527581335505, 1.1706849177509873)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 40.96852722985821, con sigma = 6.48001376488443

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5624313683579517, con incertezza = 0.022514255305571294,
#  q1 = 5.546740548239988, con incertezza = 0.03402271433709345
# Stimiamo i parametri del fit lineare: m2 = 0.3315759059603839, con incertezza = 0.012925915487481945,
#  q2 = 4.333906754859937, con incertezza = 0.014879070425504858
# La forza di coesistenza qui vale: fc = 4.783731354023282, con incertezza = 0.02229080519002188
# Il tempo medi di residenza vale: tc = 3.8830709174241465, con incertezza = 0.22229490540638708
# Stimiamo un nuovo DeltaG_NU = 109.67923020096113, con incertezza = 19.055375124350167
# ((-0.5624313683579517, 0.022514255305571294),
#  (5.546740548239988, 0.03402271433709345),
#  (0.3315759059603839, 0.012925915487481945),
#  (4.333906754859937, 0.014879070425504858),
#  (4.783731354023282, 0.02229080519002188),
#  (3.8830709174241465, 0.22229490540638708),
#  (109.67923020096113, 19.055375124350167))

# %%
grafici.write_on_txt()
