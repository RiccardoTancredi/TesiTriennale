# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 14bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/14cp"
# molecule name is a number in these experimets
number = "14"

# %%
file = Txt_hop(dir_name, number, different_name="hopcp", first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.5730  -0.0932 -192.22785   4.6908  20552.01758
# 1      -0.0076  -0.0236 -191.47140   4.5292  20552.01758
# 2       0.1529  -0.0274 -192.32165   4.5898  20552.01953
# 3      -0.0495  -0.0323 -192.01725   4.4383  20552.01953
# 4      -0.1961   0.1707 -192.18140   4.2211  20552.02148
# ...        ...      ...        ...      ...          ...
# 51896  -0.4787  -0.1396 -202.11860   4.5847  20685.33984
# 51897  -0.1856  -0.0700 -201.67610   4.5241  20685.33984
# 51898   0.0238  -0.0700 -201.95490   4.7059  20685.34180
# 51899  -0.0285  -0.1048 -201.14295   4.7413  20685.34180
# 51900  -0.6515  -0.0787 -201.94345   4.6706  20685.34370
#
# [51901 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.749707252635607, con deviazione standard = 0.3054215094786547

# %%
prova = [2., 4.9, 0.1, 0.5, 4.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.7683136033524405, mu_1 = 4.926071035488431, sigma_1 = 0.1491255854167658
# c_2 = 0.730071736399064, mu_2 = 4.385061053917408, sigma_2 = 0.18098993755108378
# sigma_c_1 = 0.03979856366512559, sigma_mu_1 = 0.005099541746847006, sigma_sigma_1 = 0.0053926136341325885
# sigma_c_2 = 0.035368766756451855, sigma_mu_2 = 0.013293207992491491, sigma_sigma_2 = 0.013356362518200663
# w_U = 0.33121492624375987, sigma_w_U = 0.05835116626693771
# w_N = 0.6609998845823418, sigma_w_N = 0.014107583457968633

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5144 sec nello stato nativo e 2729 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5730  -0.0932 -192.22785   4.6908    0.00000
# 1     -0.0076  -0.0236 -191.47140   4.5292    0.00000
# 2      0.1529  -0.0274 -192.32165   4.5898    0.00195
# 3     -0.0495  -0.0323 -192.01725   4.4383    0.00195
# 4     -0.1961   0.1707 -192.18140   4.2211    0.00390
# ...       ...      ...        ...      ...        ...
# 7868  -0.4630  -0.0323 -192.55005   4.8726    8.21484
# 7869   0.2960  -0.1309 -192.43440   5.1099    8.21484
# 7870   0.5892  -0.0323 -192.75305   5.1655    8.21680
# 7871   1.0603   0.0779 -192.86490   5.0493    8.21680
# 7872   0.5857   0.0499 -192.66700   4.9803    8.21872
#
# [7873 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7933457894736713, con deviazione standard = 0.1962193941555414

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [0.4, 4.9, 0.1, 1.4, 4.3, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par, True, 500)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.1332   0.2935 -209.28330   3.3441    0.00000
# 1      -0.3740   0.1562 -209.12175   3.3071    0.00195
# 2      -0.4055  -0.0004 -209.46075   3.1051    0.00195
# 3       0.0029  -0.0410 -209.28725   3.4687    0.00391
# 4      -0.6428  -0.1125 -209.49660   3.4990    0.00391
# ...        ...      ...        ...      ...        ...
# 11775  -0.2484  -0.2208 -210.01470   3.6555   12.30664
# 11776   0.0238  -0.3281 -209.56610   3.8424   12.30664
# 11777   0.2908  -0.2324 -210.09775   3.9686   12.30859
# 11778   0.4950  -0.3165 -209.81425   3.9585   12.30859
# 11779  -0.1402  -0.4798 -209.83985   4.1117   12.30857
#
# [11780 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.646847551965334, con deviazione standard = 0.28937910938326983

# %%
prova = [2., 4.8, 0.1, 0.5, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.095135511217402, mu_1 = 4.772140871440359, sigma_1 = 0.14558533123141024
# c_2 = 0.5093291977836527, mu_2 = 4.202366309708266, sigma_2 = 0.17557584052996358
# sigma_c_1 = 0.033997707229558895, sigma_mu_1 = 0.0031494048678975257, sigma_sigma_1 = 0.00337495386170739
# sigma_c_2 = 0.030284530467308723, sigma_mu_2 = 0.01386563823725109, sigma_sigma_2 = 0.0144595671649393
# w_U = 0.22415749445592165, sigma_w_U = 0.07766287876078146
# w_N = 0.7645742563770138, sigma_w_N = 0.006342976231011332

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7644 sec nello stato nativo e 2507 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.3641   0.3186 -199.34590   4.1100    0.00000
# 1       0.3623   0.2896 -199.46400   4.1117    0.00000
# 2       0.0133   0.1156 -199.59900   4.6235    0.00586
# 3       0.3274   0.0074 -199.45280   4.4080    0.00586
# 4      -0.3287  -0.0661 -199.19785   4.1050    0.00781
# ...        ...      ...        ...      ...        ...
# 10146   0.3746   0.0750 -200.36830   4.8019   10.60547
# 10147   0.2123   0.1678 -200.56695   4.7211   10.60742
# 10148   0.3117   0.2403 -200.48485   4.7110   10.60742
# 10149   0.6206   0.2345 -200.30440   4.6958   10.60937
# 10150   0.3379   0.0286 -200.11535   4.9584   10.60929
#
# [10151 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.636693065456918, con deviazione standard = 0.26271468251391805

# %%
prova = [2., 4.7, 0.1, .5, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.0557081389572898, mu_1 = 4.728777562591833, sigma_1 = 0.1586615348491152
# c_2 = 0.4250733724383427, mu_2 = 4.2045187686381436, sigma_2 = 0.1614297515981934
# sigma_c_1 = 0.04411054211719094, sigma_mu_1 = 0.005134176667986745, sigma_sigma_1 = 0.005565521260125238
# sigma_c_2 = 0.0422774138689587, sigma_mu_2 = 0.024873876896127644, sigma_sigma_2 = 0.02411675101551838
# w_U = 0.1720035511269454, sigma_w_U = 0.14673185690647986
# w_N = 0.817566411363027, sigma_w_N = 0.007072861907155352

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8571 sec nello stato nativo e 2230 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.9871   0.0257 -194.42535   5.0392    0.00000
# 1       0.8719  -0.0903 -194.18305   5.1705    0.00391
# 2       0.5787  -0.0584 -193.83640   5.1756    0.00391
# 3      -0.1018  -0.0468 -194.41365   4.9736    0.00586
# 4       0.4636   0.0170 -194.36420   4.9685    0.00586
# ...        ...      ...        ...      ...        ...
# 10796   0.0413  -0.0584 -194.77850   4.7649   11.22266
# 10797   0.3693   0.0847 -195.01250   4.8524   11.22266
# 10798   0.1442   0.0779 -194.96015   4.8726   11.22461
# 10799  -0.1332   0.2374 -194.76770   5.0140   11.22657
# 10800   0.3693   0.3215 -195.24330   4.7261   11.22656
#
# [10801 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.8342322503541135, con deviazione standard = 0.3372097038283678

# %%
prova = [1., 5., 0.1, 1., 4.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.045725339480033, mu_1 = 5.058484341683905, sigma_1 = 0.2134001909986449
# c_2 = 0.9484935382110338, mu_2 = 4.530991039097019, sigma_2 = 0.18104858752809966
# sigma_c_1 = 0.025771816552342643, sigma_mu_1 = 0.01405643001554049, sigma_sigma_1 = 0.013081384533168709
# sigma_c_2 = 0.03926367675375224, sigma_mu_2 = 0.013691471831575779, sigma_sigma_2 = 0.009489303958550882
# w_U = 0.43044676838925644, sigma_w_U = 0.037359909388962095
# w_N = 0.559374120368016, sigma_w_N = 0.028438934041950338

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6208 sec nello stato nativo e 5088 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.4159   0.0199 -200.88700   4.8423    0.00000
# 1      -0.1612  -0.1280 -201.55440   5.0140    0.00000
# 2       0.1180  -0.1280 -201.82830   4.9534    0.00196
# 3      -0.0076  -0.3484 -201.14745   5.1487    0.00391
# 4      -0.2170  -0.2875 -201.00830   5.0392    0.00391
# ...        ...      ...        ...      ...        ...
# 11291  -0.4787  -0.1396 -202.11860   4.5847   11.80078
# 11292  -0.1856  -0.0700 -201.67610   4.5241   11.80078
# 11293   0.0238  -0.0700 -201.95490   4.7059   11.80274
# 11294  -0.0285  -0.1048 -201.14295   4.7413   11.80274
# 11295  -0.6515  -0.0787 -201.94345   4.6706   11.80464
#
# [11296 rows x 5 columns]

# %%
forces_average
# Out:
# [4.655566044702919, 4.487253590574312, 4.466648165614988, 4.794737690390463]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.875555738830059, con sigma = 1.9719684698810638
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 13.181707604084815, con sigma = 3.821654075889845
# La differenza di energia libera DeltaG_NU = 64.26815015667555, con sigma = 18.124745716802103

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -24.715121126876554, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.0808283803948016, con incertezza = 0.6986864827250032,
#  q1 = 13.792195984675065, con incertezza = 3.2160492871312942
# Stimiamo i parametri del fit lineare: m2 = 2.2021269720606482, con incertezza = 0.6534413474382195,
#  q2 = -2.1363669330473254, con incertezza = 3.0077862550564944
# La forza di coesistenza qui vale: fc = 4.851897515392282, con incertezza = 1.9488245810152716
# Il tempo medi di residenza vale: tc = 5157.088480548268, con incertezza = 22347.42803141948
# Stimiamo un nuovo DeltaG_NU = 63.95629437288666, con incertezza = 31.681733012015506
# ((-1.0808283803948016, 0.6986864827250032),
#  (13.792195984675065, 3.2160492871312942),
#  (2.2021269720606482, 0.6534413474382195),
#  (-2.1363669330473254, 3.0077862550564944),
#  (4.851897515392282, 1.9488245810152716),
#  (5157.088480548268, 22347.42803141948),
#  (63.95629437288666, 31.681733012015506))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare il pimo punto, quello più in alto
forces_average = remove_element(forces_average, 3)
w_U = remove_element(w_U, 3)
w_N = remove_element(w_N, 3)
sigma_w_U = remove_element(sigma_w_U, 3)
sigma_w_N = remove_element(sigma_w_N, 3)
native_time = remove_element(native_time, 3)
unfolded_time = remove_element(unfolded_time, 3)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.856455832301354, con sigma = 4.17573243749255
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 14.112997691859782, con sigma = 8.795516645618443
# La differenza di energia libera DeltaG_NU = 68.53914995188798, con sigma = 40.60071668053597

# %%
f_c
# Out:
# (4.856455832301354, 4.17573243749255)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -24.609157395253757, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -2.567796398835792, con incertezza = 0.29844233174790863,
#  q1 = 20.49658155712637, con incertezza = 1.3541159428059917
# Stimiamo i parametri del fit lineare: m2 = 0.8510151603797402, con incertezza = 0.48267229520621624,
#  q2 = 3.9554753535893945, con incertezza = 2.1900186030489834
# La forza di coesistenza qui vale: fc = 4.838262044291331, con incertezza = 1.1009940914256044
# Il tempo medi di residenza vale: tc = 3206.4179934717417, con incertezza = 13403.833861675726
# Stimiamo un nuovo DeltaG_NU = 68.28238106369635, con incertezza = 45.30307775627789
# ((-2.567796398835792, 0.29844233174790863),
#  (20.49658155712637, 1.3541159428059917),
#  (0.8510151603797402, 0.48267229520621624),
#  (3.9554753535893945, 2.1900186030489834),
#  (4.838262044291331, 1.1009940914256044),
#  (3206.4179934717417, 13403.833861675726),
#  (68.28238106369635, 45.30307775627789))
