# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 15bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/15"
# molecule name is a number in these experimets
number = "15"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force    lambda  Y_force    time(sec)
# 0       0.0935  -0.1773  36.85240   4.8235  26103.02148
# 1       0.8752  -0.1038  36.70365   5.1265  26103.02148
# 2       0.7374  -0.1280  36.75730   5.0154  26103.02344
# 3       0.3657  -0.2208  37.01360   4.8841  26103.02344
# 4       0.8107  -0.2034  36.64605   4.8033  26103.02539
# ...        ...      ...       ...      ...          ...
# 59627  -0.5033  -0.0497   7.22150   3.3338  26209.05469
# 59628   0.0202   0.0837   6.94400   3.5812  26209.05469
# 59629   0.1511  -0.0178   7.12965   3.4954  26209.05469
# 59630  -0.1107  -0.1570   7.55255   3.3742  26209.05664
# 59631  -0.5504  -0.2527   7.02780   3.2681  26209.05850
#
# [59632 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %%
new_sigma = []

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.895567141216994, con deviazione standard = 0.20079530822172986

# %%
prova = [0.2, 5.6, 0.1, 2.5, 4.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.1485648345182451, mu_1 = 5.592908875439378, sigma_1 = 0.08076517310762095
# c_2 = 2.5187278663444226, mu_2 = 4.8637923809386585, sigma_2 = 0.1530969995440488
# sigma_c_1 = 0.07775465012023894, sigma_mu_1 = 0.05078895948242254, sigma_sigma_1 = 0.04789604179983003
# sigma_c_2 = 0.05313726124618407, sigma_mu_2 = 0.0037698639072849993, sigma_sigma_2 = 0.0037235600573765743
# w_U = 0.9665801243661067, sigma_w_U = 0.0007323921513760146
# w_N = 0.03007669321360814, sigma_w_N = 0.5814272712461012

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
new_sigma.append(abs(fitting_par[1]-fitting_par[4]))

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.322 sec nello stato nativo e 8.388 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.0935  -0.1773  36.85240   4.8235    0.00000
# 1      0.8752  -0.1038  36.70365   5.1265    0.00000
# 2      0.7374  -0.1280  36.75730   5.0154    0.00196
# 3      0.3657  -0.2208  37.01360   4.8841    0.00196
# 4      0.8107  -0.2034  36.64605   4.8033    0.00391
# ...       ...      ...       ...      ...        ...
# 8705   0.5472  -0.0613  39.63660   4.9515    9.06641
# 8706  -0.2416  -0.0584  39.75840   4.8589    9.07032
# 8707  -0.1787  -0.0468  39.39750   4.9397    9.07032
# 8708  -0.4667  -0.2237  39.74960   4.6518    9.07227
# 8709  -0.5190  -0.2411  39.84395   4.6165    9.07222
#
# [8710 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.625408250762213, con deviazione standard = 0.2579441818153584

# %%
prova = [0.4, 5.2, 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.24443143481508264, mu_1 = 5.261925689453627, sigma_1 = 0.13556235502853545
# c_2 = 2.0326817566374746, mu_2 = 4.566273797848304, sigma_2 = 0.18052514475067458
# sigma_c_1 = 0.044370410490108834, sigma_mu_1 = 0.029097232710161285, sigma_sigma_1 = 0.029495027214517945
# sigma_c_2 = 0.037757280864087694, sigma_mu_2 = 0.003930132648012141, sigma_sigma_2 = 0.003995586069457963
# w_U = 0.9198076673642983, sigma_w_U = 0.0017958848920741808
# w_N = 0.08305888489230573, sigma_w_N = 0.1946563296320136

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
new_sigma.append(abs(fitting_par[1]-fitting_par[4]))

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.027 sec nello stato nativo e 9.469 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0      -0.5661  -0.0903  34.14155   4.5104    0.00000
# 1       0.2401  -0.1077  33.76890   4.3387    0.00000
# 2       1.3708   0.0083  33.76090   4.3185    0.00195
# 3       0.9939   0.0625  33.99030   4.2849    0.00195
# 4       0.0725  -0.0574  34.23330   4.2781    0.00391
# ...        ...      ...       ...      ...        ...
# 10491  -0.2520  -0.2150  25.29995   4.7478   10.92383
# 10492   0.2610  -0.1019  25.40125   4.7983   10.92578
# 10493   0.6955  -0.1715  25.56610   4.7427   10.92578
# 10494   0.2034  -0.3368  25.46305   4.8286   10.92578
# 10495   0.2034  -0.2585  25.37340   4.7023   10.92767
#
# [10496 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.225500256410272, con deviazione standard = 0.33171607217924104

# %%
prova = [0.7, 4.7, 0.1, 1.6, 4.0, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8540427682542184, mu_1 = 4.678378476620764, sigma_1 = 0.13544426004217125
# c_2 = 1.6875046641782694, mu_2 = 4.038632012007985, sigma_2 = 0.16728755123424502
# sigma_c_1 = 0.036438868271978855, sigma_mu_1 = 0.0068604469444007886, sigma_sigma_1 = 0.007035532070668559
# sigma_c_2 = 0.03230587181926297, sigma_mu_2 = 0.0037808717080539487, sigma_sigma_2 = 0.003879183262477653
# w_U = 0.7076174595550235, sigma_w_U = 0.0064895999848021265
# w_N = 0.2899547039089536, sigma_w_N = 0.03534521392160268

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
new_sigma.append(abs(fitting_par[1]-fitting_par[4]))

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.694 sec nello stato nativo e 6.276 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.1982  -0.0874  19.59950   4.6569    0.00000
# 1      0.0167  -0.1038  20.01440   4.7225    0.00000
# 2     -0.2520  -0.0323  19.59465   4.6821    0.00195
# 3     -0.0531   0.0315  19.77430   4.7831    0.00195
# 4     -0.2625  -0.0381  20.35600   4.7023    0.00391
# ...       ...      ...       ...      ...        ...
# 8965  -0.0793  -0.1802  23.76635   4.0711    9.37109
# 8966   0.4547  -0.0845  23.51030   4.0913    9.37305
# 8967   0.8421  -0.1831  23.77820   4.1115    9.37305
# 8968  -0.1212  -0.3513  23.41445   4.1216    9.37500
# 8969  -0.1997  -0.3203  23.57965   3.7327    9.37499
#
# [8970 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(9)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.9733058686809986, con deviazione standard = 0.34459570602461587

# %%
prova = [1., 4.3, 0.1, 1., 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.389369064484271, mu_1 = 4.251666851064519, sigma_1 = 0.15475625352301955
# c_2 = 1.1184904119277286, mu_2 = 3.64322410434943, sigma_2 = 0.1629799192340315
# sigma_c_1 = 0.03625269149686606, sigma_mu_1 = 0.004952928793131463, sigma_sigma_1 = 0.005306434278556301
# sigma_c_2 = 0.03463979154725945, sigma_mu_2 = 0.006253675329663662, sigma_sigma_2 = 0.006504980718219417
# w_U = 0.4569369704724963, sigma_w_U = 0.019856865116556703
# w_N = 0.538959046817531, sigma_w_N = 0.014266197673584396

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
new_sigma.append(abs(fitting_par[1]-fitting_par[4]))

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.6450000000000005 sec nello stato nativo e 3.96 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      1.0567  -0.4479   8.02230   4.2041    0.00000
# 1      0.3081  -0.3136   7.97410   4.1923    0.00391
# 2      0.0987  -0.3716   8.04525   4.1519    0.00391
# 3     -0.1787  -0.3716   8.13390   4.2327    0.00586
# 4     -0.2259  -0.4702   7.77205   4.1923    0.00586
# ...       ...      ...       ...      ...        ...
# 8600  -0.2416  -0.3087  16.11185   3.8001    8.98828
# 8601  -0.7651  -0.2266  15.90425   3.6620    8.99219
# 8602  -0.0060  -0.1686  15.80645   3.9297    8.99219
# 8603  -0.0112  -0.1077  15.97990   4.0963    8.99219
# 8604  -0.3672  -0.1425  16.01415   3.7933    8.99609
#
# [8605 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.576002635135152, con deviazione standard = 0.261533751900355

# %%
prova = [2.0, 3.7, 0.1, .5, 3.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.1563032179137864, mu_1 = 3.662878893569703, sigma_1 = 0.1531543194505762
# c_2 = 0.39396214618819964, mu_2 = 3.1135932091520315, sigma_2 = 0.1641902880854379
# sigma_c_1 = 0.04129113683567066, sigma_mu_1 = 0.004007441700995373, sigma_sigma_1 = 0.004344309193474666
# sigma_c_2 = 0.039023693694875704, sigma_mu_2 = 0.022465806298842414, sigma_sigma_2 = 0.02324806230822477
# w_U = 0.1621406440357972, sigma_w_U = 0.10078821545012855
# w_N = 0.827806848490375, sigma_w_N = 0.003863703338137801

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
new_sigma.append(abs(fitting_par[1]-fitting_par[4]))

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.188 sec nello stato nativo e 1.692 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0     -0.0845   0.0112   3.57980   3.4802    0.00000
# 1      0.0150  -0.0874   3.50275   3.3641    0.00195
# 2      0.1877  -0.2469   2.94825   3.1570    0.00195
# 3      0.3448  -0.2237   2.93155   3.3085    0.00390
# 4      0.5437  -0.2382   3.50400   3.1974    0.00390
# ...       ...      ...       ...      ...        ...
# 8875  -0.1212  -0.2701  15.20385   3.1166    9.25976
# 8876  -0.4248  -0.2962  15.22090   3.3489    9.25976
# 8877  -0.4562  -0.2585  15.83395   3.2631    9.26171
# 8878  -0.5033   0.0141  15.30485   3.4499    9.26171
# 8879   0.1772   0.0702  15.43320   3.3961    9.26358
#
# [8880 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
# grafici = Graph_hop(dir_name, number, 6)
# data_frame = grafici.do_graph(9)
# # (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)

# %%
# prova = [2., 3.5, 0.1, .5, 3., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
# data_frame

# %%
forces_average
# Out:
# [5.228350628189018,
#  4.914099743650965,
#  4.358505244314374,
#  3.9474454777069745,
#  3.3882360513608676]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.011664550206401, con sigma = 0.6700767502707684
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 10.59324820315626, con sigma = 1.2517429768810566
# La differenza di energia libera DeltaG_NU = 42.496558288139624, con sigma = 5.01692303799015

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 30.9040930408423, con sigma = 3.4460912405313846

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6748362041495016, con incertezza = 0.005855561401598513,
#  q1 = 4.982138884836884, con incertezza = 0.007680486441575005
# Stimiamo i parametri del fit lineare: m2 = 0.8640887858518219, con incertezza = 0.007459422159368573,
#  q2 = 2.7876430056728765, con incertezza = 0.012069640916712952
# La forza di coesistenza qui vale: fc = 4.019827350006659, con incertezza = 0.00950519953150922
# Il tempo medi di residenza vale: tc = 4.161987607400526, con incertezza = 0.05324015490107658
# Stimiamo un nuovo DeltaG_NU = 42.58302885245644, con incertezza = 5.032798013737301
# ((-0.6748362041495016, 0.005855561401598513),
#  (4.982138884836884, 0.007680486441575005),
#  (0.8640887858518219, 0.007459422159368573),
#  (2.7876430056728765, 0.012069640916712952),
#  (4.019827350006659, 0.00950519953150922),
#  (4.161987607400526, 0.05324015490107658),
#  (42.58302885245644, 5.032798013737301))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
forces_average_std = remove_element(forces_average_std, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.0116655737523095, con sigma = 0.670227053731808
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 10.592831110710476, con sigma = 1.251975587729248
# La differenza di energia libera DeltaG_NU = 42.494895895409655, con sigma = 5.017844969066497

# %%
f_c
# Out:
# (4.0116655737523095, 0.670227053731808)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 30.904105970350205, con sigma = 3.4468603541426446

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.7682829221879011, con incertezza = 0.006992540206829264,
#  q1 = 5.105279121763214, con incertezza = 0.009184580981684502
# Stimiamo i parametri del fit lineare: m2 = 0.8346346703252013, con incertezza = 0.007558673770982936,
#  q2 = 2.8273316607684693, con incertezza = 0.012181241448549858
# La forza di coesistenza qui vale: fc = 4.013452480083101, con incertezza = 0.010499561937435498
# Il tempo medi di residenza vale: tc = 4.1417804135430885, con incertezza = 0.05462219529099241
# Stimiamo un nuovo DeltaG_NU = 42.513824292382395, con incertezza = 5.025975276004134

# %%
f_c, t_c
# Out:
# ((4.013452480083101, 0.010499561937435498),
#  (4.1417804135430885, 0.05462219529099241))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.914099743650965,
#   4.358505244314374,
#   3.9474454777069745,
#   3.3882360513608676],
#  [1.027, 2.694, 4.6450000000000005, 7.188])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = 0
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.011681137097717, con sigma = 0.675246606062739
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 10.58778803955959, con sigma = 1.2608124089130348
# La differenza di energia libera DeltaG_NU = 42.47482956189002, con sigma = 5.052754395044933

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.8446785215658007, con incertezza = 0.008707077466800913,
#  q1 = 5.210341373809542, con incertezza = 0.011630361511829057
# Stimiamo i parametri del fit lineare: m2 = 0.7900691923171909, con incertezza = 0.008081230612610358,
#  q2 = 2.889180923547542, con incertezza = 0.012811085223612032
# La forza di coesistenza qui vale: fc = 4.0109915531652005, con incertezza = 0.01209403266577116
# Il tempo medi di residenza vale: tc = 4.136661633906044, con incertezza = 0.06114596313672546
# Stimiamo un nuovo DeltaG_NU = 42.46752839337704, con incertezza = 5.058728802563164
# ((-0.8446785215658007, 0.008707077466800913),
#  (5.210341373809542, 0.011630361511829057),
#  (0.7900691923171909, 0.008081230612610358),
#  (2.889180923547542, 0.012811085223612032),
#  (4.0109915531652005, 0.01209403266577116),
#  (4.136661633906044, 0.06114596313672546),
#  (42.46752839337704, 5.058728802563164))

# %%
grafici.write_on_txt()
