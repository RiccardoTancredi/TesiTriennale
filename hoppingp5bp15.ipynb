# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 15bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/15"
# molecule name is a number in these experimets
number = "15"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force    lambda  Y_force    time(sec)
# 0       0.0935  -0.1773  36.85240   4.8235  26103.02148
# 1       0.8752  -0.1038  36.70365   5.1265  26103.02148
# 2       0.7374  -0.1280  36.75730   5.0154  26103.02344
# 3       0.3657  -0.2208  37.01360   4.8841  26103.02344
# 4       0.8107  -0.2034  36.64605   4.8033  26103.02539
# ...        ...      ...       ...      ...          ...
# 59627  -0.5033  -0.0497   7.22150   3.3338  26209.05469
# 59628   0.0202   0.0837   6.94400   3.5812  26209.05469
# 59629   0.1511  -0.0178   7.12965   3.4954  26209.05469
# 59630  -0.1107  -0.1570   7.55255   3.3742  26209.05664
# 59631  -0.5504  -0.2527   7.02780   3.2681  26209.05859
#
# [59632 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.895567141216994, con deviazione standard = 0.20079530822172986

# %%
prova = [0.2, 5.6, 0.1, 2.5, 4.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.1485648345182451, mu_1 = 5.592908875439378, sigma_1 = 0.08076517310762095
# c_2 = 2.5187278663444226, mu_2 = 4.8637923809386585, sigma_2 = 0.1530969995440488
# sigma_c_1 = 0.07775465012023894, sigma_mu_1 = 0.05078895948242254, sigma_sigma_1 = 0.04789604179983003
# sigma_c_2 = 0.05313726124618407, sigma_mu_2 = 0.0037698639072849993, sigma_sigma_2 = 0.0037235600573765743
# w_U = 0.9665801243661067, sigma_w_U = 0.0009683652202642829
# w_N = 0.03007669321360814, sigma_w_N = 0.7645158558079573

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 321 sec nello stato nativo e 8389 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.0935  -0.1773  36.85240   4.8235    0.00000
# 1      0.8752  -0.1038  36.70365   5.1265    0.00000
# 2      0.7374  -0.1280  36.75730   5.0154    0.00196
# 3      0.3657  -0.2208  37.01360   4.8841    0.00196
# 4      0.8107  -0.2034  36.64605   4.8033    0.00391
# ...       ...      ...       ...      ...        ...
# 8705   0.5472  -0.0613  39.63660   4.9515    9.06641
# 8706  -0.2416  -0.0584  39.75840   4.8589    9.07032
# 8707  -0.1787  -0.0468  39.39750   4.9397    9.07032
# 8708  -0.4667  -0.2237  39.74960   4.6518    9.07227
# 8709  -0.5190  -0.2411  39.84395   4.6165    9.07222
#
# [8710 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.625408250762213, con deviazione standard = 0.2579441818153584

# %%
prova = [0.4, 5.2, 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.24443143481508264, mu_1 = 5.261925689453627, sigma_1 = 0.13556235502853545
# c_2 = 2.0326817566374746, mu_2 = 4.566273797848304, sigma_2 = 0.18052514475067458
# sigma_c_1 = 0.044370410490108834, sigma_mu_1 = 0.029097232710161285, sigma_sigma_1 = 0.029495027214517945
# sigma_c_2 = 0.037757280864087694, sigma_mu_2 = 0.003930132648012141, sigma_sigma_2 = 0.003995586069457963
# w_U = 0.9198076673642983, sigma_w_U = 0.0023999705383551694
# w_N = 0.08305888489230573, sigma_w_N = 0.26063258077132595

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1014 sec nello stato nativo e 9482 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0      -0.5661  -0.0903  34.14155   4.5104    0.00000
# 1       0.2401  -0.1077  33.76890   4.3387    0.00000
# 2       1.3708   0.0083  33.76090   4.3185    0.00195
# 3       0.9939   0.0625  33.99030   4.2849    0.00195
# 4       0.0725  -0.0574  34.23330   4.2781    0.00391
# ...        ...      ...       ...      ...        ...
# 10491  -0.2520  -0.2150  25.29995   4.7478   10.92383
# 10492   0.2610  -0.1019  25.40125   4.7983   10.92578
# 10493   0.6955  -0.1715  25.56610   4.7427   10.92578
# 10494   0.2034  -0.3368  25.46305   4.8286   10.92578
# 10495   0.2034  -0.2585  25.37340   4.7023   10.92767
#
# [10496 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.225500256410272, con deviazione standard = 0.33171607217924104

# %%
prova = [0.7, 4.7, 0.1, 1.6, 4.0, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8540427682542184, mu_1 = 4.678378476620764, sigma_1 = 0.13544426004217125
# c_2 = 1.6875046641782694, mu_2 = 4.038632012007985, sigma_2 = 0.16728755123424502
# sigma_c_1 = 0.036438868271978855, sigma_mu_1 = 0.0068604469444007886, sigma_sigma_1 = 0.007035532070668559
# sigma_c_2 = 0.03230587181926297, sigma_mu_2 = 0.0037808717080539487, sigma_sigma_2 = 0.003879183262477653
# w_U = 0.7076174595550235, sigma_w_U = 0.008718989659072158
# w_N = 0.2899547039089536, sigma_w_N = 0.04756645645936664

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2690 sec nello stato nativo e 6280 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.1982  -0.0874  19.59950   4.6569    0.00000
# 1      0.0167  -0.1038  20.01440   4.7225    0.00000
# 2     -0.2520  -0.0323  19.59465   4.6821    0.00195
# 3     -0.0531   0.0315  19.77430   4.7831    0.00195
# 4     -0.2625  -0.0381  20.35600   4.7023    0.00391
# ...       ...      ...       ...      ...        ...
# 8965  -0.0793  -0.1802  23.76635   4.0711    9.37109
# 8966   0.4547  -0.0845  23.51030   4.0913    9.37305
# 8967   0.8421  -0.1831  23.77820   4.1115    9.37305
# 8968  -0.1212  -0.3513  23.41445   4.1216    9.37500
# 8969  -0.1997  -0.3203  23.57965   3.7327    9.37499
#
# [8970 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.971259373670328, con deviazione standard = 0.33763400328972576

# %%
prova = [1., 4.3, 0.1, 1., 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2410317111251556, mu_1 = 4.263911154995326, sigma_1 = 0.15855549456019608
# c_2 = 1.1301017566624225, mu_2 = 3.679416911022172, sigma_2 = 0.1784012189103071
# sigma_c_1 = 0.03416310406605237, sigma_mu_1 = 0.005968929799271716, sigma_sigma_1 = 0.006440285019736992
# sigma_c_2 = 0.03154088931548102, sigma_mu_2 = 0.006840276054200868, sigma_sigma_2 = 0.007095085681020565
# w_U = 0.5053651637985961, sigma_w_U = 0.023964531434713183
# w_N = 0.49323525329111445, sigma_w_N = 0.02479717169827742

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5831 sec nello stato nativo e 5920 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0       1.0567  -0.4479   8.02230   4.2041    0.00000
# 1       0.3081  -0.3136   7.97410   4.1923    0.00391
# 2       0.0987  -0.3716   8.04525   4.1519    0.00391
# 3      -0.1787  -0.3716   8.13390   4.2327    0.00586
# 4      -0.2259  -0.4702   7.77205   4.1923    0.00586
# ...        ...      ...       ...      ...        ...
# 11746   0.1197  -0.3281  17.19285   4.4347   12.27734
# 11747  -0.3201  -0.4963  17.27605   4.3034   12.27930
# 11748   0.2139  -0.5108  17.27535   4.3690   12.27930
# 11749   0.3186  -0.4122  17.08270   4.3387   12.28125
# 11750  -0.5347  -0.3658  16.83965   4.3185   12.28124
#
# [11751 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.576002635135152, con deviazione standard = 0.261533751900355

# %%
prova = [2.0, 3.7, 0.1, .5, 3.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.1563032179137864, mu_1 = 3.662878893569703, sigma_1 = 0.1531543194505762
# c_2 = 0.39396214618819964, mu_2 = 3.1135932091520315, sigma_2 = 0.1641902880854379
# sigma_c_1 = 0.04129113683567066, sigma_mu_1 = 0.004007441700995373, sigma_sigma_1 = 0.004344309193474666
# sigma_c_2 = 0.039023693694875704, sigma_mu_2 = 0.022465806298842414, sigma_sigma_2 = 0.02324806230822477
# w_U = 0.1621406440357972, sigma_w_U = 0.14304571091731338
# w_N = 0.827806848490375, sigma_w_N = 0.005549122682549213

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7177 sec nello stato nativo e 1703 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0     -0.0845   0.0112   3.57980   3.4802    0.00000
# 1      0.0150  -0.0874   3.50275   3.3641    0.00195
# 2      0.1877  -0.2469   2.94825   3.1570    0.00195
# 3      0.3448  -0.2237   2.93155   3.3085    0.00390
# 4      0.5437  -0.2382   3.50400   3.1974    0.00390
# ...       ...      ...       ...      ...        ...
# 8875  -0.1212  -0.2701  15.20385   3.1166    9.25976
# 8876  -0.4248  -0.2962  15.22090   3.3489    9.25976
# 8877  -0.4562  -0.2585  15.83395   3.2631    9.26171
# 8878  -0.5033   0.0141  15.30485   3.4499    9.26171
# 8879   0.1772   0.0702  15.43320   3.3961    9.26358
#
# [8880 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.415628572748276, con deviazione standard = 0.24462364240964432

# %%
prova = [2., 3.5, 0.1, .5, 3., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.248306672714459, mu_1 = 3.491340220803934, sigma_1 = 0.15096428334288578
# c_2 = 0.3610749525802766, mu_2 = 2.9602890762266765, sigma_2 = 0.15803658565688875
# sigma_c_1 = 0.050134782812425796, sigma_mu_1 = 0.004642382477020943, sigma_sigma_1 = 0.005042591151021066
# sigma_c_2 = 0.04788864838543491, sigma_mu_2 = 0.029321818356370734, sigma_sigma_2 = 0.030215291096993845
# w_U = 0.14303586126441814, sigma_w_U = 0.19796879945404494
# w_N = 0.8507847431960172, sigma_w_N = 0.005744579545764367

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8930 sec nello stato nativo e 1895 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force   lambda  Y_force  time(sec)
# 0       0.2470  -0.1115  9.29575   2.9719    0.00000
# 1       0.0516  -0.1309  9.04990   3.1065    0.00000
# 2       0.7217   0.0973  9.28510   3.1537    0.00196
# 3      -0.3323   0.0470  9.40710   3.1335    0.00196
# 4      -0.5975  -0.1579  9.30625   3.1469    0.00586
# ...        ...      ...      ...      ...        ...
# 10820  -0.5033  -0.0497  7.22150   3.3338   11.26563
# 10821   0.0202   0.0837  6.94400   3.5812   11.26563
# 10822   0.1511  -0.0178  7.12965   3.4954   11.26563
# 10823  -0.1107  -0.1570  7.55255   3.3742   11.26758
# 10824  -0.5504  -0.2527  7.02780   3.2681   11.26944
#
# [10825 rows x 5 columns]

# %%
forces_average
# Out:
# [5.228350628189018,
#  4.914099743650965,
#  4.358505244314374,
#  3.971664033008749,
#  3.3882360513608676,
#  3.225814648515305]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.9634780454746417, con sigma = 1.0307538996794399
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 9.485931525989649, con sigma = 1.7302767400356058
# La differenza di energia libera DeltaG_NU = 37.59728134413574, con sigma = 6.969337862948499

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.5467376189164357, con incertezza = 0.2307266251689557,
#  q1 = 14.339940792435728, con incertezza = 0.9795277471077813
# Stimiamo i parametri del fit lineare: m2 = 0.8604295542122775, con incertezza = 0.17803893029624274,
#  q2 = 4.837475391366748, con incertezza = 0.7558471977443613
# La forza di coesistenza qui vale: fc = 3.9475718625383873, con incertezza = 0.7018503099533168
# Il tempo medi di residenza vale: tc = 3767.183387973908, con incertezza = 11164.788327317718
# Stimiamo un nuovo DeltaG_NU = 37.446396381962565, con incertezza = 9.538305619228739
# ((-1.5467376189164357, 0.2307266251689557),
#  (14.339940792435728, 0.9795277471077813),
#  (0.8604295542122775, 0.17803893029624274),
#  (4.837475391366748, 0.7558471977443613),
#  (3.9475718625383873, 0.7018503099533168),
#  (3767.183387973908, 11164.788327317718),
#  (37.446396381962565, 9.538305619228739))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.963474682252946, con sigma = 1.0310383105474707
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 9.485184170497204, con sigma = 1.7306204081747396
# La differenza di energia libera DeltaG_NU = 37.59428731627208, con sigma = 6.970707229818978

# %%
f_c
# Out:
# (3.963474682252946, 1.0310383105474707)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -19.4869358610528, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.2338746641086953, con incertezza = 0.1966694786915274,
#  q1 = 13.193676888886639, con incertezza = 0.7906263876883711
# Stimiamo i parametri del fit lineare: m2 = 1.0562404592139527, con incertezza = 0.19861676870365902,
#  q2 = 4.120065517562647, con incertezza = 0.7984546342065848
# La forza di coesistenza qui vale: fc = 3.962076525724788, con incertezza = 0.6889079357370768
# Il tempo medi di residenza vale: tc = 4043.925050794536, con incertezza = 11590.12116814109
# Stimiamo un nuovo DeltaG_NU = 37.58102554410332, con incertezza = 9.471801610751411

# %%
f_c, t_c
# Out:
# ((3.962076525724788, 0.6889079357370768),
#  (4043.925050794536, 11590.12116814109))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.914099743650965,
#   4.358505244314374,
#   3.971664033008749,
#   3.3882360513608676,
#   3.225814648515305],
#  [1014, 2690, 5831, 7177, 8930])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = 0
forces_average = remove_element(forces_average, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.9634211754009696, con sigma = 1.0399411196815136
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 9.471112572822365, con sigma = 1.7430744701287824
# La differenza di energia libera DeltaG_NU = 37.53800812573052, con sigma = 7.020168648043406

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.9356965695879473, con incertezza = 0.2422883223313921,
#  q1 = 12.13182601323794, con incertezza = 0.911859981001441
# Stimiamo i parametri del fit lineare: m2 = 1.275456832032507, con incertezza = 0.31145864345336566,
#  q2 = 3.3394075804197114, con incertezza = 1.1721847263287364
# La forza di coesistenza qui vale: fc = 3.976394594049722, con incertezza = 0.9770698064765703
# Il tempo medi di residenza vale: tc = 4496.826623696598, con incertezza = 13198.957673130144
# Stimiamo un nuovo DeltaG_NU = 37.71683505913108, con incertezza = 11.543259934510523
# ((-0.9356965695879473, 0.2422883223313921),
#  (12.13182601323794, 0.911859981001441),
#  (1.275456832032507, 0.31145864345336566),
#  (3.3394075804197114, 1.1721847263287364),
#  (3.976394594049722, 0.9770698064765703),
#  (4496.826623696598, 13198.957673130144),
#  (37.71683505913108, 11.543259934510523))
