# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 18bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/18"
# molecule name is a number in these experimets
number = "18"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0       0.3865   0.1731  13.56415   4.0265  530.16095
# 1       0.3970   0.1847  13.64150   3.9356  530.16168
# 2      -0.3499  -0.0898  13.78725   3.9288  530.16278
# 3      -0.1318  -0.1865  13.92225   3.8649  530.16370
# 4       0.4441  -0.0676  13.70885   4.0921  530.16467
# ...        ...      ...       ...      ...        ...
# 41419   0.3411   0.1809  18.83045   3.9423  599.31616
# 41420   0.4703   0.1441  18.99845   4.0618  599.31702
# 41421   0.7896   0.1702  19.01220   4.0063  599.31799
# 41422   1.2189   0.2746  18.71440   3.9053  599.31903
# 41423   0.5854   0.2166  18.98950   4.0416  599.32000
#
# [41424 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.066966726591748, con deviazione standard = 0.33631047967374456

# %%
prova = [1., 4.6, 0.1, 1.5, 3.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.9514883470715096, mu_1 = 4.5766323612223285, sigma_1 = 0.10121643501783206
# c_2 = 1.7004367442536787, mu_2 = 3.895006859863606, sigma_2 = 0.17730374503240076
# sigma_c_1 = 0.040162836779811466, sigma_mu_1 = 0.005040381920057887, sigma_sigma_1 = 0.004949067556057776
# sigma_c_2 = 0.029581511359958106, sigma_mu_2 = 0.0035851635650814995, sigma_sigma_2 = 0.0035941803469802316
# w_U = 0.7557328910926765, sigma_w_U = 0.006448522349469288
# w_N = 0.24140399045867098, sigma_w_N = 0.0488167041226746

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1675 sec nello stato nativo e 5000 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.3865   0.1731  13.56415   4.0265    0.00000
# 1      0.3970   0.1847  13.64150   3.9356    0.00073
# 2     -0.3499  -0.0898  13.78725   3.9288    0.00183
# 3     -0.1318  -0.1865  13.92225   3.8649    0.00275
# 4      0.4441  -0.0676  13.70885   4.0921    0.00372
# ...       ...      ...       ...      ...        ...
# 6670  -0.0114  -0.1865  18.22695   3.9962    6.97772
# 6671   0.0462  -0.0995  17.81340   4.0568    6.97870
# 6672   0.2766  -0.0734  18.31545   3.8194    6.97974
# 6673  -0.3516  -0.0908  18.18425   3.8598    6.98071
# 6674   0.0986  -0.1024  18.12575   3.7487    6.98165
#
# [6675 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.394138580301676, con deviazione standard = 0.32179384651968723

# %%
prova = [0.6, 5., 0.1, 1.7, 4.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6563090239718564, mu_1 = 4.995689544066767, sigma_1 = 0.1011241089502581
# c_2 = 1.8870843634164167, mu_2 = 4.2612671526387285, sigma_2 = 0.1758451783412381
# sigma_c_1 = 0.0555650052117417, sigma_mu_1 = 0.010111214373071565, sigma_sigma_1 = 0.009832750036769589
# sigma_c_2 = 0.0408820060588345, sigma_mu_2 = 0.004430198745764595, sigma_sigma_2 = 0.004411611451497399
# w_U = 0.8317862075085535, sigma_w_U = 0.005514437333522495
# w_N = 0.1663615728530568, sigma_w_N = 0.10724026172224371

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1968 sec nello stato nativo e 9302 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0       0.1300   0.0948  29.46265   4.3901    0.00000
# 1       0.1248   0.0687  28.59345   4.2790    0.00086
# 2       0.2504  -0.0125  29.62440   4.2083    0.00226
# 3       0.2504  -0.0328  29.28015   4.3093    0.00299
# 4       0.0096  -0.0821  29.53905   4.1931    0.00397
# ...        ...      ...       ...      ...        ...
# 11265  -0.1405  -0.3373  34.03565   4.2049   11.71631
# 11266  -0.1841  -0.2416  33.87510   4.2335   11.71747
# 11267  -0.4773  -0.3025  34.21585   4.1527   11.71845
# 11268  -0.2260  -0.2561  34.21510   4.0719   11.71942
# 11269  -0.7181  -0.1923  34.07925   4.3093   11.72037
#
# [11270 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.841336474650483, con deviazione standard = 0.35405589319604674

# %%
prova = [1.7, 4.2, 0.1, 1., 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.6978124338502665, mu_1 = 4.123011703252363, sigma_1 = 0.1272222836157951
# c_2 = 0.9936794488877536, mu_2 = 3.4925698594850125, sigma_2 = 0.180731367102666
# sigma_c_1 = 0.04102381327679147, sigma_mu_1 = 0.0036959680724740116, sigma_sigma_1 = 0.003802043048380991
# sigma_c_2 = 0.034044372366360175, sigma_mu_2 = 0.0073253944250824266, sigma_sigma_2 = 0.00763043095239069
# w_U = 0.45016297866096644, sigma_w_U = 0.0294386795269588
# w_N = 0.5414306419674897, sigma_w_N = 0.017300285071632823

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6513 sec nello stato nativo e 5361 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0       0.5854   0.0078  22.47500   3.5619    0.00000
# 1       0.8053  -0.0038  22.22520   3.2639    0.00098
# 2       0.9624  -0.0241  22.17950   3.2084    0.00165
# 3      -0.0428  -0.0241  22.23850   3.4104    0.00311
# 4       0.0672   0.0803  21.98680   3.5770    0.00403
# ...        ...      ...       ...      ...        ...
# 11869  -0.6989  -0.0318  23.05600   3.4373   12.36084
# 11870   0.1666  -0.0589  23.08745   3.9288   12.36182
# 11871   0.7460   0.0301  22.43655   3.6864   12.36285
# 11872   0.1806   0.1151  22.88745   3.4979   12.36383
# 11873   0.1248   0.1886  22.42710   3.4710   12.36486
#
# [11874 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8168076087893197, con deviazione standard = 0.3223594998693143

# %%
prova = [1.7, 3.9, 0.1, .3, 3.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.6289291666543044, mu_1 = 3.9236809875822427, sigma_1 = 0.21718348822232628
# c_2 = 0.2670212646011803, mu_2 = 3.162743277793842, sigma_2 = 0.18648537403086413
# sigma_c_1 = 0.03454507312652006, sigma_mu_1 = 0.005624112309620117, sigma_sigma_1 = 0.006145005702703019
# sigma_c_2 = 0.0364042215730683, sigma_mu_2 = 0.032019195712613954, sigma_sigma_2 = 0.03306668369455877
# w_U = 0.12481895965812156, sigma_w_U = 0.1983464909197677
# w_N = 0.8867862241251638, sigma_w_N = 0.004413548235417497

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 9886 sec nello stato nativo e 1719 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0       0.1719   0.0745  18.07445   3.6174    0.00000
# 1       0.0515   0.0629  17.85165   3.6831    0.00074
# 2       0.7111   0.0456  18.07095   3.7538    0.00184
# 3       0.0829   0.2234  17.45180   3.5922    0.00312
# 4      -0.2173   0.2389  17.65855   3.5922    0.00409
# ...        ...      ...       ...      ...        ...
# 11600   0.3411   0.1809  18.83045   3.9423   12.09833
# 11601   0.4703   0.1441  18.99845   4.0618   12.09919
# 11602   0.7896   0.1702  19.01220   4.0063   12.10016
# 11603   1.2189   0.2746  18.71440   3.9053   12.10120
# 11604   0.5854   0.2166  18.98950   4.0416   12.10217
#
# [11605 rows x 5 columns]

# %%
forces_average
# Out:
# [4.2358196105429675, 4.628478348352748, 3.8077907813686878, 3.5432121326880424]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.8711152218132674, con sigma = 0.8202367705545948
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 11.780422279573562, con sigma = 1.76571167073052
# La differenza di energia libera DeltaG_NU = 45.603372005845365, con sigma = 6.829897247600088

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -18.939003284247036, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.676830326414969, con incertezza = 0.529198054677701,
#  q1 = 15.044770032498613, con incertezza = 2.156418802984483
# Stimiamo i parametri del fit lineare: m2 = 1.292372660494657, con incertezza = 0.5064541801923003,
#  q2 = 3.1838425479141206, con incertezza = 2.0637402145031674
# La forza di coesistenza qui vale: fc = 3.994650260314286, con incertezza = 1.407727208079229
# Il tempo medi di residenza vale: tc = 4215.060958387082, con incertezza = 13561.556846049549
# Stimiamo un nuovo DeltaG_NU = 47.058666925710746, con incertezza = 18.021291411703046
# ((-1.676830326414969, 0.529198054677701),
#  (15.044770032498613, 2.156418802984483),
#  (1.292372660494657, 0.5064541801923003),
#  (3.1838425479141206, 2.0637402145031674),
#  (3.994650260314286, 1.407727208079229),
#  (4215.060958387082, 13561.556846049549),
#  (47.058666925710746, 18.021291411703046))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto
# # Spoiler: no!

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 3
forces_average = remove_element(forces_average, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.8705039572005444, con sigma = 0.8303748313934805
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 11.680855744448735, con sigma = 1.7724368710928156
# La differenza di energia libera DeltaG_NU = 45.21079838237754, con sigma = 6.856924033162505

# %%
f_c
# Out:
# (3.8705039572005444, 0.8303748313934805)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -18.935366323862375, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.4839424889095547, con incertezza = 1.0318204105635267,
#  q1 = 14.198182628442806, con incertezza = 4.372137312919667
# Stimiamo i parametri del fit lineare: m2 = 0.658989209164658, con incertezza = 0.5021640432172841,
#  q2 = 5.963771324124241, con incertezza = 2.1278220006948243
# La forza di coesistenza qui vale: fc = 3.84259158223222, con incertezza = 3.0631170627137414
# Il tempo medi di residenza vale: tc = 4895.1378308353615, con incertezza = 17276.23757512363
# Stimiamo un nuovo DeltaG_NU = 44.88475795688758, con incertezza = 36.42227971172473

# %%
f_c, t_c
# Out:
# ((3.84259158223222, 3.0631170627137414),
#  (4895.1378308353615, 17276.23757512363))
