# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 18bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/18"
# molecule name is a number in these experimets
number = "18"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force    lambda  Y_force  time(sec)
# 0       0.3865   0.1731  13.56415   4.0265  530.16095
# 1       0.3970   0.1847  13.64150   3.9356  530.16168
# 2      -0.3499  -0.0898  13.78725   3.9288  530.16278
# 3      -0.1318  -0.1865  13.92225   3.8649  530.16370
# 4       0.4441  -0.0676  13.70885   4.0921  530.16467
# ...        ...      ...       ...      ...        ...
# 41419   0.3411   0.1809  18.83045   3.9423  599.31616
# 41420   0.4703   0.1441  18.99845   4.0618  599.31702
# 41421   0.7896   0.1702  19.01220   4.0063  599.31799
# 41422   1.2189   0.2746  18.71440   3.9053  599.31903
# 41423   0.5854   0.2166  18.98950   4.0416  599.32000
#
# [41424 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.066966726591748, con deviazione standard = 0.33631047967374456

# %%
prova = [1., 4.6, 0.1, 1.5, 3.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.9514883470715096, mu_1 = 4.5766323612223285, sigma_1 = 0.10121643501783206
# c_2 = 1.7004367442536787, mu_2 = 3.895006859863606, sigma_2 = 0.17730374503240076
# sigma_c_1 = 0.040162836779811466, sigma_mu_1 = 0.005040381920057887, sigma_sigma_1 = 0.004949067556057776
# sigma_c_2 = 0.029581511359958106, sigma_mu_2 = 0.0035851635650814995, sigma_sigma_2 = 0.0035941803469802316
# w_U = 0.7557328910926765, sigma_w_U = 0.004860362197587461
# w_N = 0.24140399045867098, sigma_w_N = 0.03686421089730987

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.68 sec nello stato nativo e 4.995 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.3865   0.1731  13.56415   4.0265    0.00000
# 1      0.3970   0.1847  13.64150   3.9356    0.00073
# 2     -0.3499  -0.0898  13.78725   3.9288    0.00183
# 3     -0.1318  -0.1865  13.92225   3.8649    0.00275
# 4      0.4441  -0.0676  13.70885   4.0921    0.00372
# ...       ...      ...       ...      ...        ...
# 6670  -0.0114  -0.1865  18.22695   3.9962    6.97772
# 6671   0.0462  -0.0995  17.81340   4.0568    6.97870
# 6672   0.2766  -0.0734  18.31545   3.8194    6.97974
# 6673  -0.3516  -0.0908  18.18425   3.8598    6.98071
# 6674   0.0986  -0.1024  18.12575   3.7487    6.98165
#
# [6675 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.384360329964321, con deviazione standard = 0.3214844064288954

# %%
prova = [0.6, 5., 0.1, 1.7, 4.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6487436320301527, mu_1 = 4.984972615749109, sigma_1 = 0.10194129972779867
# c_2 = 1.8746314614544095, mu_2 = 4.250768390147871, sigma_2 = 0.1768970154739268
# sigma_c_1 = 0.047973699136900125, sigma_mu_1 = 0.008900258530303452, sigma_sigma_1 = 0.008662735032843889
# sigma_c_2 = 0.03535924135943334, sigma_mu_2 = 0.003879713733520112, sigma_sigma_2 = 0.0038662030482902116
# w_U = 0.8312398232424095, sigma_w_U = 0.0036136620387132723
# w_N = 0.16577277538179186, sigma_w_N = 0.0708931133393753

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.18 sec nello stato nativo e 5.548 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.1300   0.0948  29.46265   4.3901    0.00000
# 1      0.1248   0.0687  28.59345   4.2790    0.00086
# 2      0.2504  -0.0125  29.62440   4.2083    0.00226
# 3      0.2504  -0.0328  29.28015   4.3093    0.00299
# 4      0.0096  -0.0821  29.53905   4.1931    0.00397
# ...       ...      ...       ...      ...        ...
# 6723   0.5174   0.0281  33.43965   5.0314    6.99500
# 6724  -0.1998   0.1267  33.34875   5.1627    6.99597
# 6725   0.0672   0.1441  32.95490   5.0314    6.99701
# 6726   0.8734   0.0600  33.63005   5.0365    6.99799
# 6727   0.1771   0.0166  33.08775   5.0365    6.99896
#
# [6728 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8580433765459636, con deviazione standard = 0.3493203725821148

# %%
prova = [1.7, 4.2, 0.1, 1., 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.777797670268068, mu_1 = 4.121486734506851, sigma_1 = 0.1272225546439759
# c_2 = 0.9489914830679732, mu_2 = 3.494059595066468, sigma_2 = 0.1788738348156175
# sigma_c_1 = 0.04137353131356906, sigma_mu_1 = 0.0035570774940060345, sigma_sigma_1 = 0.0036601820070922245
# sigma_c_2 = 0.03450376693554477, sigma_mu_2 = 0.007694126412843124, sigma_sigma_2 = 0.008008842230142667
# w_U = 0.42549951239291833, sigma_w_U = 0.02420704115908722
# w_N = 0.566939059515137, sigma_w_N = 0.011641353383582166

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.868 sec nello stato nativo e 2.843 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.5854   0.0078  22.47500   3.5619    0.00000
# 1      0.8053  -0.0038  22.22520   3.2639    0.00098
# 2      0.9624  -0.0241  22.17950   3.2084    0.00165
# 3     -0.0428  -0.0241  22.23850   3.4104    0.00311
# 4      0.0672   0.0803  21.98680   3.5770    0.00403
# ...       ...      ...       ...      ...        ...
# 6706   0.1614   0.0891  24.20580   4.1527    6.99597
# 6707   0.2975   0.0803  24.23325   4.0467    6.99701
# 6708  -0.6710  -0.0821  23.92830   4.2790    6.99835
# 6709   0.1666  -0.0898  24.12970   4.4540    6.99890
# 6710   0.5854   0.0977  24.15805   4.2992    6.99988
#
# [6711 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7136712792954025, con deviazione standard = 0.36157057857719127

# %%
prova = [1.7, 3.9, 0.1, .3, 3.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.32803177877939, mu_1 = 3.845079142442349, sigma_1 = 0.2508460289519436
# c_2 = 0.4763186129054246, mu_2 = 3.121338549045399, sigma_2 = 0.13991944608946197
# sigma_c_1 = 0.037811914009934736, sigma_mu_1 = 0.008581543833722005, sigma_sigma_1 = 0.009506528280904614
# sigma_c_2 = 0.04931574251415769, sigma_mu_2 = 0.01830893933073055, sigma_sigma_2 = 0.018149942383347484
# w_U = 0.16705734075808054, sigma_w_U = 0.10201870186666998
# w_N = 0.8350368321291614, sigma_w_N = 0.005713568800522104

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.3180000000000005 sec nello stato nativo e 1.381 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0      0.1719   0.0745  18.07445   3.6174    0.00000
# 1      0.0515   0.0629  17.85165   3.6831    0.00074
# 2      0.7111   0.0456  18.07095   3.7538    0.00184
# 3      0.0829   0.2234  17.45180   3.5922    0.00312
# 4     -0.2173   0.2389  17.65855   3.5922    0.00409
# ...       ...      ...       ...      ...        ...
# 6694   0.5924  -0.9057  11.08870   3.6393    6.99604
# 6695   1.4021  -0.8941  11.34865   3.8144    6.99738
# 6696   1.1927  -0.4533  13.65105   3.4508    6.99836
# 6697   1.3183   0.0919  17.74045   3.9086    6.99891
# 6698   1.4998  -0.2870  15.69725   3.8076    6.99994
#
# [6699 rows x 5 columns]

# %%
forces_average
# Out:
# [4.2358196105429675, 4.61787050294849, 3.8077731647866595, 3.4832088457438743]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.90068214800167, con sigma = 0.5651480244213273
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 12.504214939044509, con sigma = 1.2845544879365134
# La differenza di energia libera DeltaG_NU = 48.774967987506706, con sigma = 4.983192311164456

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 29.511314405633826, con sigma = 2.870190278000915

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6417691721150549, con incertezza = 0.004544687441697135,
#  q1 = 4.627267549926559, con incertezza = 0.003925486577444286
# Stimiamo i parametri del fit lineare: m2 = 0.8085766119026432, con incertezza = 0.0060884394203575215,
#  q2 = 3.0150874209840626, con incertezza = 0.008928525105256397
# La forza di coesistenza qui vale: fc = 3.913887666278659, con incertezza = 0.0061072813249195375
# Il tempo medi di residenza vale: tc = 3.0391664495474275, con incertezza = 0.027035057530501946
# Stimiamo un nuovo DeltaG_NU = 48.94009262642365, con incertezza = 5.028181919973042
# ((-0.6417691721150549, 0.004544687441697135),
#  (4.627267549926559, 0.003925486577444286),
#  (0.8085766119026432, 0.0060884394203575215),
#  (3.0150874209840626, 0.008928525105256397),
#  (3.913887666278659, 0.0061072813249195375),
#  (3.0391664495474275, 0.027035057530501946),
#  (48.94009262642365, 5.028181919973042))

# %% [markdown]
# # Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 1
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.894068208938421, con sigma = 0.6079395169927998
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 13.852723245396364, con sigma = 1.5348800146518
# La differenza di energia libera DeltaG_NU = 53.94344919712025, con sigma = 5.932957586269435

# %%
f_c
# Out:
# (3.894068208938421, 0.6079395169927998)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 29.428898077960646, con sigma = 3.0839740661155455

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5531775086383429, con incertezza = 0.005579393992015794,
#  q1 = 4.527071665550199, con incertezza = 0.005367391514306123
# Stimiamo i parametri del fit lineare: m2 = 0.6594990293555248, con incertezza = 0.006668301279965457,
#  q2 = 3.16208051614783, con incertezza = 0.009322569002338799
# La forza di coesistenza qui vale: fc = 3.9044139495949417, con incertezza = 0.007070579700323702
# Il tempo medi di residenza vale: tc = 3.0820717304582783, con incertezza = 0.03696158042105735
# Stimiamo un nuovo DeltaG_NU = 54.086765879203675, con incertezza = 5.993607310668014

# %%
f_c, t_c
# Out:
# ((3.9044139495949417, 0.007070579700323702),
#  (3.0820717304582783, 0.03696158042105735))

# %%
grafici.write_on_txt()
