# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np
from hmm import HMM

# %% [markdown]
# # 19bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/19"
# molecule name is a number in these experimets
number = "19"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force   time(sec)
# 0       -1.0113  -0.0072 -440.88660   4.7926  1519.21777
# 1       -0.8577  -0.0420 -440.98115   4.9340  1519.21838
# 2       -0.9415   0.0276 -441.08630   4.5906  1519.21948
# 3        0.0497   0.1707 -440.61380   4.7522  1519.22070
# 4       -0.5716   0.0895 -440.71835   4.7657  1519.22168
# ...         ...      ...        ...      ...         ...
# 211494   0.1369  -0.3755 -353.50240   7.3075  2398.81616
# 211495   0.6866  -0.1928 -353.76465   7.3681  2398.81714
# 211496   0.9536  -0.1899 -353.58285   7.1055  2398.81812
# 211497   0.8122  -0.2508 -353.61860   7.1257  2398.81909
# 211498   0.9640  -0.1609 -353.43285   7.0752  2398.82000
#
# [211499 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.096793582337592, con deviazione standard = 0.21204805117194062

# %%
prova = [0.1, 5.8, 0.1, 2., 5.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.10653893474502793, mu_1 = 5.843272069456419, sigma_1 = 0.077898929614244
# c_2 = 2.2275779997977767, mu_2 = 5.073590156921196, sigma_2 = 0.1742103907359082
# sigma_c_1 = 0.06759098690015042, sigma_mu_1 = 0.059740841149418744, sigma_sigma_1 = 0.055785795411679134
# sigma_c_2 = 0.04187270140346116, sigma_mu_2 = 0.003817229233788903, sigma_sigma_2 = 0.003777923430702076
# w_U = 0.9727403005492267, sigma_w_U = 0.00045144015363621383
# w_N = 0.02080318228122722, sigma_w_N = 0.7086371776848046

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.342 sec nello stato nativo e 12.295 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -1.0113  -0.0072 -440.88660   4.7926    0.00000
# 1      -0.8577  -0.0420 -440.98115   4.9340    0.00061
# 2      -0.9415   0.0276 -441.08630   4.5906    0.00171
# 3       0.0497   0.1707 -440.61380   4.7522    0.00293
# 4      -0.5716   0.0895 -440.71835   4.7657    0.00391
# ...        ...      ...        ...      ...        ...
# 12632  -0.2086  -0.1406 -445.82915   5.2521   13.18628
# 12633  -0.0306  -0.0652 -445.70480   5.1107   13.18726
# 12634  -0.4861  -0.1232 -446.04880   5.1713   13.18848
# 12635  -0.5279  -0.3030 -446.04130   5.3127   13.18946
# 12636  -0.4459  -0.1812 -445.65300   5.2639   13.19053
#
# [12637 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.968339137168169, con deviazione standard = 0.27237771990573734

# %% [markdown]
# ## Drift?!

# %%
# prova = [0.1, 5.9, 0.1, 1.5, 4.7, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par, False)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.5505  -0.0710 -467.22455   4.7976    0.00000
# 1       0.4964  -0.1193 -467.08455   4.6849    0.00097
# 2       0.4301   0.4365 -467.00545   4.3381    0.00402
# 3       0.0584   0.4249 -466.89045   4.4138    0.00500
# 4       0.2102   0.2857 -467.11815   4.6663    0.00598
# ...        ...      ...        ...      ...        ...
# 13555  -1.2416  -0.6684 -469.34420   5.5467   14.12317
# 13556  -1.1561   0.1581 -470.18500   5.2723   14.12426
# 13557  -0.4337   0.0653 -470.23725   5.3885   14.12524
# 13558   0.0060   0.1900 -470.58910   5.1764   14.12622
# 13559   0.3097   0.4162 -470.44540   5.0097   14.12715
#
# [13560 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.714646297882774, con deviazione standard = 0.34267012372820294

# %%
prova = [0.7, 5.1, 0.1, 1.4, 4.5, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.7260224265116292, mu_1 = 5.130515812341688, sigma_1 = 0.17491956331781244
# c_2 = 1.4222125229853662, mu_2 = 4.516720141599011, sigma_2 = 0.19095935103125417
# sigma_c_1 = 0.032428558550233605, sigma_mu_1 = 0.01129332331460023, sigma_sigma_1 = 0.012191234034652575
# sigma_c_2 = 0.03018012419775431, sigma_mu_2 = 0.005939215413710621, sigma_sigma_2 = 0.005982989138542113
# w_U = 0.6807620895547296, sigma_w_U = 0.008396464960278559
# w_N = 0.3183305757328214, sigma_w_N = 0.03856652537033174

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.801 sec nello stato nativo e 5.37 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.3063   0.3137 -497.02280   4.0587    0.00000
# 1     -0.2505   0.2712 -497.34695   4.4088    0.00085
# 2     -0.3761   0.0933 -497.44445   4.6512    0.00207
# 3     -0.1667   0.0276 -497.70255   4.4223    0.00305
# 4      0.3515   0.0943 -497.53865   4.6461    0.00402
# ...       ...      ...        ...      ...        ...
# 8166  -0.8054   0.1987 -502.16305   4.7471    8.49499
# 8167  -0.7373   0.1755 -501.78330   4.7320    8.49597
# 8168  -0.4040   0.1281 -502.09770   4.7589    8.49682
# 8169  -0.5908  -1.2687 -500.22280   4.8229    8.49792
# 8170   0.2416   0.3553 -502.23770   4.7471    8.49914
#
# [8171 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[1.0, 0.0], [0.005068443520954483, 0.9949315564790455]], [0.0, 1.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.3264380244424965, con deviazione standard = 0.3471440916296199

# %%
prova = [1., 4.7, 0.1, 1.5, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.0541080647874388, mu_1 = 4.726053127791096, sigma_1 = 0.12958323208132144
# c_2 = 1.652203329316524, mu_2 = 4.094935188675319, sigma_2 = 0.15504528412048785
# sigma_c_1 = 0.04867707792806693, sigma_mu_1 = 0.007046263911036927, sigma_sigma_1 = 0.0071251061562624535
# sigma_c_2 = 0.043867335986244156, sigma_mu_2 = 0.004827947419310236, sigma_sigma_2 = 0.004890163692677997
# w_U = 0.6421137773638105, sigma_w_U = 0.010573446242893816
# w_N = 0.3423922123789333, sigma_w_N = 0.034508947255897766

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.836 sec nello stato nativo e 5.101 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.3028  -0.4132 -527.05470   4.6108    0.00000
# 1     -0.9834  -0.4828 -527.67565   4.5704    0.00110
# 2     -1.3812  -0.5002 -527.57645   4.7320    0.00232
# 3     -0.5087  -0.4712 -527.33325   4.5704    0.00317
# 4      0.5522  -0.4635 -527.11715   4.6310    0.00415
# ...       ...      ...        ...      ...        ...
# 7932  -0.3552  -0.5679 -523.85610   4.9407    8.27868
# 7933  -0.5018  -0.5118 -524.04595   5.0047    8.27942
# 7934  -0.2610  -0.5292 -523.95925   4.9744    8.28052
# 7935  -0.4180  -0.4190 -524.06755   4.9542    8.28161
# 7936  -0.5960  -0.3813 -524.23395   5.0451    8.28257
#
# [7937 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9943782003230028, 0.0056217996769964045],
#   [0.008230711095780949, 0.9917692889042188]],
#  [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.960084485086511, con deviazione standard = 0.2852078534006537

# %%
prova = [1.4, 4.2, 0.1, 1.4, 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.0236946389151107, mu_1 = 4.188168589126574, sigma_1 = 0.09178169758013263
# c_2 = 1.8496416352698348, mu_2 = 3.957631554959171, sigma_2 = 0.1274445478383183
# sigma_c_1 = 0.2830089896876833, sigma_mu_1 = 0.03477525164139579, sigma_sigma_1 = 0.026848646208164118
# sigma_c_2 = 0.21998155907210135, sigma_mu_2 = 0.03152640924919813, sigma_sigma_2 = 0.014849446080438334
# w_U = 0.590879316257714, sigma_w_U = 0.031190131543173
# w_N = 0.23551384844135045, sigma_w_N = 0.18480670153701637

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.89 sec nello stato nativo e 5.257 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5086  -0.2856 -539.36235   3.8735    0.00000
# 1      0.2887  -0.2856 -539.66805   3.9543    0.00097
# 2      0.6028  -0.2131 -539.56500   3.9442    0.00195
# 3      0.3568  -0.1493 -539.85765   4.0149    0.00293
# 4     -0.0271  -0.1425 -539.54195   3.9846    0.00390
# ...       ...      ...        ...      ...        ...
# 8142  -0.2016   0.1127 -522.87055   4.2203    8.49499
# 8143  -0.1248   0.0276 -523.06990   4.1933    8.49597
# 8144  -1.0043  -1.9367 -520.65070   4.5839    8.49695
# 8145  -1.2207  -2.9343 -519.40240   4.7051    8.49804
# 8146  -1.2556  -2.9043 -519.21830   4.6613    8.49902
#
# [8147 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.3720458461160874, con deviazione standard = 0.2376207253334407

# %% [markdown]
# ## Suspicious Data?!

# %%
# prova = [2., 3.5, 0.1, .5, 3., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.4232   0.4220 -528.54615   3.2018    0.00000
# 1      0.1526   0.2973 -528.63145   3.2725    0.00098
# 2      0.2573   0.2509 -528.86240   3.3937    0.00207
# 3     -0.1772   0.2103 -528.57645   3.2321    0.00305
# 4     -0.2348   0.1001 -528.52095   3.4796    0.00403
# ...       ...      ...        ...      ...        ...
# 8144  -0.1824  -0.9526 -526.91200   3.2574    8.49499
# 8145   0.1055  -0.9584 -526.97710   3.3331    8.49597
# 8146   0.1317  -0.6423 -526.21495   3.2927    8.49695
# 8147  -0.1510  -0.8511 -526.97220   3.3281    8.49805
# 8148  -0.3028  -0.9236 -526.79545   3.3129    8.49902
#
# [8149 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.04381647278471, con deviazione standard = 0.30548812821610183

# %%
prova = [1.7, 4.2, 0.1, 0.5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.023386799756668, mu_1 = 4.1761814537847, sigma_1 = 0.14698620953459568
# c_2 = 0.5569865119235267, mu_2 = 3.5925617685493836, sigma_2 = 0.16854918533635369
# sigma_c_1 = 0.042821661748170356, sigma_mu_1 = 0.00394310560364156, sigma_sigma_1 = 0.004229346225783016
# sigma_c_2 = 0.03926525441190889, sigma_mu_2 = 0.015069070805882703, sigma_sigma_2 = 0.015811397317913138
# w_U = 0.23532131699247819, sigma_w_U = 0.06312417088446329
# w_N = 0.7454962051635691, sigma_w_N = 0.006021973752707756

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.2090000000000005 sec nello stato nativo e 1.754 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5173   0.2944 -539.63000   4.2472    0.00000
# 1     -0.0201   0.4800 -539.28555   4.0856    0.00097
# 2     -0.2156   0.4916 -539.73320   3.9711    0.00231
# 3     -0.6274   0.3911 -539.92955   4.1058    0.00329
# 4     -0.1877   0.2751 -539.96525   4.1664    0.00427
# ...       ...      ...        ...      ...        ...
# 6958  -0.7391   0.0392 -541.49145   3.6614    7.22766
# 6959  -0.1196   0.0827 -541.62065   3.6513    7.22851
# 6960  -0.8106   0.1030 -541.04800   3.6513    7.22949
# 6961   0.0950   0.2393 -541.53375   3.6159    7.23059
# 6962  -0.2034   0.4191 -541.18320   3.2877    7.23148
#
# [6963 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=100)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[1.0, 1.5437613598594598e-196], [1.0, 7.488513412021905e-71]], [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.258336082094145, con deviazione standard = 0.3466430332819321

# %%
prova = [1.2, 4.7, 0.1, 1., 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2915456554221563, mu_1 = 4.484344040707167, sigma_1 = 0.18635452958922738
# c_2 = 0.8239577353984894, mu_2 = 3.9020558423375338, sigma_2 = 0.188099760044113
# sigma_c_1 = 0.03137859994664059, sigma_mu_1 = 0.007713783284794731, sigma_sigma_1 = 0.008097006444487792
# sigma_c_2 = 0.03078791494136466, sigma_mu_2 = 0.012095148460308734, sigma_sigma_2 = 0.011303198962893828
# w_U = 0.3884929222317395, sigma_w_U = 0.028927113466045644
# w_N = 0.6033087864665997, sigma_w_N = 0.012661710792752837

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.846 sec nello stato nativo e 3.291 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.7826   0.4065 -512.68660   4.2270    0.00000
# 1      0.8593   0.5264 -513.05185   4.1664    0.00061
# 2     -0.7251   0.2596 -512.69270   4.2135    0.00220
# 3     -0.4180   0.3669 -512.70850   4.2219    0.00306
# 4     -0.4547   0.3292 -512.64365   4.1613    0.00403
# ...       ...      ...        ...      ...        ...
# 8132   0.5243   0.1088 -508.38875   4.2068    8.49463
# 8133   0.0078   0.2364 -508.69065   3.9846    8.49585
# 8134  -0.2226   0.3795 -509.21725   3.7759    8.49683
# 8135   0.1893   0.4491 -508.89700   3.9442    8.49805
# 8136  -0.4547   0.2770 -509.10885   4.0704    8.49915
#
# [8137 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9951854645599943, 0.004814535440005677], [0.0, 1.0]], [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.724341108394473, con deviazione standard = 0.21626766944496628

# %% [markdown]
# # Suspicious data?!

# %%
# prova = [1.4, 4.2, 0.1, 1.4, 3.9, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      1.4090  -0.7351 -463.97375   4.4492    0.00000
# 1      1.1420  -0.5060 -461.08870   4.6613    0.00097
# 2      1.0269  -0.8076 -463.45715   4.6310    0.00244
# 3      1.2520  -0.7873 -464.11720   4.3078    0.00317
# 4      0.5976  -0.8482 -464.13680   4.5906    0.00415
# ...       ...      ...        ...      ...        ...
# 6130   0.1055  -0.6800 -463.29100   4.6175    6.38073
# 6131   1.3567  -0.5350 -463.74900   4.6310    6.38183
# 6132   0.7180  -0.4741 -461.92275   4.7370    6.38281
# 6133   0.4981  -0.6829 -462.56850   4.5906    6.38379
# 6134   0.5557  -0.1899 -459.84015   4.8431    6.38468
#
# [6135 rows x 5 columns]

# %% [markdown]
# # File 10

# %%
grafici = Graph_hop(dir_name, number, 10)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.305392090741892, con deviazione standard = 0.3265927831142661

# %%
prova = [0.5, 4.9, 0.1, 1.4, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.39365686270669864, mu_1 = 4.954747378565698, sigma_1 = 0.1498673054205291
# c_2 = 1.6819581062455997, mu_2 = 4.196506026407927, sigma_2 = 0.20351872103219595
# sigma_c_1 = 0.03725466029524172, sigma_mu_1 = 0.016804552584976852, sigma_sigma_1 = 0.01737869680371634
# sigma_c_2 = 0.03146472659672331, sigma_mu_2 = 0.004465709984320136, sigma_sigma_2 = 0.00458881196154038
# w_U = 0.8580438309732223, sigma_w_U = 0.0032299739934146133
# w_N = 0.14788177681941236, sigma_w_N = 0.0952310744948334

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.309 sec nello stato nativo e 6.846 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0636  -0.8018 -472.26515   4.2068    0.00000
# 1      0.2102  -0.4828 -469.90605   4.3078    0.00110
# 2     -0.3971  -0.1657 -466.79865   4.2405    0.00232
# 3     -0.2016  -0.0884 -466.49290   4.4963    0.00330
# 4     -0.3063  -0.3397 -468.24690   4.3684    0.00427
# ...       ...      ...        ...      ...        ...
# 8150   0.9850  -0.7032 -478.14480   3.8230    8.49561
# 8151   0.1753  -0.5369 -476.09260   4.0991    8.49622
# 8152  -0.4250  -0.1348 -472.53260   4.1462    8.49719
# 8153  -0.2086  -0.4055 -474.56225   3.9038    8.49817
# 8154   0.5295  -0.8163 -478.11335   4.0502    8.49915
#
# [8155 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.0, 1.0], [3.962836437526779e-273, 1.0]], [0.0, 1.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 11

# %%
grafici = Graph_hop(dir_name, number, 11)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7969957231472455, con deviazione standard = 0.34850902833219793

# %%
prova = [1.4, 4., 0.2, 0.5, 3.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.613758317164108, mu_1 = 3.9898086159349724, sigma_1 = 0.1842206251606719
# c_2 = 0.608950259742041, mu_2 = 3.3013624802925303, sigma_2 = 0.1760877947051292
# sigma_c_1 = 0.043542438349231, sigma_mu_1 = 0.006062120835407435, sigma_sigma_1 = 0.006547997209075824
# sigma_c_2 = 0.0436945336125879, sigma_mu_2 = 0.01569066423897425, sigma_sigma_2 = 0.016332088069060155
# w_U = 0.2687825121348219, sigma_w_U = 0.06366571077815504
# w_N = 0.7451894187476504, sigma_w_N = 0.00868412301436206

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.372 sec nello stato nativo e 1.754 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.4824   0.0044 -488.13210   4.1529    0.00000
# 1      0.4266  -0.0227 -488.15775   4.0654    0.00098
# 2      0.0846  -0.1870 -489.54690   4.0755    0.00171
# 3      0.1683  -0.3436 -489.55960   4.0250    0.00306
# 4     -0.1248  -0.8308 -493.90020   3.7422    0.00428
# ...       ...      ...        ...      ...        ...
# 6121   1.6760  -0.8695 -501.38200   3.8163    6.39063
# 6122   1.0373  -0.8859 -501.34250   3.9240    6.39173
# 6123   1.1473  -0.8366 -500.73735   3.8634    6.39270
# 6124   0.7285  -0.7641 -500.62610   3.7876    6.39368
# 6125   0.3044  -0.6655 -500.05390   3.9290    6.39477
#
# [6126 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9952773392674771, 0.004722660732522479],
#   [0.03950340796344681, 0.9604965920365544]],
#  [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 12

# %%
grafici = Graph_hop(dir_name, number, 12)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.496796174561527, con deviazione standard = 0.2785028603868385

# %%
prova = [2., 3.7, 0.1, 0.5, 3., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.018634197866012, mu_1 = 3.58912416538937, sigma_1 = 0.17071688008798055
# c_2 = 0.42599832586701597, mu_2 = 2.966193490579414, sigma_2 = 0.13199525889214714
# sigma_c_1 = 0.05494239891852505, sigma_mu_1 = 0.005455333618095416, sigma_sigma_1 = 0.0057554321937011614
# sigma_c_2 = 0.061593356899682046, sigma_mu_2 = 0.02292732655968594, sigma_sigma_2 = 0.023291525850453246
# w_U = 0.14094710456323972, sigma_w_U = 0.14631357049527494
# w_N = 0.8638215331596907, sigma_w_N = 0.00451238855701643

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.0200000000000005 sec nello stato nativo e 1.221 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3638  -0.7921 -515.48775   3.5469    0.00000
# 1      0.7128  -0.4596 -513.86900   3.7422    0.00085
# 2     -0.1388  -0.3088 -511.71610   3.6614    0.00232
# 3      0.3097  -0.6133 -514.30375   3.4947    0.00330
# 4      0.5766  -0.2943 -512.37290   3.6765    0.00427
# ...       ...      ...        ...      ...        ...
# 7236  -0.0969   0.2712 -508.17530   3.3853    7.55347
# 7237  -0.5122   0.1523 -508.04970   3.0604    7.55432
# 7238  -0.4861   0.0073 -508.15985   3.2271    7.55530
# 7239  -0.7897   0.0537 -507.82425   3.4897    7.55652
# 7240  -0.6483   0.1030 -508.11010   3.2877    7.55740
#
# [7241 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9983100413229241, 0.0016899586770763345],
#   [0.14240354235271954, 0.8575964576472795]],
#  [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 13

# %%
grafici = Graph_hop(dir_name, number, 13)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7062810239223447, con deviazione standard = 0.2854524668371392

# %%
prova = [2., 3.8, 0.1, 0.3, 3.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.1658824185456047, mu_1 = 3.804846842194273, sigma_1 = 0.15931206975077392
# c_2 = 0.38256803535850037, mu_2 = 3.1385096561464065, sigma_2 = 0.151092800546352
# sigma_c_1 = 0.051920655315158715, sigma_mu_1 = 0.0044730156509493356, sigma_sigma_1 = 0.0046234182314458866
# sigma_c_2 = 0.052808923237616975, sigma_mu_2 = 0.024597200332304163, sigma_sigma_2 = 0.025089172049977144
# w_U = 0.14489132564156276, sigma_w_U = 0.13932318059126833
# w_N = 0.8649151215261192, sigma_w_N = 0.0040601025186803134

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.2250000000000005 sec nello stato nativo e 1.428 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3463  -0.7032 -501.77185   3.1867    0.00000
# 1      0.3568  -0.6452 -502.74695   3.0352    0.00134
# 2     -0.3866  -0.4045 -499.91795   3.0604    0.00220
# 3      0.5295  -0.2653 -499.26325   3.0352    0.00317
# 4      0.2521  -0.6568 -501.70960   3.1059    0.00439
# ...       ...      ...        ...      ...        ...
# 8648   0.5801  -0.6800 -493.18305   3.6749    9.03223
# 8649   0.5871  -0.7873 -493.74895   3.6361    9.03333
# 8650   0.1840  -0.8598 -493.94810   3.5957    9.03430
# 8651   0.0479  -0.8047 -493.52785   3.5654    9.03528
# 8652   0.7285  -0.6568 -493.20120   3.5856    9.03618
#
# [8653 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.994202505642813, 0.005797494357187595],
#   [0.05487364919861448, 0.9451263508013835]],
#  [0.0, 1.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 14

# %%
grafici = Graph_hop(dir_name, number, 14)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8640278481012453, con deviazione standard = 0.3788837210048488

# %%
prova = [1.2, 4.2, 0.1, 0.8, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.374008431726286, mu_1 = 4.192597304954615, sigma_1 = 0.15780917926901292
# c_2 = 1.0198725309586403, mu_2 = 3.4974917873403495, sigma_2 = 0.18390779863817242
# sigma_c_1 = 0.04505648926781623, sigma_mu_1 = 0.0061811781264643284, sigma_sigma_1 = 0.006464608587126665
# sigma_c_2 = 0.0412707003198014, sigma_mu_2 = 0.008864516850426338, sigma_sigma_2 = 0.009219332379442533
# w_U = 0.4701494959907772, sigma_w_U = 0.025871539053692806
# w_N = 0.5435150736623956, sigma_w_N = 0.01817748092738413

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.306 sec nello stato nativo e 3.831 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.6185  -0.7496 -485.85900   3.2776    0.00000
# 1      1.3828  -0.7206 -485.91310   3.3281    0.00086
# 2      0.8803  -0.6974 -485.45485   3.4190    0.00232
# 3      1.1106  -0.6877 -486.06450   3.4796    0.00305
# 4      0.6290  -0.7032 -485.70175   3.4729    0.00403
# ...       ...      ...        ...      ...        ...
# 8132   0.9379  -0.4509 -475.08165   4.2371    8.49500
# 8133  -0.0254  -0.5466 -474.65185   4.2219    8.49597
# 8134   0.2940  -0.5553 -475.82200   4.0755    8.49695
# 8135   1.3567  -0.4915 -475.89390   3.9593    8.49817
# 8136   0.5976  -0.1696 -473.17915   3.7775    8.49915
#
# [8137 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9772330945050524, 0.02276690549494751],
#   [0.004675067591876542, 0.995324932408123]],
#  [0.0, 1.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 15

# %%
grafici = Graph_hop(dir_name, number, 15)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.280058147174755, con deviazione standard = 0.3216906682807305

# %%
prova = [0.5, 4.8, 0.1, 1.4, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.5497041073091872, mu_1 = 4.882036616118466, sigma_1 = 0.12903187268992156
# c_2 = 1.9262205741691427, mu_2 = 4.148121296658668, sigma_2 = 0.16994848423714215
# sigma_c_1 = 0.04329012661735321, sigma_mu_1 = 0.011911249286618679, sigma_sigma_1 = 0.011795555053165338
# sigma_c_2 = 0.03717796376189262, sigma_mu_2 = 0.0038178268601207588, sigma_sigma_2 = 0.0038175411029940085
# w_U = 0.8205654877117604, sigma_w_U = 0.003970308848974524
# w_N = 0.177793515192408, sigma_w_N = 0.07471671964465589

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.677 sec nello stato nativo e 7.455 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5243  -0.3059 -474.58795   4.8229    0.00000
# 1      0.7477  -0.3977 -476.13840   4.7926    0.00086
# 2      0.2102  -0.2701 -472.84895   4.8667    0.00208
# 3     -0.0271  -0.2431 -470.79415   4.9205    0.00305
# 4     -0.0899  -0.3281 -472.30705   4.9205    0.00403
# ...       ...      ...        ...      ...        ...
# 9127  -0.2086  -0.0227 -473.29500   4.9205    9.50403
# 9128   0.2311  -0.1541 -477.51865   4.7387    9.50501
# 9129   0.7756  -0.1899 -480.44545   4.6512    9.50611
# 9130   0.7965  -0.1261 -479.70285   4.7017    9.50708
# 9131   0.7075  -0.1638 -479.98015   4.8683    9.50803
#
# [9132 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9950713176013739, 0.004928682398626081], [0.0, 1.0]], [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 16

# %%
grafici = Graph_hop(dir_name, number, 16)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.180799409303483, con deviazione standard = 0.3480554913241303

# %%
prova = [0.8, 4.5, 0.1, 1., 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.768621994540552, mu_1 = 4.619733511221367, sigma_1 = 0.15379142791249603
# c_2 = 1.3473394869279491, mu_2 = 3.991833429590342, sigma_2 = 0.20734198135613616
# sigma_c_1 = 0.03565575349071809, sigma_mu_1 = 0.009767186508362335, sigma_sigma_1 = 0.010304897081197174
# sigma_c_2 = 0.030477019666686533, sigma_mu_2 = 0.00627184606179618, sigma_sigma_2 = 0.006647932394630792
# w_U = 0.7002517720054564, sigma_w_U = 0.008214972054564134
# w_N = 0.2963021967648975, sigma_w_N = 0.04007004981742556

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.618 sec nello stato nativo e 5.508 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      1.1263  -0.2972 -476.62755   4.8077    0.00000
# 1      0.4039  -0.2769 -473.16740   4.7522    0.00097
# 2     -0.0411  -0.1290 -472.14850   4.6209    0.00207
# 3     -0.3133  -0.0652 -472.29850   4.6714    0.00329
# 4      0.0148  -0.0691 -472.60975   4.7051    0.00390
# ...       ...      ...        ...      ...        ...
# 8121  -0.0777   0.4017 -472.49635   3.4139    8.49389
# 8122  -0.3342   0.3930 -472.18840   3.5957    8.49487
# 8123  -0.0550   0.6037 -471.98415   3.6951    8.49585
# 8124   0.5592   0.6617 -472.47670   3.9038    8.49878
# 8125  -0.1946   0.6540 -472.15630   3.8365    8.49975
#
# [8126 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9635042227574767, 0.036495777242524924],
#   [0.0038873208310861718, 0.9961126791689139]],
#  [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 17

# %%
grafici = Graph_hop(dir_name, number, 17)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8057323612302483, con deviazione standard = 0.2768784651187152

# %%
prova = [5., 4., 0.1, 0.5, 3.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 4.049078319140998, mu_1 = 3.9392322732234484, sigma_1 = 0.07310530612632817
# c_2 = 0.6368708898508434, mu_2 = 3.3433824837512143, sigma_2 = 0.14661215326460783
# sigma_c_1 = 0.09267506284506567, sigma_mu_1 = 0.00198314277557843, sigma_sigma_1 = 0.001916174859151558
# sigma_c_2 = 0.06295087722859005, sigma_mu_2 = 0.016843760848185826, sigma_sigma_2 = 0.016772717400142318
# w_U = 0.23405143325150476, sigma_w_U = 0.08473613224857923
# w_N = 0.7419848048003936, sigma_w_N = 0.006172988573053822

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.212 sec nello stato nativo e 1.949 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1893  -0.1696 -481.12255   3.9779    0.00000
# 1      0.0217  -0.2102 -480.90140   3.9139    0.00146
# 2      0.3568  -0.3784 -480.51345   4.0250    0.00268
# 3     -0.3831  -0.3668 -480.75275   4.0250    0.00342
# 4      0.3219  -0.3513 -480.22435   3.9577    0.00439
# ...       ...      ...        ...      ...        ...
# 8156   0.0915  -0.1116 -479.98060   3.9577    8.49512
# 8157  -0.1109  -0.2392 -480.56315   3.9509    8.49609
# 8158   0.0898  -0.2392 -480.68280   3.8785    8.49707
# 8159   0.7232  -0.1232 -480.23225   3.9290    8.49805
# 8160   0.4458  -0.1058 -480.14810   3.8987    8.49902
#
# [8161 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9982787985841256, 0.0017212014158756613],
#   [0.05555641952804964, 0.9444435804719492]],
#  [1.0, 0.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 18

# %%
grafici = Graph_hop(dir_name, number, 18)
data_frame = grafici.do_graph(8.5)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.1481291238374975, con deviazione standard = 0.31597861637333297

# %%
prova = [2.5, 4.4, 0.1, 1., 3.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 3.316120675743436, mu_1 = 4.3470822396433135, sigma_1 = 0.07821855763730426
# c_2 = 0.8707230335439312, mu_2 = 3.7305774563901357, sigma_2 = 0.15128526098844705
# sigma_c_1 = 0.0578052219378912, sigma_mu_1 = 0.0016183549682916665, sigma_sigma_1 = 0.0015606374105314143
# sigma_c_2 = 0.039915356599734476, sigma_mu_2 = 0.008067347702649623, sigma_sigma_2 = 0.008023828296975026
# w_U = 0.3301920298991526, sigma_w_U = 0.03443290335464222
# w_N = 0.6501746968180282, sigma_w_N = 0.006631709386043244

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.446 sec nello stato nativo e 2.726 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0217  -0.3165 -469.94435   3.9240    0.00000
# 1     -0.3831  -0.4093 -469.77055   3.6749    0.00097
# 2      0.2521  -0.2740 -469.90615   3.4190    0.00171
# 3      0.5243  -0.1425 -470.17905   3.7422    0.00317
# 4      0.0148  -0.2083 -469.74200   3.4325    0.00415
# ...       ...      ...        ...      ...        ...
# 8167   0.7477  -0.3127 -466.42940   4.3078    8.49414
# 8168   0.4126  -0.4325 -466.15595   4.2337    8.49511
# 8169   0.3568  -0.4519 -466.19370   4.3886    8.49609
# 8170   0.1893  -0.4751 -466.24945   4.2539    8.49707
# 8171  -0.0830  -0.4751 -465.98725   4.3213    8.49804
#
# [8172 rows x 5 columns]

# %%
A = [[0.92, 0.08], [0.03, 0.97]] # taken by an article
PI = [0.5, 0.5]
hidden = HMM(2, A, PI, data_frame['Y_force'][:600], fitting_par)
alpha, beta, X, A, PI = hidden.iteration(MAX_ITERATION=200)
# Out:
# Loading 1%
# Loading 2%
# Loading 3%
# Loading 4%
# Loading 5%
# Loading 6%
# Loading 7%
# Loading 8%
# Loading 9%
# Loading 10%
# Loading 11%
# Loading 12%
# Loading 13%
# Loading 14%
# Loading 15%
# Loading 16%
# Loading 17%
# Loading 18%
# Loading 19%
# Loading 20%
# Loading 21%
# Loading 22%
# Loading 23%
# Loading 24%
# Loading 25%
# Loading 26%
# Loading 27%
# Loading 28%
# Loading 28%
# Loading 30%
# Loading 31%
# Loading 32%
# Loading 33%
# Loading 34%
# Loading 35%
# Loading 36%
# Loading 37%
# Loading 38%
# Loading 39%
# Loading 40%
# Loading 41%
# Loading 42%
# Loading 43%
# Loading 44%
# Loading 45%
# Loading 46%
# Loading 47%
# Loading 48%
# Loading 49%
# Loading 50%
# Loading 51%
# Loading 52%
# Loading 53%
# Loading 54%
# Loading 55%
# Loading 56%
# Loading 56%
# Loading 57%
# Loading 59%
# Loading 60%
# Loading 61%
# Loading 62%
# Loading 63%
# Loading 64%
# Loading 65%
# Loading 66%
# Loading 67%
# Loading 68%
# Loading 69%
# Loading 70%
# Loading 71%
# Loading 72%
# Loading 73%
# Loading 74%
# Loading 75%
# Loading 76%
# Loading 77%
# Loading 78%
# Loading 79%
# Loading 80%
# Loading 81%
# Loading 82%
# Loading 83%
# Loading 84%
# Loading 85%
# Loading 86%
# Loading 87%
# Loading 88%
# Loading 89%
# Loading 90%
# Loading 91%
# Loading 92%
# Loading 93%
# Loading 94%
# Loading 95%
# Loading 96%
# Loading 97%
# Loading 98%
# Loading 99%
# Loading 100%

# %%
A, PI
# Out:
# ([[0.9782210415904168, 0.02177895840957935],
#   [0.01407892727605852, 0.9859210727239406]],
#  [0.0, 1.0])

# %%
grafici.subplots(fitting_par, n_points_fig=600, X=X)

# %% [markdown]
# # File 19

# %%
grafici = Graph_hop(dir_name, number, 19)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 6.577826360924704, con deviazione standard = 3.572000126648681

# %% [markdown]
# # ?????

# %%
forces_average
# Out:
# [5.458431113188808,
#  4.8236179769703496,
#  4.410494158233208,
#  4.072900072042873,
#  3.884371611167042,
#  4.19319994152235,
#  4.5756267024868125,
#  3.6455855481137514,
#  3.277658827984392,
#  3.4716782491703397,
#  3.845044546147482,
#  4.515078956388567,
#  4.305783470405855,
#  3.6413073784873315,
#  4.038829848016725]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.1762921492953415, con sigma = 0.5165376191010824
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 5.519065360579314, con sigma = 0.48450736537610406
# La differenza di energia libera DeltaG_NU = 23.049229336835253, con sigma = 2.0081736998945305

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -20.737043351879038, con sigma = -1.2291704238873482

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6342924860895759, con incertezza = 0.003856386125151597,
#  q1 = 4.974984216837679, con incertezza = 0.0052033450003822
# Stimiamo i parametri del fit lineare: m2 = 0.6549654086405633, con incertezza = 0.003617991446363864,
#  q2 = 3.3095735196693057, con incertezza = 0.005068222135908293
# La forza di coesistenza qui vale: fc = 4.15563108680452, con incertezza = 0.004989612983185942
# Il tempo medi di residenza vale: tc = 3.639182838720209, con incertezza = 0.028144913855160235
# Stimiamo un nuovo DeltaG_NU = 22.93519958252939, con incertezza = 2.0136221809639725
# ((-0.6342924860895759, 0.003856386125151597),
#  (4.974984216837679, 0.0052033450003822),
#  (0.6549654086405633, 0.003617991446363864),
#  (3.3095735196693057, 0.005068222135908293),
#  (4.15563108680452, 0.004989612983185942),
#  (3.639182838720209, 0.028144913855160235),
#  (22.93519958252939, 2.0136221809639725))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto, il primo nella lista

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
forces_average_std = remove_element(forces_average_std, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.176294995247985, con sigma = 0.516556051775262
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 5.518927328143327, con sigma = 0.48451247027251554
# La differenza di energia libera DeltaG_NU = 23.04866857966231, con sigma = 2.008194026795992

# %%
f_c
# Out:
# (4.176294995247985, 0.516556051775262)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -20.737059950075846, con sigma = -1.2292140001772456

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6427574568633091, con incertezza = 0.0040457034464753995,
#  q1 = 4.986485537068172, con incertezza = 0.00546227978074473
# Stimiamo i parametri del fit lineare: m2 = 0.6459138172618929, con incertezza = 0.0036565283345249586,
#  q2 = 3.3196639979679583, con incertezza = 0.005102475558694212
# La forza di coesistenza qui vale: fc = 4.155116052057869, con incertezza = 0.005139719795455187
# Il tempo medi di residenza vale: tc = 3.645312120012716, con incertezza = 0.02907180121491835
# Stimiamo un nuovo DeltaG_NU = 22.931783531309193, con incertezza = 2.0134053670760883

# %%
f_c, t_c
# Out:
# ((4.155116052057869, 0.005139719795455187),
#  (3.645312120012716, 0.02907180121491835))

# %%
grafici.write_on_txt()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-160-34283a3d455e> in <module>
# ----> 1 grafici.write_on_txt()
#
# c:\Users\ricta\Documents\TesiTriennale\graph_hop.py in write_on_txt(self)
#     384     def write_on_txt(self):
#     385         status = "r" if os.path.isfile(self.nome_txt) else "a"
# --> 386         f = open(self.nome_txt, status)
#     387         f.write(self.output)
#     388         f.close()
#
# UnsupportedOperation: not writable
