# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 19_2bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/19_2"
# molecule name is a number in these experimets
number = "19_2"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force   time(sec)
# 0       0.6813   0.2596 -454.75250   3.9947  3379.28784
# 1      -0.3342   0.0624 -455.10955   4.0654  3379.28931
# 2       0.2625   0.0189 -454.67085   3.8634  3379.29175
# 3      -0.9153  -0.1870 -454.21525   3.8381  3379.29297
# 4      -0.2767  -0.1493 -454.32550   3.6260  3379.29395
# ...        ...      ...        ...      ...         ...
# 56607   0.2940  -0.1077 -420.98595   4.7791  3471.68164
# 56608  -0.2924  -0.2237 -420.74155   4.7859  3471.68262
# 56609  -0.0149  -0.2218 -420.53020   4.6815  3471.68359
# 56610  -0.1091  -0.0217 -420.46210   4.8330  3471.68457
# 56611  -0.2924  -0.0130 -420.55305   4.8784  3471.68550
#
# [56612 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.246754593175862, con deviazione standard = 0.36528415864973407

# %%
prova = [1.2, 4.7, 0.1, 1.5, 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.5871465333698374, mu_1 = 4.659145508164722, sigma_1 = 0.09908314531504261
# c_2 = 1.5035480828615917, mu_2 = 3.968506721602793, sigma_2 = 0.15995624011450799
# sigma_c_1 = 0.049734121708657986, sigma_mu_1 = 0.0036597213743513493, sigma_sigma_1 = 0.003568370179413713
# sigma_c_2 = 0.038127831237736796, sigma_mu_2 = 0.004718917270314911, sigma_sigma_2 = 0.004693319789411037
# w_U = 0.6028488580451129, sigma_w_U = 0.015287130206453944
# w_N = 0.3941910354648511, sigma_w_N = 0.028778806989491458

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3481 sec nello stato nativo e 5282 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.6813   0.2596 -454.75250   3.9947    0.00000
# 1     -0.3342   0.0624 -455.10955   4.0654    0.00147
# 2      0.2625   0.0189 -454.67085   3.8634    0.00391
# 3     -0.9153  -0.1870 -454.21525   3.8381    0.00513
# 4     -0.2767  -0.1493 -454.32550   3.6260    0.00611
# ...       ...      ...        ...      ...        ...
# 8758  -0.0132   0.2093 -455.12140   3.8567    9.13721
# 8759  -0.1737   0.1436 -455.31050   3.7220    9.13819
# 8760  -0.1615   0.1581 -455.48405   3.8280    9.13941
# 8761  -0.3447   0.1668 -455.28745   3.8684    9.14038
# 8762   0.2364   0.2161 -455.48310   3.8533    9.14156
#
# [8763 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.01919109867751, con deviazione standard = 0.35370932545382333

# %%
prova = [1.8, 4.3, 0.1, .5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.3276347747973394, mu_1 = 4.281757002005727, sigma_1 = 0.10002803299898033
# c_2 = 0.9716375293873136, mu_2 = 3.625751253329097, sigma_2 = 0.16649749975330877
# sigma_c_1 = 0.04591101428143631, sigma_mu_1 = 0.002322578322126608, sigma_sigma_1 = 0.0022857864767698807
# sigma_c_2 = 0.034800311713763785, sigma_mu_2 = 0.006930744872144441, sigma_sigma_2 = 0.0069438095176771394
# w_U = 0.40551033885574794, sigma_w_U = 0.032083540078386645
# w_N = 0.5836150729090942, sigma_w_N = 0.01224102654944166

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, True)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4645 sec nello stato nativo e 3219 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2259   0.1407 -457.48715   3.6159    0.00000
# 1     -0.2714   0.2132 -458.49720   3.5200    0.00122
# 2     -1.0043   0.2596 -457.73325   3.4796    0.00171
# 3      0.2451   0.2480 -457.88890   3.6277    0.00318
# 4     -0.3866   0.1494 -458.40935   3.7472    0.00415
# ...       ...      ...        ...      ...        ...
# 7859   0.0008   0.0121 -454.70090   4.2809    8.16724
# 7860  -0.6274   0.0624 -455.36295   4.3953    8.16822
# 7861  -1.0602   0.1243 -455.35670   4.4694    8.16919
# 7862  -0.3971   0.1861 -455.09955   4.3415    8.17017
# 7863   0.4772   0.2219 -455.52330   4.3583    8.17113
#
# [7864 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.6336835165996986, con deviazione standard = 0.21482250043085616

# %%
prova = [2.5, 3.7, 0.1, 0.2, 3.1, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 3.123696710399312, mu_1 = 3.6835628332869734, sigma_1 = 0.11395607081653084
# c_2 = 0.24581580697282088, mu_2 = 3.1078711207669976, sigma_2 = 0.14916265240720528
# sigma_c_1 = 0.05686654574660713, sigma_mu_1 = 0.0024461570838043975, sigma_sigma_1 = 0.0024836895155675035
# sigma_c_2 = 0.049118120413143986, sigma_mu_2 = 0.034872279025046055, sigma_sigma_2 = 0.035626620117054954
# w_U = 0.09190938031132753, sigma_w_U = 0.27785756838588327
# w_N = 0.892269937348937, sigma_w_N = 0.00261004261033435

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8457 sec nello stato nativo e 1001 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2505   0.2364 -462.09320   3.8735    0.00000
# 1     -1.0253   0.0044 -462.14535   3.8432    0.00146
# 2     -0.7792  -0.0536 -461.72630   3.7068    0.00220
# 3     -0.0463  -0.0913 -461.70555   3.6260    0.00342
# 4      0.0636  -0.0739 -461.58815   3.6715    0.00415
# ...       ...      ...        ...      ...        ...
# 9453  -0.0830   0.0392 -459.98940   3.5856    9.85693
# 9454  -0.0830  -0.0014 -459.70515   3.5351    9.85815
# 9455   0.2992  -0.0101 -459.74230   3.4947    9.85913
# 9456   0.0113   0.0392 -460.00910   3.4846    9.86011
# 9457   0.1544   0.1204 -459.88895   3.5873    9.86102
#
# [9458 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.651251222272565, con deviazione standard = 0.218640240462514

# %%
prova = [1., 3.7, 0.1, .5, 3.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.8071374283722115, mu_1 = 3.7028971649881384, sigma_1 = 0.12679048303509632
# c_2 = 0.25586013486985376, mu_2 = 3.131282892808231, sigma_2 = 0.1491767355325464
# sigma_c_1 = 0.04245081788435843, sigma_mu_1 = 0.002280020873525385, sigma_sigma_1 = 0.00236404158382934
# sigma_c_2 = 0.03867560463960308, sigma_mu_2 = 0.026725022069170285, sigma_sigma_2 = 0.027633011085069516
# w_U = 0.0956739396846962, sigma_w_U = 0.21330104736973812
# w_N = 0.8921549005311511, sigma_w_N = 0.0022968411335193097

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 11778 sec nello stato nativo e 1476 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2348   0.1175 -456.24185   3.7573    0.00000
# 1      -0.2714   0.0740 -456.25515   3.7422    0.00122
# 2      -0.0201   0.1204 -456.31395   3.6412    0.00195
# 3       0.3847   0.1668 -455.81905   3.7422    0.00318
# 4      -0.4599   0.1629 -456.01795   3.7422    0.00415
# ...        ...      ...        ...      ...        ...
# 13249  -0.3552   0.3843 -450.48155   3.9795   13.81275
# 13250   0.1840   0.6511 -450.70205   4.1058   13.81372
# 13251  -0.1667   0.5177 -450.66880   3.9088   13.81470
# 13252  -0.2226   0.3988 -450.24135   3.8499   13.81568
# 13253  -0.5855   0.3408 -450.42080   3.9644   13.81661
#
# [13254 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.191887684301808, con deviazione standard = 0.33931657470131765

# %%
prova = [2.0, 4.5, 0.1, .7, 3.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.9344784134651238, mu_1 = 4.425442878529959, sigma_1 = 0.12814705191130807
# c_2 = 0.7895749495260671, mu_2 = 3.8038496929669017, sigma_2 = 0.19002019380716004
# sigma_c_1 = 0.05037046713915112, sigma_mu_1 = 0.0041104892191776935, sigma_sigma_1 = 0.004255476224894764
# sigma_c_2 = 0.040918299336482146, sigma_mu_2 = 0.011841982610542262, sigma_sigma_2 = 0.012487855816581222
# w_U = 0.37608243674561165, sigma_w_U = 0.05200598481626913
# w_N = 0.6213873982526367, sigma_w_N = 0.01587026242868072

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3555 sec nello stato nativo e 2210 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1404   0.2364 -433.00785   3.6681    0.00000
# 1      0.3306   0.2393 -432.44055   3.7220    0.00342
# 2      0.5505   0.2277 -432.54725   3.9947    0.00440
# 3      0.5400   0.2422 -432.43560   3.9139    0.00537
# 4      0.1317   0.1610 -432.04615   3.7977    0.00635
# ...       ...      ...        ...      ...        ...
# 5760  -0.1196  -0.1232 -432.94485   3.5200    6.02002
# 5761   0.3411  -0.1203 -432.88280   3.4644    6.02124
# 5762   0.1055  -0.1319 -433.19650   3.5351    6.02222
# 5763  -0.2453  -0.1870 -433.16795   3.4897    6.02320
# 5764   0.4196  -0.1116 -433.13795   3.2018    6.02416
#
# [5765 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.316172540841178, con deviazione standard = 0.33843130199299487

# %%
prova = [0.5, 4.8, 0.1, 1.5, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6646831886403822, mu_1 = 4.834134580478471, sigma_1 = 0.1433363279288542
# c_2 = 1.6265848197192663, mu_2 = 4.151386214692452, sigma_2 = 0.18712621484120925
# sigma_c_1 = 0.03224618462141879, sigma_mu_1 = 0.008318272405278172, sigma_sigma_1 = 0.008570346616531707
# sigma_c_2 = 0.027829372690760502, sigma_mu_2 = 0.003792350782648614, sigma_sigma_2 = 0.003924155688901111
# w_U = 0.7629591431772041, sigma_w_U = 0.00646340294907474
# w_N = 0.23881461598877485, sigma_w_N = 0.05874606159978987

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2878 sec nello stato nativo e 8630 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.5732   0.2828 -420.38130   4.2943    0.00000
# 1      -0.0132   0.1977 -420.40295   4.2270    0.00122
# 2       0.1613   0.2480 -420.27725   4.0048    0.00219
# 3      -0.0620   0.1610 -420.50085   4.1664    0.00293
# 4      -0.6065   0.0392 -419.90165   4.1866    0.00439
# ...        ...      ...        ...      ...        ...
# 11503   0.2940  -0.1077 -420.98595   4.7791   11.97485
# 11504  -0.2924  -0.2237 -420.74155   4.7859   11.97583
# 11505  -0.0149  -0.2218 -420.53020   4.6815   11.97680
# 11506  -0.1091  -0.0217 -420.46210   4.8330   11.97778
# 11507  -0.2924  -0.0130 -420.55305   4.8784   11.97871
#
# [11508 rows x 5 columns]

# %%
forces_average
# Out:
# [4.313826114883758,
#  3.9537541276674117,
#  3.3957169770269857,
#  3.4170900288981847,
#  4.114646285748431,
#  4.492760397585462]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.144096519039876, con sigma = 0.683420886208731
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 10.023833145587332, con sigma = 1.1668687661642316
# La differenza di energia libera DeltaG_NU = 41.539732046065, con sigma = 4.852434280848759

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.182235883111205, con incertezza = 0.1598555740830492,
#  q1 = 13.193480198112855, con incertezza = 0.6346215116728847
# Stimiamo i parametri del fit lineare: m2 = 1.6404926012649967, con incertezza = 0.3093964303449639,
#  q2 = 1.4598048066203397, con incertezza = 1.2282939481763298
# La forza di coesistenza qui vale: fc = 4.15685584229528, con incertezza = 0.7091629934785971
# Il tempo medi di residenza vale: tc = 3940.6306795387823, con incertezza = 11996.691525912018
# Stimiamo un nuovo DeltaG_NU = 41.66762937342777, con incertezza = 8.605731899441782
# ((-1.182235883111205, 0.1598555740830492),
#  (13.193480198112855, 0.6346215116728847),
#  (1.6404926012649967, 0.3093964303449639),
#  (1.4598048066203397, 1.2282939481763298),
#  (4.15685584229528, 0.7091629934785971),
#  (3940.6306795387823, 11996.691525912018),
#  (41.66762937342777, 8.605731899441782))

# %% [markdown]
# ### Vediamo cosa accade eliminando il primo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.144030849814025, con sigma = 0.686022087114266
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 10.011450111394185, con sigma = 1.1698444222143314
# La differenza di energia libera DeltaG_NU = 41.48775811299156, con sigma = 4.865039537822171

# %%
f_c
# Out:
# (4.144030849814025, 0.686022087114266)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -20.548681234471168, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.3150985506170287, con incertezza = 0.1887373284623462,
#  q1 = 13.759930485016866, con incertezza = 0.7691271138092723
# Stimiamo i parametri del fit lineare: m2 = 1.5217690699712485, con incertezza = 0.4277599338144769,
#  q2 = 1.965973926528047, con incertezza = 1.7431726829787506
# La forza di coesistenza qui vale: fc = 4.157386997156787, con incertezza = 0.9594560697170248
# Il tempo medi di residenza vale: tc = 3994.0333769036306, con incertezza = 12317.582326233261
# Stimiamo un nuovo DeltaG_NU = 41.62147251579405, con incertezza = 10.766620559188963

# %%
f_c, t_c
# Out:
# ((4.157386997156787, 0.9594560697170248),
#  (3994.0333769036306, 12317.582326233261))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.313826114883758,
#   3.9537541276674117,
#   3.4170900288981847,
#   4.114646285748431,
#   4.492760397585462],
#  [3481, 4645, 11778, 3555, 2878])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.143905362932029, con sigma = 0.6906963048469027
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 9.98840253948603, con sigma = 1.1750712156911185
# La differenza di energia libera DeltaG_NU = 41.39099485050006, con sigma = 4.887192345198197

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.7915935300696081, con incertezza = 0.19668710118103702,
#  q1 = 11.524428309812066, con incertezza = 0.8307351486338097
# Stimiamo i parametri del fit lineare: m2 = 2.1579984831955, con incertezza = 0.9280734417486854,
#  q2 = -0.7508906218145489, con incertezza = 3.9198465087451444
# La forza di coesistenza qui vale: fc = 4.161700627212579, con incertezza = 1.907121022701116
# Il tempo medi di residenza vale: tc = 3752.032676677402, con incertezza = 12994.381227328528
# Stimiamo un nuovo DeltaG_NU = 41.568741113430725, con incertezza = 19.66679702475632
# ((-0.7915935300696081, 0.19668710118103702),
#  (11.524428309812066, 0.8307351486338097),
#  (2.1579984831955, 0.9280734417486854),
#  (-0.7508906218145489, 3.9198465087451444),
#  (4.161700627212579, 1.907121022701116),
#  (3752.032676677402, 12994.381227328528),
#  (41.568741113430725, 19.66679702475632))
