# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 19_2bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/19_2"
# molecule name is a number in these experimets
number = "19_2"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force   time(sec)
# 0       0.6813   0.2596 -454.75250   3.9947  3379.28784
# 1      -0.3342   0.0624 -455.10955   4.0654  3379.28931
# 2       0.2625   0.0189 -454.67085   3.8634  3379.29175
# 3      -0.9153  -0.1870 -454.21525   3.8381  3379.29297
# 4      -0.2767  -0.1493 -454.32550   3.6260  3379.29395
# ...        ...      ...        ...      ...         ...
# 56607   0.2940  -0.1077 -420.98595   4.7791  3471.68164
# 56608  -0.2924  -0.2237 -420.74155   4.7859  3471.68262
# 56609  -0.0149  -0.2218 -420.53020   4.6815  3471.68359
# 56610  -0.1091  -0.0217 -420.46210   4.8330  3471.68457
# 56611  -0.2924  -0.0130 -420.55305   4.8784  3471.68550
#
# [56612 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.233826745068286, con deviazione standard = 0.3608567926866637

# %%
prova = [1.2, 4.7, 0.1, 1.5, 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.6231937000512284, mu_1 = 4.638992197011565, sigma_1 = 0.09844862330628146
# c_2 = 1.5078366929305775, mu_2 = 3.954550631588435, sigma_2 = 0.15841983225273265
# sigma_c_1 = 0.062212921615334454, sigma_mu_1 = 0.0044479709150956805, sigma_sigma_1 = 0.004336570428402762
# sigma_c_2 = 0.047785983671034454, sigma_mu_2 = 0.005839968352441939, sigma_sigma_2 = 0.005813710099375826
# w_U = 0.5987613940498231, sigma_w_U = 0.014668754187896123
# w_N = 0.400562168965079, sigma_w_N = 0.026468205114596445

# %%
from scipy.integrate import quad

# %%
def double_gaussian(x, params=fitting_par):
        # params is a vector of the parameters:
        # params = [f_F, sigma_F, w_F, f_U, sigma_U, w_U]
        (c1, mu1, sigma1, c2, mu2, sigma2) = params
        res =   c1 * np.exp( - (x - mu1)**2.0 / (2.0 * sigma1**2.0) ) \
          + c2 * np.exp( - (x - mu2)**2.0 / (2.0 * sigma2**2.0) )
        return res

quad(double_gaussian, -np.inf, np.inf)
# Out:
# (0.9993235630211408, 2.932809202736872e-09)

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.124 sec nello stato nativo e 3.148 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.6813   0.2596 -454.75250   3.9947    0.00000
# 1     -0.3342   0.0624 -455.10955   4.0654    0.00147
# 2      0.2625   0.0189 -454.67085   3.8634    0.00391
# 3     -0.9153  -0.1870 -454.21525   3.8381    0.00513
# 4     -0.2767  -0.1493 -454.32550   3.6260    0.00611
# ...       ...      ...        ...      ...        ...
# 5267  -0.2644  -0.0381 -453.40660   3.9913    5.49512
# 5268  -0.0411   0.0450 -453.27075   4.0755    5.49610
# 5269   0.0479   0.0073 -453.24300   3.9139    5.49707
# 5270  -0.1510  -0.0710 -453.11605   3.9139    5.49805
# 5271  -0.6012  -0.0652 -453.63350   4.0401    5.49903
#
# [5272 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.01919109867751, con deviazione standard = 0.35370932545382333

# %%
prova = [1.8, 4.3, 0.1, .5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.3276347747973394, mu_1 = 4.281757002005727, sigma_1 = 0.10002803299898033
# c_2 = 0.9716375293873136, mu_2 = 3.625751253329097, sigma_2 = 0.16649749975330877
# sigma_c_1 = 0.04591101428143631, sigma_mu_1 = 0.002322578322126608, sigma_sigma_1 = 0.0022857864767698807
# sigma_c_2 = 0.034800311713763785, sigma_mu_2 = 0.006930744872144441, sigma_sigma_2 = 0.0069438095176771394
# w_U = 0.40551033885574794, sigma_w_U = 0.024187497004399563
# w_N = 0.5836150729090942, sigma_w_N = 0.009243466625384006

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, True)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.657 sec nello stato nativo e 3.207 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2259   0.1407 -457.48715   3.6159    0.00000
# 1     -0.2714   0.2132 -458.49720   3.5200    0.00122
# 2     -1.0043   0.2596 -457.73325   3.4796    0.00171
# 3      0.2451   0.2480 -457.88890   3.6277    0.00318
# 4     -0.3866   0.1494 -458.40935   3.7472    0.00415
# ...       ...      ...        ...      ...        ...
# 7859   0.0008   0.0121 -454.70090   4.2809    8.16724
# 7860  -0.6274   0.0624 -455.36295   4.3953    8.16822
# 7861  -1.0602   0.1243 -455.35670   4.4694    8.16919
# 7862  -0.3971   0.1861 -455.09955   4.3415    8.17017
# 7863   0.4772   0.2219 -455.52330   4.3583    8.17113
#
# [7864 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(6)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.6707795209996488, con deviazione standard = 0.1917894735469664

# %%
prova = [2.5, 3.7, 0.1, 0.2, 3.1, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 3.264593018016701, mu_1 = 3.7033728872131935, sigma_1 = 0.11311916788731853
# c_2 = 0.15529469199919965, mu_2 = 3.11122377947711, sigma_2 = 0.15349565320670294
# sigma_c_1 = 0.06776184312121784, sigma_mu_1 = 0.0027646100920033783, sigma_sigma_1 = 0.0027940768138667773
# sigma_c_2 = 0.057496293082542164, sigma_mu_2 = 0.06632318729290392, sigma_sigma_2 = 0.06764126700784963
# w_U = 0.059750649051198666, sigma_w_U = 0.39881740729624493
# w_N = 0.9256678568067684, sigma_w_N = 0.0014431513306557326

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.348 sec nello stato nativo e 0.41400000000000003 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2505   0.2364 -462.09320   3.8735    0.00000
# 1     -1.0253   0.0044 -462.14535   3.8432    0.00146
# 2     -0.7792  -0.0536 -461.72630   3.7068    0.00220
# 3     -0.0463  -0.0913 -461.70555   3.6260    0.00342
# 4      0.0636  -0.0739 -461.58815   3.6715    0.00415
# ...       ...      ...        ...      ...        ...
# 5757   0.4196   0.2132 -461.05295   3.8836    5.99536
# 5758   0.3568   0.2654 -461.58435   3.6614    5.99658
# 5759   0.7965   0.2441 -461.57835   3.6210    5.99731
# 5760   0.5034   0.2132 -460.97545   3.5402    5.99804
# 5761   0.3149   0.2325 -460.87800   3.6749    5.99927
#
# [5762 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(6)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.6833966110531753, con deviazione standard = 0.1980137055428563

# %%
prova = [1., 3.7, 0.1, .5, 3.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 3.048989120483361, mu_1 = 3.718550715739621, sigma_1 = 0.12039167544681542
# c_2 = 0.18580622904989547, mu_2 = 3.1305222956440475, sigma_2 = 0.1408066735173472
# sigma_c_1 = 0.06634485797199263, sigma_mu_1 = 0.0030701591605766503, sigma_sigma_1 = 0.003106753857964952
# sigma_c_2 = 0.06087458469818976, sigma_mu_2 = 0.05381489582316169, sigma_sigma_2 = 0.05497762223127707
# w_U = 0.06558030651700286, sigma_w_U = 0.35091252609970913
# w_N = 0.9201153316332868, sigma_w_N = 0.0016590142458199765

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.312 sec nello stato nativo e 0.442 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2348   0.1175 -456.24185   3.7573    0.00000
# 1     -0.2714   0.0740 -456.25515   3.7422    0.00122
# 2     -0.0201   0.1204 -456.31395   3.6412    0.00195
# 3      0.3847   0.1668 -455.81905   3.7422    0.00318
# 4     -0.4599   0.1629 -456.01795   3.7422    0.00415
# ...       ...      ...        ...      ...        ...
# 5749  -0.5175   0.0073 -454.02000   3.6412    5.99512
# 5750   0.0270   0.0276 -453.59530   3.5149    5.99585
# 5751   0.4824   0.1204 -453.81925   3.6058    5.99707
# 5752   0.4196  -0.0072 -453.95310   3.7422    5.99756
# 5753  -0.4808   0.1552 -454.28710   3.6412    5.99927
#
# [5754 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.191887684301808, con deviazione standard = 0.33931657470131765

# %%
prova = [2.0, 4.5, 0.1, .7, 3.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.9344784134651238, mu_1 = 4.425442878529959, sigma_1 = 0.12814705191130807
# c_2 = 0.7895749495260671, mu_2 = 3.8038496929669017, sigma_2 = 0.19002019380716004
# sigma_c_1 = 0.05037046713915112, sigma_mu_1 = 0.0041104892191776935, sigma_sigma_1 = 0.004255476224894764
# sigma_c_2 = 0.040918299336482146, sigma_mu_2 = 0.011841982610542262, sigma_sigma_2 = 0.012487855816581222
# w_U = 0.37608243674561165, sigma_w_U = 0.03812998638843069
# w_N = 0.6213873982526367, sigma_w_N = 0.011614069790938044

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.589 sec nello stato nativo e 2.176 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1404   0.2364 -433.00785   3.6681    0.00000
# 1      0.3306   0.2393 -432.44055   3.7220    0.00342
# 2      0.5505   0.2277 -432.54725   3.9947    0.00440
# 3      0.5400   0.2422 -432.43560   3.9139    0.00537
# 4      0.1317   0.1610 -432.04615   3.7977    0.00635
# ...       ...      ...        ...      ...        ...
# 5760  -0.1196  -0.1232 -432.94485   3.5200    6.02002
# 5761   0.3411  -0.1203 -432.88280   3.4644    6.02124
# 5762   0.1055  -0.1319 -433.19650   3.5351    6.02222
# 5763  -0.2453  -0.1870 -433.16795   3.4897    6.02320
# 5764   0.4196  -0.1116 -433.13795   3.2018    6.02416
#
# [5765 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(6)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.391290986159178, con deviazione standard = 0.3421633194536025

# %%
prova = [0.5, 4.8, 0.1, 1.5, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8634351402323563, mu_1 = 4.870935770574732, sigma_1 = 0.1280593245630974
# c_2 = 1.6216050685622425, mu_2 = 4.205359513356009, sigma_2 = 0.17734303723495987
# sigma_c_1 = 0.04451425490069575, sigma_mu_1 = 0.007822083723303222, sigma_sigma_1 = 0.007905167987707436
# sigma_c_2 = 0.03720742312816676, sigma_mu_2 = 0.004768567679679657, sigma_sigma_2 = 0.004866822201720439
# w_U = 0.7208570817940325, sigma_w_U = 0.0074097923900815965
# w_N = 0.2771601965851743, sigma_w_N = 0.04331484364515611

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.6620000000000001 sec nello stato nativo e 4.118 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5732   0.2828 -420.38130   4.2943    0.00000
# 1     -0.0132   0.1977 -420.40295   4.2270    0.00122
# 2      0.1613   0.2480 -420.27725   4.0048    0.00219
# 3     -0.0620   0.1610 -420.50085   4.1664    0.00293
# 4     -0.6065   0.0392 -419.90165   4.1866    0.00439
# ...       ...      ...        ...      ...        ...
# 5775   0.2416   0.0537 -419.69995   4.8885    5.99316
# 5776  -0.3133  -0.1203 -419.68760   4.7724    5.99414
# 5777  -0.3761  -0.2160 -420.00085   4.7421    5.99536
# 5778  -0.5489  -0.2102 -419.96730   4.7219    5.99609
# 5779  -0.9485  -0.3939 -419.80625   4.7320    5.99902
#
# [5780 rows x 5 columns]

# %%
forces_average
# Out:
# [4.2967714143,
#  3.9537541276674117,
#  3.4072983333451514,
#  3.424536505691834,
#  4.114646285748431,
#  4.53814764196537]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.150927542030166, con sigma = 0.5636843318845184
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 9.418719197601611, con sigma = 0.9057957843456226
# La differenza di energia libera DeltaG_NU = 39.096420927972794, con sigma = 3.748419202509343

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 32.67732239217494, con sigma = 2.9477124400191475

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5295858370657562, con incertezza = 0.004967569128748538,
#  q1 = 4.750495016083539, con incertezza = 0.005543406716889989
# Stimiamo i parametri del fit lineare: m2 = 0.5222143143451984, con incertezza = 0.007911219545946065,
#  q2 = 3.6045960280781477, con incertezza = 0.009323074559740352
# La forza di coesistenza qui vale: fc = 4.173530015706265, con incertezza = 0.007460813895864789
# Il tempo medi di residenza vale: tc = 2.972681950256787, con incertezza = 0.04203713110831153
# Stimiamo un nuovo DeltaG_NU = 39.30930728069915, con incertezza = 3.781018956601775
# ((-0.5295858370657562, 0.004967569128748538),
#  (4.750495016083539, 0.005543406716889989),
#  (0.5222143143451984, 0.007911219545946065),
#  (3.6045960280781477, 0.009323074559740352),
#  (4.173530015706265, 0.007460813895864789),
#  (2.972681950256787, 0.04203713110831153),
#  (39.30930728069915, 3.781018956601775))

# %% [markdown]
# ### Vediamo cosa accade eliminando il primo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.150916610318256, con sigma = 0.5640498376106491
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 9.415342591791703, con sigma = 0.9060566536481041
# La differenza di energia libera DeltaG_NU = 39.08230195610512, con sigma = 3.7495213961977183

# %%
f_c
# Out:
# (4.150916610318256, 0.5640498376106491)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 32.67718211230886, con sigma = 2.949613309922405

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.522920983755342, con incertezza = 0.004990963509268676,
#  q1 = 4.745483422308918, con incertezza = 0.005555275501289064
# Stimiamo i parametri del fit lineare: m2 = 0.5620585668124968, con incertezza = 0.009045221519932726,
#  q2 = 3.5574629659825723, con incertezza = 0.010668969657628927
# La forza di coesistenza qui vale: fc = 4.17290044098129, con incertezza = 0.008094672204373758
# Il tempo medi di residenza vale: tc = 2.9890941053009477, con incertezza = 0.04549033399702519
# Stimiamo un nuovo DeltaG_NU = 39.289287253277514, con incertezza = 3.7816522839865336

# %%
f_c, t_c
# Out:
# ((4.17290044098129, 0.008094672204373758),
#  (2.9890941053009477, 0.04549033399702519))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.2967714143,
#   3.9537541276674117,
#   3.424536505691834,
#   4.114646285748431,
#   4.53814764196537],
#  [2.124, 4.657, 5.312, 3.589, 1.6620000000000001])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.150900330405928, con sigma = 0.5645829271194825
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 9.410500705095208, con sigma = 0.9064442208284349
# La differenza di energia libera DeltaG_NU = 39.06205048606492, con sigma = 3.7511597546200903

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 32.67697320262191, con sigma = 2.9523855831057193

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.512881137447815, con incertezza = 0.00502669273208857,
#  q1 = 4.737963373080097, con incertezza = 0.005573319882515036
# Stimiamo i parametri del fit lineare: m2 = 0.6924165833673707, con incertezza = 0.012097819970833368,
#  q2 = 3.4031422153066218, con incertezza = 0.014292559467491098
# La forza di coesistenza qui vale: fc = 4.169967116333468, con incertezza = 0.009485224299953307
# Il tempo medi di residenza vale: tc = 3.0266662876328123, con incertezza = 0.05302197737581584
# Stimiamo un nuovo DeltaG_NU = 39.241478488479935, con incertezza = 3.7808963893601546
# ((-0.512881137447815, 0.00502669273208857),
#  (4.737963373080097, 0.005573319882515036),
#  (0.6924165833673707, 0.012097819970833368),
#  (3.4031422153066218, 0.014292559467491098),
#  (4.169967116333468, 0.009485224299953307),
#  (3.0266662876328123, 0.05302197737581584),
#  (39.241478488479935, 3.7808963893601546))

# %%
grafici.write_on_txt()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-60-34283a3d455e> in <module>
# ----> 1 grafici.write_on_txt()
#
# c:\Users\ricta\Documents\TesiTriennale\graph_hop.py in write_on_txt(self)
#     390         status = "r" if os.path.isfile(self.nome_txt) else "a"
#     391         f = open(self.nome_txt, status)
# --> 392         f.write(self.output)
#     393         f.close()
#
# UnsupportedOperation: not writable
