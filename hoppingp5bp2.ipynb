# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 2bs_hop-constposition

# %%
# directory name
dir_name = "P5bp_3bs_hop/2cp"
# molecule name is a number in these experimets
number = "2"

# %%
file = Txt_hop(dir_name, number, "_constpos", first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0       0.4181  -0.0259  289.72955   0.6917  10742.13477
# 1       0.2139  -0.1071  289.44350   0.7674  10742.13672
# 2       0.0307  -0.2782  289.66460   0.8583  10742.13672
# 3      -0.4824  -0.1245  289.13545   0.6765  10742.13867
# 4       0.0830   0.0031  289.43655   0.6361  10742.13965
# ...        ...      ...        ...      ...          ...
# 72389   1.1579   0.4825  338.75835   4.1374  10882.96973
# 72390   0.7042   0.4400  338.87120   4.2317  10882.97168
# 72391   0.0621   0.5425  338.81110   4.0196  10882.97168
# 72392   0.1301   0.5280  338.76570   4.0297  10882.97266
# 72393   0.5018   0.5599  339.04785   4.0196  10882.97460
#
# [72394 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 0.6937366604593382, con deviazione standard = 0.1135309456605055

# %% [markdown]
# ## $f_y$ troppo bassa -> no fit

# %%
# prova = [0.2, 4.8, 0.1, 2.1, 4.2, 0.2]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.4181  -0.0259  289.72955   0.6917    0.00000
# 1      0.2139  -0.1071  289.44350   0.7674    0.00195
# 2      0.0307  -0.2782  289.66460   0.8583    0.00195
# 3     -0.4824  -0.1245  289.13545   0.6765    0.00390
# 4      0.0830   0.0031  289.43655   0.6361    0.00488
# ...       ...      ...        ...      ...        ...
# 8050   0.5856  -0.3140  289.70235   0.8785    8.37988
# 8051   0.1807  -0.0781  289.54545   0.6900    8.38085
# 8052   0.1772   0.0002  289.88585   0.6462    8.38281
# 8053   0.4233   0.0988  289.95560   0.5503    8.38378
# 8054   0.3238   0.1162  289.79655   0.5654    8.38373
#
# [8055 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.9510027963525887, con deviazione standard = 0.22412776181364877

# %%
prova = [0.3, 3.6, 0.1, 2., 2.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.1689775443631496, mu_1 = 3.5520844189714995, sigma_1 = 0.13643267826534405
# c_2 = 2.1044788855432417, mu_2 = 2.908935154359521, sigma_2 = 0.18051440675752264
# sigma_c_1 = 0.061162411378980416, sigma_mu_1 = 0.05960430670594383, sigma_sigma_1 = 0.06570706751955854
# sigma_c_2 = 0.05212221033469423, sigma_mu_2 = 0.0053108156308975165, sigma_sigma_2 = 0.005570290497986973
# w_U = 0.9522399009082477, sigma_w_U = 0.0016862502310427245
# w_N = 0.05778795599445493, sigma_w_N = 0.4139764852861998

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.887 sec nello stato nativo e 10.628 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.7112   0.2467  341.24580   2.9187    0.00000
# 1       1.4022   0.4729  341.44380   2.6763    0.00098
# 2       1.3464   0.4477  341.19820   2.7638    0.00195
# 3       0.9625   0.5057  341.19770   2.8581    0.00195
# 4       0.5926   0.5173  341.30135   2.7773    0.00293
# ...        ...      ...        ...      ...        ...
# 11510   1.2609   0.3714  340.67740   3.1864   11.99414
# 11511   1.3255   0.5019  340.73050   3.0601   11.99414
# 11512   1.4790   0.5792  340.86665   2.9389   11.99512
# 11513   1.1440   0.5869  340.67685   2.8716   11.99609
# 11514   0.3081   0.5831  341.02890   2.9238   11.99902
#
# [11515 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.76995121101238, con deviazione standard = 0.2440966808707332

# %%
prova = [3.5, 2.9, 0.2, 0.8, 2.4, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.941628943726967, mu_1 = 2.8954669139552034, sigma_1 = 0.09881604242605804
# c_2 = 0.6658721630194582, mu_2 = 2.4209070962516694, sigma_2 = 0.15813815053587815
# sigma_c_1 = 0.07967212272229106, sigma_mu_1 = 0.0034198730399871108, sigma_sigma_1 = 0.003547680243916009
# sigma_c_2 = 0.06308367682723533, sigma_mu_2 = 0.01845238768743874, sigma_sigma_2 = 0.019839504433732707
# w_U = 0.26394743682535915, sigma_w_U = 0.08278889709881415
# w_N = 0.7286270339973732, sigma_w_N = 0.008576457151525257

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8.290000000000001 sec nello stato nativo e 3.188 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.0411  -0.1129  326.40025   3.0197    0.00000
# 1       0.0202   0.1597  326.42525   2.8177    0.00196
# 2      -0.1892   0.1113  325.77120   2.8716    0.00196
# 3       0.3203   0.1191  326.21825   2.8514    0.00391
# 4      -0.0705   0.1191  326.12855   2.7706    0.00489
# ...        ...      ...        ...      ...        ...
# 11473   0.2645   0.2815  327.02475   2.8177   11.99317
# 11474   0.4739   0.2660  326.57095   2.8043   11.99512
# 11475   1.1510   0.3511  326.90680   2.7302   11.99707
# 11476   0.6973   0.2969  326.63395   2.8312   11.99805
# 11477   0.9049   0.1771  326.81425   2.8985   11.99805
#
# [11478 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.378274730434783, con deviazione standard = 0.22639374020042333

# %%
prova = [2.5, 3.5, 0.1, 0.5, 3., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.9367163243532866, mu_1 = 3.457840911628196, sigma_1 = 0.11324420079927952
# c_2 = 0.36398849539900635, mu_2 = 2.9513625836872013, sigma_2 = 0.17323113488476113
# sigma_c_1 = 0.069975393929259, sigma_mu_1 = 0.0036008856826656808, sigma_sigma_1 = 0.0037522498969192984
# sigma_c_2 = 0.056604306221471494, sigma_mu_2 = 0.03466578116561183, sigma_sigma_2 = 0.03725612880186676
# w_U = 0.1580532905149055, sigma_w_U = 0.15761163969843536
# w_N = 0.8336195722121594, sigma_w_N = 0.004586897153197067

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 9.404 sec nello stato nativo e 2.096 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.6536   0.4468  333.45485   2.8834    0.00000
# 1       1.1667   0.5512  333.00010   2.6864    0.00196
# 2       0.9573   0.5106  333.06910   2.8026    0.00293
# 3       0.6850   0.4497  332.99115   2.9440    0.00293
# 4       1.0358   0.3308  333.49490   3.0096    0.00391
# ...        ...      ...        ...      ...        ...
# 11495   1.5488   0.3453  332.32720   3.5348   11.99610
# 11496   1.7687   0.4004  332.71360   3.5247   11.99610
# 11497   1.5017   0.4004  333.02140   3.4237   11.99805
# 11498   1.4494   0.3656  332.69640   3.4793   11.99903
# 11499   1.2836   0.3820  332.88450   3.4237   11.99903
#
# [11500 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.269560849414391, con deviazione standard = 0.28155409673942094

# %%
prova = [0.7, 4.8, 0.1, 2., 4.2, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6709731948965406, mu_1 = 4.7838196612717825, sigma_1 = 0.09485394362169376
# c_2 = 1.87726713257131, mu_2 = 4.164239683689394, sigma_2 = 0.17918899534751564
# sigma_c_1 = 0.06593382650601691, sigma_mu_1 = 0.011122411042518094, sigma_sigma_1 = 0.010947275748990768
# sigma_c_2 = 0.046484811461164045, sigma_mu_2 = 0.005171387364493342, sigma_sigma_2 = 0.005246348686729871
# w_U = 0.8431936849257468, sigma_w_U = 0.004589060801545252
# w_N = 0.1595329869181638, sigma_w_N = 0.09608774604397305

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.048 sec nello stato nativo e 9.819 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.9782   0.6556  339.46525   4.3024    0.00000
# 1       1.4441   0.6527  340.02395   4.3529    0.00097
# 2       2.0409   0.7687  339.51565   4.1812    0.00390
# 3       2.0671   0.7948  339.34300   4.1105    0.00488
# 4       2.0828   0.7455  339.38690   4.1812    0.00488
# ...        ...      ...        ...      ...        ...
# 11862   1.1579   0.4825  338.75835   4.1374   12.39746
# 11863   0.7042   0.4400  338.87120   4.2317   12.39941
# 11864   0.0621   0.5425  338.81110   4.0196   12.39941
# 11865   0.1301   0.5280  338.76570   4.0297   12.40039
# 11866   0.5018   0.5599  339.04785   4.0196   12.40233
#
# [11867 rows x 5 columns]

# %%
forces_average
# Out:
# [3.23050978666551, 2.6581870051034366, 3.2046017476576987, 4.474029672480588]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.4214095131671325, con sigma = 1.1980953477339213
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 5.949383407333073, con sigma = 1.534743969430942
# La differenza di energia libera DeltaG_NU = 20.355276987328065, con sigma = 4.820217310059997

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -16.228758591264253, con sigma = -2.9443939570675184

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.022282061868502, con incertezza = 0.006863891704214679,
#  q1 = 5.070321145208432, con incertezza = 0.009493673022062065
# Stimiamo i parametri del fit lineare: m2 = 1.2558173051778252, con incertezza = 0.0082270281785004,
#  q2 = 1.5139039293237289, con incertezza = 0.01609193469514548
# La forza di coesistenza qui vale: fc = 3.47440238200142, con incertezza = 0.012150857982476152
# Il tempo medi di residenza vale: tc = 4.764218380574168, con incertezza = 0.05244386669809966
# Stimiamo un nuovo DeltaG_NU = 20.670551881877753, con incertezza = 5.332808098331804
# ((-1.022282061868502, 0.006863891704214679),
#  (5.070321145208432, 0.009493673022062065),
#  (1.2558173051778252, 0.0082270281785004),
#  (1.5139039293237289, 0.01609193469514548),
#  (3.47440238200142, 0.012150857982476152),
#  (4.764218380574168, 0.05244386669809966),
#  (20.670551881877753, 5.332808098331804))

# %% [markdown]
# # Eliminiamo il secondo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
post = 0
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:3], w_N[:3], forces_average[:3], sigma_w_U[:3], sigma_w_N[:3])
# Out:
# La forza di coesistenza vale f_c = 3.4247555178061253, con sigma = 1.199957987634292
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 5.943433198647988, con sigma = 1.5348063690853027
# La differenza di energia libera DeltaG_NU = 20.354805641781805, con sigma = 4.8202175726670635

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -16.249156451063055, con sigma = -2.948567795113413

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.1751848367675521, con incertezza = 0.007205211347702675,
#  q1 = 5.310582154975161, con incertezza = 0.010098837560362244
# Stimiamo i parametri del fit lineare: m2 = 1.305249020036893, con incertezza = 0.008307676928037657,
#  q2 = 1.4562984497495683, con incertezza = 0.01614810618191607
# La forza di coesistenza qui vale: fc = 3.484492031847772, con incertezza = 0.01260517122504363
# Il tempo medi di residenza vale: tc = 4.729761682385754, con incertezza = 0.048791814764351515
# Stimiamo un nuovo DeltaG_NU = 20.709845622508432, con incertezza = 5.348545283849464
# ((-1.1751848367675521, 0.007205211347702675),
#  (5.310582154975161, 0.010098837560362244),
#  (1.305249020036893, 0.008307676928037657),
#  (1.4562984497495683, 0.01614810618191607),
#  (3.484492031847772, 0.01260517122504363),
#  (4.729761682385754, 0.048791814764351515),
#  (20.709845622508432, 5.348545283849464))

# %%
grafici.write_on_txt()
