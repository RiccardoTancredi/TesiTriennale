# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 20bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/20"
# molecule name is a number in these experimets
number = "20"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force   time(sec)
# 0      -0.4648   0.6745 -210.93280   3.7673  8915.01953
# 1      -0.2135   0.7557 -211.38960   3.8346  8915.02051
# 2      -0.0250   0.7576 -211.60785   4.1006  8915.02148
# 3       0.3310   0.7402 -211.38995   4.3531  8915.02246
# 4       0.3728   0.5314 -211.33795   3.8077  8915.02441
# ...        ...      ...        ...      ...         ...
# 70678  -0.2274   0.2607 -290.44930   2.6428  9027.52734
# 70679  -0.1559   0.1022 -290.80475   2.7169  9027.52734
# 70680   0.8754   0.2066 -290.79655   3.2320  9027.52930
# 70681   1.0639   0.1689 -290.65015   3.0199  9027.52930
# 70682   0.2053   0.2124 -290.82105   2.8482  9027.53120
#
# [70683 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph(8)
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.8963047916666627, con deviazione standard = 0.2466468933024182

# %%
prova = [0.2, 4.6, 0.1, 2., 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.19783653695631145, mu_1 = 4.559223029979528, sigma_1 = 0.125524253403622
# c_2 = 2.0598032920909173, mu_2 = 3.8481879579959, sigma_2 = 0.18189016194679267
# sigma_c_1 = 0.04621127197748548, sigma_mu_1 = 0.03446505863453452, sigma_sigma_1 = 0.03443319134232052
# sigma_c_2 = 0.037826137659641566, sigma_mu_2 = 0.0038878640221487906, sigma_sigma_2 = 0.003930013599402769
# w_U = 0.9391282217566834, sigma_w_U = 0.0013262514080188863
# w_N = 0.06224781081717075, sigma_w_N = 0.2543863327879015

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.5680000000000001 sec nello stato nativo e 7.112 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.4648   0.6745 -210.93280   3.7673    0.00000
# 1     -0.2135   0.7557 -211.38960   3.8346    0.00098
# 2     -0.0250   0.7576 -211.60785   4.1006    0.00195
# 3      0.3310   0.7402 -211.38995   4.3531    0.00293
# 4      0.3728   0.5314 -211.33795   3.8077    0.00488
# ...       ...      ...        ...      ...        ...
# 7675  -0.0739   0.3613 -217.23705   4.0366    7.99512
# 7676  -0.3531   0.4038 -217.14940   3.8885    7.99512
# 7677   0.2786   0.5430 -217.03330   3.9188    7.99609
# 7678   0.6032   0.6590 -217.95165   4.1309    7.99707
# 7679  -0.1297   0.5005 -217.59730   4.0972    7.99805
#
# [7680 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.739616281249991, con deviazione standard = 0.3723812742541482

# %%
prova = [1., 4.2, 0.1, 1., 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.3725431378409962, mu_1 = 4.20312835786902, sigma_1 = 0.09848288828741099
# c_2 = 1.5080303345221306, mu_2 = 3.4893298512681197, sigma_2 = 0.17396134735457144
# sigma_c_1 = 0.04847818083467926, sigma_mu_1 = 0.004089013971529912, sigma_sigma_1 = 0.004008322085558585
# sigma_c_2 = 0.03565239981516373, sigma_mu_2 = 0.00477442366428461, sigma_sigma_2 = 0.004772581168131073
# w_U = 0.6575863269770712, sigma_w_U = 0.009261149649885536
# w_N = 0.33882598850548395, sigma_w_N = 0.02680530993401846

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.215 sec nello stato nativo e 4.1850000000000005 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.4333   0.3922 -226.20175   3.4643    0.00000
# 1      0.3938   0.4386 -225.26495   3.6461    0.00196
# 2     -0.0669   0.5169 -225.61605   3.2926    0.00196
# 3     -0.3391   0.5053 -225.77700   3.3381    0.00391
# 4     -0.1664   0.3922 -225.85100   3.6310    0.00391
# ...       ...      ...        ...      ...        ...
# 6395   0.3624   0.4125 -225.38990   3.6764    7.99610
# 6396   0.0797   0.4357 -225.89265   3.5148    7.99610
# 6397  -0.0320   0.4309 -225.55120   3.6124    7.99707
# 6398   0.1216   0.4270 -225.65110   3.3364    7.99903
# 6399   0.3379   0.4927 -225.53575   3.3835    7.99903
#
# [6400 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.540241915698814, con deviazione standard = 0.3781566365257382

# %%
prova = [1., 4., 0.1, 1., 3.2, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2603739677352348, mu_1 = 3.9158149881521602, sigma_1 = 0.14184331071918674
# c_2 = 1.098460159118227, mu_2 = 3.236504129416552, sigma_2 = 0.2012951116041936
# sigma_c_1 = 0.03891303896878926, sigma_mu_1 = 0.00533342185574825, sigma_sigma_1 = 0.0055374913610908355
# sigma_c_2 = 0.03248504128012045, sigma_mu_2 = 0.007107364821345771, sigma_sigma_2 = 0.007495676638488445
# w_U = 0.5542522594997171, sigma_w_U = 0.01566019089786647
# w_N = 0.4481240147019552, sigma_w_N = 0.020245286907038095

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.475 sec nello stato nativo e 4.188 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.1140   0.3806 -231.38830   3.2522    0.00000
# 1     -0.1507   0.2646 -231.36520   3.1613    0.00000
# 2      0.5822   0.3458 -231.68555   2.9997    0.00098
# 3      0.2577   0.4038 -231.28605   3.1007    0.00195
# 4     -0.2135   0.5778 -231.26545   3.0401    0.00391
# ...       ...      ...        ...      ...        ...
# 7658   0.5194   0.2153 -231.60950   3.6007    7.99512
# 7659   0.7759   0.3429 -232.27790   3.4037    7.99512
# 7660   0.3205   0.3864 -232.22820   3.4239    7.99707
# 7661  -0.2554   0.2733 -232.21815   3.4441    7.99805
# 7662   0.2577   0.1834 -232.00420   3.6461    7.99902
#
# [7663 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.031619391686392, con deviazione standard = 1.9723962561635573

# %% [markdown]
# ## Super suspicious data

# %%
# prova = [1., 4.3, 0.1, 1., 3.6, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1791   0.5836 -241.78400   3.6815    0.00000
# 1      -0.0250   0.3951 -241.68165   3.6663    0.00097
# 2      -0.0983   0.3110 -241.50275   3.6663    0.00195
# 3      -0.2344   0.0442 -241.69455   3.7875    0.00390
# 4       0.1791   0.1399 -241.42770   3.7118    0.00390
# ...        ...      ...        ...      ...        ...
# 14790   0.8614   0.4038 -102.92260  11.3356   15.47656
# 14791   0.6660   0.3922 -102.58005  11.4837   15.47754
# 14792   0.2681   0.1602 -102.94035  11.2817   15.47949
# 14793   0.4671   0.1950 -103.31230  11.2312   15.47949
# 14794  -0.0303   0.2182 -103.36365  11.3827   15.48045
#
# [14795 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.1418098290040457, con deviazione standard = 0.24853993853762485

# %%
prova = [2.0, 3.2, 0.1, .3, 2.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.95243971260887, mu_1 = 3.221689364548381, sigma_1 = 0.1131990688439954
# c_2 = 0.3668630765053926, mu_2 = 2.633269881654686, sigma_2 = 0.15591056977597853
# sigma_c_1 = 0.059409068505601056, sigma_mu_1 = 0.002684012026476137, sigma_sigma_1 = 0.0027279026646772563
# sigma_c_2 = 0.050183519070271444, sigma_mu_2 = 0.024893601018391692, sigma_sigma_2 = 0.025520940286665437
# w_U = 0.1433737011533831, sigma_w_U = 0.13354229703914094
# w_N = 0.8377488240881807, sigma_w_N = 0.003362648783890252

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.464 sec nello stato nativo e 1.197 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5927   0.4560 -258.50165   3.1007    0.00000
# 1      0.6939   0.3342 -258.40290   3.1478    0.00097
# 2     -0.6951  -0.0138 -258.85495   3.0654    0.00488
# 3     -0.2763   0.0703 -258.60385   3.1209    0.00586
# 4     -0.4072   0.0906 -258.34545   3.2522    0.00781
# ...       ...      ...        ...      ...        ...
# 7656  -0.0198   0.1022 -261.99355   3.1815    7.99219
# 7657  -0.0931   0.1283 -261.70840   3.2724    7.99414
# 7658  -0.0564   0.1022 -261.61115   3.1108    7.99414
# 7659   0.1949   0.2327 -261.78970   3.2472    7.99609
# 7660   0.0378   0.3110 -261.49870   3.0603    7.99805
#
# [7661 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.3507320193818795, con deviazione standard = 0.31213642275473114

# %%
prova = [2., 3.5, 0.1, .5, 3., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.359570035769598, mu_1 = 3.4695263679032675, sigma_1 = 0.12306022181330352
# c_2 = 0.5062012423242674, mu_2 = 2.8635908071722653, sigma_2 = 0.17901520506976432
# sigma_c_1 = 0.05066189383965056, sigma_mu_1 = 0.0032000882424804127, sigma_sigma_1 = 0.0033076380363912935
# sigma_c_2 = 0.04176716345002764, sigma_mu_2 = 0.017534498826607854, sigma_sigma_2 = 0.018436534717076795
# w_U = 0.22714493713242123, sigma_w_U = 0.0707912911629221
# w_N = 0.7278476768460074, sigma_w_N = 0.005753565697457833

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.804 sec nello stato nativo e 1.832 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2135   0.4154 -264.61795   3.4441    0.00000
# 1      0.0954   0.4589 -264.45735   3.3886    0.00097
# 2      0.0378   0.3574 -264.72725   3.5249    0.00097
# 3     -0.0460   0.3922 -264.12880   3.4037    0.00293
# 4     -0.3496   0.3255 -264.68815   3.5401    0.00390
# ...       ...      ...        ...      ...        ...
# 7631  -0.1925  -0.0254 -269.05215   2.6210    7.99414
# 7632  -0.3234   0.0297 -268.56865   3.0250    7.99609
# 7633  -0.0041   0.0500 -268.41090   2.9341    7.99707
# 7634   0.2734   0.1921 -268.68300   2.9947    7.99707
# 7635   0.7079   0.2878 -268.28480   2.7876    7.99902
#
# [7636 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.717487270433189, con deviazione standard = 0.22863881529812605

# %%
prova = [2., 2.8, 0.1, .3, 2.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.896605718118043, mu_1 = 2.7733604026149346, sigma_1 = 0.11876055697422354
# c_2 = 0.29249767140113303, mu_2 = 2.2288237515389344, sigma_2 = 0.15199257883967024
# sigma_c_1 = 0.05466943651241669, sigma_mu_1 = 0.0026966334085198685, sigma_sigma_1 = 0.0028117327978929595
# sigma_c_2 = 0.048056821847516584, sigma_mu_2 = 0.029702302304573776, sigma_sigma_2 = 0.031178457754139396
# w_U = 0.11143836480836694, sigma_w_U = 0.16701133330216125
# w_N = 0.8622864141455991, sigma_w_N = 0.0024827196865600913

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.197 sec nello stato nativo e 0.936 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2815  -0.0254 -284.75175   2.7624    0.00000
# 1     -0.0320   0.1061 -284.63575   2.9256    0.00098
# 2     -0.2693   0.1254 -284.85320   2.9862    0.00293
# 3     -0.4438  -0.1298 -285.16330   2.9997    0.00391
# 4     -0.4648  -0.1994 -284.36690   2.8179    0.00489
# ...       ...      ...        ...      ...        ...
# 7128  -0.2274   0.2607 -290.44930   2.6428    7.42578
# 7129  -0.1559   0.1022 -290.80475   2.7169    7.42578
# 7130   0.8754   0.2066 -290.79655   3.2320    7.42774
# 7131   1.0639   0.1689 -290.65015   3.0199    7.42774
# 7132   0.2053   0.2124 -290.82105   2.8482    7.42964
#
# [7133 rows x 5 columns]

# %%
forces_average
# Out:
# [4.203705493987714,
#  3.84622910456857,
#  3.576159558784356,
#  2.9274796231015334,
#  3.166558587537766,
#  2.5010920770769345]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.4937667629129416, con sigma = 0.7250359193090175
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 8.449218119357212, con sigma = 1.2125482783536965
# La differenza di energia libera DeltaG_NU = 29.51959743801202, con sigma = 4.425037706082294

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -16.669159759630226, con sigma = -1.791442214847739

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6846368272033618, con incertezza = 0.0057373545415526014,
#  q1 = 4.366674755433545, con incertezza = 0.006363409255621066
# Stimiamo i parametri del fit lineare: m2 = 0.7447198203499972, con incertezza = 0.006135312650466455,
#  q2 = 2.6928933490305442, con incertezza = 0.008325106382478428
# La forza di coesistenza qui vale: fc = 3.5649627450173678, con incertezza = 0.007140598517612964
# Il tempo medi di residenza vale: tc = 3.2252270105786445, con incertezza = 0.032429276003044745
# Stimiamo un nuovo DeltaG_NU = 30.121147820034167, con incertezza = 4.323110453405878
# ((-0.6846368272033618, 0.0057373545415526014),
#  (4.366674755433545, 0.006363409255621066),
#  (0.7447198203499972, 0.006135312650466455),
#  (2.6928933490305442, 0.008325106382478428),
#  (3.5649627450173678, 0.007140598517612964),
#  (3.2252270105786445, 0.032429276003044745),
#  (30.121147820034167, 4.323110453405878))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
forces_average_std = remove_element(forces_average_std, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.4935660400274307, con sigma = 0.7268871196165803
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 8.43421679683764, con sigma = 1.2135311627466243
# La differenza di energia libera DeltaG_NU = 29.465493375660916, con sigma = 4.428541116051125

# %%
f_c
# Out:
# (3.4935660400274307, 0.7268871196165803)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -16.667940144876404, con sigma = -1.7959940710130555

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.8213288260130412, con incertezza = 0.006779577140518541,
#  q1 = 4.52198453487761, con incertezza = 0.007571925161351572
# Stimiamo i parametri del fit lineare: m2 = 0.7402722780858062, con incertezza = 0.006313639422552129,
#  q2 = 2.6976788102265035, con incertezza = 0.00847806214414578
# La forza di coesistenza qui vale: fc = 3.56248541875652, con incertezza = 0.007868458328844164
# Il tempo medi di residenza vale: tc = 3.2162874786739306, con incertezza = 0.03232610926929548
# Stimiamo un nuovo DeltaG_NU = 30.046774357365404, con incertezza = 4.32369641416567

# %%
f_c, t_c
# Out:
# ((3.56248541875652, 0.007868458328844164),
#  (3.2162874786739306, 0.03232610926929548))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.84622910456857,
#   3.576159558784356,
#   2.9274796231015334,
#   3.166558587537766,
#   2.5010920770769345],
#  [2.215, 3.475, 6.464, 5.804, 6.197])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -1
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.49352894621757, con sigma = 0.7463880560234606
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 8.432398338316048, con sigma = 1.2456774880371526
# La differenza di energia libera DeltaG_NU = 29.45882768094405, con sigma = 4.546887526954551

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -16.667714757433703, con sigma = -1.843766718094949

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.7246070702048493, con incertezza = 0.007243046582239137,
#  q1 = 4.435175434039202, con incertezza = 0.007910072345742624
# Stimiamo i parametri del fit lineare: m2 = 0.6847345994795847, con incertezza = 0.0077573157743555,
#  q2 = 2.7751016728069358, con incertezza = 0.010552518820602324
# La forza di coesistenza qui vale: fc = 3.581655517382087, con incertezza = 0.009135592317170696
# Il tempo medi di residenza vale: tc = 3.247570711503793, con incertezza = 0.041873055993148486
# Stimiamo un nuovo DeltaG_NU = 30.20194603319322, con incertezza = 4.462252651297608
# ((-0.7246070702048493, 0.007243046582239137),
#  (4.435175434039202, 0.007910072345742624),
#  (0.6847345994795847, 0.0077573157743555),
#  (2.7751016728069358, 0.010552518820602324),
#  (3.581655517382087, 0.009135592317170696),
#  (3.247570711503793, 0.041873055993148486),
#  (30.20194603319322, 4.462252651297608))

# %%
grafici.write_on_txt()
