# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 20bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/20"
# molecule name is a number in these experimets
number = "20"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force   time(sec)
# 0      -0.4648   0.6745 -210.93280   3.7673  8915.01953
# 1      -0.2135   0.7557 -211.38960   3.8346  8915.02051
# 2      -0.0250   0.7576 -211.60785   4.1006  8915.02148
# 3       0.3310   0.7402 -211.38995   4.3531  8915.02246
# 4       0.3728   0.5314 -211.33795   3.8077  8915.02441
# ...        ...      ...        ...      ...         ...
# 70678  -0.2274   0.2607 -290.44930   2.6428  9027.52734
# 70679  -0.1559   0.1022 -290.80475   2.7169  9027.52734
# 70680   0.8754   0.2066 -290.79655   3.2320  9027.52930
# 70681   1.0639   0.1689 -290.65015   3.0199  9027.52930
# 70682   0.2053   0.2124 -290.82105   2.8482  9027.53120
#
# [70683 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.9301017903047883, con deviazione standard = 0.2415688878220727

# %%
prova = [0.2, 4.6, 0.1, 2., 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.16043122209946103, mu_1 = 4.570119841786133, sigma_1 = 0.13516597950671835
# c_2 = 2.0068318952173114, mu_2 = 3.890421330969846, sigma_2 = 0.18804309176816855
# sigma_c_1 = 0.04651288778557562, sigma_mu_1 = 0.04670383962611815, sigma_sigma_1 = 0.047779969208895504
# sigma_c_2 = 0.0389245418723638, sigma_mu_2 = 0.0042920564239635845, sigma_sigma_2 = 0.004432091887874049
# w_U = 0.9459285033812658, sigma_w_U = 0.0016591708100512303
# w_N = 0.05435584129291415, sigma_w_N = 0.43245795599384174

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 812 sec nello stato nativo e 10080 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.4648   0.6745 -210.93280   3.7673    0.00000
# 1      -0.2135   0.7557 -211.38960   3.8346    0.00098
# 2      -0.0250   0.7576 -211.60785   4.1006    0.00195
# 3       0.3310   0.7402 -211.38995   4.3531    0.00293
# 4       0.3728   0.5314 -211.33795   3.8077    0.00488
# ...        ...      ...        ...      ...        ...
# 10887   0.4357   0.3400 -216.43790   4.0703   11.33399
# 10888   0.0326   0.4676 -216.03645   4.0299   11.33496
# 10889  -0.2815   0.6155 -216.20040   3.9895   11.33496
# 10890   0.4147   0.6387 -216.33205   3.8683   11.33594
# 10891   0.3868   0.6629 -216.19465   4.0030   11.33687
#
# [10892 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.717402313624662, con deviazione standard = 0.371918078169971

# %%
prova = [1., 4.2, 0.1, 1., 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2842633497614875, mu_1 = 4.173126142554919, sigma_1 = 0.10758128972147553
# c_2 = 1.4573297295568375, mu_2 = 3.4674114329944783, sigma_2 = 0.17823734980689646
# sigma_c_1 = 0.04410478739594935, sigma_mu_1 = 0.004337473365927741, sigma_sigma_1 = 0.004284450773182018
# sigma_c_2 = 0.0336418740356135, sigma_mu_2 = 0.004777571802710932, sigma_sigma_2 = 0.004791750495971994
# w_U = 0.6510981702156005, sigma_w_U = 0.012272009397515387
# w_N = 0.3463225491425428, sigma_w_N = 0.034239690216227435

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3974 sec nello stato nativo e 7307 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.4333   0.3922 -226.20175   3.4643    0.00000
# 1       0.3938   0.4386 -225.26495   3.6461    0.00196
# 2      -0.0669   0.5169 -225.61605   3.2926    0.00196
# 3      -0.3391   0.5053 -225.77700   3.3381    0.00391
# 4      -0.1664   0.3922 -225.85100   3.6310    0.00391
# ...        ...      ...        ...      ...        ...
# 11276  -0.2554   0.3071 -223.39655   3.5047   13.08106
# 11277   0.0535   0.3429 -223.56875   3.4542   13.08204
# 11278  -0.1559   0.3719 -223.47195   3.3280   13.08204
# 11279  -0.1297   0.4386 -223.67335   3.4290   13.08399
# 11280  -0.1664   0.5343 -223.44550   3.6259   13.08396
#
# [11281 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.537750768693223, con deviazione standard = 0.37384749687099217

# %%
prova = [1., 4., 0.1, 1., 3.2, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.1754669479833026, mu_1 = 3.9256838568774333, sigma_1 = 0.14340061945485474
# c_2 = 1.135519379775072, mu_2 = 3.2551886949519844, sigma_2 = 0.20370382972392165
# sigma_c_1 = 0.0372532072149575, sigma_mu_1 = 0.005613444526516107, sigma_sigma_1 = 0.005854658298554935
# sigma_c_2 = 0.031120741939377736, sigma_mu_2 = 0.006740128882648949, sigma_sigma_2 = 0.0071543874154898325
# w_U = 0.5798072998258313, sigma_w_U = 0.018823164178192027
# w_N = 0.4225240010156311, sigma_w_N = 0.029966934633022614

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3692 sec nello stato nativo e 4894 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.1140   0.3806 -231.38830   3.2522    0.00000
# 1     -0.1507   0.2646 -231.36520   3.1613    0.00000
# 2      0.5822   0.3458 -231.68555   2.9997    0.00098
# 3      0.2577   0.4038 -231.28605   3.1007    0.00195
# 4     -0.2135   0.5778 -231.26545   3.0401    0.00391
# ...       ...      ...        ...      ...        ...
# 8581   0.0099   0.5314 -233.12240   3.3162    8.95117
# 8582   0.2402   0.5817 -233.02145   3.2690    8.95215
# 8583   0.0448   0.5469 -233.10955   3.2556    8.95313
# 8584  -0.2484   0.7131 -233.38060   3.2825    8.95410
# 8585   0.3781   0.6880 -232.88430   3.5552    8.95502
#
# [8586 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.031619391686392, con deviazione standard = 1.9723962561635573

# %% [markdown]
# ## Super suspicious data

# %%
# prova = [1., 4.3, 0.1, 1., 3.6, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1791   0.5836 -241.78400   3.6815    0.00000
# 1      -0.0250   0.3951 -241.68165   3.6663    0.00097
# 2      -0.0983   0.3110 -241.50275   3.6663    0.00195
# 3      -0.2344   0.0442 -241.69455   3.7875    0.00390
# 4       0.1791   0.1399 -241.42770   3.7118    0.00390
# ...        ...      ...        ...      ...        ...
# 14790   0.8614   0.4038 -102.92260  11.3356   15.47656
# 14791   0.6660   0.3922 -102.58005  11.4837   15.47754
# 14792   0.2681   0.1602 -102.94035  11.2817   15.47949
# 14793   0.4671   0.1950 -103.31230  11.2312   15.47949
# 14794  -0.0303   0.2182 -103.36365  11.3827   15.48045
#
# [14795 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.151238274134778, con deviazione standard = 0.2446625498816928

# %%
prova = [2.0, 3.2, 0.1, .3, 2.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.973747036896647, mu_1 = 3.225916558524111, sigma_1 = 0.11357987702747113
# c_2 = 0.3456191106559179, mu_2 = 2.635504731872442, sigma_2 = 0.1540890968762315
# sigma_c_1 = 0.053925098763346585, sigma_mu_1 = 0.002422698112008812, sigma_sigma_1 = 0.002458683073146364
# sigma_c_2 = 0.045891866543489125, sigma_mu_2 = 0.023864217114422215, sigma_sigma_2 = 0.024407807879677747
# w_U = 0.13349333785967263, sigma_w_U = 0.17499260172313957
# w_N = 0.8466333085118517, sigma_w_N = 0.0037696964918417972

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7493 sec nello stato nativo e 1291 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5927   0.4560 -258.50165   3.1007    0.00000
# 1      0.6939   0.3342 -258.40290   3.1478    0.00097
# 2     -0.6951  -0.0138 -258.85495   3.0654    0.00488
# 3     -0.2763   0.0703 -258.60385   3.1209    0.00586
# 4     -0.4072   0.0906 -258.34545   3.2522    0.00781
# ...       ...      ...        ...      ...        ...
# 8779   0.5927   0.0993 -262.14585   3.3684    9.16601
# 8780   0.5718   0.1689 -261.56650   3.1916    9.16797
# 8781   0.4671   0.1602 -261.70425   3.2017    9.16894
# 8782  -0.0198   0.2704 -261.53340   3.3482    9.16894
# 8783   0.3624   0.3835 -261.95930   3.4795    9.16987
#
# [8784 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.32357052757274, con deviazione standard = 0.323468768420948

# %%
prova = [2., 3.5, 0.1, .5, 3., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.304809021457234, mu_1 = 3.4667148941994226, sigma_1 = 0.12071210457818006
# c_2 = 0.5847616587405248, mu_2 = 2.858791025208887, sigma_2 = 0.17766007595138225
# sigma_c_1 = 0.04961717251174665, sigma_mu_1 = 0.003127930829077209, sigma_sigma_1 = 0.0032198081487994443
# sigma_c_2 = 0.040636211448696495, sigma_mu_2 = 0.014583257401411299, sigma_sigma_2 = 0.015262487205920702
# w_U = 0.2604106052654047, sigma_w_U = 0.07705883092043654
# w_N = 0.6973899766926768, sigma_w_N = 0.008926097373575843

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6708 sec nello stato nativo e 2504 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2135   0.4154 -264.61795   3.4441    0.00000
# 1      0.0954   0.4589 -264.45735   3.3886    0.00097
# 2      0.0378   0.3574 -264.72725   3.5249    0.00097
# 3     -0.0460   0.3922 -264.12880   3.4037    0.00293
# 4     -0.3496   0.3255 -264.68815   3.5401    0.00390
# ...       ...      ...        ...      ...        ...
# 9207  -0.2187   0.2182 -268.60165   2.9088    9.63476
# 9208  -0.3444   0.2356 -268.33105   2.9846    9.63476
# 9209  -0.1035   0.1138 -268.84600   3.2371    9.63671
# 9210  -0.2344   0.2820 -268.37570   3.0957    9.63671
# 9211  -0.0460   0.3081 -268.38745   2.9543    9.63863
#
# [9212 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.717487270433189, con deviazione standard = 0.22863881529812605

# %%
prova = [2., 2.8, 0.1, .3, 2.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.896605718118043, mu_1 = 2.7733604026149346, sigma_1 = 0.11876055697422354
# c_2 = 0.29249767140113303, mu_2 = 2.2288237515389344, sigma_2 = 0.15199257883967024
# sigma_c_1 = 0.05466943651241669, sigma_mu_1 = 0.0026966334085198685, sigma_sigma_1 = 0.0028117327978929595
# sigma_c_2 = 0.048056821847516584, sigma_mu_2 = 0.029702302304573776, sigma_sigma_2 = 0.031178457754139396
# w_U = 0.11143836480836694, sigma_w_U = 0.22662354900375759
# w_N = 0.8622864141455991, sigma_w_N = 0.003374116879212214

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6197 sec nello stato nativo e 936 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2815  -0.0254 -284.75175   2.7624    0.00000
# 1     -0.0320   0.1061 -284.63575   2.9256    0.00098
# 2     -0.2693   0.1254 -284.85320   2.9862    0.00293
# 3     -0.4438  -0.1298 -285.16330   2.9997    0.00391
# 4     -0.4648  -0.1994 -284.36690   2.8179    0.00489
# ...       ...      ...        ...      ...        ...
# 7128  -0.2274   0.2607 -290.44930   2.6428    7.42578
# 7129  -0.1559   0.1022 -290.80475   2.7169    7.42578
# 7130   0.8754   0.2066 -290.79655   3.2320    7.42774
# 7131   1.0639   0.1689 -290.65015   3.0199    7.42774
# 7132   0.2053   0.2124 -290.82105   2.8482    7.42964
#
# [7133 rows x 5 columns]

# %%
forces_average
# Out:
# [4.23027058637799,
#  3.8202687877746984,
#  3.590436275914709,
#  2.9307106451982765,
#  3.1627529597041546,
#  2.5010920770769345]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.475115199906242, con sigma = 0.9334466335069405
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 8.532994319338865, con sigma = 1.5790539622626025
# La differenza di energia libera DeltaG_NU = 29.653138259848106, con sigma = 5.7733212214375245

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -16.555780478050643, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.0873042094017245, con incertezza = 0.36507935936491664,
#  q1 = 11.944621998663433, con incertezza = 1.249016182324344
# Stimiamo i parametri del fit lineare: m2 = 1.4983689233352975, con incertezza = 0.12484487906934523,
#  q2 = 3.02013386158552, con incertezza = 0.42712158473941236
# La forza di coesistenza qui vale: fc = 3.4515144331607917, con incertezza = 0.7251827343500313
# Il tempo medi di residenza vale: tc = 3611.129295612097, con incertezza = 9321.438072767112
# Stimiamo un nuovo DeltaG_NU = 29.45175305127714, con incertezza = 8.245907384187706
# ((-1.0873042094017245, 0.36507935936491664),
#  (11.944621998663433, 1.249016182324344),
#  (1.4983689233352975, 0.12484487906934523),
#  (3.02013386158552, 0.42712158473941236),
#  (3.4515144331607917, 0.7251827343500313),
#  (3611.129295612097, 9321.438072767112),
#  (29.45175305127714, 8.245907384187706))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.4750020844177962, con sigma = 0.9345724007459871
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 8.525855622991678, con sigma = 1.5796681866233535
# La differenza di energia libera DeltaG_NU = 29.62736606134127, con sigma = 5.77551086738005

# %%
f_c
# Out:
# (3.4750020844177962, 0.9345724007459871)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -16.555092562181095, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.48306138854889596, con incertezza = 0.21698937066692872,
#  q1 = 10.139515346978783, con incertezza = 0.702008195770441
# Stimiamo i parametri del fit lineare: m2 = 1.629724729413559, con incertezza = 0.15668514954172524,
#  q2 = 2.6277233352119977, con incertezza = 0.50691081934716
# La forza di coesistenza qui vale: fc = 3.555396330893666, con incertezza = 0.6089509510801707
# Il tempo medi di residenza vale: tc = 4546.171178866611, con incertezza = 13245.492110243096
# Stimiamo un nuovo DeltaG_NU = 30.31279579971374, con incertezza = 7.648426280477624

# %%
f_c, t_c
# Out:
# ((3.555396330893666, 0.6089509510801707),
#  (4546.171178866611, 13245.492110243096))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.8202687877746984,
#   3.590436275914709,
#   2.9307106451982765,
#   3.1627529597041546,
#   2.5010920770769345],
#  [3974, 3692, 7493, 6708, 6197])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -1
forces_average = remove_element(forces_average, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.4748948863392854, con sigma = 0.9581709696893898
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 8.521268523496403, con sigma = 1.61850935082644
# La differenza di energia libera DeltaG_NU = 29.610512417421564, con sigma = 5.918903774564856

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.8414258180722056, con incertezza = 0.21008744179165878,
#  q1 = 11.399247209919851, con incertezza = 0.7130430800675712
# Stimiamo i parametri del fit lineare: m2 = 1.8772405672454695, con incertezza = 0.16771485517133147,
#  q2 = 1.7576492970733273, con incertezza = 0.5692292513586646
# La forza di coesistenza qui vale: fc = 3.5464439347602803, con incertezza = 0.48538564400578466
# Il tempo medi di residenza vale: tc = 4515.077907068857, con incertezza = 12344.386951482087
# Stimiamo un nuovo DeltaG_NU = 30.220201071617506, con incertezza = 7.074912828765169
# ((-0.8414258180722056, 0.21008744179165878),
#  (11.399247209919851, 0.7130430800675712),
#  (1.8772405672454695, 0.16771485517133147),
#  (1.7576492970733273, 0.5692292513586646),
#  (3.5464439347602803, 0.48538564400578466),
#  (4515.077907068857, 12344.386951482087),
#  (30.220201071617506, 7.074912828765169))
