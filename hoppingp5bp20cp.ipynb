# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 20bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/20cp"
# molecule name is a number in these experimets
number = "20"

# %%
file = Txt_hop(dir_name, number, different_name='hopcp', first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force   time(sec)
# 0       0.2332  -0.6866 -302.55685   4.0501  9074.19434
# 1      -0.3112  -0.5319 -302.56290   3.9087  9074.19629
# 2      -0.0111  -0.4430 -302.63065   4.0030  9074.19824
# 3       0.0169  -0.5551 -302.47170   3.7202  9074.19824
# 4      -0.6375  -0.4894 -302.57960   3.5148  9074.19922
# ...        ...      ...        ...      ...         ...
# 54919  -0.2833   0.2182 -200.61585   0.0034  9233.32422
# 54920  -0.8068   0.2569 -200.77105   0.8720  9233.32617
# 54921  -0.6794   0.4908 -200.58065   1.0958  9233.32617
# 54922   0.2263   0.3110 -201.18650   0.6565  9233.32812
# 54923  -0.1245   0.2675 -200.85025   1.1514  9233.33000
#
# [54924 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph(10)
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.054916951983308, con deviazione standard = 0.23601957643396465

# %%
prova = [0.2, 4.8, 0.1, 2., 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.17702919968931466, mu_1 = 4.777453556809545, sigma_1 = 0.09370687817591834
# c_2 = 2.1484163372470273, mu_2 = 4.010880765155822, sigma_2 = 0.1775719271470752
# sigma_c_1 = 0.051871932050902944, sigma_mu_1 = 0.032457692650094724, sigma_sigma_1 = 0.03145377427644877
# sigma_c_2 = 0.036416849176730604, sigma_mu_2 = 0.0034985182441329807, sigma_sigma_2 = 0.003480009355966829
# w_U = 0.9562747496588613, sigma_w_U = 0.0008141378293324536
# w_N = 0.04158208959996549, sigma_w_N = 0.3229094977135504

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.47800000000000004 sec nello stato nativo e 9.102 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2332  -0.6866 -302.55685   4.0501    0.00000
# 1     -0.3112  -0.5319 -302.56290   3.9087    0.00195
# 2     -0.0111  -0.4430 -302.63065   4.0030    0.00390
# 3      0.0169  -0.5551 -302.47170   3.7202    0.00390
# 4     -0.6375  -0.4894 -302.57960   3.5148    0.00488
# ...       ...      ...        ...      ...        ...
# 9575  -0.6480  -0.4575 -303.47410   4.0198    9.99511
# 9576  -0.7370  -0.4662 -303.48315   4.1612    9.99609
# 9577  -0.7736  -0.4778 -303.58135   4.0299    9.99609
# 9578  -0.4229  -0.4604 -303.69285   3.8178    9.99707
# 9579  -0.2763  -0.4314 -303.28340   3.8683    9.99804
#
# [9580 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.751356988449731, con deviazione standard = 0.3528975217413225

# %%
prova = [0.8, 4.2, 0.1, 1.5, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.1709267926425841, mu_1 = 4.234241734551009, sigma_1 = 0.098342476512687
# c_2 = 1.5814400128394752, mu_2 = 3.5439371210950363, sigma_2 = 0.1785539357076627
# sigma_c_1 = 0.04355574467657023, sigma_mu_1 = 0.004306800607196528, sigma_sigma_1 = 0.004231484847738846
# sigma_c_2 = 0.03156841661953696, sigma_mu_2 = 0.004138666373511846, sigma_sigma_2 = 0.004147071679475145
# w_U = 0.70780248735213, sigma_w_U = 0.006665928511501801
# w_N = 0.2886428595326085, sigma_w_N = 0.030415086211851364

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.806 sec nello stato nativo e 6.631 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.3286  -0.0138 -313.31810   3.3532    0.00000
# 1     -0.2763   0.0442 -313.65705   3.3027    0.00098
# 2      0.0483   0.2501 -313.10780   3.4189    0.00390
# 3     -0.6113   0.1486 -313.76265   3.5855    0.00586
# 4     -0.4229   0.0529 -313.64905   3.5199    0.00586
# ...       ...      ...        ...      ...        ...
# 9432  -0.2711  -0.5677 -313.30530   4.2925    9.82715
# 9433  -0.3915  -0.4894 -313.45185   4.3481    9.82812
# 9434  -0.0250  -0.5010 -313.02985   4.3834    9.83008
# 9435   0.2996  -0.3212 -313.12440   4.2218    9.83105
# 9436   0.7916  -0.2149 -313.41350   4.2858    9.83098
#
# [9437 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.1461232097989864, con deviazione standard = 0.2929924218209679

# %%
prova = [1.8, 3.4, 0.1, 0.5, 2.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.8858351732956116, mu_1 = 3.2359334299174294, sigma_1 = 0.18207047576836619
# c_2 = 0.3367623735978211, mu_2 = 2.591247863032502, sigma_2 = 0.15858812309519388
# sigma_c_1 = 0.03797660949738903, sigma_mu_1 = 0.004472726623876785, sigma_sigma_1 = 0.004863019194849725
# sigma_c_2 = 0.03982110120572019, sigma_mu_2 = 0.023510718577230288, sigma_sigma_2 = 0.024333724127338523
# w_U = 0.13387027492854608, sigma_w_U = 0.12131462864477728
# w_N = 0.8606631186776016, sigma_w_N = 0.003234793746401202

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8.013 sec nello stato nativo e 1.539 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.8696   0.1757 -324.59130   2.4610    0.00000
# 1     -0.1227   0.0481 -324.35595   2.8381    0.00293
# 2      0.5892   0.1215 -324.81520   2.5620    0.00391
# 3     -0.7300  -0.1569 -324.48675   2.5620    0.00488
# 4     -0.2082  -0.1936 -324.24305   3.1411    0.00586
# ...       ...      ...        ...      ...        ...
# 9547   0.0012  -0.0428 -324.41060   3.0906    9.95899
# 9548   0.2943   0.0210 -324.31755   3.0048    9.96094
# 9549   0.5142  -0.0573 -324.41210   3.0351    9.96191
# 9550   0.1216  -0.0167 -323.97630   2.9997    9.96191
# 9551  -0.4909  -0.0892 -324.20060   3.0048    9.96281
#
# [9552 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(10)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.2038270744180886, con deviazione standard = 0.2662295498133695

# %%
prova = [2., 3.3, 0.1, .4, 2.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.5425061579705894, mu_1 = 3.2934610701241858, sigma_1 = 0.1277007002375693
# c_2 = 0.3899684757613994, mu_2 = 2.711195454816281, sigma_2 = 0.1696750610479947
# sigma_c_1 = 0.047106537453230256, sigma_mu_1 = 0.0028912366360441576, sigma_sigma_1 = 0.003024465788450596
# sigma_c_2 = 0.040620513692566106, sigma_mu_2 = 0.02125356320266587, sigma_sigma_2 = 0.022452271467238466
# w_U = 0.16585839150723236, sigma_w_U = 0.10042920887132588
# w_N = 0.8138516088203778, sigma_w_N = 0.0036470188095439815

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.84 sec nello stato nativo e 1.741 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.1925  -0.1762 -309.77390   3.4492    0.00000
# 1     -0.9673  -0.2110 -309.02345   3.4239    0.00098
# 2     -0.3915   0.0094 -309.56205   3.1613    0.00196
# 3     -0.5328  -0.1095 -309.46335   3.3280    0.00391
# 4     -0.1454  -0.0573 -309.84125   3.3532    0.00391
# ...       ...      ...        ...      ...        ...
# 9576  -0.2903   0.2027 -309.08975   3.0266    9.99512
# 9577  -0.2763   0.2105 -309.06950   3.4441    9.99610
# 9578   0.1146   0.2337 -309.09215   3.4306    9.99610
# 9579   0.1582   0.2559 -309.05860   3.2017    9.99805
# 9580   0.3100   0.2095 -309.28425   3.2118    9.99805
#
# [9581 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.218601786283891, con deviazione standard = 0.321411489832693

# %%
prova = [1.4, 3.4, 0.1, .5, 2.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.3413944616265947, mu_1 = 3.294319931692101, sigma_1 = 0.26309264391487613
# c_2 = 0.36191511416932104, mu_2 = 2.6833980043664813, sigma_2 = 0.12201980185300909
# sigma_c_1 = 0.02699758824524062, sigma_mu_1 = 0.007145673373985329, sigma_sigma_1 = 0.008114719086771435
# sigma_c_2 = 0.04070443357883681, sigma_mu_2 = 0.017472174073841405, sigma_sigma_2 = 0.01695280648386481
# w_U = 0.1106947362764188, sigma_w_U = 0.1169406005211329
# w_N = 0.8846167297359372, sigma_w_N = 0.002806734818236254

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.79 sec nello stato nativo e 1.615 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2542   0.1215 -299.13670   3.6865    0.00000
# 1      0.2751   0.1409 -299.28415   3.8279    0.00000
# 2      0.4566   0.1950 -298.97990   3.7269    0.00098
# 3      0.0448   0.2685 -299.36360   3.6461    0.00196
# 4      0.3170   0.1795 -299.26725   3.6259    0.00391
# ...       ...      ...        ...      ...        ...
# 9400   0.3624   0.2472 -299.15730   3.2320    9.79785
# 9401   0.1163   0.1515 -299.25320   3.1512    9.79785
# 9402   0.1530   0.0645 -299.34445   3.3229    9.79981
# 9403   0.6974  -0.0486 -299.09810   3.1916    9.79981
# 9404   0.2263  -0.1221 -299.50030   3.1074    9.80071
#
# [9405 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 0.8035999452504774, con deviazione standard = 0.43529409407966

# %% [markdown]
# ## Suspiciuos Data: force too low

# %%
forces_average
# Out:
# [4.394167160982683,
#  3.8890894278230226,
#  2.9135906464749657,
#  3.0023282624702334,
#  2.988858968029291]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.580090811403451, con sigma = 0.9252039229870662
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 11.933066485059648, con sigma = 2.1007196261164194
# La differenza di energia libera DeltaG_NU = 42.72146167502852, con sigma = 8.082768305982677

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -17.19254951959725, con sigma = -2.2718845534038725

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.682153960439485, con incertezza = 0.005183612962275266,
#  q1 = 4.534409979144395, con incertezza = 0.006661845937863469
# Stimiamo i parametri del fit lineare: m2 = 0.6681218393989702, con incertezza = 0.004773277198790522,
#  q2 = 2.6367232458543364, con incertezza = 0.008246038021000724
# La forza di coesistenza qui vale: fc = 3.575706193634683, con incertezza = 0.0072594460836025165
# Il tempo medi di residenza vale: tc = 4.077184828652481, con incertezza = 0.04380410651583685
# Stimiamo un nuovo DeltaG_NU = 42.66913973968223, con incertezza = 7.512055679622085
# ((-0.682153960439485, 0.005183612962275266),
#  (4.534409979144395, 0.006661845937863469),
#  (0.6681218393989702, 0.004773277198790522),
#  (2.6367232458543364, 0.008246038021000724),
#  (3.575706193634683, 0.0072594460836025165),
#  (4.077184828652481, 0.04380410651583685),
#  (42.66913973968223, 7.512055679622085))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
forces_average_std = remove_element(forces_average_std, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.579970699370584, con sigma = 0.926376754198786
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 11.925472151509496, con sigma = 2.1021068798064064
# La differenza di energia libera DeltaG_NU = 42.69284087856387, con sigma = 8.08788931569508

# %%
f_c
# Out:
# (3.579970699370584, 0.926376754198786)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -17.191822866282404, con sigma = -2.2747406256446268

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.888651960059057, con incertezza = 0.006587636577874578,
#  q1 = 4.806026401235246, con incertezza = 0.008542502542897547
# Stimiamo i parametri del fit lineare: m2 = 0.653532323332291, con incertezza = 0.004843456247779301,
#  q2 = 2.652757725400104, con incertezza = 0.008295320586870152
# La forza di coesistenza qui vale: fc = 3.5652496342027336, con incertezza = 0.008144429737509916
# Il tempo medi di residenza vale: tc = 4.040005386303469, con incertezza = 0.043214357984691615
# Stimiamo un nuovo DeltaG_NU = 42.517285225864114, con incertezza = 7.495165115915034

# %%
f_c, t_c
# Out:
# ((3.5652496342027336, 0.008144429737509916),
#  (4.040005386303469, 0.043214357984691615))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.8890894278230226,
#   2.9135906464749657,
#   3.0023282624702334,
#   2.988858968029291],
#  [2.806, 8.013, 7.84, 7.79])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -1
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.570209241627972, con sigma = 1.050092192142363
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 11.561221085589992, con sigma = 2.3106183364622925
# La differenza di energia libera DeltaG_NU = 41.27597836427756, con sigma = 8.907053303210187

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -17.132752879137797, con sigma = -2.5749015020287076

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.8934614114237613, con incertezza = 0.008220262545327414,
#  q1 = 4.810977485855109, con incertezza = 0.009929500562061554
# Stimiamo i parametri del fit lineare: m2 = 0.6654463957195453, con incertezza = 0.006117656616638734,
#  q2 = 2.630247877513699, con incertezza = 0.010893498017449769
# La forza di coesistenza qui vale: fc = 3.5611295186602208, con incertezza = 0.010251710396313946
# Il tempo medi di residenza vale: tc = 4.050672781128298, con incertezza = 0.053424352637206914
# Stimiamo un nuovo DeltaG_NU = 41.171005679651486, con incertezza = 8.229264719441723
# ((-0.8934614114237613, 0.008220262545327414),
#  (4.810977485855109, 0.009929500562061554),
#  (0.6654463957195453, 0.006117656616638734),
#  (2.630247877513699, 0.010893498017449769),
#  (3.5611295186602208, 0.010251710396313946),
#  (4.050672781128298, 0.053424352637206914),
#  (41.171005679651486, 8.229264719441723))

# %%
grafici.write_on_txt()
