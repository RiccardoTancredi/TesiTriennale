# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 20bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/20cp"
# molecule name is a number in these experimets
number = "20"

# %%
file = Txt_hop(dir_name, number, different_name='hopcp', first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force   time(sec)
# 0       0.2332  -0.6866 -302.55685   4.0501  9074.19434
# 1      -0.3112  -0.5319 -302.56290   3.9087  9074.19629
# 2      -0.0111  -0.4430 -302.63065   4.0030  9074.19824
# 3       0.0169  -0.5551 -302.47170   3.7202  9074.19824
# 4      -0.6375  -0.4894 -302.57960   3.5148  9074.19922
# ...        ...      ...        ...      ...         ...
# 54919  -0.2833   0.2182 -200.61585   0.0034  9233.32422
# 54920  -0.8068   0.2569 -200.77105   0.8720  9233.32617
# 54921  -0.6794   0.4908 -200.58065   1.0958  9233.32617
# 54922   0.2263   0.3110 -201.18650   0.6565  9233.32812
# 54923  -0.1245   0.2675 -200.85025   1.1514  9233.33008
#
# [54924 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.081875458618657, con deviazione standard = 0.26677315957837083

# %%
prova = [0.2, 4.8, 0.1, 2., 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.2991936761919891, mu_1 = 4.783382329325186, sigma_1 = 0.09901671352743105
# c_2 = 2.10417166308996, mu_2 = 4.01357782797653, sigma_2 = 0.17490318499560095
# sigma_c_1 = 0.055232730817956606, sigma_mu_1 = 0.02156300284138202, sigma_sigma_1 = 0.02096568895583918
# sigma_c_2 = 0.04034536061484344, sigma_mu_2 = 0.0038985392918798275, sigma_sigma_2 = 0.0038770416256388917
# w_U = 0.9225051936876705, sigma_w_U = 0.0021764541034330707
# w_N = 0.07425930010454405, sigma_w_N = 0.2591442781577926

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 957 sec nello stato nativo e 10872 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.2332  -0.6866 -302.55685   4.0501    0.00000
# 1      -0.3112  -0.5319 -302.56290   3.9087    0.00195
# 2      -0.0111  -0.4430 -302.63065   4.0030    0.00390
# 3       0.0169  -0.5551 -302.47170   3.7202    0.00390
# 4      -0.6375  -0.4894 -302.57960   3.5148    0.00488
# ...        ...      ...        ...      ...        ...
# 11824  -0.5799  -0.5590 -302.89670   3.9138   12.34277
# 11825  -0.7317  -0.6025 -303.07060   4.4592   12.34277
# 11826  -0.1088  -0.5851 -302.72505   4.3380   12.34472
# 11827  -0.0878  -0.5416 -302.80755   4.1057   12.34472
# 11828  -0.0250  -0.5213 -303.00290   3.8885   12.34666
#
# [11829 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.751356988449731, con deviazione standard = 0.3528975217413225

# %%
prova = [0.8, 4.2, 0.1, 1.5, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.1709267926425841, mu_1 = 4.234241734551009, sigma_1 = 0.098342476512687
# c_2 = 1.5814400128394752, mu_2 = 3.5439371210950363, sigma_2 = 0.1785539357076627
# sigma_c_1 = 0.04355574467657023, sigma_mu_1 = 0.004306800607196528, sigma_sigma_1 = 0.004231484847738846
# sigma_c_2 = 0.03156841661953696, sigma_mu_2 = 0.004138666373511846, sigma_sigma_2 = 0.004147071679475145
# w_U = 0.70780248735213, sigma_w_U = 0.008839804771601192
# w_N = 0.2886428595326085, sigma_w_N = 0.04025821869108248

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2806 sec nello stato nativo e 6631 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.3286  -0.0138 -313.31810   3.3532    0.00000
# 1     -0.2763   0.0442 -313.65705   3.3027    0.00098
# 2      0.0483   0.2501 -313.10780   3.4189    0.00390
# 3     -0.6113   0.1486 -313.76265   3.5855    0.00586
# 4     -0.4229   0.0529 -313.64905   3.5199    0.00586
# ...       ...      ...        ...      ...        ...
# 9432  -0.2711  -0.5677 -313.30530   4.2925    9.82715
# 9433  -0.3915  -0.4894 -313.45185   4.3481    9.82812
# 9434  -0.0250  -0.5010 -313.02985   4.3834    9.83008
# 9435   0.2996  -0.3212 -313.12440   4.2218    9.83105
# 9436   0.7916  -0.2149 -313.41350   4.2858    9.83098
#
# [9437 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.1461232097989864, con deviazione standard = 0.2929924218209679

# %%
prova = [1.8, 3.4, 0.1, 0.5, 2.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.8858351732956116, mu_1 = 3.2359334299174294, sigma_1 = 0.18207047576836619
# c_2 = 0.3367623735978211, mu_2 = 2.591247863032502, sigma_2 = 0.15858812309519388
# sigma_c_1 = 0.03797660949738903, sigma_mu_1 = 0.004472726623876785, sigma_sigma_1 = 0.004863019194849725
# sigma_c_2 = 0.03982110120572019, sigma_mu_2 = 0.023510718577230288, sigma_sigma_2 = 0.024333724127338523
# w_U = 0.13387027492854608, sigma_w_U = 0.16672465634028277
# w_N = 0.8606631186776016, sigma_w_N = 0.004478018695466797

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8013 sec nello stato nativo e 1539 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.8696   0.1757 -324.59130   2.4610    0.00000
# 1     -0.1227   0.0481 -324.35595   2.8381    0.00293
# 2      0.5892   0.1215 -324.81520   2.5620    0.00391
# 3     -0.7300  -0.1569 -324.48675   2.5620    0.00488
# 4     -0.2082  -0.1936 -324.24305   3.1411    0.00586
# ...       ...      ...        ...      ...        ...
# 9547   0.0012  -0.0428 -324.41060   3.0906    9.95899
# 9548   0.2943   0.0210 -324.31755   3.0048    9.96094
# 9549   0.5142  -0.0573 -324.41210   3.0351    9.96191
# 9550   0.1216  -0.0167 -323.97630   2.9997    9.96191
# 9551  -0.4909  -0.0892 -324.20060   3.0048    9.96281
#
# [9552 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.1964552588703565, con deviazione standard = 0.26633196766024525

# %%
prova = [2., 3.3, 0.1, .4, 2.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.5284402598190066, mu_1 = 3.2829720577582666, sigma_1 = 0.12900890215037963
# c_2 = 0.3906943951661402, mu_2 = 2.700869906694461, sigma_2 = 0.1644282617171545
# sigma_c_1 = 0.037050638194426444, sigma_mu_1 = 0.0022902787874682453, sigma_sigma_1 = 0.002396021176306014
# sigma_c_2 = 0.03257345466519605, sigma_mu_2 = 0.016416514504575763, sigma_sigma_2 = 0.017259404150564976
# w_U = 0.16102880896745578, sigma_w_U = 0.10960343521905584
# w_N = 0.817640340712554, sigma_w_N = 0.003809498492485823

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 9062 sec nello stato nativo e 1986 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.1925  -0.1762 -309.77390   3.4492    0.00000
# 1      -0.9673  -0.2110 -309.02345   3.4239    0.00098
# 2      -0.3915   0.0094 -309.56205   3.1613    0.00196
# 3      -0.5328  -0.1095 -309.46335   3.3280    0.00391
# 4      -0.1454  -0.0573 -309.84125   3.3532    0.00391
# ...        ...      ...        ...      ...        ...
# 11043   0.7428   0.1757 -309.09075   3.1613   11.52344
# 11044   0.4566   0.0481 -309.24125   3.2017   11.52344
# 11045   0.2367   0.0558 -309.30965   3.1260   11.52540
# 11046   0.1216   0.0239 -309.38205   3.1159   11.52540
# 11047   0.1844   0.0616 -309.48210   3.0502   11.52728
#
# [11048 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.218601786283891, con deviazione standard = 0.321411489832693

# %%
prova = [1.4, 3.4, 0.1, .5, 2.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.3413944616265947, mu_1 = 3.294319931692101, sigma_1 = 0.26309264391487613
# c_2 = 0.36191511416932104, mu_2 = 2.6833980043664813, sigma_2 = 0.12201980185300909
# sigma_c_1 = 0.02699758824524062, sigma_mu_1 = 0.007145673373985329, sigma_sigma_1 = 0.008114719086771435
# sigma_c_2 = 0.04070443357883681, sigma_mu_2 = 0.017472174073841405, sigma_sigma_2 = 0.01695280648386481
# w_U = 0.1106947362764188, sigma_w_U = 0.15812707192920264
# w_N = 0.8846167297359372, sigma_w_N = 0.0040768178973679715

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7790 sec nello stato nativo e 1615 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2542   0.1215 -299.13670   3.6865    0.00000
# 1      0.2751   0.1409 -299.28415   3.8279    0.00000
# 2      0.4566   0.1950 -298.97990   3.7269    0.00098
# 3      0.0448   0.2685 -299.36360   3.6461    0.00196
# 4      0.3170   0.1795 -299.26725   3.6259    0.00391
# ...       ...      ...        ...      ...        ...
# 9400   0.3624   0.2472 -299.15730   3.2320    9.79785
# 9401   0.1163   0.1515 -299.25320   3.1512    9.79785
# 9402   0.1530   0.0645 -299.34445   3.3229    9.79981
# 9403   0.6974  -0.0486 -299.09810   3.1916    9.79981
# 9404   0.2263  -0.1221 -299.50030   3.1074    9.80071
#
# [9405 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 0.8035999452504774, con deviazione standard = 0.43529409407966

# %% [markdown]
# ## Suspiciuos Data: force too low

# %%
forces_average
# Out:
# [4.3984800786508575,
#  3.8890894278230226,
#  2.9135906464749657,
#  2.9919209822263637,
#  2.988858968029291]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.578449589827824, con sigma = 1.1254123843817887
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 11.871985941775275, con sigma = 2.54517722422921
# La differenza di energia libera DeltaG_NU = 42.48330322378742, con sigma = 9.775546281691954

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.421723375376108, con incertezza = 0.13200629145595977,
#  q1 = 13.258509259124844, con incertezza = 0.4604939612866254
# Stimiamo i parametri del fit lineare: m2 = 1.3361002779847564, con incertezza = 0.08673547493856938,
#  q2 = 3.4913036250808314, con incertezza = 0.3025701442733873
# La forza di coesistenza qui vale: fc = 3.5416353116491175, con incertezza = 0.284717363152304
# Il tempo medi di residenza vale: tc = 3726.719181191803, con incertezza = 9392.322434434162
# Stimiamo un nuovo DeltaG_NU = 42.046244630793225, con incertezza = 9.627008637843877
# ((-1.421723375376108, 0.13200629145595977),
#  (13.258509259124844, 0.4604939612866254),
#  (1.3361002779847564, 0.08673547493856938),
#  (3.4913036250808314, 0.3025701442733873),
#  (3.5416353116491175, 0.284717363152304),
#  (3726.719181191803, 9392.322434434162),
#  (42.046244630793225, 9.627008637843877))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
forces_average = remove_element(forces_average, 0)
w_U = remove_element(w_U, 0)
w_N = remove_element(w_N, 0)
sigma_w_U = remove_element(sigma_w_U, 0)
sigma_w_N = remove_element(sigma_w_N, 0)
native_time = remove_element(native_time, 0)
unfolded_time = remove_element(unfolded_time, 0)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.578288978112915, con sigma = 1.1319941650831158
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 11.860850028639998, con sigma = 2.5580368455043336
# La differenza di energia libera DeltaG_NU = 42.441548928532754, con sigma = 9.822623162277832

# %%
f_c
# Out:
# (3.578288978112915, 1.1319941650831158)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -17.181648318378503, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.158167465008642, con incertezza = 0.13772150005143882,
#  q1 = 12.45154112930224, con incertezza = 0.4435984514721851
# Stimiamo i parametri del fit lineare: m2 = 1.474456072313675, con incertezza = 0.12896926842290884,
#  q2 = 3.067679214271847, con incertezza = 0.4154076770581756
# La forza di coesistenza qui vale: fc = 3.5644526389727824, con incertezza = 0.3443152928375999
# Il tempo medi di residenza vale: tc = 4118.762578800952, con incertezza = 10532.666879259124
# Stimiamo un nuovo DeltaG_NU = 42.27743818504624, con incertezza = 9.990793588581793

# %%
f_c, t_c
# Out:
# ((3.962076525724788, 0.6889079357370768),
#  (4043.925050794536, 11590.12116814109))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.8890894278230226,
#   2.9135906464749657,
#   2.9919209822263637,
#   2.988858968029291],
#  [2806, 8013, 9062, 7790])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -1
forces_average = remove_element(forces_average, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.57045551867923, con sigma = 1.2488959726498643
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 11.570080631511862, con sigma = 2.7531735636586223
# La differenza di energia libera DeltaG_NU = 41.3104582423452, con sigma = 10.590890279601076

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.1719529911165216, con incertezza = 0.19869320422678313,
#  q1 = 12.506330964218089, con incertezza = 0.65463925671666
# Stimiamo i parametri del fit lineare: m2 = 1.4333376682747392, con incertezza = 0.13199951967412796,
#  q2 = 3.2311020799243146, con incertezza = 0.4349019743295594
# La forza di coesistenza qui vale: fc = 3.560151283258728, con incertezza = 0.4441408899309506
# Il tempo medi di residenza vale: tc = 4163.040680121914, con incertezza = 10669.99290545914
# Stimiamo un nuovo DeltaG_NU = 41.19123740768391, con incertezza = 11.067082479331328
# ((-1.1719529911165216, 0.19869320422678313),
#  (12.506330964218089, 0.65463925671666),
#  (1.4333376682747392, 0.13199951967412796),
#  (3.2311020799243146, 0.4349019743295594),
#  (3.560151283258728, 0.4441408899309506),
#  (4163.040680121914, 10669.99290545914),
#  (41.19123740768391, 11.067082479331328))
