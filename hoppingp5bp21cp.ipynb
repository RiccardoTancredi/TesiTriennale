# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 21bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/21cp"
# molecule name is a number in these experimets
number = "21"

# %%
file = Txt_hop(dir_name, number, different_name= 'hopcp', first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.0422  -0.0890 -560.11740   5.1431  11330.68457
# 1       0.1532  -0.0832 -560.46835   5.0757  11330.68750
# 2      -0.0980  -0.0078 -559.87250   5.0959  11330.68848
# 3      -0.1556   0.0009 -560.09050   5.0858  11330.68945
# 4      -0.3336   0.0067 -559.79880   5.0555  11330.69043
# ...        ...      ...        ...      ...          ...
# 71539  -0.0980   0.1430  -98.14910   0.1628  11827.60645
# 71540  -0.5936   0.0347  -97.33870   0.1897  11827.60645
# 71541   0.1847  -0.0745  -97.49145   0.1712  11827.60938
# 71542   0.0276  -0.1064  -97.46330   0.6459  11827.60938
# 71543  -0.3127   0.0183  -97.29550   0.2874  11827.61130
#
# [71544 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.195045215248938, con deviazione standard = 0.2983736765842688

# %%
prova = [1.5, 5.5, 0.1, 1.5, 4.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.6711028459699038, mu_1 = 5.4778808456248305, sigma_1 = 0.11188483382051956
# c_2 = 1.482130932000499, mu_2 = 4.9386822662032515, sigma_2 = 0.1428566088841494
# sigma_c_1 = 0.053089513742976296, sigma_mu_1 = 0.0042596390125891346, sigma_sigma_1 = 0.0043105551009144545
# sigma_c_2 = 0.045689098133476005, sigma_mu_2 = 0.005237861373908594, sigma_sigma_2 = 0.005310211873799213
# w_U = 0.5307339163320598, sigma_w_U = 0.016870144332530614
# w_N = 0.46866695610753956, sigma_w_N = 0.01971843076925327

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.642 sec nello stato nativo e 4.07 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.0422  -0.0890 -560.11740   5.1431    0.00000
# 1      0.1532  -0.0832 -560.46835   5.0757    0.00293
# 2     -0.0980  -0.0078 -559.87250   5.0959    0.00391
# 3     -0.1556   0.0009 -560.09050   5.0858    0.00488
# 4     -0.3336   0.0067 -559.79880   5.0555    0.00586
# ...       ...      ...        ...      ...        ...
# 7707   0.2370   0.0212 -559.85570   4.7172    8.03027
# 7708   0.0381   0.0850 -559.80825   4.7980    8.03223
# 7709   0.2108   0.1343 -559.80750   4.7071    8.03320
# 7710   0.0852   0.2329 -559.80750   4.6667    8.03320
# 7711   0.0224   0.2416 -559.56025   4.6717    8.03413
#
# [7712 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(8)
# Out:
# f media vale = 4.979491380884069, con deviazione standard = 0.2596268836155372

# %%
prova = [0.7, 5.4, 0.1, 1.5, 4.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.9346348818595953, mu_1 = 5.399479434255575, sigma_1 = 0.09591678444838794
# c_2 = 2.239914999294079, mu_2 = 4.851819125614545, sigma_2 = 0.13869003747612194
# sigma_c_1 = 0.06911581521921492, sigma_mu_1 = 0.008450235368044555, sigma_sigma_1 = 0.00825156644483562
# sigma_c_2 = 0.05557828069261847, sigma_mu_2 = 0.004034385368881559, sigma_sigma_2 = 0.004030128596962154
# w_U = 0.7786938373211039, sigma_w_U = 0.006461278294292915
# w_N = 0.22471213733240944, sigma_w_N = 0.06661704026112625

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.7750000000000001 sec nello stato nativo e 5.894 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0067  -0.2166 -556.73175   4.9343    0.00000
# 1      0.2161  -0.2746 -557.34250   4.7525    0.00097
# 2      0.1253  -0.2282 -557.06655   4.9613    0.00195
# 3     -0.0911  -0.1702 -557.13090   5.0286    0.00390
# 4     -0.7210  -0.2050 -557.43005   4.6970    0.00390
# ...       ...      ...        ...      ...        ...
# 7664  -0.3336   0.1546 -556.50380   4.8737    7.99511
# 7665   0.2422   0.2271 -556.70890   4.7879    7.99609
# 7666  -0.0562   0.0154 -556.29380   5.0151    7.99707
# 7667  -0.5954   0.0096 -556.83555   4.9192    7.99707
# 7668  -0.8205   0.0444 -556.58555   4.7929    7.99804
#
# [7669 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(8)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4
rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 0.37834254004288226, con deviazione standard = 0.2788152691640573

# %% [markdown]
# ## NO Data!

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0     -0.5727   0.1894 -94.99170   0.6274    0.00000
# 1     -0.4191   0.3015 -95.28455   0.1830    0.00000
# 2     -0.6355   0.1468 -95.08165   0.2075    0.00098
# 3     -0.5797   0.1894 -95.07240   0.2975    0.00195
# 4     -0.4959  -0.0117 -95.62050   0.4119    0.00391
# ...       ...      ...       ...      ...        ...
# 7924  -0.0980   0.1430 -98.14910   0.1628    8.25977
# 7925  -0.5936   0.0347 -97.33870   0.1897    8.25977
# 7926   0.1847  -0.0745 -97.49145   0.1712    8.26270
# 7927   0.0276  -0.1064 -97.46330   0.6459    8.26270
# 7928  -0.3127   0.0183 -97.29550   0.2874    8.26462
#
# [7929 rows x 5 columns]

# %%
forces_average
# Out:
# [5.208281555914041, 5.12564927993506, 4.4217006724994015]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.141730261315241, con sigma = 4.940324743368495
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 0.5991190665082441, con sigma = 0.45889564518559856
# La differenza di energia libera DeltaG_NU = 2.4813895678881335, con sigma = 2.268987700108171

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -20.53523311662975, con sigma = -8.755836106758757

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.22340197756859126, con incertezza = 0.007512658891651968,
#  q1 = 5.279248635456078, con incertezza = 0.008646659782110544
# Stimiamo i parametri del fit lineare: m2 = 0.5232986985798621, con incertezza = 0.014228437948545423,
#  q2 = 4.250057056813026, con incertezza = 0.021422330990089642
# La forza di coesistenza qui vale: fc = 4.971329490194602, con incertezza = 0.012840818431435173
# Il tempo medi di residenza vale: tc = 3.968224630406343, con incertezza = 0.17018417139789357
# Stimiamo un nuovo DeltaG_NU = 2.978418283470295, con incertezza = 2.281334425445857
# ((-0.22340197756859126, 0.007512658891651968),
#  (5.279248635456078, 0.008646659782110544),
#  (0.5232986985798621, 0.014228437948545423),
#  (4.250057056813026, 0.021422330990089642),
#  (4.971329490194602, 0.012840818431435173),
#  (3.968224630406343, 0.17018417139789357),
#  (2.978418283470295, 2.281334425445857))

# %% [markdown]
# ### Vediamo cosa accade eliminando il punto più lontano

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare il punto più lontano
post = 1
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.122413466350862, con sigma = 6.29024164363838
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 0.47073314806139505, con sigma = 0.4601678254200046
# La differenza di energia libera DeltaG_NU = 1.9405566686260292, con sigma = 2.2735553206480317

# %%
f_c
# Out:
# (4.122413466350862, 6.29024164363838)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -20.4222338212291, con sigma = -6.904219116558623

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -16.949367545658184, con incertezza = 0.14047529052896893,
#  q1 = 27.11589812094488, con incertezza = 0.1833396128487745
# Stimiamo i parametri del fit lineare: m2 = 15.219830351780942, con incertezza = 0.12614095698034208,
#  q2 = -16.154926770248455, con incertezza = 0.1753327357851819
# La forza di coesistenza qui vale: fc = 4.317284446370328, con incertezza = 0.17900224571155351
# Il tempo medi di residenza vale: tc = 3.8385747695083663, con incertezza = 0.04283187629789099
# Stimiamo un nuovo DeltaG_NU = 2.032288898516401, con incertezza = 1.9884615310168368

# %%
f_c, t_c
# Out:
# ((4.317284446370328, 0.17900224571155351),
#  (3.8385747695083663, 0.04283187629789099))

# %%
grafici.write_on_txt()
