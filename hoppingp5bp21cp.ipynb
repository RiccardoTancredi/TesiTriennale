# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 21bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/21cp"
# molecule name is a number in these experimets
number = "21"

# %%
file = Txt_hop(dir_name, number, different_name= 'hopcp', first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0      -0.0422  -0.0890 -560.11740   5.1431  11330.68457
# 1       0.1532  -0.0832 -560.46835   5.0757  11330.68750
# 2      -0.0980  -0.0078 -559.87250   5.0959  11330.68848
# 3      -0.1556   0.0009 -560.09050   5.0858  11330.68945
# 4      -0.3336   0.0067 -559.79880   5.0555  11330.69043
# ...        ...      ...        ...      ...          ...
# 71539  -0.0980   0.1430  -98.14910   0.1628  11827.60645
# 71540  -0.5936   0.0347  -97.33870   0.1897  11827.60645
# 71541   0.1847  -0.0745  -97.49145   0.1712  11827.60938
# 71542   0.0276  -0.1064  -97.46330   0.6459  11827.60938
# 71543  -0.3127   0.0183  -97.29550   0.2874  11827.61130
#
# [71544 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.195045215248938, con deviazione standard = 0.2983736765842688

# %%
prova = [1.5, 5.5, 0.1, 1.5, 4.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.6711028459699038, mu_1 = 5.4778808456248305, sigma_1 = 0.11188483382051956
# c_2 = 1.482130932000499, mu_2 = 4.9386822662032515, sigma_2 = 0.1428566088841494
# sigma_c_1 = 0.053089513742976296, sigma_mu_1 = 0.0042596390125891346, sigma_sigma_1 = 0.0043105551009144545
# sigma_c_2 = 0.045689098133476005, sigma_mu_2 = 0.005237861373908594, sigma_sigma_2 = 0.005310211873799213
# w_U = 0.5307339163320598, sigma_w_U = 0.022632346325365465
# w_N = 0.46866695610753956, sigma_w_N = 0.026502635520257844

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3642 sec nello stato nativo e 4070 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.0422  -0.0890 -560.11740   5.1431    0.00000
# 1      0.1532  -0.0832 -560.46835   5.0757    0.00293
# 2     -0.0980  -0.0078 -559.87250   5.0959    0.00391
# 3     -0.1556   0.0009 -560.09050   5.0858    0.00488
# 4     -0.3336   0.0067 -559.79880   5.0555    0.00586
# ...       ...      ...        ...      ...        ...
# 7707   0.2370   0.0212 -559.85570   4.7172    8.03027
# 7708   0.0381   0.0850 -559.80825   4.7980    8.03223
# 7709   0.2108   0.1343 -559.80750   4.7071    8.03320
# 7710   0.0852   0.2329 -559.80750   4.6667    8.03320
# 7711   0.0224   0.2416 -559.56025   4.6717    8.03413
#
# [7712 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.968891435901943, con deviazione standard = 0.2625951864515608

# %%
prova = [0.7, 5.4, 0.1, 1.5, 4.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.930431222018009, mu_1 = 5.39591917376362, sigma_1 = 0.09326944050803188
# c_2 = 2.206070209017649, mu_2 = 4.842256720051099, sigma_2 = 0.14169379264171147
# sigma_c_1 = 0.07432028931515638, sigma_mu_1 = 0.00888601739750549, sigma_sigma_1 = 0.008640768013522164
# sigma_c_2 = 0.05809414454335788, sigma_mu_2 = 0.004370434052651505, sigma_sigma_2 = 0.004359430714534365
# w_U = 0.7835380457420209, sigma_w_U = 0.008809311208785708
# w_N = 0.21752720574390247, sigma_w_N = 0.09584536140689408

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2558 sec nello stato nativo e 8745 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.
rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.8543249670619133, con deviazione standard = 0.2312616933374248

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [2., 3.5, 0.1, .5, 3., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.3912   0.0734 -538.56860   2.9951    0.00000
# 1      -0.1539   0.0231 -538.10060   3.0894    0.00097
# 2      -0.3912   0.0270 -538.18555   3.1567    0.00195
# 3      -0.1748  -0.0233 -538.38900   2.8672    0.00390
# 4       0.0904  -0.1084 -538.80250   2.9749    0.00390
# ...        ...      ...        ...      ...        ...
# 10621  -0.9356  -0.0620 -537.44510   2.4565   11.07422
# 10622  -0.0492   0.2358 -537.24205   2.2545   11.07714
# 10623  -0.0562   0.1314 -537.27495   2.3184   11.07714
# 10624   0.1690   0.1720 -537.28320   2.4245   11.07714
# 10625   0.4098   0.1807 -537.59060   2.3891   11.07804
#
# [10626 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 0.37834254004288226, con deviazione standard = 0.2788152691640573

# %% [markdown]
# # NO Data!

# %%
data_frame
# Out:
#       X_force  Z_force    lambda  Y_force  time(sec)
# 0     -0.5727   0.1894 -94.99170   0.6274    0.00000
# 1     -0.4191   0.3015 -95.28455   0.1830    0.00000
# 2     -0.6355   0.1468 -95.08165   0.2075    0.00098
# 3     -0.5797   0.1894 -95.07240   0.2975    0.00195
# 4     -0.4959  -0.0117 -95.62050   0.4119    0.00391
# ...       ...      ...       ...      ...        ...
# 7924  -0.0980   0.1430 -98.14910   0.1628    8.25977
# 7925  -0.5936   0.0347 -97.33870   0.1897    8.25977
# 7926   0.1847  -0.0745 -97.49145   0.1712    8.26270
# 7927   0.0276  -0.1064 -97.46330   0.6459    8.26270
# 7928  -0.3127   0.0183 -97.29550   0.2874    8.26462
#
# [7929 rows x 5 columns]

# %%
forces_average
# Out:
# [5.208281555914041, 5.119087946907359, 4.4190813242366875]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 6.4275312659289385, con sigma = 10.814799788722796
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = -0.5057440454720444, con sigma = 0.6723180144197772
# La differenza di energia libera DeltaG_NU = -3.2506856648289526, con sigma = 3.352854371757325

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.3854282662125534, con incertezza = 0.4509046041435203,
#  q1 = 10.02547454854998, con incertezza = 2.222118727559211
# Stimiamo i parametri del fit lineare: m2 = 0.13913669178355548, con incertezza = 0.9039949584339696,
#  q2 = 7.952083796564868, con incertezza = 4.455008934521576
# La forza di coesistenza qui vale: fc = 3.952591038306625, con incertezza = 12.166060063936692
# Il tempo medi di residenza vale: tc = 4924.776823766571, con incertezza = 22349.87502227971
# Stimiamo un nuovo DeltaG_NU = -1.9989993818097411, con incertezza = -6.702245623417707
# ((-0.3854282662125534, 0.4509046041435203),
#  (10.02547454854998, 2.222118727559211),
#  (0.13913669178355548, 0.9039949584339696),
#  (7.952083796564868, 4.455008934521576),
#  (3.952591038306625, 12.166060063936692),
#  (4924.776823766571, 22349.87502227971),
#  (-1.9989993818097411, -6.702245623417707))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# # proviamo ad eliminare l'ultimo punto, quello più in alto
# forces_average = remove_element(forces_average, 0)
# w_U = remove_element(w_U, 0)
# w_N = remove_element(w_N, 0)
# sigma_w_U = remove_element(sigma_w_U, 0)
# sigma_w_N = remove_element(sigma_w_N, 0)
# native_time = remove_element(native_time, 0)
# unfolded_time = remove_element(unfolded_time, 0)

# %%
# x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)

# %%
f_c
# Out:
# (6.4275312659289385, 10.814799788722796)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -32.83771802065099, con sigma = None

# %%
# m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)

# %%
# f_c, t_c
