# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 22bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/22"
# molecule name is a number in these experimets
number = "22"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force    time(sec)
# 0        0.3344   0.3818 -906.90170   3.8574  17315.59570
# 1        0.1459   0.3557 -907.39935   3.9331  17315.59570
# 2        0.3972   0.3325 -906.94460   4.0341  17315.59766
# 3       -0.4875   0.2165 -907.06345   3.9735  17315.59766
# 4       -0.2205   0.2281 -906.96275   4.0543  17315.59961
# ...         ...      ...        ...      ...          ...
# 119360  -0.5940   0.1005 -865.27975   4.2496  17925.61719
# 119361  -0.6708   0.0850 -864.64630   4.0543  17925.61914
# 119362  -0.1420  -0.0387 -864.84910   4.4432  17925.61914
# 119363  -0.7755  -0.0416 -864.94280   4.2008  17925.62109
# 119364  -1.4717  -0.1576 -864.89835   4.1957  17925.62100
#
# [119365 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 3.9467640743550945, con deviazione standard = 0.22173403590335386

# %%
prova = [2., 4., 0.1, .2, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 2.3667096916079715, mu_1 = 3.9917070420997525, sigma_1 = 0.1537718511808804
# c_2 = 0.20368191620341392, mu_2 = 3.443262942749878, sigma_2 = 0.1543479713228392
# sigma_c_1 = 0.0461432109222628, sigma_mu_1 = 0.003920938244283518, sigma_sigma_1 = 0.004288311980422465
# sigma_c_2 = 0.044783084276535524, sigma_mu_2 = 0.0453958276075298, sigma_sigma_2 = 0.046755958328851585
# w_U = 0.07880310537532227, sigma_w_U = 0.24355899904754882
# w_N = 0.9122455762775586, sigma_w_N = 0.001888896509208277

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.665 sec nello stato nativo e 0.607 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3344   0.3818 -906.90170   3.8574    0.00000
# 1      0.1459   0.3557 -907.39935   3.9331    0.00000
# 2      0.3972   0.3325 -906.94460   4.0341    0.00196
# 3     -0.4875   0.2165 -907.06345   3.9735    0.00196
# 4     -0.2205   0.2281 -906.96275   4.0543    0.00391
# ...       ...      ...        ...      ...        ...
# 5267  -0.2886  -0.0329 -911.97895   4.2260    5.49414
# 5268   0.5228   0.1556 -911.94760   3.9382    5.49414
# 5269  -0.2415   0.0164 -911.74370   4.0038    5.49610
# 5270  -0.1577   0.0396 -911.83710   3.9937    5.49610
# 5271  -0.2938   0.0193 -911.68800   4.1351    5.49805
#
# [5272 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# Out:
# f media vale = 4.667218420031059, con deviazione standard = 0.34919253409985973

# %%
prova = [1., 5., 0.1, 1., 4.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.0914729819201845, mu_1 = 5.0385576240604575, sigma_1 = 0.14398552891389518
# c_2 = 1.2437709597509874, mu_2 = 4.420601533572112, sigma_2 = 0.1944452118759688
# sigma_c_1 = 0.037704666515007236, sigma_mu_1 = 0.006446051611815326, sigma_sigma_1 = 0.006802676187624011
# sigma_c_2 = 0.0319599339618252, sigma_mu_2 = 0.0063457715661875734, sigma_sigma_2 = 0.0067139326069160475
# w_U = 0.6062162866031716, sigma_w_U = 0.012195001996248555
# w_N = 0.3939324617056551, sigma_w_N = 0.025369812587260853

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.106 sec nello stato nativo e 3.0460000000000003 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0098  -0.1083 -915.74105   4.5795    0.00000
# 1      0.2297  -0.1354 -915.97045   4.5257    0.00000
# 2     -0.0635  -0.1315 -916.06345   4.5593    0.00391
# 3     -0.2101  -0.0465 -915.78975   4.3439    0.00391
# 4     -0.0914   0.0038 -915.78190   4.2227    0.00586
# ...       ...      ...        ...      ...        ...
# 5147  -0.6969   0.0976 -921.63565   4.4129    5.36914
# 5148   0.1407   0.2948 -921.64095   4.5189    5.36914
# 5149   0.2244   0.2658 -921.58050   4.4381    5.37109
# 5150   0.1616   0.1846 -921.18860   4.4280    5.37305
# 5151   0.0517   0.1788 -921.17250   4.5543    5.37299
#
# [5152 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 5.110655930276614, con deviazione standard = 0.22885868732131892

# %%
prova = [2., 5.8, 0.1, 0.4, 5., 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.15389271138628405, mu_1 = 5.825859159006971, sigma_1 = 0.08329936057142327
# c_2 = 2.0763993228953415, mu_2 = 5.078676629549716, sigma_2 = 0.1858288185339531
# sigma_c_1 = 0.06213357395290937, sigma_mu_1 = 0.040467638391394604, sigma_sigma_1 = 0.03815686122414359
# sigma_c_2 = 0.03891059072831544, sigma_mu_2 = 0.004055593555343945, sigma_sigma_2 = 0.004023348104602423
# w_U = 0.9671946342465331, sigma_w_U = 0.0006954053880483937
# w_N = 0.03213288008024836, sigma_w_N = 0.4489572167766979

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.212 sec nello stato nativo e 5.066 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1948   0.3247 -944.59515   4.7815    0.00000
# 1      0.1250   0.1585 -944.42860   5.2865    0.00000
# 2     -0.2101   0.2087 -944.92065   4.9431    0.00195
# 3     -0.1839   0.2484 -944.93480   5.0239    0.00195
# 4      0.0517   0.2629 -945.20945   5.1401    0.00390
# ...       ...      ...        ...      ...        ...
# 5273  -0.0530   0.2600 -938.50355   4.8775    5.49218
# 5274   0.0621   0.1672 -938.23540   5.1350    5.49414
# 5275   0.5228   0.1556 -938.21685   4.9381    5.49414
# 5276   0.1145   0.1121 -938.59940   5.0643    5.49609
# 5277  -0.5661   0.0773 -938.69520   4.8219    5.49609
#
# [5278 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.982902280068389, con deviazione standard = 0.22335625353349609

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [1., 4.3, 0.1, 1., 3.6, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2101   0.2861 -930.62760   5.0037    0.00000
# 1      0.3553   0.5219 -930.85565   4.7546    0.00196
# 2      0.7217   0.6689 -930.79115   4.6704    0.00196
# 3      0.7008   0.6747 -931.20020   4.6048    0.00391
# 4      0.8264   0.5326 -930.97455   4.8977    0.00391
# ...       ...      ...        ...      ...        ...
# 5258  -0.1403   0.0270 -933.96690   5.2259    5.49414
# 5259  -0.4718  -0.0880 -934.47175   5.3168    5.49610
# 5260  -0.3985  -0.0126 -934.07965   5.2764    5.49610
# 5261  -0.8697   0.0280 -934.20300   5.2966    5.49805
# 5262  -0.6760   0.1266 -934.22190   5.2259    5.49805
#
# [5263 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.161278547040974, con deviazione standard = 0.3003947122095252

# %%
prova = [1.5, 4.3, 0.1, .6, 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.6669034997678895, mu_1 = 4.285853844312113, sigma_1 = 0.18393274022068834
# c_2 = 0.4223370476464408, mu_2 = 3.745503299734681, sigma_2 = 0.21512315872320814
# sigma_c_1 = 0.03964608484921174, sigma_mu_1 = 0.010123807610929268, sigma_sigma_1 = 0.008976182296966811
# sigma_c_2 = 0.03741137410137266, sigma_mu_2 = 0.04449651472048015, sigma_sigma_2 = 0.0353629019879125
# w_U = 0.22773840778198481, sigma_w_U = 0.09286883819138345
# w_N = 0.7685275375857665, sigma_w_N = 0.007760122846331126

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.849 sec nello stato nativo e 1.423 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -1.0756   0.2899 -870.46960   3.9197    0.00000
# 1     -0.5800   0.2397 -870.28150   4.1015    0.00195
# 2      0.0203   0.3093 -870.60710   4.0947    0.00195
# 3     -0.2380   0.2165 -870.25370   3.8927    0.00390
# 4     -0.4544   0.2474 -870.12285   3.9197    0.00390
# ...       ...      ...        ...      ...        ...
# 5267  -1.0477   0.2339 -873.24005   4.1099    5.49218
# 5268  -0.2467   0.3992 -873.29465   4.1048    5.49414
# 5269  -0.2886   0.4717 -873.48700   3.9836    5.49609
# 5270   0.1319   0.4059 -873.36790   4.1217    5.49609
# 5271  -0.1822   0.2629 -873.47915   4.1486    5.49804
#
# [5272 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 3.369846251180351, con deviazione standard = 0.2253314897575714

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [2., 3.5, 0.1, .5, 3., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5032  -0.0039 -899.75410   3.6503    0.00000
# 1     -0.5870   0.0889 -898.97440   3.5897    0.00195
# 2      0.1599   0.3209 -899.56965   3.6638    0.00195
# 3     -0.0146   0.3209 -899.48865   3.4079    0.00390
# 4      0.4338   0.2571 -899.61120   3.5443    0.00390
# ...       ...      ...        ...      ...        ...
# 5290   0.3762  -0.0677 -883.66865   3.7311    5.49414
# 5291  -0.1839  -0.1779 -883.77260   3.6251    5.49609
# 5292  -0.1577  -0.1460 -883.71615   3.7261    5.49609
# 5293   0.3029  -0.0503 -883.89560   3.5190    5.49805
# 5294   0.9050  -0.0474 -883.63570   3.6200    5.49805
#
# [5295 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.183228109028964, con deviazione standard = 0.3222545641963262

# %%
prova = [1.2, 4.5, 0.1, 0.7, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.411735186425819, mu_1 = 4.35146566540226, sigma_1 = 0.1932241300846631
# c_2 = 0.6221845891522838, mu_2 = 3.8131305136274944, sigma_2 = 0.198751309119659
# sigma_c_1 = 0.028018755766325714, sigma_mu_1 = 0.009358535811835387, sigma_sigma_1 = 0.008569257758223241
# sigma_c_2 = 0.030930374555452656, sigma_mu_2 = 0.0215689668889716, sigma_sigma_2 = 0.016717940404123135
# w_U = 0.3099696564717624, sigma_w_U = 0.0445241738862721
# w_N = 0.6837613276601177, sigma_w_N = 0.009224442301753986

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.473 sec nello stato nativo e 1.81 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.0059   0.5819 -824.29355   4.5290    0.00000
# 1      0.2820   0.5355 -824.57430   4.5139    0.00195
# 2      0.5438   0.5413 -824.42135   4.7209    0.00195
# 3     -0.4823   0.3673 -824.40500   4.7007    0.00195
# 4     -0.3776   0.1237 -824.09230   4.7142    0.00390
# ...       ...      ...        ...      ...        ...
# 5278  -0.0164   0.3006 -813.10800   3.7412    5.49414
# 5279  -0.1316   0.3325 -813.05450   3.8119    5.49609
# 5280   0.0621   0.4137 -813.08930   3.6806    5.49609
# 5281   0.1878   0.4282 -813.03675   3.5897    5.49804
# 5282  -0.0844   0.2977 -812.94640   3.9668    5.49804
#
# [5283 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph()
# Out:
# f media vale = 5.06253803599787, con deviazione standard = 0.20388751433713537

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [0.2, 5.6, 0.1, 2.5, 4.9, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.9220   0.2107 -791.22550   5.1552    0.00000
# 1     -0.2520   0.3479 -791.11330   5.1047    0.00000
# 2      0.4740   0.3905 -790.84470   5.0172    0.00195
# 3      0.2401   0.4224 -790.91310   4.8724    0.00195
# 4     -0.4247   0.3818 -791.12160   4.9583    0.00391
# ...       ...      ...        ...      ...        ...
# 3773  -0.1752   0.1507 -800.10375   5.2461    3.92969
# 3774  -0.4142   0.2513 -800.17785   5.0542    3.93164
# 3775  -0.1054   0.3325 -800.03310   4.9785    3.93164
# 3776   0.1407   0.2368 -800.12940   5.1855    3.93359
# 3777   0.6170   0.3267 -800.31820   5.3471    3.93353
#
# [3778 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.722338103350376, con deviazione standard = 0.29714900890773605

# %%
prova = [0.5, 5.3, 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.5385705771658771, mu_1 = 5.276113942539483, sigma_1 = 0.11615116949915387
# c_2 = 1.8385630678801947, mu_2 = 4.615987238262701, sigma_2 = 0.18300118145383923
# sigma_c_1 = 0.05040218608553004, sigma_mu_1 = 0.012941128360195531, sigma_sigma_1 = 0.012910359456560303
# sigma_c_2 = 0.0391971389624398, sigma_mu_2 = 0.004564915700670462, sigma_sigma_2 = 0.00464345608905716
# w_U = 0.8433781780685449, sigma_w_U = 0.003890113104854943
# w_N = 0.15680364170151334, sigma_w_N = 0.09179592601779185

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.896 sec nello stato nativo e 4.3870000000000005 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2454  -0.7028 -634.70695   4.6098    0.00000
# 1      0.4600  -0.8014 -634.86840   4.3624    0.00196
# 2      0.2297  -0.9551 -634.99325   4.5997    0.00196
# 3      0.2820  -0.8797 -634.76190   4.5896    0.00391
# 4      0.8736  -0.7840 -634.76100   4.6502    0.00391
# ...       ...      ...        ...      ...        ...
# 5278   0.4042  -0.3674 -630.46980   4.4449    5.49414
# 5279  -0.0146  -0.6149 -630.55085   4.2698    5.49610
# 5280   0.9364  -0.3142 -630.37950   4.4785    5.49610
# 5281   0.2715  -0.4476 -630.44925   4.3674    5.49805
# 5282   0.0203  -0.4708 -630.30050   4.5896    5.49805
#
# [5283 rows x 5 columns]

# %% [markdown]
# # File 10

# %%
grafici = Graph_hop(dir_name, number, 10)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.100152285226614, con deviazione standard = 0.34112557947215616

# %%
prova = [2., 4.2, 0.1, .5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.9865240811556617, mu_1 = 4.286098408846858, sigma_1 = 0.1398562238288098
# c_2 = 0.6461744532768283, mu_2 = 3.6377419229743753, sigma_2 = 0.1786505461204295
# sigma_c_1 = 0.04907280414834881, sigma_mu_1 = 0.00414631134140947, sigma_sigma_1 = 0.004300868636370523
# sigma_c_2 = 0.04291233042414335, sigma_mu_2 = 0.014104520280777336, sigma_sigma_2 = 0.014681344954541695
# w_U = 0.28936371158959456, sigma_w_U = 0.054385262259867444
# w_N = 0.6964109100089989, sigma_w_N = 0.00841970448953644

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.697 sec nello stato nativo e 1.576 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3972  -0.6245 -629.05730   3.9533    0.00000
# 1      0.0831  -0.6303 -628.71900   3.8321    0.00196
# 2      0.1110  -0.6110 -628.60450   3.9062    0.00196
# 3     -0.5451  -0.7657 -629.07745   3.9803    0.00391
# 4     -0.1944  -0.7376 -628.99350   3.8220    0.00391
# ...       ...      ...        ...      ...        ...
# 5268  -0.2729  -1.0363 -629.84495   4.1402    5.49610
# 5269   0.2611  -0.9087 -629.84555   4.2765    5.49610
# 5270   1.0987  -0.7637 -630.05270   4.0796    5.49805
# 5271   0.5019  -0.8391 -629.56970   4.2361    5.49805
# 5272   0.0342  -0.9513 -629.98995   4.2159    5.49805
#
# [5273 rows x 5 columns]

# %% [markdown]
# # File 11

# %%
grafici = Graph_hop(dir_name, number, 11)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.860218638604466, con deviazione standard = 0.3192987226939993

# %% [markdown]
# # Drift?!

# %%
prova = [0.3, 5.5, 0.1, 1., 4.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.17528362431587885, mu_1 = 5.395651550165972, sigma_1 = 0.3597514584089038
# c_2 = 1.5075623787545316, mu_2 = 4.762056550754092, sigma_2 = 0.2267130049166301
# sigma_c_1 = 0.034131025365896246, sigma_mu_1 = 0.28111330751973035, sigma_sigma_1 = 0.23783515136880887
# sigma_c_2 = 0.133101022152995, sigma_mu_2 = 0.016460740650563514, sigma_sigma_2 = 0.010703602789230512
# w_U = 0.8567254306632657, sigma_w_U = 0.014445535839433499
# w_N = 0.15806431802461154, sigma_w_N = 0.32867667190756

# %% [markdown]
# ## I don't like this fit

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0517  -0.4099 -674.71180   4.6755    0.00000
# 1      0.6537  -0.4998 -675.02915   4.9280    0.00000
# 2     -0.0426  -0.6187 -674.92455   4.8371    0.00195
# 3      0.4495  -0.5868 -674.92210   4.8118    0.00195
# 4     -0.1787  -0.5839 -674.90435   4.7916    0.00390
# ...       ...      ...        ...      ...        ...
# 5269  -0.6987  -0.1277 -671.31450   5.1317    5.49414
# 5270  -0.5800  -0.1779 -671.23705   5.0576    5.49609
# 5271  -0.6446  -0.2127 -670.97180   4.9179    5.49609
# 5272  -0.2572  -0.4621 -671.35900   4.9987    5.49804
# 5273   0.0517  -0.3838 -671.22655   5.1956    5.49804
#
# [5274 rows x 5 columns]

# %% [markdown]
# # File 12

# %%
grafici = Graph_hop(dir_name, number, 12)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.4107623480243126, con deviazione standard = 0.387417219018139

# %%
prova = [0.7, 5., 0.1, 1.5, 4.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.7355472632828519, mu_1 = 4.853970211176146, sigma_1 = 0.18876486998247552
# c_2 = 1.2104831409896246, mu_2 = 4.171341540003239, sigma_2 = 0.21372945977579452
# sigma_c_1 = 0.022448041921363408, sigma_mu_1 = 0.008170529093675294, sigma_sigma_1 = 0.008773934236009607
# sigma_c_2 = 0.020707653908162753, sigma_mu_2 = 0.005198423108143208, sigma_sigma_2 = 0.00536453552722047
# w_U = 0.6485046095667987, sigma_w_U = 0.007384108309898998
# w_N = 0.34803401479492474, sigma_w_N = 0.024876844788905665

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.938 sec nello stato nativo e 3.326 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2938  -0.1818 -724.84875   4.6469    0.00000
# 1     -0.3846  -0.1702 -724.82775   4.8017    0.00000
# 2     -0.1891  -0.2243 -725.01565   4.7815    0.00195
# 3     -0.7755  -0.2475 -724.52015   4.7209    0.00195
# 4     -0.4055  -0.2591 -724.99200   4.6469    0.00390
# ...       ...      ...        ...      ...        ...
# 5259   0.1250  -0.0271 -732.43305   5.0980    5.49414
# 5260  -0.2031  -0.1161 -732.17250   5.1586    5.49609
# 5261  -0.2834  -0.2417 -732.44655   5.2613    5.49609
# 5262  -0.1054  -0.2562 -732.35770   5.3219    5.49805
# 5263  -0.1839  -0.0677 -732.71130   5.0845    5.49805
#
# [5264 rows x 5 columns]

# %% [markdown]
# # File 13

# %%
grafici = Graph_hop(dir_name, number, 13)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.566981499715948, con deviazione standard = 0.354561220400428

# %%
prova = [1.2, 4.9, 0.1, 1.4, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.3632432644552661, mu_1 = 4.853529772594237, sigma_1 = 0.1499375025547546
# c_2 = 0.9415099947127711, mu_2 = 4.248305971024045, sigma_2 = 0.20359739880492403
# sigma_c_1 = 0.03713910206728362, sigma_mu_1 = 0.005722311473858503, sigma_sigma_1 = 0.00602500080035323
# sigma_c_2 = 0.0315547462070626, sigma_mu_2 = 0.009343899248417062, sigma_sigma_2 = 0.009833042385919496
# w_U = 0.48049303192299486, sigma_w_U = 0.021164766620481897
# w_N = 0.5123580540055475, sigma_w_N = 0.016265014694491212

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.769 sec nello stato nativo e 2.512 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5189  -0.2736 -772.23725   4.7866    0.00000
# 1     -0.8906  -0.2185 -772.50690   4.7563    0.00195
# 2     -0.8383  -0.2591 -772.77220   4.7613    0.00195
# 3     -0.5870  -0.1895 -772.80595   4.9633    0.00391
# 4      0.4600  -0.0735 -772.54250   4.9835    0.00391
# ...       ...      ...        ...      ...        ...
# 5276  -0.0269  -0.0329 -781.98730   4.4785    5.49414
# 5277   0.1250  -0.0909 -782.22570   4.4078    5.49414
# 5278  -0.5189  -0.1286 -782.12840   4.0493    5.49609
# 5279  -0.2258   0.0396 -782.14010   3.9129    5.49805
# 5280  -0.3636   0.0347 -782.38275   4.0207    5.49805
#
# [5281 rows x 5 columns]

# %% [markdown]
# # File 14

# %%
grafici = Graph_hop(dir_name, number, 14)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.1892292032024345, con deviazione standard = 0.3213958932167022

# %%
prova = [1.2, 4.4, 0.1, .5, 3.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.5041767715157062, mu_1 = 4.3557416163278155, sigma_1 = 0.18811729595960644
# c_2 = 0.5877551489493384, mu_2 = 3.7885727908648623, sigma_2 = 0.19750952727479335
# sigma_c_1 = 0.03159619536646173, sigma_mu_1 = 0.007894412922188381, sigma_sigma_1 = 0.007822368219143908
# sigma_c_2 = 0.03140736356942128, sigma_mu_2 = 0.020661869646535644, sigma_sigma_2 = 0.018133655147260765
# w_U = 0.2909875621744019, sigma_w_U = 0.04996653115528382
# w_N = 0.7092797148952409, sigma_w_N = 0.008600200539589481

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.567 sec nello stato nativo e 1.679 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3204   0.1314 -815.97875   3.4820    0.00000
# 1     -0.2869   0.2126 -815.71035   3.4820    0.00000
# 2     -0.6917   0.0019 -815.58820   3.8624    0.00000
# 3     -0.1891  -0.0619 -815.26345   3.8321    0.00195
# 4     -0.6079  -0.0271 -815.72015   3.6907    0.00390
# ...       ...      ...        ...      ...        ...
# 5241  -0.8802  -0.1779 -823.15795   4.2563    5.49414
# 5242  -1.7178  -0.3210 -822.94510   4.5324    5.49609
# 5243  -0.5521  -0.1895 -823.15750   4.5257    5.49609
# 5244  -0.5451  -0.0648 -822.58290   4.3977    5.49804
# 5245  -0.7022  -0.0532 -823.15725   4.3220    5.49804
#
# [5246 rows x 5 columns]

# %% [markdown]
# # File 15

# %%
grafici = Graph_hop(dir_name, number, 15)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 4.159949848714067, con deviazione standard = 0.3001510913829645

# %%
prova = [1.5, 4.5, 0.1, 0.5, 3.8, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.169064546998596, mu_1 = 4.262495815793415, sigma_1 = 0.19622315991356445
# c_2 = 0.44416103769676707, mu_2 = 4.010644829535511, sigma_2 = 0.3890586436686004
# sigma_c_1 = 0.13448604579617787, sigma_mu_1 = 0.010906538594419606, sigma_sigma_1 = 0.01579559742968465
# sigma_c_2 = 0.12154605284937585, sigma_mu_2 = 0.08680877916521354, sigma_sigma_2 = 0.03453144699517787
# w_U = 0.4331571241906445, sigma_w_U = 0.15941017389166562
# w_N = 0.575014358779307, sigma_w_N = 0.05279112278444641

# %% [markdown]
# ## I don't like too much, but let's try

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.677 sec nello stato nativo e 1.611 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.7824  -0.2746 -844.86950   4.1217    0.00000
# 1     -0.6359  -0.1625 -845.02985   4.1015    0.00196
# 2     -0.0687   0.0077 -844.59025   3.9937    0.00391
# 3     -0.5661  -0.0503 -844.88800   4.1957    0.00391
# 4     -0.6498   0.0773 -844.38500   4.2159    0.00586
# ...       ...      ...        ...      ...        ...
# 5283  -0.4718   0.1295 -847.51710   3.8523    5.49414
# 5284   0.0778   0.0628 -847.34790   4.3220    5.49610
# 5285   0.0203   0.1353 -847.50430   4.1351    5.49610
# 5286  -0.5032   0.1701 -846.76150   3.8927    5.49805
# 5287  -0.2659   0.1005 -847.59370   4.0880    5.49805
#
# [5288 rows x 5 columns]

# %% [markdown]
# # File 16

# %%
grafici = Graph_hop(dir_name, number, 16)
data_frame = grafici.do_graph(5.5)
# Out:
# f media vale = 3.967971469140486, con deviazione standard = 0.24221755553532023

# %%
prova = [1.5, 4.0, 0.1, .5, 3.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 2.0409775778268213, mu_1 = 4.0161924395078685, sigma_1 = 0.1739308096218989
# c_2 = 0.23079527292767812, mu_2 = 3.5144978332350334, sigma_2 = 0.1617897431548778
# sigma_c_1 = 0.03314892947679666, sigma_mu_1 = 0.005333378010224397, sigma_sigma_1 = 0.005495364773973737
# sigma_c_2 = 0.03507140259592773, sigma_mu_2 = 0.045304129624030624, sigma_sigma_2 = 0.0393281465631102
# w_U = 0.0935982716365775, sigma_w_U = 0.17314751747628465
# w_N = 0.8898251701332742, sigma_w_N = 0.0021206887045895143

# %% [markdown]
# ## Good one for $f_c$ or bad data?

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, n_points_fig=500)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.457 sec nello stato nativo e 0.8250000000000001 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.8383  -0.2553 -864.77080   4.0274    0.00000
# 1     -0.3148  -0.1973 -865.08130   4.0745    0.00000
# 2      0.3658  -0.1547 -865.34360   4.4078    0.00000
# 3      0.3029   0.0135 -864.98525   4.0846    0.00195
# 4      0.1808  -0.0851 -864.94060   4.0947    0.00390
# ...       ...      ...        ...      ...        ...
# 5277  -0.0146  -0.2050 -865.45800   4.3304    5.49414
# 5278  -0.2729  -0.0929 -865.43045   4.4045    5.49609
# 5279  -0.4771  -0.0358 -865.39940   4.2614    5.49609
# 5280  -0.6236   0.0280 -865.96270   4.1503    5.49804
# 5281  -0.4614   0.0947 -865.60500   4.0745    5.49804
#
# [5282 rows x 5 columns]

# %%
forces_average
# Out:
# [3.717484992424815,
#  4.729579578816285,
#  5.452267894278343,
#  4.015678572023397,
#  4.082298089514877,
#  4.946050590401092,
#  3.9619201659106165,
#  4.512655875589693,
#  4.5509178718091405,
#  4.072157203596339,
#  4.136570322664463,
#  3.765345136371451]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.459890184885364, con sigma = 0.5627305651373359
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 7.520841951323472, con sigma = 0.6662709246511619
# La differenza di energia libera DeltaG_NU = 33.54212920078164, con sigma = 3.0136021720539494

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.70716064077001, con sigma = 3.038750486431716

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5668642249351856, con incertezza = 0.004765174800551296,
#  q1 = 4.961113115440303, con incertezza = 0.004328793166973448
# Stimiamo i parametri del fit lineare: m2 = 0.8093301767041705, con incertezza = 0.00632644242414597,
#  q2 = 3.7176163538494054, con incertezza = 0.006717908506825678
# La forza di coesistenza qui vale: fc = 4.448907988658105, con incertezza = 0.005108228178509373
# Il tempo medi di residenza vale: tc = 2.468415345798037, con incertezza = 0.019241918438021758
# Stimiamo un nuovo DeltaG_NU = 33.459533838678006, con incertezza = 2.964426994365576
# ((-0.5668642249351856, 0.004765174800551296),
#  (4.961113115440303, 0.004328793166973448),
#  (0.8093301767041705, 0.00632644242414597),
#  (3.7176163538494054, 0.006717908506825678),
#  (4.448907988658105, 0.005108228178509373),
#  (2.468415345798037, 0.019241918438021758),
#  (33.459533838678006, 2.964426994365576))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.459888887167009, con sigma = 0.5628246397887707
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 7.520020936160186, con sigma = 0.6663101084475448
# La differenza di energia libera DeltaG_NU = 33.53845780444406, con sigma = 3.0137753893425065

# %%
f_c
# Out:
# (4.459888887167009, 0.5628246397887707)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.70714344938457, con sigma = 3.0392565541144854

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6383876612028149, con incertezza = 0.005693531577587107,
#  q1 = 5.023331288810746, con incertezza = 0.005107425739577874
# Stimiamo i parametri del fit lineare: m2 = 0.7824768050619592, con incertezza = 0.006451165986394398,
#  q2 = 3.738716789010478, con incertezza = 0.006790748757854346
# La forza di coesistenza qui vale: fc = 4.44616009089165, con incertezza = 0.00566774574885974
# Il tempo medi di residenza vale: tc = 2.4697271936312117, con incertezza = 0.02002433843325547
# Stimiamo un nuovo DeltaG_NU = 33.43521696902508, con incertezza = 2.962827993067344

# %%
f_c, t_c
# Out:
# ((4.44616009089165, 0.00566774574885974),
#  (2.4697271936312117, 0.02002433843325547))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.717484992424815,
#   4.729579578816285,
#   4.015678572023397,
#   4.082298089514877,
#   4.946050590401092,
#   3.9619201659106165,
#   4.512655875589693,
#   4.5509178718091405,
#   4.072157203596339,
#   4.136570322664463,
#   3.765345136371451],
#  [4.665, 2.106, 3.849, 3.473, 0.896, 3.697, 1.938, 2.769, 3.567, 3.677, 4.457])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -2
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.46195898059342, con sigma = 0.563986768839346
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 7.611536505077778, con sigma = 0.6754328399304259
# La differenza di energia libera DeltaG_NU = 33.962363664946444, con sigma = 3.057036375398068

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.734569535335496, con sigma = 3.04612775207029

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6379116108111156, con incertezza = 0.00570578834079922,
#  q1 = 5.023107529865407, con incertezza = 0.005110446940942396
# Stimiamo i parametri del fit lineare: m2 = 0.7827548272857335, con incertezza = 0.006469731633424816,
#  q2 = 3.7383717457905514, con incertezza = 0.00681789940159313
# La forza di coesistenza qui vale: fc = 4.446231880868058, con incertezza = 0.005681952998060686
# Il tempo medi di residenza vale: tc = 2.47024933903064, con incertezza = 0.020087063456275187
# Stimiamo un nuovo DeltaG_NU = 33.84265627126785, con incertezza = 3.0034424223708953
# ((-0.6379116108111156, 0.00570578834079922),
#  (5.023107529865407, 0.005110446940942396),
#  (0.7827548272857335, 0.006469731633424816),
#  (3.7383717457905514, 0.00681789940159313),
#  (4.446231880868058, 0.005681952998060686),
#  (2.47024933903064, 0.020087063456275187),
#  (33.84265627126785, 3.0034424223708953))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.717484992424815,
#   4.729579578816285,
#   4.015678572023397,
#   4.082298089514877,
#   4.946050590401092,
#   3.9619201659106165,
#   4.512655875589693,
#   4.5509178718091405,
#   4.072157203596339,
#   3.765345136371451],
#  [4.665, 2.106, 3.849, 3.473, 0.896, 3.697, 1.938, 2.769, 3.567, 4.457])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = 0
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.461810909481285, con sigma = 0.5652428452328156
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 7.601520450218359, con sigma = 0.6760506745128183
# La differenza di energia libera DeltaG_NU = 33.91654687342936, con sigma = 3.0598926970746088

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.7326076004635, con sigma = 3.0528469725858107

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6221622904620844, con incertezza = 0.005808035684212829,
#  q1 = 5.014047833844322, con incertezza = 0.005148419870754746
# Stimiamo i parametri del fit lineare: m2 = 0.8375936543899914, con incertezza = 0.007148771569306301,
#  q2 = 3.6792982720885674, con incertezza = 0.007564032215413979
# La forza di coesistenza qui vale: fc = 4.445164489019598, con incertezza = 0.006013909824491118
# Il tempo medi di residenza vale: tc = 2.495189990501016, con incertezza = 0.021256884371176777
# Stimiamo un nuovo DeltaG_NU = 33.79000876786692, con incertezza = 3.005504141406252
# ((-0.6221622904620844, 0.005808035684212829),
#  (5.014047833844322, 0.005148419870754746),
#  (0.8375936543899914, 0.007148771569306301),
#  (3.6792982720885674, 0.007564032215413979),
#  (4.445164489019598, 0.006013909824491118),
#  (2.495189990501016, 0.021256884371176777),
#  (33.79000876786692, 3.005504141406252))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.729579578816285,
#   4.015678572023397,
#   4.082298089514877,
#   4.946050590401092,
#   3.9619201659106165,
#   4.512655875589693,
#   4.5509178718091405,
#   4.072157203596339,
#   3.765345136371451],
#  [2.106, 3.849, 3.473, 0.896, 3.697, 1.938, 2.769, 3.567, 4.457])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -1
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.46144702452804, con sigma = 0.5682962448774485
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 7.577723088292181, con sigma = 0.6775842062730554
# La differenza di energia libera DeltaG_NU = 33.80761012495858, con sigma = 3.0669924813269134

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.727786262260025, con sigma = 3.0691781459948784

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.6069524145474928, con incertezza = 0.005904768576647217,
#  q1 = 5.005510280147646, con incertezza = 0.0051829734759292045
# Stimiamo i parametri del fit lineare: m2 = 0.871909417522958, con incertezza = 0.00772082699427943,
#  q2 = 3.6417118888579796, con incertezza = 0.008210940295665194
# La forza di coesistenza qui vale: fc = 4.445782042797466, con incertezza = 0.006288142498930614
# Il tempo medi di residenza vale: tc = 2.5148033182896103, con incertezza = 0.022471724228306962
# Stimiamo un nuovo DeltaG_NU = 33.68890523122114, con incertezza = 3.012768533795276
# ((-0.6069524145474928, 0.005904768576647217),
#  (5.005510280147646, 0.0051829734759292045),
#  (0.871909417522958, 0.00772082699427943),
#  (3.6417118888579796, 0.008210940295665194),
#  (4.445782042797466, 0.006288142498930614),
#  (2.5148033182896103, 0.022471724228306962),
#  (33.68890523122114, 3.012768533795276))

# %%
grafici.write_on_txt()
