# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 22bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/22"
# molecule name is a number in these experimets
number = "22"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force    time(sec)
# 0        0.3344   0.3818 -906.90170   3.8574  17315.59570
# 1        0.1459   0.3557 -907.39935   3.9331  17315.59570
# 2        0.3972   0.3325 -906.94460   4.0341  17315.59766
# 3       -0.4875   0.2165 -907.06345   3.9735  17315.59766
# 4       -0.2205   0.2281 -906.96275   4.0543  17315.59961
# ...         ...      ...        ...      ...          ...
# 119360  -0.5940   0.1005 -865.27975   4.2496  17925.61719
# 119361  -0.6708   0.0850 -864.64630   4.0543  17925.61914
# 119362  -0.1420  -0.0387 -864.84910   4.4432  17925.61914
# 119363  -0.7755  -0.0416 -864.94280   4.2008  17925.62109
# 119364  -1.4717  -0.1576 -864.89835   4.1957  17925.62100
#
# [119365 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.935248752291025, con deviazione standard = 0.22038527871583347

# %%
prova = [2., 4., 0.1, .2, 3.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 2.3186937262331617, mu_1 = 3.975692877233913, sigma_1 = 0.15875895800260487
# c_2 = 0.18770430361657178, mu_2 = 3.4191480127467373, sigma_2 = 0.1482644338402122
# sigma_c_1 = 0.03912349199492396, sigma_mu_1 = 0.003408621768481668, sigma_sigma_1 = 0.003741986062286243
# sigma_c_2 = 0.039275402200892984, sigma_mu_2 = 0.04076386381421082, sigma_sigma_2 = 0.04172778769210861
# w_U = 0.06975914479928953, sigma_w_U = 0.3235999524386844
# w_N = 0.9227234564697994, sigma_w_N = 0.0020221209478497796

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6357 sec nello stato nativo e 736 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3344   0.3818 -906.90170   3.8574    0.00000
# 1      0.1459   0.3557 -907.39935   3.9331    0.00000
# 2      0.3972   0.3325 -906.94460   4.0341    0.00196
# 3     -0.4875   0.2165 -907.06345   3.9735    0.00196
# 4     -0.2205   0.2281 -906.96275   4.0543    0.00391
# ...       ...      ...        ...      ...        ...
# 7088   0.0412   0.3673 -917.22675   3.7917    7.39063
# 7089  -0.3985   0.2571 -917.19630   3.7059    7.39258
# 7090  -0.5556   0.2107 -917.27865   3.8271    7.39258
# 7091  -0.6341   0.1527 -917.32650   3.7513    7.39453
# 7092  -0.1001   0.1817 -917.35795   3.9887    7.39450
#
# [7093 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.667218420031059, con deviazione standard = 0.34919253409985973

# %%
prova = [1., 5., 0.1, 1., 4.4, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.0914729819201845, mu_1 = 5.0385576240604575, sigma_1 = 0.14398552891389518
# c_2 = 1.2437709597509874, mu_2 = 4.420601533572112, sigma_2 = 0.1944452118759688
# sigma_c_1 = 0.037704666515007236, sigma_mu_1 = 0.006446051611815326, sigma_sigma_1 = 0.006802676187624011
# sigma_c_2 = 0.0319599339618252, sigma_mu_2 = 0.0063457715661875734, sigma_sigma_2 = 0.0067139326069160475
# w_U = 0.6062162866031716, sigma_w_U = 0.016955178003798855
# w_N = 0.3939324617056551, sigma_w_N = 0.03548039761344598

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2099 sec nello stato nativo e 3053 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0098  -0.1083 -915.74105   4.5795    0.00000
# 1      0.2297  -0.1354 -915.97045   4.5257    0.00000
# 2     -0.0635  -0.1315 -916.06345   4.5593    0.00391
# 3     -0.2101  -0.0465 -915.78975   4.3439    0.00391
# 4     -0.0914   0.0038 -915.78190   4.2227    0.00586
# ...       ...      ...        ...      ...        ...
# 5147  -0.6969   0.0976 -921.63565   4.4129    5.36914
# 5148   0.1407   0.2948 -921.64095   4.5189    5.36914
# 5149   0.2244   0.2658 -921.58050   4.4381    5.37109
# 5150   0.1616   0.1846 -921.18860   4.4280    5.37305
# 5151   0.0517   0.1788 -921.17250   4.5543    5.37299
#
# [5152 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.1140242632883535, con deviazione standard = 0.2643477754062084

# %%
prova = [2., 5.1, 0.1, 0.4, 5.7, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.9459988097600833, mu_1 = 5.0647423048747235, sigma_1 = 0.19330344390749504
# c_2 = 0.15268083522231066, mu_2 = 5.837167144570246, sigma_2 = 0.14352249755459087
# sigma_c_1 = 0.03398825746497376, sigma_mu_1 = 0.003943189999712122, sigma_sigma_1 = 0.0039740085521477566
# sigma_c_2 = 0.040153443548396804, sigma_mu_2 = 0.04447802546691645, sigma_sigma_2 = 0.044380164267168995
# w_U = 0.05492808327504682, sigma_w_U = 0.38275926098915736
# w_N = 0.9429140260290133, sigma_w_N = 0.0014817340415763192

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 10148 sec nello stato nativo e 745 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1948   0.3247 -944.59515   4.7815    0.00000
# 1       0.1250   0.1585 -944.42860   5.2865    0.00000
# 2      -0.2101   0.2087 -944.92065   4.9431    0.00195
# 3      -0.1839   0.2484 -944.93480   5.0239    0.00195
# 4       0.0517   0.2629 -945.20945   5.1401    0.00390
# ...        ...      ...        ...      ...        ...
# 10888  -0.9779   0.0657 -926.14945   5.7444   11.33789
# 10889  -1.0006  -0.0851 -926.13800   5.7713   11.33984
# 10890  -0.1682  -0.0822 -925.84280   5.9077   11.34179
# 10891  -0.4404  -0.0445 -925.76590   6.0592   11.34179
# 10892  -0.4457   0.1034 -926.15895   5.8218   11.34565
#
# [10893 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.000043442153506, con deviazione standard = 0.2179601227014266

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [1., 4.3, 0.1, 1., 3.6, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2101   0.2861 -930.62760   5.0037    0.00000
# 1      0.3553   0.5219 -930.85565   4.7546    0.00196
# 2      0.7217   0.6689 -930.79115   4.6704    0.00196
# 3      0.7008   0.6747 -931.20020   4.6048    0.00391
# 4      0.8264   0.5326 -930.97455   4.8977    0.00391
# ...       ...      ...        ...      ...        ...
# 6979  -0.1525   0.2687 -936.51820   5.0795    7.27930
# 6980  -0.3095   0.2861 -936.42595   4.8876    7.27930
# 6981   0.2663   0.2281 -936.57995   5.1603    7.28125
# 6982  -0.1787   0.2948 -936.73225   4.7866    7.28125
# 6983  -0.3619   0.2977 -936.71820   5.0239    7.28319
#
# [6984 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.133938082747111, con deviazione standard = 0.3107723958685997

# %%
prova = [1.5, 4.3, 0.1, .6, 3.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.5646054353160543, mu_1 = 4.287381636943431, sigma_1 = 0.1810202648567959
# c_2 = 0.5681894266098068, mu_2 = 3.7495649645355758, sigma_2 = 0.1996289257276961
# sigma_c_1 = 0.034350494768930276, sigma_mu_1 = 0.008795735578852696, sigma_sigma_1 = 0.008275762408907306
# sigma_c_2 = 0.034005203808253365, sigma_mu_2 = 0.025617071579076438, sigma_sigma_2 = 0.021356611076174373
# w_U = 0.2843194377136869, sigma_w_U = 0.08702746454305381
# w_N = 0.7099405207497718, sigma_w_N = 0.01441946477347554

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5706 sec nello stato nativo e 2681 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -1.0756   0.2899 -870.46960   3.9197    0.00000
# 1     -0.5800   0.2397 -870.28150   4.1015    0.00195
# 2      0.0203   0.3093 -870.60710   4.0947    0.00195
# 3     -0.2380   0.2165 -870.25370   3.8927    0.00390
# 4     -0.4544   0.2474 -870.12285   3.9197    0.00390
# ...       ...      ...        ...      ...        ...
# 8382  -0.9220   0.4775 -879.16325   3.4079    8.75000
# 8383  -0.9220   0.3789 -879.09195   3.6840    8.75000
# 8384  -0.6149   0.4987 -879.72665   3.4753    8.75195
# 8385  -0.0216   0.4755 -879.27040   3.5359    8.75390
# 8386   0.1407   0.4630 -878.84490   3.3372    8.75386
#
# [8387 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.337459992533608, con deviazione standard = 0.22505621866906395

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [2., 3.5, 0.1, .5, 3., 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5032  -0.0039 -899.75410   3.6503    0.00000
# 1     -0.5870   0.0889 -898.97440   3.5897    0.00195
# 2      0.1599   0.3209 -899.56965   3.6638    0.00195
# 3     -0.0146   0.3209 -899.48865   3.4079    0.00390
# 4      0.4338   0.2571 -899.61120   3.5443    0.00390
# ...       ...      ...        ...      ...        ...
# 8031   0.0988   0.0483 -890.05115   3.3271    8.33984
# 8032   0.6694   0.1469 -889.57680   3.3170    8.34180
# 8033   0.3605   0.1092 -889.68240   3.2312    8.34375
# 8034  -1.2152  -0.1750 -889.97775   3.2867    8.34375
# 8035  -1.3722  -0.3867 -889.64935   3.5039    8.34568
#
# [8036 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.174621326558645, con deviazione standard = 0.3296351001400363

# %%
prova = [1.2, 4.5, 0.1, 0.7, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.1888403246653236, mu_1 = 4.390365973103858, sigma_1 = 0.192687270881737
# c_2 = 0.7336554584710352, mu_2 = 3.8817428899442032, sigma_2 = 0.22936560004109358
# sigma_c_1 = 0.04513571632066585, sigma_mu_1 = 0.01577668745898998, sigma_sigma_1 = 0.011943738132965223
# sigma_c_2 = 0.04034171237122761, sigma_mu_2 = 0.030534253149558783, sigma_sigma_2 = 0.019643262025704246
# w_U = 0.42180368620319414, sigma_w_U = 0.05843951309160322
# w_N = 0.5742043622035122, sigma_w_N = 0.03066017211819761

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4123 sec nello stato nativo e 3159 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.0059   0.5819 -824.29355   4.5290    0.00000
# 1      0.2820   0.5355 -824.57430   4.5139    0.00195
# 2      0.5438   0.5413 -824.42135   4.7209    0.00195
# 3     -0.4823   0.3673 -824.40500   4.7007    0.00195
# 4     -0.3776   0.1237 -824.09230   4.7142    0.00390
# ...       ...      ...        ...      ...        ...
# 7277   0.1459   0.7810 -812.84485   4.1015    7.57812
# 7278   0.2035   0.7791 -812.62990   4.0644    7.57812
# 7279   0.3553   0.6805 -812.76260   4.2361    7.58008
# 7280  -0.4823   0.5384 -812.60310   4.3119    7.58008
# 7281  -0.2677   0.5384 -812.78355   4.1250    7.58201
#
# [7282 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.06253803599787, con deviazione standard = 0.20388751433713537

# %% [markdown]
# # Suspicious Data?!

# %%
# prova = [0.2, 5.6, 0.1, 2.5, 4.9, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.9220   0.2107 -791.22550   5.1552    0.00000
# 1     -0.2520   0.3479 -791.11330   5.1047    0.00000
# 2      0.4740   0.3905 -790.84470   5.0172    0.00195
# 3      0.2401   0.4224 -790.91310   4.8724    0.00195
# 4     -0.4247   0.3818 -791.12160   4.9583    0.00391
# ...       ...      ...        ...      ...        ...
# 3773  -0.1752   0.1507 -800.10375   5.2461    3.92969
# 3774  -0.4142   0.2513 -800.17785   5.0542    3.93164
# 3775  -0.1054   0.3325 -800.03310   4.9785    3.93164
# 3776   0.1407   0.2368 -800.12940   5.1855    3.93359
# 3777   0.6170   0.3267 -800.31820   5.3471    3.93353
#
# [3778 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.6751141336672495, con deviazione standard = 0.2981136722934492

# %%
prova = [0.5, 5.3, 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.4451140030822962, mu_1 = 5.2787032654498365, sigma_1 = 0.1137185109314498
# c_2 = 1.7762759897349358, mu_2 = 4.5835712447364, sigma_2 = 0.19654320499100267
# sigma_c_1 = 0.04838485838174512, sigma_mu_1 = 0.014711051367163365, sigma_sigma_1 = 0.01458872448158351
# sigma_c_2 = 0.03586816491065301, sigma_mu_2 = 0.004630042039522046, sigma_sigma_2 = 0.004704047218730298
# w_U = 0.8751014698662055, sigma_w_U = 0.003973150667182238
# w_N = 0.12687976209070095, sigma_w_N = 0.14714716654199492

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 886 sec nello stato nativo e 5503 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2454  -0.7028 -634.70695   4.6098    0.00000
# 1      0.4600  -0.8014 -634.86840   4.3624    0.00196
# 2      0.2297  -0.9551 -634.99325   4.5997    0.00196
# 3      0.2820  -0.8797 -634.76190   4.5896    0.00391
# 4      0.8736  -0.7840 -634.76100   4.6502    0.00391
# ...       ...      ...        ...      ...        ...
# 6384   0.3413  -0.5801 -628.64225   4.4853    6.64063
# 6385  -0.0269  -0.6100 -628.81270   4.5947    6.64258
# 6386   0.1825  -0.4998 -629.10305   4.4533    6.64258
# 6387   0.7008  -0.4737 -628.85390   4.5442    6.64453
# 6388   0.0412  -0.6535 -628.41495   4.6704    6.64445
#
# [6389 rows x 5 columns]

# %% [markdown]
# # File 10

# %%
grafici = Graph_hop(dir_name, number, 10)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.120573280765227, con deviazione standard = 0.3106267365159412

# %%
prova = [2., 4.2, 0.1, .5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 2.26538419841413, mu_1 = 4.254226472154932, sigma_1 = 0.13305781932554236
# c_2 = 0.5131911270395716, mu_2 = 3.6315346836488005, sigma_2 = 0.17245978284668484
# sigma_c_1 = 0.05002605302687301, sigma_mu_1 = 0.00352830670123487, sigma_sigma_1 = 0.003653325516159968
# sigma_c_2 = 0.043382848515933006, sigma_mu_2 = 0.01733047280604132, sigma_sigma_2 = 0.018012123390443717
# w_U = 0.2218487101418096, sigma_w_U = 0.10152303341969698
# w_N = 0.7555656449153927, sigma_w_N = 0.007816884776392325

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5902 sec nello stato nativo e 1834 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3972  -0.6245 -629.05730   3.9533    0.00000
# 1      0.0831  -0.6303 -628.71900   3.8321    0.00196
# 2      0.1110  -0.6110 -628.60450   3.9062    0.00196
# 3     -0.5451  -0.7657 -629.07745   3.9803    0.00391
# 4     -0.1944  -0.7376 -628.99350   3.8220    0.00391
# ...       ...      ...        ...      ...        ...
# 7731   0.6694  -0.6767 -632.14980   4.2967    8.06055
# 7732   0.7322  -0.6651 -631.86415   4.1755    8.06250
# 7733   0.7113  -0.6883 -632.34405   4.1755    8.06250
# 7734   1.5489  -0.5414 -631.89060   4.0813    8.06446
# 7735   1.9537  -0.5994 -631.92265   4.1688    8.06440
#
# [7736 rows x 5 columns]

# %% [markdown]
# # File 11

# %%
grafici = Graph_hop(dir_name, number, 11)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.961801281722632, con deviazione standard = 0.32386791972642165

# %% [markdown]
# # Drift?!

# %%
prova = [0.3, 5.5, 0.1, 1., 4.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.0854643028977211, mu_1 = 5.015596717217766, sigma_1 = 0.29718465975929687
# c_2 = 0.47367628310518, mu_2 = 4.64614192421032, sigma_2 = 0.15019961495519993
# sigma_c_1 = 0.05945350994394001, sigma_mu_1 = 0.051569836145303305, sigma_sigma_1 = 0.03267556763759118
# sigma_c_2 = 0.2055990343569309, sigma_mu_2 = 0.02086800761851357, sigma_sigma_2 = 0.03521491978784468
# w_U = 0.1783365635355024, sigma_w_U = 0.39889948379989143
# w_N = 0.8085965198096441, sigma_w_N = 0.02190645681340215

# %% [markdown]
# ## I don't like this fit

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0517  -0.4099 -674.71180   4.6755    0.00000
# 1      0.6537  -0.4998 -675.02915   4.9280    0.00000
# 2     -0.0426  -0.6187 -674.92455   4.8371    0.00195
# 3      0.4495  -0.5868 -674.92210   4.8118    0.00195
# 4     -0.1787  -0.5839 -674.90435   4.7916    0.00390
# ...       ...      ...        ...      ...        ...
# 7797   0.1250  -0.1083 -675.23355   5.3539    8.11523
# 7798  -0.0286  -0.1006 -675.25615   5.3741    8.11718
# 7799  -0.4561  -0.0416 -675.15860   5.0593    8.11718
# 7800  -0.8959  -0.2330 -675.38730   5.2916    8.11718
# 7801  -0.6289  -0.1141 -675.08640   5.5643    8.11906
#
# [7802 rows x 5 columns]

# %% [markdown]
# # File 12

# %%
grafici = Graph_hop(dir_name, number, 12)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.484278773529089, con deviazione standard = 0.3840577387729026

# %%
prova = [0.7, 5., 0.1, 1.5, 4.3, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.7280947277908147, mu_1 = 4.958818463279763, sigma_1 = 0.16523094731290566
# c_2 = 1.124618197053323, mu_2 = 4.27762016301262, sigma_2 = 0.2480906591183017
# sigma_c_1 = 0.03258959559080332, sigma_mu_1 = 0.010807576560220076, sigma_sigma_1 = 0.011158158229502462
# sigma_c_2 = 0.026642468717809075, sigma_mu_2 = 0.008343965071877013, sigma_sigma_2 = 0.008837520160766747
# w_U = 0.699367511216525, sigma_w_U = 0.012900728162252706
# w_N = 0.3015568605196564, sigma_w_N = 0.05666111234050963

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2768 sec nello stato nativo e 5679 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2938  -0.1818 -724.84875   4.6469    0.00000
# 1     -0.3846  -0.1702 -724.82775   4.8017    0.00000
# 2     -0.1891  -0.2243 -725.01565   4.7815    0.00195
# 3     -0.7755  -0.2475 -724.52015   4.7209    0.00195
# 4     -0.4055  -0.2591 -724.99200   4.6469    0.00390
# ...       ...      ...        ...      ...        ...
# 8442  -0.0059  -0.1141 -739.74460   4.6300    8.79492
# 8443   0.0360  -0.1547 -740.21005   4.4078    8.79492
# 8444  -0.8854  -0.1982 -740.01570   4.3472    8.79883
# 8445  -0.7179  -0.2997 -739.95270   4.4634    8.79883
# 8446  -0.6079  -0.1625 -739.48430   4.4179    8.80077
#
# [8447 rows x 5 columns]

# %% [markdown]
# # File 13

# %%
grafici = Graph_hop(dir_name, number, 13)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.530322474778148, con deviazione standard = 0.33435189097577633

# %%
prova = [1.2, 4.9, 0.1, 1.4, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.0494224881282421, mu_1 = 4.85509854003257, sigma_1 = 0.15331151422747172
# c_2 = 1.146551777160288, mu_2 = 4.29946104601493, sigma_2 = 0.2054661663748556
# sigma_c_1 = 0.0376117399511509, sigma_mu_1 = 0.009229065180460724, sigma_sigma_1 = 0.009371375598848503
# sigma_c_2 = 0.03220510751508882, sigma_mu_2 = 0.00965197522094887, sigma_sigma_2 = 0.009506757566978228
# w_U = 0.5905054685263089, sigma_w_U = 0.021829059495808618
# w_N = 0.4032877902974056, sigma_w_N = 0.04184250261651647

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3495 sec nello stato nativo e 4732 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.5189  -0.2736 -772.23725   4.7866    0.00000
# 1     -0.8906  -0.2185 -772.50690   4.7563    0.00195
# 2     -0.8383  -0.2591 -772.77220   4.7613    0.00195
# 3     -0.5870  -0.1895 -772.80595   4.9633    0.00391
# 4      0.4600  -0.0735 -772.54250   4.9835    0.00391
# ...       ...      ...        ...      ...        ...
# 8222  -0.6149  -0.7193 -788.80595   4.5997    8.56641
# 8223  -1.0529  -0.7347 -788.83545   4.4886    8.56836
# 8224  -0.6603  -0.6593 -788.95415   4.4583    8.56836
# 8225  -0.2677  -0.5288 -788.92820   4.5745    8.57031
# 8226  -0.5242  -0.3780 -789.04240   4.4331    8.57029
#
# [8227 rows x 5 columns]

# %% [markdown]
# # File 14

# %%
grafici = Graph_hop(dir_name, number, 14)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.208585104091885, con deviazione standard = 0.32403808583879345

# %%
prova = [1.2, 4.4, 0.1, .5, 3.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.5003335252035837, mu_1 = 4.366669638016241, sigma_1 = 0.1947089370099154
# c_2 = 0.5498646412273496, mu_2 = 3.7838341950181276, sigma_2 = 0.19402259672570302
# sigma_c_1 = 0.03273710999335172, sigma_mu_1 = 0.008009978362155156, sigma_sigma_1 = 0.008156906780187611
# sigma_c_2 = 0.03307832912908001, sigma_mu_2 = 0.02174053487205998, sigma_sigma_2 = 0.019397636178665172
# w_U = 0.2674225590509616, sigma_w_U = 0.08543946414853398
# w_N = 0.732257171535634, sigma_w_N = 0.012631621950912495

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3893 sec nello stato nativo e 1679 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.3204   0.1314 -815.97875   3.4820    0.00000
# 1     -0.2869   0.2126 -815.71035   3.4820    0.00000
# 2     -0.6917   0.0019 -815.58820   3.8624    0.00000
# 3     -0.1891  -0.0619 -815.26345   3.8321    0.00195
# 4     -0.6079  -0.0271 -815.72015   3.6907    0.00390
# ...       ...      ...        ...      ...        ...
# 5567  -0.5591   0.1198 -822.37030   4.3506    5.82617
# 5568   0.3762   0.2358 -822.33040   4.6873    5.82812
# 5569  -0.1630   0.2310 -822.50130   4.4129    5.82812
# 5570  -0.3200   0.2078 -822.24650   4.2917    5.82812
# 5571  -0.7859   0.0193 -821.73790   4.4482    5.83006
#
# [5572 rows x 5 columns]

# %% [markdown]
# # File 15

# %%
grafici = Graph_hop(dir_name, number, 15)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.213161786600496, con deviazione standard = 0.3214996275021919

# %%
prova = [0.8, 4.5, 0.1, 1.0, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 1.3069699494825586, mu_1 = 4.251786451654484, sigma_1 = 0.28893993173030025
# c_2 = 0.17945151528903386, mu_2 = 3.595438741849226, sigma_2 = 0.10869574236371775
# sigma_c_1 = 0.02512723021485154, sigma_mu_1 = 0.007006149050338112, sigma_sigma_1 = 0.007956954504233891
# sigma_c_2 = 0.04208159825006398, sigma_mu_2 = 0.03077152701121623, sigma_sigma_2 = 0.030313415720551354
# w_U = 0.048893327759113925, sigma_w_U = 0.344911447690134
# w_N = 0.9465925937883828, sigma_w_N = 0.0016421082902172192

# %% [markdown]
# ## I don't like too much, but let's try

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6098 sec nello stato nativo e 753 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.7824  -0.2746 -844.86950   4.1217    0.00000
# 1     -0.6359  -0.1625 -845.02985   4.1015    0.00196
# 2     -0.0687   0.0077 -844.59025   3.9937    0.00391
# 3     -0.5661  -0.0503 -844.88800   4.1957    0.00391
# 4     -0.6498   0.0773 -844.38500   4.2159    0.00586
# ...       ...      ...        ...      ...        ...
# 6846   1.1231  -0.2359 -847.96575   5.3135    7.13086
# 6847   0.2715  -0.1702 -848.23230   5.1047    7.13086
# 6848  -0.0426  -0.1576 -848.62010   4.9684    7.13281
# 6849  -0.4980  -0.1692 -848.12105   4.9027    7.13281
# 6850  -0.0373  -0.2388 -848.50895   4.9835    7.13469
#
# [6851 rows x 5 columns]

# %% [markdown]
# # File 16

# %%
grafici = Graph_hop(dir_name, number, 16)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.035856380402399, con deviazione standard = 0.2723423524488904

# %%
prova = [1.5, 4.4, 0.1, .5, 3.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.3346223316706379, mu_1 = 3.952022323488669, sigma_1 = 0.3905806352448547
# c_2 = 1.3927572258585241, mu_2 = 4.082942672552396, sigma_2 = 0.1927257765585944
# sigma_c_1 = 0.17572365722248984, sigma_mu_1 = 0.07741461493463102, sigma_sigma_1 = 0.06992186648667453
# sigma_c_2 = 0.16617142769765791, sigma_mu_2 = 0.009139057658444905, sigma_sigma_2 = 0.014524049533919938
# w_U = 0.6728297076987726, sigma_w_U = 0.04623169331086017
# w_N = 0.3276088028060583, sigma_w_N = 0.37329654585379324

# %% [markdown]
# # Good one for $f_c$ or bad data?

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, n_points_fig=500)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4381 sec nello stato nativo e 6355 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.8383  -0.2553 -864.77080   4.0274    0.00000
# 1      -0.3148  -0.1973 -865.08130   4.0745    0.00000
# 2       0.3658  -0.1547 -865.34360   4.4078    0.00000
# 3       0.3029   0.0135 -864.98525   4.0846    0.00195
# 4       0.1808  -0.0851 -864.94060   4.0947    0.00390
# ...        ...      ...        ...      ...        ...
# 10731  -0.5940   0.1005 -865.27975   4.2496   11.18750
# 10732  -0.6708   0.0850 -864.64630   4.0543   11.18945
# 10733  -0.1420  -0.0387 -864.84910   4.4432   11.18945
# 10734  -0.7755  -0.0416 -864.94280   4.2008   11.19140
# 10735  -1.4717  -0.1576 -864.89835   4.1957   11.19131
#
# [10736 rows x 5 columns]

# %%
forces_average
# Out:
# [3.697420444990325,
#  4.729579578816285,
#  5.450954724722485,
#  4.018473300739504,
#  4.13605443152403,
#  4.931137255093118,
#  3.9428805779018665,
#  4.6182193131461915,
#  4.57727979302375,
#  4.075251916517184,
#  3.923612596751855,
#  4.017482498020533]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.3947537688553195, con sigma = 0.8425033923602401
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 7.1143672043483726, con sigma = 0.9496042701428297
# La differenza di energia libera DeltaG_NU = 31.26589208433069, con sigma = 4.302364357172243

# %%
G0 = grafici.G0(f_c[0])

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.3453915702214467, con incertezza = 0.37112184143715266,
#  q1 = 9.794068641981662, con incertezza = 1.622260490325404
# Stimiamo i parametri del fit lineare: m2 = 0.24685096022054537, con incertezza = 0.492553488470844,
#  q2 = 6.697161622547808, con incertezza = 2.153066649646315
# La forza di coesistenza qui vale: fc = 5.229119592479494, con incertezza = 7.097181727830031
# Il tempo medi di residenza vale: tc = 2945.3260854292857, con incertezza = 11812.266667293088
# Stimiamo un nuovo DeltaG_NU = 37.20187693635163, con incertezza = 50.73553824578874
# ((-0.3453915702214467, 0.37112184143715266),
#  (9.794068641981662, 1.622260490325404),
#  (0.24685096022054537, 0.492553488470844),
#  (6.697161622547808, 2.153066649646315),
#  (5.229119592479494, 7.097181727830031),
#  (2945.3260854292857, 11812.266667293088),
#  (37.20187693635163, 50.73553824578874))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.394919794135988, con sigma = 0.8405957507320523
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 7.133958690168383, con sigma = 0.9500534615051626
# La differenza di energia libera DeltaG_NU = 31.35317625796947, con sigma = 4.304332281154787

# %%
f_c
# Out:
# (4.394919794135988, 0.8405957507320523)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -22.00247442035686, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.3417051565189928, con incertezza = 0.2000827601250197,
#  q1 = 13.901494033241747, con incertezza = 0.8522580956722631
# Stimiamo i parametri del fit lineare: m2 = 1.3308932860789677, con incertezza = 0.45831234567335893,
#  q2 = 2.2280637096910545, con incertezza = 1.9521942186716412
# La forza di coesistenza qui vale: fc = 4.367820521590691, con incertezza = 1.1415769723085125
# Il tempo medi di residenza vale: tc = 3106.2351733732794, con incertezza = 10151.114670413843
# Stimiamo un nuovo DeltaG_NU = 31.159851167097706, con incertezza = 9.140231714210467

# %%
f_c, t_c
# Out:
# ((4.367820521590691, 1.1415769723085125),
#  (3106.2351733732794, 10151.114670413843))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([3.697420444990325,
#   4.729579578816285,
#   4.018473300739504,
#   4.13605443152403,
#   4.931137255093118,
#   3.9428805779018665,
#   4.6182193131461915,
#   4.57727979302375,
#   4.075251916517184,
#   3.923612596751855,
#   4.017482498020533],
#  [6357, 2099, 5706, 4123, 886, 5902, 2768, 3495, 3893, 6098, 4381])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -2
forces_average = remove_element(forces_average, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.394732915745033, con sigma = 0.8414148908318673
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 7.128276098423673, con sigma = 0.9502371782152886
# La differenza di energia libera DeltaG_NU = 31.326869602261098, con sigma = 4.305201285478646

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.3231072697242108, con incertezza = 0.21868116861052597,
#  q1 = 13.814144301778063, con incertezza = 0.93850817863857
# Stimiamo i parametri del fit lineare: m2 = 1.1353555044454648, con incertezza = 0.43134758302843196,
#  q2 = 3.1464569018206463, con incertezza = 1.8512029992274066
# La forza di coesistenza qui vale: fc = 4.339169790179285, con incertezza = 1.2005486128692828
# Il tempo medi di residenza vale: tc = 3206.5703168638343, con incertezza = 10464.207186836722
# Stimiamo un nuovo DeltaG_NU = 30.93080030233706, con incertezza = 9.499356360239693
# ((-1.3231072697242108, 0.21868116861052597),
#  (13.814144301778063, 0.93850817863857),
#  (1.1353555044454648, 0.43134758302843196),
#  (3.1464569018206463, 1.8512029992274066),
#  (4.339169790179285, 1.2005486128692828),
#  (3206.5703168638343, 10464.207186836722),
#  (30.93080030233706, 9.499356360239693))
