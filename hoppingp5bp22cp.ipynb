# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 22bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/22cp"
# molecule name is a number in these experimets
number = "22"

# %%
file = Txt_hop(dir_name, number, different_name='hopcp', first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0       0.2977   0.1672 -826.92290   4.5644  18061.60742
# 1       0.2297   0.0657 -826.91805   4.4785  18061.60742
# 2      -0.0844   0.1005 -827.03200   4.5189  18061.60938
# 3      -0.0565   0.1082 -826.31795   4.7007  18061.60938
# 4      -0.1682   0.0463 -827.00405   4.6267  18061.61133
# ...        ...      ...        ...      ...          ...
# 53526  -0.5556  -0.0938 -879.04965   4.9381  18180.42773
# 53527  -0.5713  -0.0184 -879.07080   4.9330  18180.42969
# 53528  -0.5137   0.0396 -879.12650   4.9078  18180.42969
# 53529   0.2297   0.2658 -879.11650   4.5391  18180.42969
# 53530   0.2611   0.2310 -879.39490   4.6553  18180.43160
#
# [53531 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.642407664777802, con deviazione standard = 0.3291096518608248

# %%
prova = [0.4, 5.1, 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.33587627449052276, mu_1 = 5.188771322677314, sigma_1 = 0.18921068553769085
# c_2 = 1.4013758567595362, mu_2 = 4.533680823237956, sigma_2 = 0.2409963111631501
# sigma_c_1 = 0.03340674341804033, sigma_mu_1 = 0.033086921016926306, sigma_sigma_1 = 0.033278115150664984
# sigma_c_2 = 0.029395566648936805, sigma_mu_2 = 0.008900785605185898, sigma_sigma_2 = 0.008598805218072141
# w_U = 0.8465545734894596, sigma_w_U = 0.004386592641224216
# w_N = 0.15929968638132147, sigma_w_N = 0.1123907734629865

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1.413 sec nello stato nativo e 5.293 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2977   0.1672 -826.92290   4.5644    0.00000
# 1      0.2297   0.0657 -826.91805   4.4785    0.00000
# 2     -0.0844   0.1005 -827.03200   4.5189    0.00196
# 3     -0.0565   0.1082 -826.31795   4.7007    0.00196
# 4     -0.1682   0.0463 -827.00405   4.6267    0.00391
# ...       ...      ...        ...      ...        ...
# 6701   0.2785   0.1623 -827.40260   4.4247    6.98828
# 6702  -0.3148   0.1275 -827.48900   4.6738    6.99024
# 6703   0.3972   0.1507 -827.36475   4.6805    6.99024
# 6704   0.4809   0.1662 -827.69450   4.5795    6.99219
# 6705   0.6415   0.1701 -827.80920   4.6738    6.99218
#
# [6706 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.626853640704255, con deviazione standard = 0.33368886545618826

# %%
prova = [0.6, 5., 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6002797115571347, mu_1 = 5.045577901461751, sigma_1 = 0.18269266833931763
# c_2 = 1.3518462927041175, mu_2 = 4.46479555886525, sigma_2 = 0.21278730707964022
# sigma_c_1 = 0.03616067657300098, sigma_mu_1 = 0.02178601744305418, sigma_sigma_1 = 0.02139562414768138
# sigma_c_2 = 0.03370996536953178, sigma_mu_2 = 0.01045202241226883, sigma_sigma_2 = 0.009308547443419288
# w_U = 0.7210459917175307, sigma_w_U = 0.00911818373055527
# w_N = 0.27489365665624, sigma_w_N = 0.06057501559437084

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2.107 sec nello stato nativo e 4.595 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.0216  -0.2050 -855.81165   4.6940    0.00000
# 1      0.3972  -0.3635 -855.61465   4.9229    0.00195
# 2      0.2017  -0.2398 -855.63855   4.9566    0.00391
# 3      0.0412  -0.2794 -855.24375   4.7765    0.00391
# 4     -0.3619  -0.2736 -855.51965   4.9583    0.00586
# ...       ...      ...        ...      ...        ...
# 6697   0.3710   0.1005 -855.49130   5.2360    6.99414
# 6698   0.4181   0.0367 -855.88185   5.2966    6.99609
# 6699  -0.1891  -0.0909 -855.23115   5.4279    6.99609
# 6700  -0.1839  -0.0445 -855.65340   5.2310    6.99805
# 6701  -0.3828  -0.1750 -855.56755   5.4027    6.99805
#
# [6702 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.926298556977062, con deviazione standard = 0.309240402079406

# %%
prova = [0.8, 5.1, 0.1, 1.2, 4.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.1282937025391878, mu_1 = 5.600884628000195, sigma_1 = 0.15422543123055493
# c_2 = 1.425971777640665, mu_2 = 4.886773265744797, sigma_2 = 0.2646233415628134
# sigma_c_1 = 0.030383812973742503, sigma_mu_1 = 0.0502413969518036, sigma_sigma_1 = 0.05182537728149237
# sigma_c_2 = 0.023184924532241972, sigma_mu_2 = 0.0056990128805318625, sigma_sigma_2 = 0.0061214257593792815
# w_U = 0.9458646909869692, sigma_w_U = 0.0009896160181867627
# w_N = 0.049596527042360894, sigma_w_N = 0.2746570898215296

# %% [markdown]
# # Is this $f_c$ ?? Try to take this data...

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 0.6970000000000001 sec nello stato nativo e 6.025 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1093   0.1266 -893.47605   4.4735    0.00000
# 1      0.7113   0.2745 -893.46555   4.4381    0.00000
# 2      1.1091   0.4021 -894.22455   4.2563    0.00000
# 3     -0.0914   0.3363 -894.07665   4.3573    0.00196
# 4     -0.2572   0.3122 -894.06060   4.4179    0.00391
# ...       ...      ...        ...      ...        ...
# 6717  -0.3008   0.2203 -891.35930   5.1249    6.99414
# 6718   0.0901   0.2087 -891.26535   4.9297    6.99610
# 6719   0.0621   0.2745 -891.07910   4.6098    6.99610
# 6720  -0.1473   0.1469 -891.07235   5.0441    6.99805
# 6721  -0.6149   0.0889 -891.63010   4.7883    6.99805
#
# [6722 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.183345162728494, con deviazione standard = 0.32254645948501076

# %% [markdown]
# # Drift?

# %%
prova = [.8, 4.5, 0.1, 1., 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2864412193921275, mu_1 = 4.232677735129901, sigma_1 = 0.2885636986191697
# c_2 = 0.1417609245418359, mu_2 = 3.62004158435169, sigma_2 = 0.19641879737428378
# sigma_c_1 = 0.02388509535940612, sigma_mu_1 = 0.01487730678420293, sigma_sigma_1 = 0.01355236833991042
# sigma_c_2 = 0.04987504071937907, sigma_mu_2 = 0.0943015318398184, sigma_sigma_2 = 0.06753082664346435
# w_U = 0.06979583684425643, sigma_w_U = 0.3643664041154819
# w_N = 0.9305111404848077, sigma_w_N = 0.0020893937551536516

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.473 sec nello stato nativo e 1.256 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2153  -0.3345 -879.47450   4.0998    0.00000
# 1      0.2454  -0.1924 -878.76005   4.0190    0.00195
# 2     -0.2363  -0.0822 -878.68600   3.8372    0.00195
# 3      0.0150  -0.0010 -878.36745   3.9281    0.00391
# 4     -0.9849  -0.0793 -878.47440   3.9129    0.00391
# ...       ...      ...        ...      ...        ...
# 6724  -0.2048   0.1411 -879.04120   4.3927    6.99414
# 6725  -0.5451   0.2890 -878.75310   3.9028    6.99609
# 6726  -0.0216   0.4543 -879.14280   3.9230    6.99609
# 6727   0.2558   0.5152 -879.46565   3.7412    6.99805
# 6728   0.3710   0.5152 -879.16735   3.7513    6.99805
#
# [6729 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(7)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.367594498813765, con deviazione standard = 0.30046366105718025

# %%
prova = [1., 4.5, 0.1, 0.7, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.03057541034352, mu_1 = 4.459318201710702, sigma_1 = 0.21558187930169162
# c_2 = 0.480757250408176, mu_2 = 4.252241462932937, sigma_2 = 0.37310587945841384
# sigma_c_1 = 0.22565860201938812, sigma_mu_1 = 0.01729799853940433, sigma_sigma_1 = 0.024862904775311973
# sigma_c_2 = 0.22098816723585737, sigma_mu_2 = 0.10250203352218669, sigma_sigma_2 = 0.03960810251740497
# w_U = 0.4496223276687001, sigma_w_U = 0.2576922925623692
# w_N = 0.5569060855129412, sigma_w_N = 0.10180775228272812

# %% [markdown]
# # I don't like this one.. or it could be $f_c$?!

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.593 sec nello stato nativo e 2.1510000000000002 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.3706   0.2435 -879.13550   4.5728    0.00000
# 1      0.2611   0.3354 -879.21855   4.4129    0.00000
# 2      0.0046   0.2919 -879.10955   4.4331    0.00195
# 3      0.2506   0.4398 -879.57545   4.4381    0.00195
# 4     -0.1996   0.3296 -879.55440   4.4230    0.00391
# ...       ...      ...        ...      ...        ...
# 6739  -0.4404   0.2832 -880.00385   4.3775    6.99414
# 6740  -0.0112   0.2687 -880.37365   4.3573    6.99610
# 6741  -0.2101   0.2745 -880.17350   4.6401    6.99610
# 6742   0.1040   0.3325 -880.36965   4.3927    6.99610
# 6743  -0.1158   0.2745 -880.27740   4.4280    6.99805
#
# [6744 rows x 5 columns]

# %%
forces_average
# Out:
# [4.861226072957635,
#  4.7551867301635005,
#  5.243828946872496,
#  3.9263596597407955,
#  4.3557798323218195]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.4484571995506546, con sigma = 2.902327203339769
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 13.484548800088039, con sigma = 6.033102662880842
# La differenza di energia libera DeltaG_NU = 59.98543819244377, con sigma = 28.48496343766019

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.5557872472868, con sigma = 14.987194661296375

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5076134867493347, con incertezza = 0.019488245655551694,
#  q1 = 5.08628525129367, con incertezza = 0.014027653587529965
# Stimiamo i parametri del fit lineare: m2 = 0.7401235547395139, con incertezza = 0.02969111378880468,
#  q2 = 3.671891190671215, con incertezza = 0.04627205904728204
# La forza di coesistenza qui vale: fc = 4.5108711400852615, con incertezza = 0.02797865420123592
# Il tempo medi di residenza vale: tc = 3.1067197330371172, con incertezza = 0.15665872473802375
# Stimiamo un nuovo DeltaG_NU = 60.82706201938848, con incertezza = 27.217163703957887
# ((-0.5076134867493347, 0.019488245655551694),
#  (5.08628525129367, 0.014027653587529965),
#  (0.7401235547395139, 0.02969111378880468),
#  (3.671891190671215, 0.04627205904728204),
#  (4.5108711400852615, 0.02797865420123592),
#  (3.1067197330371172, 0.15665872473802375),
#  (60.82706201938848, 27.217163703957887))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = 2
forces_average = remove_element(forces_average, post)
forces_average_std = remove_element(forces_average_std, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.447536784777019, con sigma = 2.94170973574129
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 13.432197527157417, con sigma = 6.092305209436566
# La differenza di energia libera DeltaG_NU = 59.74019260242353, con sigma = 28.76016181943627

# %%
f_c
# Out:
# (4.447536784777019, 2.94170973574129)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.54360820633273, con sigma = 15.168153275613218

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.5448590790179303, con incertezza = 0.029748463885330305,
#  q1 = 5.115473876687476, con incertezza = 0.02251739730916269
# Stimiamo i parametri del fit lineare: m2 = 0.6254419125861391, con incertezza = 0.03150524220548246,
#  q2 = 3.8086446117456076, con incertezza = 0.04794754486390256
# La forza di coesistenza qui vale: fc = 4.507051090722002, con incertezza = 0.03502260265100972
# Il tempo medi di residenza vale: tc = 3.05463717120981, con incertezza = 0.18726070447890936
# Stimiamo un nuovo DeltaG_NU = 60.53960051556821, con incertezza = 27.462360374632016

# %%
f_c, t_c
# Out:
# ((4.507051090722002, 0.03502260265100972),
#  (3.05463717120981, 0.18726070447890936))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.861226072957635,
#   4.7551867301635005,
#   3.9263596597407955,
#   4.3557798323218195],
#  [1.413, 2.107, 5.473, 4.593])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -2
forces_average = remove_element(forces_average, pos)
forces_average_std = remove_element(forces_average_std, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.442059867456368, con sigma = 3.074089236019497
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 13.186515958788616, con sigma = 6.252897224014751
# La differenza di energia libera DeltaG_NU = 58.57529333210784, con sigma = 29.524871855901377

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.471159514306486, con sigma = 15.764455777321944

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.36041594760179263, con incertezza = 0.03891275754974564,
#  q1 = 5.007492341237948, con incertezza = 0.02688309298456698
# Stimiamo i parametri del fit lineare: m2 = 0.5737584592227437, con incertezza = 0.060018007748361704,
#  q2 = 3.889462938257814, con incertezza = 0.09316623603808337
# La forza di coesistenza qui vale: fc = 4.576142880389962, con incertezza = 0.05613204961272598
# Il tempo medi di residenza vale: tc = 3.309543089351152, con incertezza = 0.4582497749812386
# Stimiamo un nuovo DeltaG_NU = 60.34338112195913, con incertezza = 28.62372301970333
# ((-0.36041594760179263, 0.03891275754974564),
#  (5.007492341237948, 0.02688309298456698),
#  (0.5737584592227437, 0.060018007748361704),
#  (3.889462938257814, 0.09316623603808337),
#  (4.576142880389962, 0.05613204961272598),
#  (3.309543089351152, 0.4582497749812386),
#  (60.34338112195913, 28.62372301970333))

# %%
grafici.write_on_txt()
