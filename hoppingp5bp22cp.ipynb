# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 22bs_hop-const-position

# %%
# directory name
dir_name = "P5bp_3bs_hop/22cp"
# molecule name is a number in these experimets
number = "22"

# %%
file = Txt_hop(dir_name, number, different_name='hopcp', first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0       0.2977   0.1672 -826.92290   4.5644  18061.60742
# 1       0.2297   0.0657 -826.91805   4.4785  18061.60742
# 2      -0.0844   0.1005 -827.03200   4.5189  18061.60938
# 3      -0.0565   0.1082 -826.31795   4.7007  18061.60938
# 4      -0.1682   0.0463 -827.00405   4.6267  18061.61133
# ...        ...      ...        ...      ...          ...
# 53526  -0.5556  -0.0938 -879.04965   4.9381  18180.42773
# 53527  -0.5713  -0.0184 -879.07080   4.9330  18180.42969
# 53528  -0.5137   0.0396 -879.12650   4.9078  18180.42969
# 53529   0.2297   0.2658 -879.11650   4.5391  18180.42969
# 53530   0.2611   0.2310 -879.39490   4.6553  18180.43160
#
# [53531 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.4440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.642407664777802, con deviazione standard = 0.3291096518608248

# %%
prova = [0.4, 5.1, 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# Out:
# c_1 = 0.33587627449052276, mu_1 = 5.188771322677314, sigma_1 = 0.18921068553769085
# c_2 = 1.4013758567595362, mu_2 = 4.533680823237956, sigma_2 = 0.2409963111631501
# sigma_c_1 = 0.03340674341804033, sigma_mu_1 = 0.033086921016926306, sigma_sigma_1 = 0.033278115150664984
# sigma_c_2 = 0.029395566648936805, sigma_mu_2 = 0.008900785605185898, sigma_sigma_2 = 0.008598805218072141
# w_U = 0.8465545734894596, sigma_w_U = 0.0065933156565146965
# w_N = 0.15929968638132147, sigma_w_N = 0.17104984884393892

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1395 sec nello stato nativo e 5311 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.2977   0.1672 -826.92290   4.5644    0.00000
# 1      0.2297   0.0657 -826.91805   4.4785    0.00000
# 2     -0.0844   0.1005 -827.03200   4.5189    0.00196
# 3     -0.0565   0.1082 -826.31795   4.7007    0.00196
# 4     -0.1682   0.0463 -827.00405   4.6267    0.00391
# ...       ...      ...        ...      ...        ...
# 6701   0.2785   0.1623 -827.40260   4.4247    6.98828
# 6702  -0.3148   0.1275 -827.48900   4.6738    6.99024
# 6703   0.3972   0.1507 -827.36475   4.6805    6.99024
# 6704   0.4809   0.1662 -827.69450   4.5795    6.99219
# 6705   0.6415   0.1701 -827.80920   4.6738    6.99218
#
# [6706 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.651557263087022, con deviazione standard = 0.3247803355468111

# %%
prova = [0.6, 5., 0.1, 1.5, 4.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.4804937667976985, mu_1 = 5.027302550035193, sigma_1 = 0.23368958362670575
# c_2 = 1.3102812010204579, mu_2 = 4.503915279453943, sigma_2 = 0.21825821099158152
# sigma_c_1 = 0.0386830961757432, sigma_mu_1 = 0.056170647927337454, sigma_sigma_1 = 0.04113758592114002
# sigma_c_2 = 0.06860744287073858, sigma_mu_2 = 0.018977607461765515, sigma_sigma_2 = 0.009966381766004622
# w_U = 0.7168446286085823, sigma_w_U = 0.019554484062219622
# w_N = 0.2814602357644176, sigma_w_N = 0.1387603712307006

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3982 sec nello stato nativo e 7900 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.0216  -0.2050 -855.81165   4.6940    0.00000
# 1       0.3972  -0.3635 -855.61465   4.9229    0.00195
# 2       0.2017  -0.2398 -855.63855   4.9566    0.00391
# 3       0.0412  -0.2794 -855.24375   4.7765    0.00391
# 4      -0.3619  -0.2736 -855.51965   4.9583    0.00586
# ...        ...      ...        ...      ...        ...
# 11877  -0.6655  -0.2504 -855.57675   5.2310   12.40430
# 11878  -1.0739  -0.1228 -855.05015   5.2714   12.40625
# 11879  -0.1944  -0.0358 -855.52925   5.5390   12.40820
# 11880   0.0883  -0.0561 -855.27945   5.4128   12.41016
# 11881  -0.3724  -0.1460 -855.67370   5.2663   12.41015
#
# [11882 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.896284656556633, con deviazione standard = 0.3487682031866056

# %%
prova = [0.8, 5.1, 0.1, 1.2, 4.7, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.302561213607946, mu_1 = 4.933021339376278, sigma_1 = 0.15273495482610056
# c_2 = 0.9707172835623162, mu_2 = 4.886798680675005, sigma_2 = 0.3607645254234785
# sigma_c_1 = 0.10822475794715358, sigma_mu_1 = 0.021720787390895974, sigma_sigma_1 = 0.03976269707580088
# sigma_c_2 = 0.1147656171886159, sigma_mu_2 = 0.01110693084035031, sigma_sigma_2 = 0.01818470739929296
# w_U = 0.8778221244745998, sigma_w_U = 0.014887696450041158
# w_N = 0.11583548689309052, sigma_w_N = 0.3883525445862449

# %% [markdown]
# # Is this $f_c$ ?? Try to take this data...

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4204 sec nello stato nativo e 7006 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1093   0.1266 -893.47605   4.4735    0.00000
# 1       0.7113   0.2745 -893.46555   4.4381    0.00000
# 2       1.1091   0.4021 -894.22455   4.2563    0.00000
# 3      -0.0914   0.3363 -894.07665   4.3573    0.00196
# 4      -0.2572   0.3122 -894.06060   4.4179    0.00391
# ...        ...      ...        ...      ...        ...
# 11205  -0.0321   0.1759 -890.89985   3.9836   11.67969
# 11206  -0.6603   0.0889 -890.67610   3.8321   11.68360
# 11207  -0.2206   0.0193 -890.89020   4.3472   11.68360
# 11208   0.4286   0.0483 -891.01035   4.1351   11.68555
# 11209   0.7584   0.0222 -890.80480   4.7866   11.68554
#
# [11210 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.296821030353105, con deviazione standard = 0.3739059281454826

# %% [markdown]
# # Drift?

# %%
prova = [.8, 4.5, 0.1, 1., 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.20516601442169022, mu_1 = 4.788306219712519, sigma_1 = 0.1910465490012269
# c_2 = 1.074953537057903, mu_2 = 4.248271465578275, sigma_2 = 0.32889597754633054
# sigma_c_1 = 0.060712041287475906, sigma_mu_1 = 0.04669513075413887, sigma_sigma_1 = 0.04480435746562848
# sigma_c_2 = 0.024690643594258023, sigma_mu_2 = 0.021536740825685904, sigma_sigma_2 = 0.013791903795435528
# w_U = 0.8862131485080743, sigma_w_U = 0.004697596158934999
# w_N = 0.09825045113834242, sigma_w_N = 0.3346162889597861

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2375 sec nello stato nativo e 7311 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0     -0.2153  -0.3345 -879.47450   4.0998    0.00000
# 1      0.2454  -0.1924 -878.76005   4.0190    0.00195
# 2     -0.2363  -0.0822 -878.68600   3.8372    0.00195
# 3      0.0150  -0.0010 -878.36745   3.9281    0.00391
# 4     -0.9849  -0.0793 -878.47440   3.9129    0.00391
# ...       ...      ...        ...      ...        ...
# 9681  -0.0146   0.5451 -879.46025   4.5055   10.07226
# 9682  -0.0844   0.4137 -878.98145   4.6452   10.07226
# 9683   0.0988   0.4659 -879.44315   4.2967   10.07422
# 9684   0.7636   0.5239 -878.93515   4.1957   10.07422
# 9685   0.5595   0.5529 -879.28040   4.0947   10.07613
#
# [9686 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.321365352032454, con deviazione standard = 0.31519871574115266

# %%
prova = [0.8, 4.7, 0.1, 1.5, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8907122462724414, mu_1 = 4.435151259695753, sigma_1 = 0.20996141291869497
# c_2 = 0.5699666121129074, mu_2 = 4.216320344519382, sigma_2 = 0.375810637438176
# sigma_c_1 = 0.17941752480362352, sigma_mu_1 = 0.016966937946921452, sigma_sigma_1 = 0.02421998417274442
# sigma_c_2 = 0.17377783259131604, sigma_mu_2 = 0.07396519130602244, sigma_sigma_2 = 0.028992665820931164
# w_U = 0.5369185627582334, sigma_w_U = 0.14743061598028534
# w_N = 0.46877759244561323, sigma_w_N = 0.12463140386854456

# %% [markdown]
# # I don't like this one.. or it could be $f_c$?!

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7739 sec nello stato nativo e 6308 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.3706   0.2435 -879.13550   4.5728    0.00000
# 1       0.2611   0.3354 -879.21855   4.4129    0.00000
# 2       0.0046   0.2919 -879.10955   4.4331    0.00195
# 3       0.2506   0.4398 -879.57545   4.4381    0.00195
# 4      -0.1996   0.3296 -879.55440   4.4230    0.00391
# ...        ...      ...        ...      ...        ...
# 14042  -0.5556  -0.0938 -879.04965   4.9381   14.62695
# 14043  -0.5713  -0.0184 -879.07080   4.9330   14.62891
# 14044  -0.5137   0.0396 -879.12650   4.9078   14.62891
# 14045   0.2297   0.2658 -879.11650   4.5391   14.62891
# 14046   0.2611   0.2310 -879.39490   4.6553   14.63082
#
# [14047 rows x 5 columns]

# %%
forces_average
# Out:
# [4.861226072957635,
#  4.765608914744568,
#  4.909910010025642,
#  4.518288842645397,
#  4.325735802107568]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.262929552397243, con sigma = 3.7065656040262542
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 8.75411861124101, con sigma = 5.218535998584211
# La differenza di energia libera DeltaG_NU = 37.31819093305001, con sigma = 23.621145326197713

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -21.240825049780852, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.360143218649877, con incertezza = 1.2871305432460325,
#  q1 = 14.480391332530138, con incertezza = 6.025549718974377
# Stimiamo i parametri del fit lineare: m2 = -0.04280596100469644, con incertezza = 0.3577406396540133,
#  q2 = 9.010844266027608, con incertezza = 1.6747207033407858
# La forza di coesistenza qui vale: fc = 4.151971740539453, con incertezza = 6.3456020363359755
# Il tempo medi di residenza vale: tc = 6857.6159119149515, con incertezza = 31741.10602200013
# Stimiamo un nuovo DeltaG_NU = 36.34685308720316, con incertezza = 59.62623288336193
# ((-1.360143218649877, 1.2871305432460325),
#  (14.480391332530138, 6.025549718974377),
#  (-0.04280596100469644, 0.3577406396540133),
#  (9.010844266027608, 1.6747207033407858),
#  (4.151971740539453, 6.3456020363359755),
#  (6857.6159119149515, 31741.10602200013),
#  (36.34685308720316, 59.62623288336193))

# %% [markdown]
# ### Vediamo cosa accade eliminando l'ultimo punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
post = -2
forces_average = remove_element(forces_average, post)
w_U = remove_element(w_U, post)
w_N = remove_element(w_N, post)
sigma_w_U = remove_element(sigma_w_U, post)
sigma_w_N = remove_element(sigma_w_N, post)
native_time = remove_element(native_time, post)
unfolded_time = remove_element(unfolded_time, post)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.2686244319284254, con sigma = 3.707958157876987
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 8.756391286962971, con sigma = 5.218537957142134
# La differenza di energia libera DeltaG_NU = 37.377745783055325, con sigma = 23.62146041463847

# %%
f_c
# Out:
# (4.2686244319284254, 3.707958157876987)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -21.273833786292464, con sigma = None

# %%
m1, q_1, m2, q_2, f_c, t_c, DeltaGNU = grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.8797932081311348, con incertezza = 1.3369860921942072,
#  q1 = 17.071392991545363, con incertezza = 6.312279154470512
# Stimiamo i parametri del fit lineare: m2 = 0.030873451874208105, con incertezza = 0.4457230799974794,
#  q2 = 8.643474934871648, con incertezza = 2.104381723009741
# La forza di coesistenza qui vale: fc = 4.410982948040841, con incertezza = 4.765850204110889
# Il tempo medi di residenza vale: tc = 6500.648399227336, con incertezza = 31267.386536314418
# Stimiamo un nuovo DeltaG_NU = 38.62429265316706, con incertezza = 47.65920132597112

# %%
f_c, t_c
# Out:
# ((4.410982948040841, 4.765850204110889),
#  (6500.648399227336, 31267.386536314418))

# %% [markdown]
# ### Tolgo un altro punto

# %%
forces_average, native_time
# Out:
# ([4.861226072957635, 4.765608914744568, 4.909910010025642, 4.325735802107568],
#  [1395, 3982, 4204, 7739])

# %%
# proviamo ad eliminare l'ultimo punto, quello più in alto
pos = -2
forces_average = remove_element(forces_average, pos)
w_U = remove_element(w_U, pos)
w_N = remove_element(w_N, pos)
sigma_w_U = remove_element(sigma_w_U, pos)
sigma_w_N = remove_element(sigma_w_N, pos)
native_time = remove_element(native_time, pos)
unfolded_time = remove_element(unfolded_time, pos)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.266484160606808, con sigma = 3.814874352204835
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 8.600640649586213, con sigma = 5.276614563321237
# La differenza di energia libera DeltaG_NU = 36.694497102530626, con sigma = 23.86845468597324

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -2.6770147155504262, con incertezza = 1.4080699078662067,
#  q1 = 20.611818087409908, con incertezza = 6.556957814302374
# Stimiamo i parametri del fit lineare: m2 = -0.06355405058742794, con incertezza = 0.6943503593616629,
#  q2 = 9.062823285429438, con incertezza = 3.2333804827359423
# La forza di coesistenza qui vale: fc = 4.419042902313581, con incertezza = 3.856464947839021
# Il tempo medi di residenza vale: tc = 6515.734410293578, con incertezza = 36566.93155298896
# Stimiamo un nuovo DeltaG_NU = 38.00660001790362, con incertezza = 40.54418129884791
# ((-2.6770147155504262, 1.4080699078662067),
#  (20.611818087409908, 6.556957814302374),
#  (-0.06355405058742794, 0.6943503593616629),
#  (9.062823285429438, 3.2333804827359423),
#  (4.419042902313581, 3.856464947839021),
#  (6515.734410293578, 36566.93155298896),
#  (38.00660001790362, 40.54418129884791))
