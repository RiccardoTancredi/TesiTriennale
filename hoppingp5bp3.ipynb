# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 2bs_hop-constposition

# %%
# directory name
dir_name = "P5bp_3bs_hop/2cp"
# molecule name is a number in these experimets
number = "2"

# %%
file = Txt_hop(dir_name, number, "_constpos", first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0       0.4181  -0.0259  289.72955   0.6917  10742.13477
# 1       0.2139  -0.1071  289.44350   0.7674  10742.13672
# 2       0.0307  -0.2782  289.66460   0.8583  10742.13672
# 3      -0.4824  -0.1245  289.13545   0.6765  10742.13867
# 4       0.0830   0.0031  289.43655   0.6361  10742.13965
# ...        ...      ...        ...      ...          ...
# 72389   1.1579   0.4825  338.75835   4.1374  10882.96973
# 72390   0.7042   0.4400  338.87120   4.2317  10882.97168
# 72391   0.0621   0.5425  338.81110   4.0196  10882.97168
# 72392   0.1301   0.5280  338.76570   4.0297  10882.97266
# 72393   0.5018   0.5599  339.04785   4.0196  10882.97460
#
# [72394 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 0.6937366604593382, con deviazione standard = 0.1135309456605055

# %% [markdown]
# ## $f_y$ troppo bassa -> no fit

# %%
# prova = [0.2, 4.8, 0.1, 2.1, 4.2, 0.2]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.4181  -0.0259  289.72955   0.6917    0.00000
# 1      0.2139  -0.1071  289.44350   0.7674    0.00195
# 2      0.0307  -0.2782  289.66460   0.8583    0.00195
# 3     -0.4824  -0.1245  289.13545   0.6765    0.00390
# 4      0.0830   0.0031  289.43655   0.6361    0.00488
# ...       ...      ...        ...      ...        ...
# 8050   0.5856  -0.3140  289.70235   0.8785    8.37988
# 8051   0.1807  -0.0781  289.54545   0.6900    8.38085
# 8052   0.1772   0.0002  289.88585   0.6462    8.38281
# 8053   0.4233   0.0988  289.95560   0.5503    8.38378
# 8054   0.3238   0.1162  289.79655   0.5654    8.38373
#
# [8055 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.985117502589153, con deviazione standard = 0.24284552155702754

# %%
prova = [0.3, 3.6, 0.1, 2., 2.9, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.21361264182595469, mu_1 = 3.594360723664712, sigma_1 = 0.12241159888627517
# c_2 = 1.9610083403406955, mu_2 = 2.934094806328663, sigma_2 = 0.1917849220217352
# sigma_c_1 = 0.060429664098694366, sigma_mu_1 = 0.04128069328079812, sigma_sigma_1 = 0.04255374948500426
# sigma_c_2 = 0.047828056418479814, sigma_mu_2 = 0.005479080146638873, sigma_sigma_2 = 0.005692746452694069
# w_U = 0.9427224190370923, sigma_w_U = 0.002518094270914486
# w_N = 0.06554498310363202, sigma_w_N = 0.42251882785208483

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)
# Out:
# La molecola sta 1112 sec nello stato nativo e 12406 sec nello stato unfolded
# (1112, 12406)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.7112   0.2467  341.24580   2.9187    0.00000
# 1       1.4022   0.4729  341.44380   2.6763    0.00098
# 2       1.3464   0.4477  341.19820   2.7638    0.00195
# 3       0.9625   0.5057  341.19770   2.8581    0.00195
# 4       0.5926   0.5173  341.30135   2.7773    0.00293
# ...        ...      ...        ...      ...        ...
# 13513   0.8526   0.6701  340.59500   2.9339   14.09668
# 13514   0.4966   0.6034  340.41855   2.8935   14.09863
# 13515   0.6065   0.5048  340.34930   3.0147   14.09863
# 13516   0.7793   0.5454  340.53445   2.8985   14.10059
# 13517   1.2714   0.5309  340.57490   2.8834   14.10053
#
# [13518 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.772135959510188, con deviazione standard = 0.24922541462831618

# %%
prova = [3.5, 2.9, 0.2, 0.8, 2.4, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.884880094135304, mu_1 = 2.9032723938136655, sigma_1 = 0.09908045372544941
# c_2 = 0.6760130027897567, mu_2 = 2.4235848410403227, sigma_2 = 0.16226379971451338
# sigma_c_1 = 0.05352285472682947, sigma_mu_1 = 0.0023589125119015007, sigma_sigma_1 = 0.002443295192046782
# sigma_c_2 = 0.041954475265599485, sigma_mu_2 = 0.01243257719407974, sigma_sigma_2 = 0.013395703419688527
# w_U = 0.27495816782995947, sigma_w_U = 0.07399913594798636
# w_N = 0.7164826660709503, sigma_w_N = 0.00848508113938126

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)
# Out:
# La molecola sta 10081 sec nello stato nativo e 4046 sec nello stato unfolded
# (10081, 4046)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.0411  -0.1129  326.40025   3.0197    0.00000
# 1       0.0202   0.1597  326.42525   2.8177    0.00196
# 2      -0.1892   0.1113  325.77120   2.8716    0.00196
# 3       0.3203   0.1191  326.21825   2.8514    0.00391
# 4      -0.0705   0.1191  326.12855   2.7706    0.00489
# ...        ...      ...        ...      ...        ...
# 14122   0.8526   0.0756  326.56635   2.9137   14.74805
# 14123   0.4756  -0.0926  326.67055   2.9945   14.75000
# 14124   0.5280  -0.0665  326.66375   3.0298   14.75098
# 14125   0.5960   0.0959  326.82200   2.9137   14.75098
# 14126   0.1930  -0.0027  326.57135   2.9490   14.75187
#
# [14127 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.4255457042736013, con deviazione standard = 0.24258831079624657

# %%
prova = [2.5, 3.5, 0.1, 0.5, 3., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 2.2454456771826328, mu_1 = 3.5396043401128847, sigma_1 = 0.13075761842532152
# c_2 = 0.507816156900352, mu_2 = 3.116017933413766, sigma_2 = 0.20911161404360962
# sigma_c_1 = 0.05540986395563053, sigma_mu_1 = 0.004867634296118132, sigma_sigma_1 = 0.00437414315939607
# sigma_c_2 = 0.031595466895666315, sigma_mu_2 = 0.03384361846304211, sigma_sigma_2 = 0.02713547061337585
# w_U = 0.2661794986984141, sigma_w_U = 0.10591357918439548
# w_N = 0.7359689445711104, sigma_w_N = 0.011064838078260615

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)
# Out:
# La molecola sta 17473 sec nello stato nativo e 7354 sec nello stato unfolded
# (17473, 7354)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.6536   0.4468  333.45485   2.8834    0.00000
# 1       1.1667   0.5512  333.00010   2.6864    0.00196
# 2       0.9573   0.5106  333.06910   2.8026    0.00293
# 3       0.6850   0.4497  332.99115   2.9440    0.00293
# 4       1.0358   0.3308  333.49490   3.0096    0.00391
# ...        ...      ...        ...      ...        ...
# 24822   1.1195   0.4845  332.90345   3.4742   25.90430
# 24823   1.0253   0.4642  333.55740   3.5096   25.90430
# 24824   0.6327   0.3511  333.52890   3.6459   25.90625
# 24825   0.7060   0.2409  333.32395   3.7267   25.90625
# 24826   0.7461   0.1655  333.01880   3.7334   25.90816
#
# [24827 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.269560849414391, con deviazione standard = 0.28155409673942094

# %%
prova = [0.7, 4.8, 0.1, 2., 4.2, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6709731948965406, mu_1 = 4.7838196612717825, sigma_1 = 0.09485394362169376
# c_2 = 1.87726713257131, mu_2 = 4.164239683689394, sigma_2 = 0.17918899534751564
# sigma_c_1 = 0.06593382650601691, sigma_mu_1 = 0.011122411042518094, sigma_sigma_1 = 0.010947275748990768
# sigma_c_2 = 0.046484811461164045, sigma_mu_2 = 0.005171387364493342, sigma_sigma_2 = 0.005246348686729871
# w_U = 0.8431936849257468, sigma_w_U = 0.006117363684622269
# w_N = 0.1595329869181638, sigma_w_N = 0.12781022561758953

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)
# Out:
# La molecola sta 2048 sec nello stato nativo e 9819 sec nello stato unfolded
# (2048, 9819)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.9782   0.6556  339.46525   4.3024    0.00000
# 1       1.4441   0.6527  340.02395   4.3529    0.00097
# 2       2.0409   0.7687  339.51565   4.1812    0.00390
# 3       2.0671   0.7948  339.34300   4.1105    0.00488
# 4       2.0828   0.7455  339.38690   4.1812    0.00488
# ...        ...      ...        ...      ...        ...
# 11862   1.1579   0.4825  338.75835   4.1374   12.39746
# 11863   0.7042   0.4400  338.87120   4.2317   12.39941
# 11864   0.0621   0.5425  338.81110   4.0196   12.39941
# 11865   0.1301   0.5280  338.76570   4.0297   12.40039
# 11866   0.5018   0.5599  339.04785   4.0196   12.40233
#
# [11867 rows x 5 columns]

# %%
forces_average
# Out:
# [3.2642277649966873, 2.663428617426994, 3.3278111367633256, 4.474029672480588]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 3.7244473037357793, con sigma = 1.9070905836890069
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = -4.364418019266748, con sigma = 1.7333894413084168
# La differenza di energia libera DeltaG_NU = -16.25504492423389, con sigma = 5.253486913555356

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -18.062483287816733, con sigma = None

# %% [markdown]
# # O sono due molecole diverse?

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# forces_average = remove_element(forces_average, 3)
# w_U = remove_element(w_U, 3)
# w_N = remove_element(w_N, 3)
# sigma_w_U = remove_element(sigma_w_U, 3)
# sigma_w_N = remove_element(sigma_w_N, 3)

# %%
# x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:3], w_N[:3], forces_average[:3], sigma_w_U[:3], sigma_w_N[:3])

# %%
# x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[3:], w_N[3:], forces_average[3:], sigma_w_U[3:], sigma_w_N[3:])
