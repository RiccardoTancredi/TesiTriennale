# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 6bs_hop-passive

# %%
# directory name
dir_name = "P5bp_3bs_hop/6passive"
# molecule name is a number in these experimets
number = "6"

# %%
file = Txt_hop(dir_name, number, different_name="hoppas", first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force    time(sec)
# 0       -0.2864   0.2184  223.95830   4.7555  11401.48633
# 1       -0.2236   0.2068  223.62470   5.0030  11401.48730
# 2       -0.5481   0.1140  223.70035   4.8565  11401.48730
# 3       -0.9355   0.0299  223.68315   4.9222  11401.48828
# 4       -0.2340   0.0560  223.65340   5.0333  11401.49023
# ...         ...      ...        ...      ...          ...
# 121677  -0.6738  -0.0629  153.58715   3.7354  11561.22656
# 121678  -0.4644  -0.0774  153.58955   3.7708  11561.22656
# 121679  -0.9146  -0.0571  153.59490   3.5789  11561.22852
# 121680   0.2109   0.0560  153.76335   3.7203  11561.22949
# 121681   0.1097   0.0009  153.62310   3.7338  11561.23047
#
# [121682 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.9919727297296825, con deviazione standard = 0.25935274672279746

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [2., 4.9, 0.1, 0.5, 4.4, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2864   0.2184  223.95830   4.7555    0.00000
# 1      -0.2236   0.2068  223.62470   5.0030    0.00097
# 2      -0.5481   0.1140  223.70035   4.8565    0.00097
# 3      -0.9355   0.0299  223.68315   4.9222    0.00195
# 4      -0.2340   0.0560  223.65340   5.0333    0.00390
# ...        ...      ...        ...      ...        ...
# 11095  -0.4905   0.1691  223.34500   5.3565   11.56445
# 11096  -0.9146   0.0618  223.10070   5.1040   11.56640
# 11097  -0.6930   0.0395  223.44575   4.9121   11.56738
# 11098  -0.1974   0.1285  223.43910   4.8313   11.56738
# 11099  -0.2742   0.2213  223.01265   5.1208   11.56827
#
# [11100 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.790300143562663, con deviazione standard = 0.2509072066884676

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [0.4, 4.9, 0.1, 1.4, 4.3, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par, True, 500)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1516   0.6079  215.37285   4.2926    0.00000
# 1      -0.1834   0.5422  214.98060   4.6158    0.00391
# 2       0.1272   0.5287  215.45720   4.6545    0.00391
# 3       0.2319   0.4591  215.54035   4.4576    0.00586
# 4      -0.1607   0.4446  215.91135   4.3162    0.00684
# ...        ...      ...        ...      ...        ...
# 17409  -0.0560   0.2677  217.47780   4.7303   18.13672
# 17410  -0.6947   0.1140  217.63580   4.6141   18.13868
# 17411  -0.4330   0.1198  217.74945   4.7353   18.13965
# 17412  -0.4696   0.2483  218.01785   4.7842   18.14063
# 17413  -0.4277   0.3682  217.66590   4.7236   18.14156
#
# [17414 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.585022233046098, con deviazione standard = 0.32995586121741904

# %%
prova = [1., 4.8, 0.1, 1.2, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.7476344103036818, mu_1 = 4.91254056862555, sigma_1 = 0.19802492563849458
# c_2 = 1.1889758847686407, mu_2 = 4.3860570970344, sigma_2 = 0.2103221126642307
# sigma_c_1 = 0.045964766062100135, sigma_mu_1 = 0.03312734799547201, sigma_sigma_1 = 0.02785022032440268
# sigma_c_2 = 0.054738909934854786, sigma_mu_2 = 0.021817647689065855, sigma_sigma_2 = 0.01486397321869586
# w_U = 0.6268273188285143, sigma_w_U = 0.03130117896312304
# w_N = 0.371106938969196, sigma_w_N = 0.09621222706067475

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5339 sec nello stato nativo e 8006 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.1607   0.3576  204.09565   4.1394    0.00000
# 1      -0.6301   0.3527  204.28950   4.1378    0.00000
# 2      -0.6581   0.3141  204.51790   4.1647    0.00098
# 3      -0.1660   0.3489  204.37780   4.1647    0.00293
# 4      -0.1136   0.2213  204.19700   4.6091    0.00391
# ...        ...      ...        ...      ...        ...
# 13340  -0.3701   0.4446  205.67900   4.2859   13.88379
# 13341  -0.4347   0.4185  205.53270   4.4677   13.88477
# 13342  -0.8814   0.2406  205.41450   4.4206   13.88672
# 13343  -0.5185   0.2290  205.74745   4.7505   13.88770
# 13344  -0.6581   0.1865  205.31065   4.5687   13.88766
#
# [13345 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.3711943122155965, con deviazione standard = 0.30337333112953413

# %%
prova = [0.8, 4.7, 0.1, 1.4, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.45985103203290506, mu_1 = 4.754457931795554, sigma_1 = 0.20373380433058733
# c_2 = 1.3893771337307244, mu_2 = 4.25128962760163, sigma_2 = 0.2197083403001734
# sigma_c_1 = 0.04390628169751732, sigma_mu_1 = 0.048753748300571664, sigma_sigma_1 = 0.03616947955957348
# sigma_c_2 = 0.0522826044702374, sigma_mu_2 = 0.017440373681634407, sigma_sigma_2 = 0.01018634413684802
# w_U = 0.765167692418628, sigma_w_U = 0.014022789992150102
# w_N = 0.2348389849457382, sigma_w_N = 0.15424210153321516

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3401 sec nello stato nativo e 8027 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.6999   0.0666  199.06560   4.1243    0.00000
# 1      -0.2497   0.1053  198.47495   4.3970    0.00098
# 2      -0.4905   0.0705  198.98320   4.3263    0.00196
# 3      -0.4487   0.0589  198.30535   4.2724    0.00196
# 4      -0.6022   0.0782  198.60840   4.4610    0.00391
# ...        ...      ...        ...      ...        ...
# 11423  -0.2811   0.2271  198.74825   4.3667   11.92090
# 11424  -0.2497   0.3112  198.91645   4.2657   11.92188
# 11425   0.2842   0.4881  198.89750   4.2202   11.92188
# 11426  -0.1084   0.5258  198.89845   4.0132   11.92285
# 11427  -0.2288   0.6244  199.09135   3.9273   11.92476
#
# [11428 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.409803926115463, con deviazione standard = 0.3236724984728712

# %%
prova = [1., 4.8, 0.1, 1., 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.9076081318675433, mu_1 = 4.657740235614398, sigma_1 = 0.2154237239196061
# c_2 = 0.9997544201097365, mu_2 = 4.1701632422170665, sigma_2 = 0.20207696256327148
# sigma_c_1 = 0.039264793163959776, sigma_mu_1 = 0.027962331005945702, sigma_sigma_1 = 0.02068625366228594
# sigma_c_2 = 0.06853216331762091, sigma_mu_2 = 0.023544701320700544, sigma_sigma_2 = 0.012608852358348233
# w_U = 0.5064074339819081, sigma_w_U = 0.04542925270336512
# w_N = 0.4900967714674971, sigma_w_N = 0.05333544275091301

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6123 sec nello stato nativo e 6383 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.5115   0.1091  193.21240   4.1849    0.00000
# 1      -0.4626   0.0666  193.19570   4.2926    0.00000
# 2      -0.4556   0.1130  193.20685   4.0637    0.00098
# 3      -0.6162   0.1169  193.10250   3.9627    0.00293
# 4      -0.8884   0.0241  192.76285   3.9627    0.00293
# ...        ...      ...        ...      ...        ...
# 12501  -0.2811   0.2880  194.06820   4.3111   13.03613
# 12502   0.0225   0.2706  194.18855   4.4374   13.03809
# 12503  -0.0299   0.2155  193.67750   4.4323   13.03809
# 12504  -0.7942   0.2532  193.95010   4.3869   13.04004
# 12505  -0.8622   0.1807  194.35045   4.6091   13.03999
#
# [12506 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.409067566030596, con deviazione standard = 0.33632661681652454

# %%
prova = [1.2, 4.8, 0.1, .8, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.1489885612620054, mu_1 = 4.6398078626584764, sigma_1 = 0.19400269606898518
# c_2 = 0.7941384686860582, mu_2 = 4.110048493194998, sigma_2 = 0.21940517087988518
# sigma_c_1 = 0.03278996453515736, sigma_mu_1 = 0.013903444317862987, sigma_sigma_1 = 0.011487853226532249
# sigma_c_2 = 0.03379804004996677, sigma_mu_2 = 0.02225457918123725, sigma_sigma_2 = 0.015569421841040994
# w_U = 0.43675011394888796, sigma_w_U = 0.04623388956313432
# w_N = 0.5587446846018803, sigma_w_N = 0.02870890441727956

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8816 sec nello stato nativo e 7010 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.3160   0.2715  187.27610   4.5889    0.00000
# 1      -0.2079   0.2039  187.34790   4.6293    0.00098
# 2      -0.3858   0.2561  187.55410   4.4677    0.00195
# 3       0.2633   0.1323  187.21475   4.8650    0.00293
# 4       0.5285   0.3682  187.21875   4.6562    0.00488
# ...        ...      ...        ...      ...        ...
# 15821   0.1586   0.2677  188.64415   4.6192   16.50684
# 15822   0.9857   0.2300  188.50750   4.5939   16.50781
# 15823   0.0277   0.1024  188.48125   4.4020   16.50977
# 15824  -0.4905   0.3199  188.44210   4.3212   16.51074
# 15825  -0.6022   0.1671  188.61825   4.3936   16.51070
#
# [15826 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.262797070371513, con deviazione standard = 0.3106926677059536

# %%
prova = [1., 4.5, 0.1, 0.5, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.3812259683518755, mu_1 = 4.4015453447053785, sigma_1 = 0.21060917732454412
# c_2 = 0.5570540032402174, mu_2 = 3.8875543213797266, sigma_2 = 0.19016070605328772
# sigma_c_1 = 0.028213952253702938, sigma_mu_1 = 0.012798224772411599, sigma_sigma_1 = 0.01095225635842737
# sigma_c_2 = 0.044516735882155815, sigma_mu_2 = 0.02902397299328503, sigma_sigma_2 = 0.019043354679102623
# w_U = 0.26552658810537483, sigma_w_U = 0.0934228578554515
# w_N = 0.7291753198010763, sigma_w_N = 0.014835163069447883

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8981 sec nello stato nativo e 4263 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2742   0.5886  180.57110   4.0368    0.00000
# 1      -0.3021   0.7317  180.74950   4.0031    0.00098
# 2      -0.8675   0.8245  180.94595   3.7001    0.00196
# 3      -0.1346   0.7549  180.64435   4.0098    0.00293
# 4       0.2319   0.7346  180.81955   4.0788    0.00489
# ...        ...      ...        ...      ...        ...
# 13239  -0.0019   0.2135  181.47860   3.9829   13.81836
# 13240  -0.4207   0.0975  181.03395   4.0906   13.81934
# 13241   0.1097   0.2019  181.07555   4.1108   13.81934
# 13242  -0.4539   0.2184  180.97625   3.8112   13.82129
# 13243  -0.0246   0.2271  181.06145   3.9374   13.82224
#
# [13244 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7929066874756194, con deviazione standard = 0.2588214347325467

# %% [markdown]
# ## Suspicious data!

# %%
# prova = [1., 4.8, 0.1, 1., 4.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.0068  -0.1441  166.48940   4.1041    0.00000
# 1      -0.1189  -0.0136  166.34430   4.0334    0.00195
# 2      -0.3440  -0.0223  166.86250   3.9223    0.00195
# 3       0.1167   0.0183  166.68655   3.9223    0.00390
# 4       0.3994  -0.0078  166.49665   3.9879    0.00390
# ...        ...      ...        ...      ...        ...
# 12810  -0.1817  -0.0658  165.27400   3.4375   13.38672
# 12811   0.3523   0.0241  165.75705   3.3365   13.38867
# 12812  -0.4016  -0.0281  165.67990   3.0840   13.38965
# 12813  -0.2759  -0.0426  165.76265   3.0739   13.38965
# 12814  -0.1607  -0.1296  165.91855   3.3870   13.39056
#
# [12815 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.491995222793455, con deviazione standard = 0.23460046122552372

# %% [markdown]
# # Suspicious data!

# %%
# prova = [1., 4.8, 0.1, 1., 4.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.7209   0.1053  153.88465   3.1412    0.00000
# 1      -0.2323   0.0318  153.65980   3.3028    0.00195
# 2      -0.2602  -0.0803  153.78485   3.4375    0.00293
# 3      -0.7837   0.0125  153.75550   3.2355    0.00391
# 4      -0.4766   0.0125  153.64195   3.2288    0.00391
# ...        ...      ...        ...      ...        ...
# 13999  -0.6738  -0.0629  153.58715   3.7354   14.57324
# 14000  -0.4644  -0.0774  153.58955   3.7708   14.57324
# 14001  -0.9146  -0.0571  153.59490   3.5789   14.57520
# 14002   0.2109   0.0560  153.76335   3.7203   14.57617
# 14003   0.1097   0.0009  153.62310   3.7338   14.57708
#
# [14004 rows x 5 columns]

# %%
forces_average
# Out:
# [4.649298832829976,
#  4.502873779698592,
#  4.413951738915732,
#  4.374928177926737,
#  4.144549833042553]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.434270351351134, con sigma = 1.603446550288826
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 13.109107739598253, con sigma = 3.36276488903554
# La differenza di energia libera DeltaG_NU = 58.129327782368215, con sigma = 14.814855141288175

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -22.228165521363994, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.4709155659937743, con incertezza = 0.9174820536759054,
#  q1 = 15.221534445373509, con incertezza = 4.0554805963873
# Stimiamo i parametri del fit lineare: m2 = 1.2983825754863187, con incertezza = 0.310739370498793,
#  q2 = 3.055433256531356, con incertezza = 1.3735390996830146
# La forza di coesistenza qui vale: fc = 4.393207436430011, con incertezza = 2.179921842621183
# Il tempo medi di residenza vale: tc = 6370.907750961146, con incertezza = 23697.03496923914
# Stimiamo un nuovo DeltaG_NU = 57.59102960656525, con incertezza = 32.16964910578261
# ((-1.4709155659937743, 0.9174820536759054),
#  (15.221534445373509, 4.0554805963873),
#  (1.2983825754863187, 0.310739370498793),
#  (3.055433256531356, 1.3735390996830146),
#  (4.393207436430011, 2.179921842621183),
#  (6370.907750961146, 23697.03496923914),
#  (57.59102960656525, 32.16964910578261))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare il pimo punto, quello più in alto
forces_average = remove_element(forces_average, 1)
w_U = remove_element(w_U, 1)
w_N = remove_element(w_N, 1)
sigma_w_U = remove_element(sigma_w_U, 1)
sigma_w_N = remove_element(sigma_w_N, 1)
native_time = remove_element(native_time, 1)
unfolded_time = remove_element(unfolded_time, 1)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.440903485269864, con sigma = 1.6974487132338427
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 12.486003241499976, con sigma = 3.3887456680732546
# La differenza di energia libera DeltaG_NU = 55.449135312268055, con sigma = 14.923983857058854

# %%
f_c
# Out:
# (4.440903485269864, 1.6974487132338427)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -22.266146350690583, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.0808351272773866, con incertezza = 0.4652242120211042,
#  q1 = 13.623455457656087, con incertezza = 2.0466724782076735
# Stimiamo i parametri del fit lineare: m2 = 1.2242075570666935, con incertezza = 0.33782100749677413,
#  q2 = 3.359313054893005, con incertezza = 1.48618435843191
# La forza di coesistenza qui vale: fc = 4.452907736797, con incertezza = 1.5613120885250786
# Il tempo medi di residenza vale: tc = 6704.916600274685, con incertezza = 22855.527046570543
# Stimiamo un nuovo DeltaG_NU = 55.59902043574766, con incertezza = 24.652354997841122
# ((-1.0808351272773866, 0.4652242120211042),
#  (13.623455457656087, 2.0466724782076735),
#  (1.2242075570666935, 0.33782100749677413),
#  (3.359313054893005, 1.48618435843191),
#  (4.452907736797, 1.5613120885250786),
#  (6704.916600274685, 22855.527046570543),
#  (55.59902043574766, 24.652354997841122))
