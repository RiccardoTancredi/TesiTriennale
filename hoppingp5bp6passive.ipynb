# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 6bs_hop-passive

# %%
# directory name
dir_name = "P5bp_3bs_hop/6passive"
# molecule name is a number in these experimets
number = "6"

# %%
file = Txt_hop(dir_name, number, different_name="hoppas", first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#         X_force  Z_force     lambda  Y_force    time(sec)
# 0       -0.2864   0.2184  223.95830   4.7555  11401.48633
# 1       -0.2236   0.2068  223.62470   5.0030  11401.48730
# 2       -0.5481   0.1140  223.70035   4.8565  11401.48730
# 3       -0.9355   0.0299  223.68315   4.9222  11401.48828
# 4       -0.2340   0.0560  223.65340   5.0333  11401.49023
# ...         ...      ...        ...      ...          ...
# 121677  -0.6738  -0.0629  153.58715   3.7354  11561.22656
# 121678  -0.4644  -0.0774  153.58955   3.7708  11561.22656
# 121679  -0.9146  -0.0571  153.59490   3.5789  11561.22852
# 121680   0.2109   0.0560  153.76335   3.7203  11561.22949
# 121681   0.1097   0.0009  153.62310   3.7338  11561.23040
#
# [121682 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.9919727297296825, con deviazione standard = 0.25935274672279746

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [2., 4.9, 0.1, 0.5, 4.4, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2864   0.2184  223.95830   4.7555    0.00000
# 1      -0.2236   0.2068  223.62470   5.0030    0.00097
# 2      -0.5481   0.1140  223.70035   4.8565    0.00097
# 3      -0.9355   0.0299  223.68315   4.9222    0.00195
# 4      -0.2340   0.0560  223.65340   5.0333    0.00390
# ...        ...      ...        ...      ...        ...
# 11095  -0.4905   0.1691  223.34500   5.3565   11.56445
# 11096  -0.9146   0.0618  223.10070   5.1040   11.56640
# 11097  -0.6930   0.0395  223.44575   4.9121   11.56738
# 11098  -0.1974   0.1285  223.43910   4.8313   11.56738
# 11099  -0.2742   0.2213  223.01265   5.1208   11.56827
#
# [11100 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.790300143562663, con deviazione standard = 0.2509072066884676

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [0.4, 4.9, 0.1, 1.4, 4.3, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par, True, 500)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.1516   0.6079  215.37285   4.2926    0.00000
# 1      -0.1834   0.5422  214.98060   4.6158    0.00391
# 2       0.1272   0.5287  215.45720   4.6545    0.00391
# 3       0.2319   0.4591  215.54035   4.4576    0.00586
# 4      -0.1607   0.4446  215.91135   4.3162    0.00684
# ...        ...      ...        ...      ...        ...
# 17409  -0.0560   0.2677  217.47780   4.7303   18.13672
# 17410  -0.6947   0.1140  217.63580   4.6141   18.13868
# 17411  -0.4330   0.1198  217.74945   4.7353   18.13965
# 17412  -0.4696   0.2483  218.01785   4.7842   18.14063
# 17413  -0.4277   0.3682  217.66590   4.7236   18.14156
#
# [17414 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.591624388763672, con deviazione standard = 0.3353360257199026

# %%
prova = [1., 4.8, 0.1, 1.2, 4.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.8138534468453915, mu_1 = 4.913281168673731, sigma_1 = 0.1940829221924341
# c_2 = 1.1477548018102581, mu_2 = 4.374355624293315, sigma_2 = 0.20913018733980215
# sigma_c_1 = 0.029415840741848057, sigma_mu_1 = 0.017993669919650436, sigma_sigma_1 = 0.015889162448411563
# sigma_c_2 = 0.032417138823307476, sigma_mu_2 = 0.01342656599993548, sigma_sigma_2 = 0.0098861295331404
# w_U = 0.6016664277378878, sigma_w_U = 0.01458198761599424
# w_N = 0.3959346074855674, sigma_w_N = 0.03285545120634313

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 4.884 sec nello stato nativo e 6.65 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.1607   0.3576  204.09565   4.1394    0.00000
# 1      -0.6301   0.3527  204.28950   4.1378    0.00000
# 2      -0.6581   0.3141  204.51790   4.1647    0.00098
# 3      -0.1660   0.3489  204.37780   4.1647    0.00293
# 4      -0.1136   0.2213  204.19700   4.6091    0.00391
# ...        ...      ...        ...      ...        ...
# 11529  -0.9582   0.2290  204.40655   4.2859   11.99414
# 11530  -0.0089   0.1903  204.84920   4.5687   11.99610
# 11531  -0.7279   0.1091  204.79370   4.5216   11.99707
# 11532  -1.2130   0.0560  204.73385   4.3717   11.99707
# 11533  -0.4644   0.0212  204.83440   4.5333   11.99903
#
# [11534 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.3711943122155965, con deviazione standard = 0.30337333112953413

# %%
prova = [0.8, 4.7, 0.1, 1.4, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.45985103203290506, mu_1 = 4.754457931795554, sigma_1 = 0.20373380433058733
# c_2 = 1.3893771337307244, mu_2 = 4.25128962760163, sigma_2 = 0.2197083403001734
# sigma_c_1 = 0.04390628169751732, sigma_mu_1 = 0.048753748300571664, sigma_sigma_1 = 0.03616947955957348
# sigma_c_2 = 0.0522826044702374, sigma_mu_2 = 0.017440373681634407, sigma_sigma_2 = 0.01018634413684802
# w_U = 0.765167692418628, sigma_w_U = 0.010379293599373979
# w_N = 0.2348389849457382, sigma_w_N = 0.09975334271957857

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 3.474 sec nello stato nativo e 7.954 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.6999   0.0666  199.06560   4.1243    0.00000
# 1      -0.2497   0.1053  198.47495   4.3970    0.00098
# 2      -0.4905   0.0705  198.98320   4.3263    0.00196
# 3      -0.4487   0.0589  198.30535   4.2724    0.00196
# 4      -0.6022   0.0782  198.60840   4.4610    0.00391
# ...        ...      ...        ...      ...        ...
# 11423  -0.2811   0.2271  198.74825   4.3667   11.92090
# 11424  -0.2497   0.3112  198.91645   4.2657   11.92188
# 11425   0.2842   0.4881  198.89750   4.2202   11.92188
# 11426  -0.1084   0.5258  198.89845   4.0132   11.92285
# 11427  -0.2288   0.6244  199.09135   3.9273   11.92476
#
# [11428 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.404155698513431, con deviazione standard = 0.32323867881678

# %%
prova = [1., 4.8, 0.1, 1., 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.9125794459146371, mu_1 = 4.65750745316264, sigma_1 = 0.21122403471793957
# c_2 = 1.0164926363304188, mu_2 = 4.166537360002667, sigma_2 = 0.2014066813989647
# sigma_c_1 = 0.03684885972331801, sigma_mu_1 = 0.02564942010594345, sigma_sigma_1 = 0.01943671962907437
# sigma_c_2 = 0.06115399711581162, sigma_mu_2 = 0.021820121716681084, sigma_sigma_2 = 0.012188882882437047
# w_U = 0.5131780174911216, sigma_w_U = 0.03253837732180548
# w_N = 0.48317443910128893, sigma_w_N = 0.03141446815944992

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5.566 sec nello stato nativo e 5.937 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.5115   0.1091  193.21240   4.1849    0.00000
# 1      -0.4626   0.0666  193.19570   4.2926    0.00000
# 2      -0.4556   0.1130  193.20685   4.0637    0.00098
# 3      -0.6162   0.1169  193.10250   3.9627    0.00293
# 4      -0.8884   0.0241  192.76285   3.9627    0.00293
# ...        ...      ...        ...      ...        ...
# 11498   0.3994   0.2735  193.37960   4.3465   11.99609
# 11499  -0.2288   0.3924  193.67695   4.1748   11.99609
# 11500  -0.0665   0.5229  193.67810   3.9930   11.99707
# 11501   0.1028   0.6234  193.20835   4.1445   11.99805
# 11502  -0.3335   0.4765  193.61280   3.9021   11.99902
#
# [11503 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.372874619598292, con deviazione standard = 0.33335424137896524

# %%
prova = [1.2, 4.8, 0.1, .8, 4.2, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.1582732451007782, mu_1 = 4.613741338061143, sigma_1 = 0.18715340244603493
# c_2 = 0.8257638753449675, mu_2 = 4.082685381289838, sigma_2 = 0.21995774985273212
# sigma_c_1 = 0.034117358935739736, sigma_mu_1 = 0.013211088294930966, sigma_sigma_1 = 0.011202693570785415
# sigma_c_2 = 0.03255299866176381, sigma_mu_2 = 0.021022624880028318, sigma_sigma_2 = 0.015484678293817167
# w_U = 0.4552868243190068, sigma_w_U = 0.028716948638567632
# w_N = 0.5433737897238989, sigma_w_N = 0.019118652702575824

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 6.247 sec nello stato nativo e 5.2540000000000004 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.3160   0.2715  187.27610   4.5889    0.00000
# 1      -0.2079   0.2039  187.34790   4.6293    0.00098
# 2      -0.3858   0.2561  187.55410   4.4677    0.00195
# 3       0.2633   0.1323  187.21475   4.8650    0.00293
# 4       0.5285   0.3682  187.21875   4.6562    0.00488
# ...        ...      ...        ...      ...        ...
# 11496  -0.0613   0.2097  189.06990   4.4677   11.99414
# 11497  -0.4330   0.1662  189.36655   4.3263   11.99512
# 11498   0.0015   0.1517  189.29620   4.0536   11.99609
# 11499   0.0905   0.2184  189.11615   4.1495   11.99805
# 11500   0.1726   0.5422  189.27840   3.9425   11.99902
#
# [11501 rows x 5 columns]

# %% [markdown]
# # File 7

# %%
grafici = Graph_hop(dir_name, number, 7)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 4.257620577742989, con deviazione standard = 0.3123461864223523

# %%
prova = [1., 4.5, 0.1, 0.5, 4., 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.347973169391781, mu_1 = 4.413619047426705, sigma_1 = 0.20351399340383908
# c_2 = 0.6109590273730714, mu_2 = 3.9098481725982306, sigma_2 = 0.200484543254218
# sigma_c_1 = 0.035068654487988855, sigma_mu_1 = 0.015470201223792196, sigma_sigma_1 = 0.012436300008791463
# sigma_c_2 = 0.05007274649011088, sigma_mu_2 = 0.033562608014225385, sigma_sigma_2 = 0.021098199533979508
# w_U = 0.3070314869275801, sigma_w_U = 0.06697308669575784
# w_N = 0.6876468506374082, sigma_w_N = 0.012320978412227738

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 7.45 sec nello stato nativo e 4.043 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2742   0.5886  180.57110   4.0368    0.00000
# 1      -0.3021   0.7317  180.74950   4.0031    0.00098
# 2      -0.8675   0.8245  180.94595   3.7001    0.00196
# 3      -0.1346   0.7549  180.64435   4.0098    0.00293
# 4       0.2319   0.7346  180.81955   4.0788    0.00489
# ...        ...      ...        ...      ...        ...
# 11488  -0.2183   0.4533  181.42680   4.2404   11.99512
# 11489  -0.1695   0.7278  181.26895   4.0772   11.99610
# 11490  -0.0159   0.4301  181.86005   4.2926   11.99805
# 11491  -0.1695   0.1246  181.31845   4.4475   11.99903
# 11492  -0.4487   0.0589  181.32090   4.3667   11.99903
#
# [11493 rows x 5 columns]

# %% [markdown]
# # File 8

# %%
grafici = Graph_hop(dir_name, number, 8)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.7877021483865376, con deviazione standard = 0.2589978332438202

# %% [markdown]
# ## Suspicious data!

# %%
# prova = [1., 4.8, 0.1, 1., 4.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.0068  -0.1441  166.48940   4.1041    0.00000
# 1      -0.1189  -0.0136  166.34430   4.0334    0.00195
# 2      -0.3440  -0.0223  166.86250   3.9223    0.00195
# 3       0.1167   0.0183  166.68655   3.9223    0.00390
# 4       0.3994  -0.0078  166.49665   3.9879    0.00390
# ...        ...      ...        ...      ...        ...
# 11492  -0.9565   0.0589  166.14535   3.3213   11.99511
# 11493  -1.2915  -0.0455  166.58490   3.3920   11.99511
# 11494  -0.8046  -0.1422  166.13715   3.6799   11.99609
# 11495  -0.3579  -0.1113  166.08825   3.8819   11.99707
# 11496  -0.0194   0.0125  166.26555   3.6193   11.99902
#
# [11497 rows x 5 columns]

# %% [markdown]
# # File 9

# %%
grafici = Graph_hop(dir_name, number, 9)
data_frame = grafici.do_graph(12)
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 3.489404430929605, con deviazione standard = 0.23204629877060481

# %% [markdown]
# # Suspicious data!

# %%
# prova = [1., 4.8, 0.1, 1., 4.2, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.7209   0.1053  153.88465   3.1412    0.00000
# 1      -0.2323   0.0318  153.65980   3.3028    0.00195
# 2      -0.2602  -0.0803  153.78485   3.4375    0.00293
# 3      -0.7837   0.0125  153.75550   3.2355    0.00391
# 4      -0.4766   0.0125  153.64195   3.2288    0.00391
# ...        ...      ...        ...      ...        ...
# 11505  -0.1346   0.0328  154.09440   3.9172   11.99512
# 11506  -0.4120   0.0067  154.18935   3.5688   11.99707
# 11507  -0.6267  -0.0948  153.95380   3.6092   11.99805
# 11508  -0.4277  -0.1441  153.96910   3.8112   11.99902
# 11509  -0.3021  -0.1693  153.55100   3.7405   11.99902
#
# [11510 rows x 5 columns]

# %%
forces_average
# Out:
# [4.643818396483523,
#  4.502873779698592,
#  4.412022406582653,
#  4.348213359675491,
#  4.161733610012468]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.423195648586889, con sigma = 0.9653747015410008
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 8.945023591707951, con sigma = 1.3772471102370822
# La differenza di energia libera DeltaG_NU = 39.56558942734967, con sigma = 6.120291057874047

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.22191976763245, con sigma = 5.178452737160522

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -0.699511535699658, con incertezza = 0.035320034778975086,
#  q1 = 5.645558462630763, con incertezza = 0.06078433284333014
# Stimiamo i parametri del fit lineare: m2 = 0.8093909891656352, con incertezza = 0.036666222292790554,
#  q2 = 3.0283928671523412, con incertezza = 0.06470270544324577
# La forza di coesistenza qui vale: fc = 4.432267680287577, con incertezza = 0.06254567762237284
# Il tempo medi di residenza vale: tc = 5.665997040109176, con incertezza = 0.47018769107311986
# Stimiamo un nuovo DeltaG_NU = 39.64673896493704, con incertezza = 6.129912568904045
# ((-0.699511535699658, 0.035320034778975086),
#  (5.645558462630763, 0.06078433284333014),
#  (0.8093909891656352, 0.036666222292790554),
#  (3.0283928671523412, 0.06470270544324577),
#  (4.432267680287577, 0.06254567762237284),
#  (5.665997040109176, 0.47018769107311986),
#  (39.64673896493704, 6.129912568904045))

# %% [markdown]
# # Eliminiamo un punto

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# proviamo ad eliminare il pimo punto, quello più in alto
forces_average = remove_element(forces_average, 1)
forces_average_std = remove_element(forces_average_std, 1)
w_U = remove_element(w_U, 1)
w_N = remove_element(w_N, 1)
sigma_w_U = remove_element(sigma_w_U, 1)
sigma_w_N = remove_element(sigma_w_N, 1)
native_time = remove_element(native_time, 1)
unfolded_time = remove_element(unfolded_time, 1)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 4.428453688374258, con sigma = 0.9845808835096346
# La differenza di lunghezza tra lo stato foldend e unfolded e' x_NU = 8.785360282719392, con sigma = 1.3788689884013903
# La differenza di energia libera DeltaG_NU = 38.905561147705406, con sigma = 6.1265285133699505

# %%
f_c
# Out:
# (4.428453688374258, 0.9845808835096346)

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = 36.29134433102918, con sigma = 5.283284003607322

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.142751302327303, con incertezza = 0.04684753295827453,
#  q1 = 6.4378658241966775, con incertezza = 0.08198334224128025
# Stimiamo i parametri del fit lineare: m2 = 0.987877225356326, con incertezza = 0.04146267169398365,
#  q2 = 2.733747688948803, con incertezza = 0.07216414264948191
# La forza di coesistenza qui vale: fc = 4.451181722284935, con incertezza = 0.07657469177955697
# Il tempo medi di residenza vale: tc = 5.688858388806173, con incertezza = 0.4115514355915827
# Stimiamo un nuovo DeltaG_NU = 39.105235114128554, con incertezza = 6.174355360115344
# ((-1.142751302327303, 0.04684753295827453),
#  (6.4378658241966775, 0.08198334224128025),
#  (0.987877225356326, 0.04146267169398365),
#  (2.733747688948803, 0.07216414264948191),
#  (4.451181722284935, 0.07657469177955697),
#  (5.688858388806173, 0.4115514355915827),
#  (39.105235114128554, 6.174355360115344))

# %%
grafici.write_on_txt()
