# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 7bs_hop

# %%
# directory name
dir_name = "P5bp_3bs_hop/7"
# molecule name is a number in these experimets
number = "7"

# %%
file = Txt_hop(dir_name, number, first_time_molecule=False)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force      lambd  a  Y_forc  e    time(sec)
# 0       0.3005   0.9629   297.3619  5   2.845  3  15531.90234
# 1       0.8659   0.9832   297.5279  5   3.107  9  15531.90430
# 2       0.3476   1.0006   297.7098  0   3.173  5  15531.90820
# 3       0.3738   0.8788   297.4753  5   3.188  7  15531.90918
# 4       0.0649   0.8150   297.6924  0   3.279  6  15531.90918
# ...        ...      ...        ...        ...             ...
# 83459   0.1905   2.3346  1028.2603  5   1.184  6  15692.77930
# 83460  -0.1340   2.3607  1028.6413  0   1.841  1  15692.78125
# 83461   0.4628   2.2911  1028.1970  0   1.295  7  15692.78125
# 83462   0.2010   2.1142  1028.6138  0   1.391  7  15692.78320
# 83463   0.3581   2.1896  1028.6583  0   1.356   3  15692.7841
#
# [83464 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.929768085716328, con deviazione standard = 0.20395670961006962

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [2., 4.9, 0.1, 0.5, 4.4, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.3005   0.9629  297.36195   2.8453    0.00000
# 1       0.8659   0.9832  297.52795   3.1079    0.00196
# 2       0.3476   1.0006  297.70980   3.1735    0.00586
# 3       0.3738   0.8788  297.47535   3.1887    0.00684
# 4       0.0649   0.8150  297.69240   3.2796    0.00684
# ...        ...      ...        ...      ...        ...
# 13948   0.2324   0.9078  298.51080   2.9109   14.52344
# 13949   0.1539   0.9194  298.64755   2.8049   14.52539
# 13950   0.2062   1.0905  298.43660   3.0018   14.52637
# 13951   0.2830   1.0625  298.47545   2.9597   14.52637
# 13952   0.1853   1.0238  298.55900   2.5490   14.52726
#
# [13953 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.64865543400867, con deviazione standard = 0.24259302571749114

# %%
prova = [0.4, 3.25, 0.1, 1.4, 2.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.21102305599755955, mu_1 = 3.1875798331821112, sigma_1 = 0.14671887342279516
# c_2 = 1.965681364344998, mu_2 = 2.600323399748986, sigma_2 = 0.18728542042621454
# sigma_c_1 = 0.04935665290815789, sigma_mu_1 = 0.04615388455631695, sigma_sigma_1 = 0.04890506960537805
# sigma_c_2 = 0.04362637872052289, sigma_mu_2 = 0.005473827919166571, sigma_sigma_2 = 0.005854475102235013
# w_U = 0.9227988078247469, sigma_w_U = 0.0029752678146288554
# w_N = 0.07760788104746133, sigma_w_N = 0.3757628762099713

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, True, 500)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1790 sec nello stato nativo e 13659 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.4471   0.8324  290.48865   2.2898    0.00000
# 1      -0.1864   0.7483  290.68655   2.2645    0.00000
# 2      -0.2335   0.6990  290.40035   2.0676    0.00098
# 3       0.3947   0.7106  291.01585   2.5625    0.00293
# 4       0.1382   0.6816  290.71920   2.3100    0.00390
# ...        ...      ...        ...      ...        ...
# 15444  -0.7151   0.8788  288.30200   2.2292   16.11328
# 15445  -0.0660   0.9136  288.21300   2.6938   16.11426
# 15446   0.3790   0.9977  288.01100   2.5675   16.11621
# 15447  -0.1811   1.1514  287.97765   2.7241   16.11621
# 15448  -0.4167   1.2152  287.98255   2.4160   16.11810
#
# [15449 rows x 5 columns]

# %% [markdown]
# # File 3

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 2.2577864864864945, con deviazione standard = 0.30704258299414733

# %%
prova = [.7, 2.7, 0.1, 1.5, 2.1, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6919066353963353, mu_1 = 2.6329394439710563, sigma_1 = 0.16530186591181087
# c_2 = 1.4234044277267848, mu_2 = 2.103875169429061, sigma_2 = 0.19952616922346
# sigma_c_1 = 0.03636504816013133, sigma_mu_1 = 0.016947946716605117, sigma_sigma_1 = 0.015979981161077923
# sigma_c_2 = 0.03263000352531567, sigma_mu_2 = 0.00916477536370194, sigma_sigma_2 = 0.008499757742212776
# w_U = 0.711898554433131, sigma_w_U = 0.013869012163877748
# w_N = 0.28669174335868786, sigma_w_N = 0.07833374361596938

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 5872 sec nello stato nativo e 12221 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.4680   1.3515  272.38945   2.5271    0.00000
# 1      -0.2440   1.2732  272.02080   2.6382    0.00098
# 2       0.3005   1.4298  272.39385   2.7544    0.00195
# 3       0.8344   1.3950  272.36160   2.4615    0.00391
# 4       0.3738   1.2152  272.48295   2.6534    0.00391
# ...        ...      ...        ...      ...        ...
# 18088   0.3807   1.1437  273.93775   2.1719   18.86816
# 18089  -0.1846   0.9503  273.74775   2.3403   18.86914
# 18090  -0.0974   0.9049  274.09530   2.1938   18.87109
# 18091  -0.2126   0.9629  273.75615   2.1585   18.87109
# 18092  -0.1079   0.9252  273.84930   2.0524   18.87204
#
# [18093 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 1.8872565492740179, con deviazione standard = 0.30408554842535873

# %%
prova = [1.2, 2., 0.1, .5, 1.5, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.4407944349872712, mu_1 = 2.057859940287321, sigma_1 = 0.18064007415133215
# c_2 = 0.7262359261574816, mu_2 = 1.5575337458653862, sigma_2 = 0.18756813162611055
# sigma_c_1 = 0.028270048767265486, sigma_mu_1 = 0.008404726987571024, sigma_sigma_1 = 0.007314540237172393
# sigma_c_2 = 0.028923072655106057, sigma_mu_2 = 0.017097587518693915, sigma_sigma_2 = 0.013873153117235859
# w_U = 0.3414496845309245, sigma_w_U = 0.05480323003548004
# w_N = 0.6523881432447759, sigma_w_N = 0.015363792858285354

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 8160 sec nello stato nativo e 4788 sec nello stato unfolded

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.2754   1.6038  258.58485   1.8151    0.00000
# 1      -0.1148   1.6541  258.22610   1.8420    0.00097
# 2       0.5413   1.6695  258.94130   1.6265    0.00195
# 3       0.0178   1.7314  258.81520   2.1383    0.00293
# 4       0.4645   1.6657  258.34010   2.2931    0.00488
# ...        ...      ...        ...      ...        ...
# 12943   0.2830   1.3525  257.48805   2.3537   13.50488
# 12944   0.3685   1.3283  256.97295   2.1080   13.50488
# 12945  -0.0660   1.5951  257.34605   2.2241   13.50683
# 12946   0.2272   1.7546  257.18795   2.1383   13.50781
# 12947  -0.1916   1.6531  257.24545   2.0120   13.50773
#
# [12948 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 1.5408375248683501, con deviazione standard = 0.26933734163520123

# %% [markdown]
# ## Suspicious data: no hopping events observed

# %%
# prova = [1., 5., 0.1, 1., 4.5, 0.1]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0      -0.0555   1.9837  243.98095   1.6585    0.00000
# 1       0.2900   1.8735  243.95100   1.4717    0.00098
# 2       0.9391   1.7430  243.21365   1.5929    0.00293
# 3       0.7716   1.6212  244.02850   1.2495    0.00489
# 4       1.0805   1.5690  243.80650   1.3404    0.00684
# ...        ...      ...        ...      ...        ...
# 17085   0.0440   1.2326  233.50555   1.8151   17.80079
# 17086   0.5727   2.2331  240.37930   1.8454   17.80176
# 17087   0.3005   1.7024  237.16245   1.9514   17.80372
# 17088  -0.2021   1.4008  234.24380   1.7848   17.80469
# 17089  -0.5528   0.9890  233.44265   1.7141   17.80460
#
# [17090 rows x 5 columns]

# %%
forces_average
# Out:
# [2.8939516164655483, 2.3684073067000586, 1.8076968430763536]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 2.0407845284031745, con sigma = 0.5761580124963731
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 11.418158336460147, con sigma = 2.3194974995095032
# La differenza di energia libera DeltaG_NU = 23.302000875905595, con sigma = 4.568576842958864

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -7.762695101887841, con sigma = None

# %%
grafici.residence_time(native_time, unfolded_time, forces_average)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -1.3875502357467482, con incertezza = 0.4824610809048241,
#  q1 = 11.661659487426324, con incertezza = 1.156970681635439
# Stimiamo i parametri del fit lineare: m2 = 0.9729099797126827, con incertezza = 0.42073255411064603,
#  q2 = 6.842801747005583, con incertezza = 1.008941956913634
# La forza di coesistenza qui vale: fc = 2.041490768986681, con incertezza = 0.8540856464729266
# Il tempo medi di residenza vale: tc = 6829.375336818183, con incertezza = 11278.394246827045
# Stimiamo un nuovo DeltaG_NU = 23.310064842711707, con incertezza = 10.840922179718946
# ((-1.3875502357467482, 0.4824610809048241),
#  (11.661659487426324, 1.156970681635439),
#  (0.9729099797126827, 0.42073255411064603),
#  (6.842801747005583, 1.008941956913634),
#  (2.041490768986681, 0.8540856464729266),
#  (6829.375336818183, 11278.394246827045),
#  (23.310064842711707, 10.840922179718946))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
# # proviamo ad eliminare il pimo punto, quello più in alto
# forces_average = remove_element(forces_average, 3)
# w_U = remove_element(w_U, 3)
# w_N = remove_element(w_N, 3)
# sigma_w_U = remove_element(sigma_w_U, 3)
# sigma_w_N = remove_element(sigma_w_N, 3)
# native_time = remove_element(native_time, 3)
# unfolded_time = remove_element(unfolded_time, 3)

# %%
f_c
# Out:
# (2.0407845284031745, 0.5761580124963731)

# %%
G0 = grafici.G0(f_c[0])
# Out:
# DeltaG0 = -7.762695101887841, con sigma = None
