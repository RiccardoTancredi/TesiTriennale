# %%
from files_sorting import Txt
# %matplotlib inline
from graphs import Graph

# %%
# directory name
dir_name = "Pulling_3bs"
# molecule name is a number in these experimets
number = "16"

# %%
file = Txt(dir_name, number)
dataFrame = file.bricolage()

# %%
# dataFrame

# %%
grafici = Graph(dir_name, number, 'u', '4', False)
grafici.do_graph()
# Out:
# The df mean is 0.003364571607254534 and the df std is 0.13229683939368864
# Il coefficient k_eff = 0.052727894523452196(pN/nm), la f_F = 4.8452529041156875(pN) e la f_U = 4.2024(pN)
# Salto avvenuto tra 4.8452529041156875(pN) e 4.2024(pN)
# x_d = 1.0900893139895356, con un x_ssDNA = 13.281983375485979(nm)
# [4.8452529041156875, 4.2024]

# %%
f_F, f_U = grafici.maximum_f()
# Out:
# The df mean is 0.003364571607254534 and the df std is 0.13229683939368864
# Il coefficient k_eff = 0.052727894523452196(pN/nm), la f_F = 4.8452529041156875(pN) e la f_U = 4.2024(pN)
# Salto avvenuto tra 4.8452529041156875(pN) e 4.2024(pN)
# x_d = 1.0900893139895356, con un x_ssDNA = 13.281983375485979(nm)

# %%
f_F, f_U
# Out:
# (4.8452529041156875, 4.2024)
