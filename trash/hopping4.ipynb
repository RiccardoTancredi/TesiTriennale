# %%
from file_hopping import Txt_hop
# %matplotlib inline
from graph_hop import Graph_hop
import numpy as np

# %% [markdown]
# # 4hop -> 2 molecole molto probabilmente

# %%
# directory name
dir_name = "0nM/4"
# molecule name is a number in these experimets
number = "4"

# %%
file = Txt_hop(dir_name, number)
dataFrame = file.bricolage()

# %%
dataFrame
# Out:
#        X_force  Z_force     lambda  Y_force    time(sec)
# 0       0.4737  -0.1781 -389.42905   1.3912  10386.97852
# 1       0.3782  -0.1146 -389.57140   1.4708  10386.97949
# 2       0.9827  -0.2366 -389.79315   1.4659  10386.98145
# 3       0.5055  -0.1858 -389.85500   1.2220  10386.98438
# 4       0.4472  -0.0612 -389.65065   1.3862  10386.98438
# ...        ...      ...        ...      ...          ...
# 51160  -0.0088  -0.5977 -284.24190   5.3433  10470.54688
# 51161  -0.1679  -0.7502 -284.38550   5.3832  10470.54883
# 51162  -0.5974  -0.8468 -284.40785   5.3931  10470.54883
# 51163  -0.5550  -0.7756 -284.58395   5.2139  10470.55078
# 51164   0.1502  -0.6714 -284.35875   5.4081  10470.55070
#
# [51165 rows x 5 columns]

# %%
forces_average = []
forces_average_std = []
w_U = []
w_N = []
sigma_w_U = []
sigma_w_N = []
native_time = []
unfolded_time = []
def mean(mu1, mu2):
    return (mu1+mu2)/2

def err_prop_mean(sigma1, sigma2):
    return np.sqrt(sigma1**2+sigma2**2)/2

# %% [markdown]
# # File 1

# %%
grafici = Graph_hop(dir_name, number, 1)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 1.3692318519315425, con deviazione standard = 0.26621397895792226

# %% [markdown]
# ## $f_y$ troppo bassa -> no fit

# %%
# prova = [0.2, 4.8, 0.1, 2.1, 4.2, 0.2]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#        X_force  Z_force     lambda  Y_force  time(sec)
# 0       0.4737  -0.1781 -389.42905   1.3912    0.00000
# 1       0.3782  -0.1146 -389.57140   1.4708    0.00097
# 2       0.9827  -0.2366 -389.79315   1.4659    0.00293
# 3       0.5055  -0.1858 -389.85500   1.2220    0.00586
# 4       0.4472  -0.0612 -389.65065   1.3862    0.00586
# ...        ...      ...        ...      ...        ...
# 18581   0.3889   0.0634 -402.37850   0.9681   19.38378
# 18582   0.3835   0.0812 -402.76840   1.2270   19.38476
# 18583  -0.0672   0.0812 -402.60800   1.0428   19.38671
# 18584  -0.1838  -0.0561 -402.66885   1.2270   19.38867
# 18585   0.0778  -0.1892 -402.13555   1.0677   19.38858
#
# [18586 rows x 5 columns]

# %% [markdown]
# # File 2

# %%
grafici = Graph_hop(dir_name, number, 2)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.754327771457515, con deviazione standard = 0.26928645538803125

# %%
prova = [0.6, 8.1, 0.1, 1.5, 7.6, 0.1]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.6101016845243598, mu_1 = 8.152978736749803, sigma_1 = 0.14295366040855745
# c_2 = 1.8722629104122828, mu_2 = 7.640082981575797, sigma_2 = 0.16578463095645996
# sigma_c_1 = 0.03442923162791692, sigma_mu_1 = 0.012217910526357399, sigma_sigma_1 = 0.013089905506517703
# sigma_c_2 = 0.0298229177839213, sigma_mu_2 = 0.004128003863565236, sigma_sigma_2 = 0.003803737021077725
# w_U = 0.7780384053147686, sigma_w_U = 0.004291458885429208
# w_N = 0.21861876594384394, sigma_w_N = 0.056538912519058335

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par, False)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1990 sec nello stato nativo e 5921 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.4737  -0.5010 -243.61880   7.9416    0.00000
# 1      0.0548  -0.4222 -243.87630   7.7973    0.00195
# 2      0.2563  -0.4197 -243.69465   7.8072    0.00195
# 3      0.1078  -0.3663 -243.62535   7.7425    0.00390
# 4      0.1927  -0.4324 -243.42945   7.8769    0.00390
# ...       ...      ...        ...      ...        ...
# 7906   0.1202  -0.2163 -239.10995   7.6446    8.26855
# 7907   0.1626  -0.1553 -238.94490   7.6313    8.26953
# 7908  -0.1626  -0.3104 -239.01190   7.9366    8.27148
# 7909   0.2245  -0.3688 -238.84400   7.8520    8.27246
# 7910  -0.0407  -0.4832 -238.79715   7.7027    8.27241
#
# [7911 rows x 5 columns]

# %% [markdown]
# # File 3 -> 2 molecole....

# %%
grafici = Graph_hop(dir_name, number, 3)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.38817959227933, con deviazione standard = 0.29092245628790603

# %%
prova = [1., 7.6, 0.2, 1., 7.1, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 1.2126885234544098, mu_1 = 7.645201327047461, sigma_1 = 0.1539754519649666
# c_2 = 1.2674895820081822, mu_2 = 7.164442833048057, sigma_2 = 0.1664474259049038
# sigma_c_1 = 0.044109527895077716, sigma_mu_1 = 0.011047047540871668, sigma_sigma_1 = 0.011423395524646052
# sigma_c_2 = 0.04281781149584468, sigma_mu_2 = 0.010842216244937147, sigma_sigma_2 = 0.00860698494116765
# w_U = 0.5288243153226503, sigma_w_U = 0.01991090401972304
# w_N = 0.46804831842774564, sigma_w_N = 0.027473673812857206

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2201 sec nello stato nativo e 2410 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1396  -0.5875 -249.62595   7.7176    0.00000
# 1      0.1396  -0.5265 -249.90815   7.3493    0.00000
# 2     -0.2262  -0.6078 -249.92495   7.5036    0.00195
# 3     -0.1626  -0.6739 -249.82770   7.5982    0.00195
# 4     -0.0460  -0.5570 -250.10460   7.4389    0.00391
# ...       ...      ...        ...      ...        ...
# 4606   0.2262  -0.6638 -248.26635   7.6977    4.80567
# 4607   0.7706  -0.4298 -248.12995   7.7624    4.80567
# 4608  -0.0035  -0.4121 -248.14280   7.5633    4.80664
# 4609  -0.3535  -0.4298 -247.79930   7.5932    4.80860
# 4610  -0.1679  -0.5061 -248.20655   7.8420    4.80953
#
# [4611 rows x 5 columns]

# %% [markdown]
# # File 4

# %%
grafici = Graph_hop(dir_name, number, 4)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.901622999145642, con deviazione standard = 0.18059332230431024

# %% [markdown]
# ## Suspicious data: $f_y$ too strong

# %%
# prova = [0.5, 8.5, 0.1, 1.7, 8., 0.2]
# fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# # (c1, mu1, sigma1, c2, mu2, sigma2)

# %%
# forces_average.append(mean(fitting_par[1], fitting_par[4]))
# forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
# w_U.append(prob[0])
# w_N.append(prob[1])
# sigma_w_U.append(err_prob[0])
# sigma_w_N.append(err_prob[1])

# %%
# grafici.subplots(fitting_par)

# %%
# native, unfolded = grafici.hmm_analysis(fitting_par)
# native_time.append(native)
# unfolded_time.append(unfolded)

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.0601  -0.2722 -233.85080   7.8072    0.00000
# 1     -0.4171  -0.4553 -233.50340   7.7574    0.00196
# 2     -0.3959  -0.4705 -233.44560   7.7276    0.00196
# 3     -0.6151  -0.4366 -233.42715   7.8105    0.00391
# 4     -0.0071  -0.3959 -233.44360   7.5185    0.00391
# ...       ...      ...        ...      ...        ...
# 7017  -0.2687  -0.4832 -235.59615   7.7226    7.28809
# 7018  -0.0990  -0.4654 -235.42540   7.7475    7.28809
# 7019   0.5320  -0.2188 -234.82720   7.8172    7.29004
# 7020   0.6381  -0.1959 -235.16665   7.6728    7.29102
# 7021   0.5585  -0.3214 -234.93475   7.6313    7.29289
#
# [7022 rows x 5 columns]

# %% [markdown]
# # File 5

# %%
grafici = Graph_hop(dir_name, number, 5)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 7.491640365501776, con deviazione standard = 0.2011179808111215

# %% [markdown]
# ## How is it this one?

# %%
prova = [0.5, 7.8, 0.1, 2., 7.4, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.2512941202740692, mu_1 = 7.825040824228607, sigma_1 = 0.18495364752028487
# c_2 = 2.2186455487503505, mu_2 = 7.447003772361192, sigma_2 = 0.1590721399217009
# sigma_c_1 = 0.09321246509220112, sigma_mu_1 = 0.3041702645222325, sigma_sigma_1 = 0.23248632184733747
# sigma_c_2 = 0.333105202132953, sigma_mu_2 = 0.0282297027617841, sigma_sigma_2 = 0.009299578435933042
# w_U = 0.8846510197223187, sigma_w_U = 0.01781998603949042
# w_N = 0.1165024777477142, sigma_w_N = 0.6456132747435317

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 1373 sec nello stato nativo e 4865 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.1061  -0.3010 -246.62550   7.5451    0.00000
# 1      0.4242  -0.3485 -246.73755   7.3194    0.00098
# 2      0.0990  -0.3756 -246.66585   7.5782    0.00196
# 3     -0.1414  -0.3180 -246.21350   7.4787    0.00293
# 4     -0.0141  -0.3281 -246.56925   7.5384    0.00391
# ...       ...      ...        ...      ...        ...
# 6233   0.6292  -0.4366 -247.52525   7.5782    6.50488
# 6234   0.3517  -0.3765 -246.91330   7.3891    6.50684
# 6235   0.3199  -0.4070 -247.12140   7.2199    6.50781
# 6236   0.8608  -0.3231 -247.37520   7.2597    6.50781
# 6237   0.8767  -0.4222 -247.10725   7.4936    6.50876
#
# [6238 rows x 5 columns]

# %% [markdown]
# # File 6

# %%
grafici = Graph_hop(dir_name, number, 6)
data_frame = grafici.do_graph()
# (2.0440e4+0.5+1.95e-3, 2.0442e4+1.-1.95e-3)
# Out:
# f media vale = 5.727073458878906, con deviazione standard = 0.2720262802833605

# %%
prova = [0.5, 6.2, 0.1, 1.5, 5.7, 0.2]
fitting_par, fitting_err, prob, err_prob = grafici.fit(guess=prova)
# (c1, mu1, sigma1, c2, mu2, sigma2)
# Out:
# c_1 = 0.4677758815132232, mu_1 = 6.0457285628656665, sigma_1 = 0.14652440274186238
# c_2 = 1.399149131959915, mu_2 = 5.660312996226013, sigma_2 = 0.23353521454598145
# sigma_c_1 = 0.15628765915864826, sigma_mu_1 = 0.045417300515698866, sigma_sigma_1 = 0.040770335376036124
# sigma_c_2 = 0.08469671597766767, sigma_mu_2 = 0.03344803750506536, sigma_sigma_2 = 0.017689695109779337
# w_U = 0.8190422744495572, sigma_w_U = 0.012267987260420991
# w_N = 0.17180575993801603, sigma_w_N = 0.29642523628680717

# %%
forces_average.append(mean(fitting_par[1], fitting_par[4]))
forces_average_std.append(err_prop_mean(fitting_err[1], fitting_err[4]))
w_U.append(prob[0])
w_N.append(prob[1])
sigma_w_U.append(err_prob[0])
sigma_w_N.append(err_prob[1])

# %%
grafici.subplots(fitting_par)

# %%
native, unfolded = grafici.hmm_analysis(fitting_par)
native_time.append(native)
unfolded_time.append(unfolded)
# Out:
# La molecola si trova 2036 sec nello stato nativo e 4761 sec nello stato unfolded

# %%
data_frame
# Out:
#       X_force  Z_force     lambda  Y_force  time(sec)
# 0      0.5903  -0.4654 -280.86325   6.4434    0.00000
# 1      0.6222  -0.5773 -280.20175   6.1447    0.00195
# 2      0.5797  -0.3892 -280.91950   6.1049    0.00293
# 3      0.4808  -0.6739 -281.39485   6.2509    0.00293
# 4     -0.0353  -0.3620 -280.37835   6.3571    0.00391
# ...       ...      ...        ...      ...        ...
# 6792  -0.0088  -0.5977 -284.24190   5.3433    7.08985
# 6793  -0.1679  -0.7502 -284.38550   5.3832    7.09180
# 6794  -0.5974  -0.8468 -284.40785   5.3931    7.09180
# 6795  -0.5550  -0.7756 -284.58395   5.2139    7.09375
# 6796   0.1502  -0.6714 -284.35875   5.4081    7.09367
#
# [6797 rows x 5 columns]

# %% [markdown]
# ## Average of the average -> $\bar{f} = \frac{\mu_1 + \mu_2}{2}$

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U, w_N, forces_average, sigma_w_U, sigma_w_N)
# Out:
# La forza di coesistenza vale f_c = 7.316615517264163, con sigma = 2.995657420302049
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 6.973988409873113, con sigma = 2.0025082707686264
# La differenza di energia libera DeltaG_NU = 51.02599181689804, con sigma = 14.892730161138667

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -37.09642098379647, con sigma = -5.763039449679562

# %%
grafici.residence_time(native_time, unfolded_time, forces_average, forces_average_std)
# Out:
# Stimiamo i parametri del fit lineare: m1 = -4.146399118293945, con incertezza = 0.0963317311254248,
#  q1 = 39.30269274283303, con incertezza = 0.7356255546300041
# Stimiamo i parametri del fit lineare: m2 = 0.5028090824335814, con incertezza = 0.01118666977571116,
#  q2 = 3.4552262198305024, con incertezza = 0.09323005222305461
# La forza di coesistenza qui vale: fc = 7.332108254749672, con incertezza = 0.16004129063194764
# Il tempo medi di residenza vale: tc = 2231.5362212485197, con incertezza = 505.45769612864854
# Stimiamo un nuovo DeltaG_NU = 51.1340379885592, con incertezza = 14.724968529746091
# ((-4.146399118293945, 0.0963317311254248),
#  (39.30269274283303, 0.7356255546300041),
#  (0.5028090824335814, 0.01118666977571116),
#  (3.4552262198305024, 0.09323005222305461),
#  (7.332108254749672, 0.16004129063194764),
#  (2231.5362212485197, 505.45769612864854),
#  (51.1340379885592, 14.724968529746091))

# %%
def remove_element(arr, pos):
    arr.pop(pos)
    return arr

# %%
forces_average = remove_element(forces_average, 3)
forces_average_std = remove_element(forces_average_std, 3)
w_U = remove_element(w_U, 3)
w_N = remove_element(w_N, 3)
sigma_w_U = remove_element(sigma_w_U, 3)
sigma_w_N = remove_element(sigma_w_N, 3)

# %%
x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[:3], w_N[:3], forces_average[:3], sigma_w_U[:3], sigma_w_N[:3])
# Out:
# La forza di coesistenza vale f_c = 7.3525113913994, con sigma = 2.439134606461795
# La differenza di lunghezza tra lo stato foldend e unfolded è x_NU = 9.601076673073964, con sigma = 2.2389532970641066
# La differenza di energia libera DeltaG_NU = 70.59202560847537, con sigma = 16.656005179438537

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -37.262995736770954, con sigma = -4.6599621370101065

# %%
grafici.residence_time(native_time[:3], unfolded_time[:3], forces_average[:3], forces_average_std[:3])
# Out:
# Stimiamo i parametri del fit lineare: m1 = -4.538460753339405, con incertezza = 0.09650895155585111,
#  q1 = 42.35408128841991, con incertezza = 0.7370312781691941
# Stimiamo i parametri del fit lineare: m2 = 0.5468832346319537, con incertezza = 0.011205948668835449,
#  q2 = 3.145947635056192, con incertezza = 0.09334399023677208
# La forza di coesistenza qui vale: fc = 7.362431516373186, con incertezza = 0.15990871197118214
# Il tempo medi di residenza vale: tc = 2230.5999403634773, con incertezza = 462.76464069295645
# Stimiamo un nuovo DeltaG_NU = 70.68726948895517, con incertezza = 16.555482935573046
# ((-4.538460753339405, 0.09650895155585111),
#  (42.35408128841991, 0.7370312781691941),
#  (0.5468832346319537, 0.011205948668835449),
#  (3.145947635056192, 0.09334399023677208),
#  (7.362431516373186, 0.15990871197118214),
#  (2230.5999403634773, 462.76464069295645),
#  (70.68726948895517, 16.555482935573046))

# %%
G0 = grafici.G0(f_c)
# Out:
# DeltaG0 = -37.262995736770954, con sigma = -4.6599621370101065

# %% [markdown]
# ## O sono due molecole diverse?

# %%
# x_NU, f_c, DeltaG_NU = grafici.deltaG(w_U[3:], w_N[3:], forces_average[3:], sigma_w_U[3:], sigma_w_N[3:])
